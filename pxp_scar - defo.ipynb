# %%
# STUDY OF SCARS IN PXP MODEL - NEEL STATE OVERLAPs ARE COMPUTED IN THE ALLOWED SUBSPACE, ENTANGLEMENT ENTROPIES ARE COMPUTED IN THE FULL HILBERT SPACE

# %%
import numpy as np
from scipy.linalg import eigh
import matplotlib.pyplot as plt
from scipy.sparse import kron, identity, csr_matrix, lil_matrix
from scipy.sparse.linalg import eigsh, eigs
from scipy.optimize import curve_fit
from qutip import Qobj, ptrace
from tqdm import tqdm
import pandas as pd
from itertools import product
from functools import reduce

# %%
# Define the Pauli matrices
def pauli_x():
    """Pauli X matrix."""
    return np.array([[0, 1], [1, 0]])

def pauli_z():
    """Pauli Z matrix."""
    return np.array([[1, 0], [0, -1]])

def pxp(N, pbc=True, sparse=False, h2=-0.05):
    """
    Constructs the Hamiltonian for the PXP model with optional h2 deformation term.

    Parameters:
        N (int): Number of spins.
        pbc (bool): Whether to use periodic boundary conditions.
        sparse (bool): Whether to return a sparse matrix (not implemented).
        h2 (float): Deformation parameter (default -0.051).

    Returns:
        H (numpy.ndarray): The Hamiltonian matrix.
    """
    I = np.eye(2)
    X = pauli_x()
    Z = pauli_z()
    P = 0.5 * (I + Z)  # Projection onto |0⟩ (unexcited)

    H = np.zeros((2**N, 2**N), dtype=np.float64)

    for i in range(1, N - 1):
        # Base PXP term
        base_term = 1
        for j in range(N):
            if j == i:
                base_term = np.kron(base_term, X)
            elif j == i - 1 or j == i + 1:
                base_term = np.kron(base_term, P)
            else:
                base_term = np.kron(base_term, I)
        H += base_term

        # h2 deformation term with Z_{i±2}
        if h2 != 0:
            for shift in [-2, 2]:
                z_term = 1
                for j in range(N):
                    if j == i:
                        z_term = np.kron(z_term, X)
                    elif j == i - 1 or j == i + 1:
                        z_term = np.kron(z_term, P)
                    elif j == i + shift:
                        if 0 <= j < N:
                            z_term = np.kron(z_term, Z)
                        else:
                            z_term = np.kron(z_term, I)
                    else:
                        z_term = np.kron(z_term, I)
                H += h2 * z_term

    # Periodic boundary conditions
    if pbc:
        for i, neighbors in [(0, [1, N - 1]), (N - 1, [0, N - 2])]:
            base_term = 1
            for j in range(N):
                if j == i:
                    base_term = np.kron(base_term, X)
                elif j in neighbors:
                    base_term = np.kron(base_term, P)
                else:
                    base_term = np.kron(base_term, I)
            H += base_term

            if h2 != 0:
                for shift in [-2, 2]:
                    j_shift = (i + shift) % N
                    z_term = 1
                    for j in range(N):
                        if j == i:
                            z_term = np.kron(z_term, X)
                        elif j in neighbors:
                            z_term = np.kron(z_term, P)
                        elif j == j_shift:
                            z_term = np.kron(z_term, Z)
                        else:
                            z_term = np.kron(z_term, I)
                    H += h2 * z_term

    return H




def construct_pxp_hamiltonian_fixed(n_spins, pbc=True):
    """
    Constructs the PXP Hamiltonian matrix for a system of n_spins with open and periodic boundary conditions (OBC and PBC).
    This function follows the implementation from the notebook.
    
    Parameters:
        n_spins (int): Number of spins in the system.
        pbc (bool): Whether to use periodic boundary conditions.
    
    Returns:
        H (numpy.ndarray): The PXP Hamiltonian matrix in the constrained subspace.
        basis (list): The list of allowed basis states in binary format.
    """
    full_basis = list(product([0, 1], repeat=n_spins))  # Generate all possible states
    
    # Filter states to enforce the Rydberg blockade (no adjacent 1s)
    allowed_basis = []
    for state in full_basis:
        if pbc:  # PBC: Enforce the blockade across periodic boundaries
            if all(state[i] + state[(i + 1) % n_spins] <= 1 for i in range(n_spins)):
                allowed_basis.append(state)
        else:  # OBC: Standard adjacency check
            if all(state[i] + state[i + 1] <= 1 for i in range(n_spins - 1)):
                allowed_basis.append(state)
    
    # Map basis states to indices
    basis_size = len(allowed_basis)
    state_to_index = {state: idx for idx, state in enumerate(allowed_basis)}
    
    # Construct the full PXP Hamiltonian
    full_H = pxp(n_spins, pbc=pbc, sparse=False, h2=-0.05)
    
    # Project full Hamiltonian onto the constrained subspace
    H = np.zeros((basis_size, basis_size), dtype=float)
    for i, state_i in enumerate(allowed_basis):
        for j, state_j in enumerate(allowed_basis):
            idx_i = int("".join(map(str, state_i)), 2)
            idx_j = int("".join(map(str, state_j)), 2)
            H[i, j] = full_H[idx_i, idx_j]
    
    return H, allowed_basis

def map_to_full_hilbert_space(reduced_state, basis_states, n_spins):
    """
    Maps a reduced dimension state back to the full Hilbert space.

    Parameters:
    reduced_state : np.array
        The state vector in the reduced dimension.
    basis_states : list of tuples
        The basis states used in the reduced dimension.
    n_spins : int
        The total number of spins in the system.

    Returns:
    np.array
        The state vector in the full Hilbert space.
    """
    # Initialize the full Hilbert space vector
    full_dim = 2**n_spins
    full_hilbert_space_vector = np.zeros(full_dim, dtype=complex)

    # Map the reduced dimension state back to the full Hilbert space
    for i, state in enumerate(basis_states):
        # Convert the basis state to its index in the full Hilbert space
        full_index = int("".join(map(str, state)), 2)
        # Debugging statement
        if full_index >= full_dim:
            print(f"Error: full_index {full_index} is out of bounds for full_hilbert_space_vector with size {full_dim}")
        # Assign the value from the reduced dimension state to the full Hilbert space vector
        full_hilbert_space_vector[full_index] = reduced_state[i]

    return full_hilbert_space_vector

def entanglement_entropy(psi, subsystem_size, reduced_dim):
    """
    Computes the bipartite entanglement entropy of a pure state.
    
    Parameters:
    psi : np.array
        The wavefunction (state vector) of the reduced system.
    subsystem_size : int
        The number of qubits in subsystem A.
    total_size : int
        The total number of qubits in the system.
    reduced_dim : int
        The dimension of the reduced Hilbert space.
    
    Returns:
    float
        The von Neumann entanglement entropy S_A.
    """
    # Calculate the size of the environment
    environment_size = reduced_dim // (subsystem_size)
    
    # Reshape psi into a 2^subsystem_size x environment_size matrix
    psi_matrix = psi.reshape((subsystem_size, environment_size))
    
    # Compute the reduced density matrix rho_A = Tr_B(|psi><psi|)
    rho_A = np.dot(psi_matrix, psi_matrix.conj().T)  # Partial trace over B
    
    # Compute eigenvalues of rho_A
    eigenvalues = np.linalg.eigvalsh(rho_A)
    
    # Filter out zero eigenvalues to avoid numerical issues in log calculation
    eigenvalues = eigenvalues[eigenvalues > 0]
    
    # Compute von Neumann entropy S_A = -Tr(rho_A log rho_A)
    entropy = -np.sum(eigenvalues * np.log2(eigenvalues))
    
    return entropy

def entanglement_entropy_full(psi, subsystem_size, total_size):
    """
    Computes the bipartite entanglement entropy of a pure state.
    
    Parameters:
    psi : np.array
        The wavefunction (state vector) of the full system.
    subsystem_size : int
        The number of qubits in subsystem A.
    total_size : int
        The total number of qubits in the system.
    
    Returns:
    float
        The von Neumann entanglement entropy S_A.
    """
    # Calculate the size of the environment
    environment_size = total_size - subsystem_size
    
    # Reshape psi into a 2^subsystem_size x 2^environment_size matrix
    psi_matrix = psi.reshape((2**subsystem_size, 2**environment_size))
    
    # Compute the reduced density matrix rho_A = Tr_B(|psi><psi|)
    rho_A = np.dot(psi_matrix, psi_matrix.conj().T)  # Partial trace over B
    
    # Compute eigenvalues of rho_A
    eigenvalues = np.linalg.eigvalsh(rho_A)
    
    # Filter out zero eigenvalues to avoid numerical issues in log calculation
    eigenvalues = eigenvalues[eigenvalues > 0]
    
    # Compute von Neumann entropy S_A = -Tr(rho_A log rho_A)
    entropy = -np.sum(eigenvalues * np.log2(eigenvalues))
    
    return entropy

def partial_trace(rho, keep, dims):
    """Compute the partial trace of a density matrix."""
    keep_dims = np.prod([dims[i] for i in keep])
    trace_dims = np.prod([dims[i] for i in range(len(dims)) if i not in keep])
    rho = rho.reshape([keep_dims, trace_dims, keep_dims, trace_dims])
    return np.trace(rho, axis1=1, axis2=3).reshape([keep_dims, keep_dims])

def fib_num(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib_num(n-1) + fib_num(n-2)


def fib_dim(n, pbc=True):
    if pbc:
        return fib_num(n-1) + fib_num(n+1)
    else:
        return fib_num(n+2)
    
def commutator(A, B):
    return np.dot(A, B) - np.dot(B, A)

# %%
n_spins = 12 # Number of spins
bc = True # if True, pbc
h = -0.05

# %%
print(fib_dim(n_spins, bc))
# Out:
# 322

# %%
# ALLOWED HILBERT SUBSPACE, NEEL STATE OVERLAP COMPUTATION

# Reconstruct the PXP Hamiltonian with pbc in the reduced Hilbert space
H, basis_states = construct_pxp_hamiltonian_fixed(n_spins, pbc=bc)
print(len(basis_states))

# Compute eigenvalues and eigenvectors
eigenvalues, eigenvectors = eigh(H)
print(len(eigenvectors[0]))

subsystem_size = len(eigenvectors[:, 0]) // 2

# Compute entanglement entropy for all eigenstates in the reduced Hilbert space
entropies = [entanglement_entropy(eigenvectors[:, i], subsystem_size, len(eigenvectors[:, i])) for i in range(eigenvectors.shape[1])]

# Construct the Neel state |1010...⟩ for length n_spins in the reduced Hilbert space
neel_state_pattern = tuple((i % 2 for i in range(n_spins)))
neel_state_vector = np.array([1 if state == neel_state_pattern else 0 for state in basis_states], dtype=float)

# Compute overlaps with all eigenstates
overlaps = np.abs(np.dot(eigenvectors.T, neel_state_vector))**2

# Identify the eigenstate with maximum overlap
max_overlap_index = np.argmax(overlaps)
print(f"Maximum overlap: {overlaps[max_overlap_index]:.4f}")
max_overlap_energy = eigenvalues[max_overlap_index]
max_overlap_vector = eigenvectors[:, max_overlap_index]
# Out:
# 322
# 322
# Maximum overlap: 0.1288

# %%
# FULL HILBERT SPACE, ENTANGLEMENT ENTROPY COMPUTATION

#  Map the max_overlap_vector back to the full Hilbert space
full_hilbert_space_vector = map_to_full_hilbert_space(max_overlap_vector, basis_states, n_spins)

print(f"Full Hilbert space vector shape: {full_hilbert_space_vector.shape}")
print(f"Full Hilbert space vector: {full_hilbert_space_vector}")

# Map all eigenvectors back to the full Hilbert space
full_hilbert_space_eigenvectors = np.zeros((2**n_spins, eigenvectors.shape[1]), dtype=complex)
for i in range(eigenvectors.shape[1]):
    full_hilbert_space_eigenvectors[:, i] = map_to_full_hilbert_space(eigenvectors[:, i], basis_states, n_spins)


# Compute entanglement entropy for all eigenstates in the full Hilbert space
subsystem_size = n_spins // 2
entropies = [entanglement_entropy_full(full_hilbert_space_eigenvectors[:, i], subsystem_size, n_spins) for i in range(eigenvectors.shape[1])]

print(len(entropies))
# Out:
# Full Hilbert space vector shape: (4096,)
# Full Hilbert space vector: [-2.42195374e-16+0.j  9.00826238e-02+0.j -1.20540967e-01+0.j ...
#   0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
# 322

# %%
# ALL PLOTS IN THE ALLOWED HILBERT SUBSPACE

# Identify indices where overlap is greater than machine precision
machine_epsilon = np.finfo(float).eps
highlight_indices = overlaps > machine_epsilon

# Plot overlap with Neel state for all energy states
plt.figure(figsize=(10, 6))
plt.plot(eigenvalues, overlaps, 'o', label='Overlap with Neel state')
plt.plot(np.array(eigenvalues)[highlight_indices], np.array(overlaps)[highlight_indices], 'ro', label='Overlap > machine precision')
plt.xlabel('Energy eigenvalues')
plt.ylabel('Overlap')
plt.title('Overlap with Neel state for all energy states')
plt.legend()
plt.show()

# Plot log of overlap as a function of energy eigenvalues
plt.figure(figsize=(10, 6))
plt.plot(eigenvalues, np.log10(overlaps), 'o', label='Log of overlap with Neel state')
plt.plot(np.array(eigenvalues)[highlight_indices], np.log10(np.array(overlaps)[highlight_indices]), 'ro', label='Overlap > machine precision')
plt.xlabel('Energy eigenvalues')
plt.ylabel('Log of overlap')
plt.title('Log of overlap with Neel state as a function of energy eigenvalues')
plt.legend()
plt.show()

# Plot entanglement entropy as a function of energy eigenvalues
plt.figure(figsize=(10, 6))
plt.plot(eigenvalues, entropies, 'o', label='Entanglement entropy')
plt.plot(np.array(eigenvalues)[highlight_indices], np.array(entropies)[highlight_indices], 'ro', label='Overlap > machine precision')
plt.xlabel('Energy eigenvalues')
plt.ylabel('Entanglement entropy')
plt.title('Entanglement entropy as a function of energy eigenvalues')
plt.legend()
plt.show()

# %%
# NEEL OVERLAP PLOT IN THE ALLOWED HILBERT SUBSPACE, ENTROPY PLOT IN THE FULL HILBERT SPACE

# Identify indices where overlap is greater than machine precision and energy is not zero
machine_epsilon = np.finfo(float).eps
highlight_indices = (overlaps > machine_epsilon) & (np.abs(eigenvalues) > machine_epsilon)

# Define a function for the curves
def sfunc(x, a, b):
    return a * (x)**2 + b

# Define the two curves 
# CURVES COEFFS SPECIFIC TO THE DATA WITH N=12
curve1 = sfunc(eigenvalues, -0.025, 2.4)
curve2 = sfunc(eigenvalues, -0.03, 1.9)

# Identify indices where entropies are between the two curves
between_curves_indices = (entropies > curve2) & (entropies < curve1)

# Combine the conditions
highlight_between_curves_indices = highlight_indices & between_curves_indices

# Fit the red points only
x_data = np.array(eigenvalues)[highlight_between_curves_indices]
y_data = np.array(entropies)[highlight_between_curves_indices]
popt, pcov = curve_fit(sfunc, x_data, y_data)

# Plot overlap with Neel state for all energy states
plt.figure(figsize=(10, 6))
plt.plot(eigenvalues, overlaps, 'o', markersize=2)
#plt.plot(np.array(eigenvalues)[highlight_indices], np.array(overlaps)[highlight_indices], 'ro', label='Overlap > machine precision')
plt.plot(np.array(eigenvalues)[highlight_between_curves_indices], np.array(overlaps)[highlight_between_curves_indices], 'rx', label='Scars')
plt.xlabel('Eigenvalues of H')
plt.ylabel(r'$|\langle \psi | \mathbb{Z}_2 \rangle|^2$')
#plt.title('Overlap with Neel state for all energy states')
plt.legend()
plt.savefig('pxp_neel.png', dpi=300, bbox_inches='tight')
plt.show()

# Plot log of overlap as a function of energy eigenvalues
plt.figure(figsize=(10, 6))
plt.plot(eigenvalues, np.log10(overlaps), 'o', markersize = 2)
#plt.plot(np.array(eigenvalues)[highlight_indices], np.log10(np.array(overlaps)[highlight_indices]), 'ro', label='Overlap > machine precision')
plt.plot(np.array(eigenvalues)[highlight_between_curves_indices], np.log10(np.array(overlaps)[highlight_between_curves_indices]), 'rx', label='Scars')
plt.xlabel('Energy eigenvalues')
plt.ylabel('Log of Neel overlap')
plt.title('Log of overlap with Neel state as a function of energy eigenvalues')
plt.legend()
plt.show()

'''# Plot entanglement entropy as a function of energy eigenvalues
plt.figure(figsize=(10, 6))
plt.plot(eigenvalues, entropies, 'o', label='Entanglement entropy')
#plt.plot(np.array(eigenvalues)[highlight_indices], np.array(entropies)[highlight_indices], 'ro', label='Overlap > machine precision')
plt.plot(np.array(eigenvalues)[highlight_between_curves_indices], np.array(entropies)[highlight_between_curves_indices], 'ro', label='Scars')
plt.xlabel('Energy eigenvalues')
plt.ylabel('Entanglement entropy')
plt.title('Entanglement entropy as a function of energy eigenvalues')
plt.legend()
plt.show()'''

# Plot entanglement entropy as a function of energy eigenvalues with curves
plt.figure(figsize=(10, 6))
plt.plot(eigenvalues, entropies, 'o', markersize=2)
plt.plot(np.array(eigenvalues)[highlight_between_curves_indices], np.array(entropies)[highlight_between_curves_indices], 'rx', label='Scars')
#plt.plot(eigenvalues, curve1, 'r-') #, label='Curve 1: -0.025 * x^2 + 2.4')
#plt.plot(eigenvalues, curve2, 'r-') #, label='Curve 2: -0.03 * x^2 + 1.9')

# Plot the fitted curve
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = sfunc(x_fit, *popt)
#plt.plot(x_fit, y_fit, 'r-', label='Fitted curve')

plt.xlabel('Eigenvalues of H')
plt.ylabel(r"$\mathcal{E}$")
#plt.title('Entanglement entropy as a function of energy eigenvalues')
plt.legend()
plt.savefig('pxp_entanglement.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# 3 spins (0,1,2) H_pxp + SU(2) structure + Casimir operator

# Number of spins
N = 3

# Define Pauli matrices and identity
I = np.array([[1, 0], [0, 1]])
X = np.array([[0, 1], [1, 0]])
Y = np.array([[0, -1j], [1j, 0]])
Z = np.array([[1, 0], [0, -1]])
P = (1/2)*(I + Z)

# Construct Qx, Qy, Qz using Kronecker products
Q_x = (1/2) * sum((-1)**i * reduce(np.kron, [X if j == i else I for j in range(N)]) for i in range(N))
Q_y = (1/2) * sum((-1)**i * reduce(np.kron, [Y if j == i else I for j in range(N)]) for i in range(N))
Q_z = (1/2) * sum((-1)**i * reduce(np.kron, [Z if j == i else I for j in range(N)]) for i in range(N))

# Define the Casimir operator
Casimir = np.dot(Q_x, Q_x) + np.dot(Q_y, Q_y) + np.dot(Q_z, Q_z)

# Define the PXP Hamiltonian in the 3-spin restricted space
H_PXP = np.kron(np.kron(X, P), P) + np.kron(np.kron(P, X), P) + np.kron(np.kron(P, P), X)

# %%
# Print scar eigenvalue and rank of RDM for each scar eigenvector
#for i in np.where(highlight_between_curves_indices)[0]:
for i in range(len(eigenvalues)):
    full_hilbert_space_vector = full_hilbert_space_eigenvectors[:, i]
    
    # Construct the density matrix
    density_matrix = np.outer(full_hilbert_space_vector, full_hilbert_space_vector.conj())
    
    # Trace out some qubits (keep other qubits)
    dims = [2] * n_spins  # Assuming n_spins = 12
    keep_qubits = [0, 1, 2]  # Adjust indices of qubits to keep as needed
    traced_out_density_matrix = partial_trace(density_matrix, keep_qubits, dims)
    
    # Compute the rank of the traced out density matrix
    rank = np.linalg.matrix_rank(traced_out_density_matrix)

    # Identify zero rows and columns
    zero_rows = np.where(~traced_out_density_matrix.any(axis=1))[0]
    zero_columns = np.where(~traced_out_density_matrix.any(axis=0))[0]
    
    # Print the eigenvalue and rank
    print(f"Eigenvalue: {eigenvalues[i]:.6f}, Rank of RDM: {rank}, Zero columns in RDM: {zero_columns}")
# Out:
# Eigenvalue: -6.892082, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -6.200869, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -5.744206, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -5.708368, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -5.238776, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -5.086992, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -5.070182, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.709264, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.702641, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.681449, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.657145, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.619482, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.614696, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.414531, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.391567, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.273062, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -4.052664, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.944404, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.937224, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.923316, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.922101, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.707081, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.699061, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.666089, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.658271, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.609303, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.594449, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.483002, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.481201, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.371510, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.340558, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.326115, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.242129, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.229889, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.215057, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.057561, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -3.054220, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.963430, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.957997, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.947030, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.945162, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.926045, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.907617, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.791491, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.749856, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.696486, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.641349, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.624190, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.618308, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.579597, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.564320, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.543990, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.540030, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.532381, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.521119, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.502901, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.493528, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.368369, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.352373, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.329767, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.326270, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.244994, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.240043, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.194135, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.194003, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.181914, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.174161, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.170074, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.114673, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.113978, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.100364, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -2.095683, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.870088, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.863587, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.832839, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.832604, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.824446, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.816974, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.765306, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.762183, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.760279, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.677449, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.666083, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.662844, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.634439, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.560854, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.547929, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.519246, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.511717, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.479793, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.471834, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.447820, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.439794, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.411976, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.402250, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.391891, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.389258, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.351407, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.340368, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.330368, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.329068, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.284268, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.278592, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.236710, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.229995, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.177395, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.177266, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.148797, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.144393, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.138369, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.113313, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.107234, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.026487, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -1.025126, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.952432, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.948027, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.918939, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.913878, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.853974, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.846237, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.826747, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.823570, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.818330, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.818081, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.801024, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.746545, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.739851, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.639490, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.636507, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.607787, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.604468, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.582927, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.582369, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.500087, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.490088, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.473820, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.463991, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.427986, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.426398, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.377662, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.368255, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.350082, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.342298, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.332753, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.330315, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.279842, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.271641, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.252652, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.247700, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.203326, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.039119, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.027795, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.025253, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.021723, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.017134, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.014132, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.010003, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.000000, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.000000, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: -0.000000, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.000000, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.000000, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.000000, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.000000, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.000000, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.010003, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.014132, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.017134, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.021723, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.025253, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.027795, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.039119, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.203326, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.247700, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.252652, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.271641, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.279842, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.330315, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.332753, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.342298, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.350082, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.368255, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.377662, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.426398, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.427986, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.463991, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.473820, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.490088, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.500087, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.582369, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.582927, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.604468, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.607787, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.636507, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.639490, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.739851, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.746545, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.801024, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.818081, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.818330, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.823570, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.826747, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.846237, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.853974, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.913878, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.918939, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.948027, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 0.952432, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.025126, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.026487, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.107234, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.113313, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.138369, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.144393, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.148797, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.177266, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.177395, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.229995, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.236710, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.278592, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.284268, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.329068, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.330368, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.340368, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.351407, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.389258, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.391891, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.402250, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.411976, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.439794, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.447820, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.471834, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.479793, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.511717, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.519246, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.547929, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.560854, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.634439, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.662844, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.666083, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.677449, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.760279, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.762183, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.765306, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.816974, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.824446, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.832604, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.832839, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.863587, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 1.870088, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.095683, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.100364, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.113978, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.114673, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.170074, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.174161, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.181914, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.194003, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.194135, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.240043, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.244994, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.326270, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.329767, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.352373, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.368369, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.493528, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.502901, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.521119, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.532381, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.540030, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.543990, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.564320, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.579597, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.618308, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.624190, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.641349, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.696486, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.749856, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.791491, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.907617, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.926045, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.945162, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.947030, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.957997, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 2.963430, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.054220, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.057561, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.215057, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.229889, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.242129, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.326115, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.340558, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.371510, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.481201, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.483002, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.594449, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.609303, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.658271, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.666089, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.699061, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.707081, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.922101, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.923316, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.937224, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 3.944404, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.052664, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.273062, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.391567, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.414531, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.614696, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.619482, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.657145, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.681449, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.702641, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 4.709264, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 5.070182, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 5.086992, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 5.238776, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 5.708368, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 5.744206, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 6.200869, Rank of RDM: 5, Zero columns in RDM: [3 6 7]
# Eigenvalue: 6.892082, Rank of RDM: 5, Zero columns in RDM: [3 6 7]

# %%
data = []

for i in np.where(highlight_between_curves_indices)[0]:
    full_hilbert_space_vector = full_hilbert_space_eigenvectors[:, i]
    density_matrix = np.outer(full_hilbert_space_vector, full_hilbert_space_vector.conj())

    dims = [2] * n_spins
    keep_qubits = [0, 1, 2]
    traced_out_density_matrix = partial_trace(density_matrix, keep_qubits, dims)
    
    rank = np.linalg.matrix_rank(traced_out_density_matrix)
    zero_columns = np.where(~traced_out_density_matrix.any(axis=0))[0]
    
    data.append({
        "Eigenvalue": eigenvalues[i],
        "RDM Rank": rank,
        "Zero Columns": list(zero_columns)
    })

# Create a DataFrame
df = pd.DataFrame(data)

with open("scar_RDM_table.tex", "w") as f:
    f.write(df.to_latex(index=False))

# %%
# Compute the rank of the RDM for the scar points only

for i in np.where(highlight_between_curves_indices)[0]:
    full_hilbert_space_vector = full_hilbert_space_eigenvectors[:, i]
    
    # Construct the density matrix
    density_matrix = np.outer(full_hilbert_space_vector, full_hilbert_space_vector.conj())
    
    # Trace out some qubits (keep other qubits)
    dims = [2] * 12  # Assuming n_spins = 12
    keep_qubits = [0, 2, 4, 5, 6, 7, 8, 9, 10, 11]  # Indices of qubits to keep
    traced_out_density_matrix = partial_trace(density_matrix, keep_qubits, dims)
    
    # Diagonalize the traced out density matrix
    to_eigenvalues, to_eigenvectors = np.linalg.eigh(traced_out_density_matrix)
    
    # Print the minimum eigenvalue
    min_eigenvalue = np.min(to_eigenvalues)
    #print(f"Eigenvector {i}: Minimum eigenvalue: {min_eigenvalue}")
    
    # Print the rank of the traced out density matrix
    rank = np.linalg.matrix_rank(traced_out_density_matrix)
    print(f"Eigenvector {i}: Rank of traced out density matrix: {rank}")
    print(f"Eigenvector {i}: reduced density matrix:\n{traced_out_density_matrix}")

print(f"reduced space dim with pbc is {fib_dim(len(keep_qubits), pbc=True)}")
print(f"reduced space dim with obc is {fib_dim(len(keep_qubits), pbc=False)}")
print(f"complementary reduced space dim with obc is {fib_dim(n_spins - len(keep_qubits), pbc=False)}")
# Out:
# Eigenvector 0: Rank of traced out density matrix: 3
# Eigenvector 0: reduced density matrix:
# [[ 0.05593214+0.j -0.02944515+0.j -0.03687551+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.02944515+0.j  0.02027551+0.j  0.01821975+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.03687551+0.j  0.01821975+0.j  0.02461963+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 1: Rank of traced out density matrix: 3
# Eigenvector 1: reduced density matrix:
# [[ 0.00658883+0.j -0.00422135+0.j -0.00486643+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00422135+0.j  0.00978483+0.j -0.00412456+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00486643+0.j -0.00412456+0.j  0.01100252+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 2: Rank of traced out density matrix: 3
# Eigenvector 2: reduced density matrix:
# [[ 0.00678491+0.j -0.0027774 +0.j -0.0076453 +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.0027774 +0.j  0.01779109+0.j -0.01332605+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.0076453 +0.j -0.01332605+0.j  0.02487475+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 3: Rank of traced out density matrix: 3
# Eigenvector 3: reduced density matrix:
# [[ 0.01575008+0.j -0.00835912+0.j -0.00985768+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00835912+0.j  0.00822216+0.j  0.00682969+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00985768+0.j  0.00682969+0.j  0.00701261+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 4: Rank of traced out density matrix: 3
# Eigenvector 4: reduced density matrix:
# [[ 0.01824925+0.j -0.006951  +0.j -0.01041319+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.006951  +0.j  0.00324445+0.j  0.00405666+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.01041319+0.j  0.00405666+0.j  0.00680996+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 5: Rank of traced out density matrix: 3
# Eigenvector 5: reduced density matrix:
# [[ 0.01784171+0.j -0.00334943+0.j -0.00747388+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00334943+0.j  0.00652698+0.j  0.00773402+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00747388+0.j  0.00773402+0.j  0.01009548+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 6: Rank of traced out density matrix: 3
# Eigenvector 6: reduced density matrix:
# [[ 0.01133931+0.j -0.00080751+0.j -0.01294335+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00080751+0.j  0.01052528+0.j -0.00941531+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.01294335+0.j -0.00941531+0.j  0.02826779+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 7: Rank of traced out density matrix: 3
# Eigenvector 7: reduced density matrix:
# [[ 0.00783005+0.j -0.00520525+0.j -0.00912316+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00520525+0.j  0.01364212+0.j  0.00147365+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00912316+0.j  0.00147365+0.j  0.01609931+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 9: Rank of traced out density matrix: 3
# Eigenvector 9: reduced density matrix:
# [[ 0.01449127+0.j -0.00282304+0.j  0.00499855+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00282304+0.j  0.00650284+0.j  0.00762585+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00499855+0.j  0.00762585+0.j  0.01435343+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 10: Rank of traced out density matrix: 3
# Eigenvector 10: reduced density matrix:
# [[ 1.21260025e-02+0.j -2.56942074e-05+0.j -9.84181960e-03+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [-2.56942074e-05+0.j  4.39771426e-03+0.j -5.31390276e-03+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [-9.84181960e-03+0.j -5.31390276e-03+0.j  1.88885356e-02+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  ...
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]]
# Eigenvector 16: Rank of traced out density matrix: 3
# Eigenvector 16: reduced density matrix:
# [[ 0.01239042+0.j -0.00504186+0.j -0.00756845+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00504186+0.j  0.01045277+0.j -0.00603259+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00756845+0.j -0.00603259+0.j  0.01450902+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 20: Rank of traced out density matrix: 3
# Eigenvector 20: reduced density matrix:
# [[ 0.00489141+0.j -0.00305993+0.j -0.00934586+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00305993+0.j  0.0222995 +0.j  0.02318077+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00934586+0.j  0.02318077+0.j  0.03261052+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 42: Rank of traced out density matrix: 3
# Eigenvector 42: reduced density matrix:
# [[ 0.05163279+0.j -0.0140425 +0.j -0.02621546+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.0140425 +0.j  0.00740437+0.j  0.01197992+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.02621546+0.j  0.01197992+0.j  0.01988355+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 44: Rank of traced out density matrix: 3
# Eigenvector 44: reduced density matrix:
# [[ 0.02832522+0.j -0.00396291+0.j -0.00677397+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00396291+0.j  0.00712377+0.j -0.00201541+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00677397+0.j -0.00201541+0.j  0.00876056+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 57: Rank of traced out density matrix: 3
# Eigenvector 57: reduced density matrix:
# [[ 0.00219987+0.j  0.0004183 +0.j -0.000625  +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.0004183 +0.j  0.00457712+0.j  0.00357899+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.000625  +0.j  0.00357899+0.j  0.00413937+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 58: Rank of traced out density matrix: 3
# Eigenvector 58: reduced density matrix:
# [[ 2.99523703e-03+0.j  4.43565166e-05+0.j -1.76214438e-03+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 4.43565166e-05+0.j  4.28673806e-03+0.j -6.72228895e-03+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [-1.76214438e-03+0.j -6.72228895e-03+0.j  1.22334518e-02+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  ...
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]]
# Eigenvector 95: Rank of traced out density matrix: 3
# Eigenvector 95: reduced density matrix:
# [[ 0.022645  +0.j -0.0031857 +0.j -0.00366701+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.0031857 +0.j  0.00834734+0.j -0.00843054+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00366701+0.j -0.00843054+0.j  0.01101145+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 226: Rank of traced out density matrix: 3
# Eigenvector 226: reduced density matrix:
# [[ 0.022645  +0.j  0.0031857 +0.j  0.00366701+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.0031857 +0.j  0.00834734+0.j -0.00843054+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00366701+0.j -0.00843054+0.j  0.01101145+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 263: Rank of traced out density matrix: 3
# Eigenvector 263: reduced density matrix:
# [[ 2.99523703e-03+0.j -4.43565166e-05+0.j  1.76214438e-03+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [-4.43565166e-05+0.j  4.28673806e-03+0.j -6.72228895e-03+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 1.76214438e-03+0.j -6.72228895e-03+0.j  1.22334518e-02+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  ...
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]]
# Eigenvector 264: Rank of traced out density matrix: 3
# Eigenvector 264: reduced density matrix:
# [[ 0.00219987+0.j -0.0004183 +0.j  0.000625  +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.0004183 +0.j  0.00457712+0.j  0.00357899+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.000625  +0.j  0.00357899+0.j  0.00413937+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 277: Rank of traced out density matrix: 3
# Eigenvector 277: reduced density matrix:
# [[ 0.02832522+0.j  0.00396291+0.j  0.00677397+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00396291+0.j  0.00712377+0.j -0.00201541+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00677397+0.j -0.00201541+0.j  0.00876056+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 279: Rank of traced out density matrix: 3
# Eigenvector 279: reduced density matrix:
# [[0.05163279+0.j 0.0140425 +0.j 0.02621546+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.0140425 +0.j 0.00740437+0.j 0.01197992+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.02621546+0.j 0.01197992+0.j 0.01988355+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  ...
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]]
# Eigenvector 301: Rank of traced out density matrix: 3
# Eigenvector 301: reduced density matrix:
# [[0.00489141+0.j 0.00305993+0.j 0.00934586+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.00305993+0.j 0.0222995 +0.j 0.02318077+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.00934586+0.j 0.02318077+0.j 0.03261052+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  ...
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]]
# Eigenvector 305: Rank of traced out density matrix: 3
# Eigenvector 305: reduced density matrix:
# [[ 0.01239042+0.j  0.00504186+0.j  0.00756845+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00504186+0.j  0.01045277+0.j -0.00603259+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00756845+0.j -0.00603259+0.j  0.01450902+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 311: Rank of traced out density matrix: 3
# Eigenvector 311: reduced density matrix:
# [[ 1.21260025e-02+0.j  2.56942074e-05+0.j  9.84181960e-03+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 2.56942074e-05+0.j  4.39771426e-03+0.j -5.31390276e-03+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 9.84181960e-03+0.j -5.31390276e-03+0.j  1.88885356e-02+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  ...
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]
#  [ 0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j ...
#    0.00000000e+00+0.j  0.00000000e+00+0.j  0.00000000e+00+0.j]]
# Eigenvector 312: Rank of traced out density matrix: 3
# Eigenvector 312: reduced density matrix:
# [[ 0.01449127+0.j  0.00282304+0.j -0.00499855+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00282304+0.j  0.00650284+0.j  0.00762585+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [-0.00499855+0.j  0.00762585+0.j  0.01435343+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 314: Rank of traced out density matrix: 3
# Eigenvector 314: reduced density matrix:
# [[0.00783005+0.j 0.00520525+0.j 0.00912316+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.00520525+0.j 0.01364212+0.j 0.00147365+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.00912316+0.j 0.00147365+0.j 0.01609931+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  ...
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]]
# Eigenvector 315: Rank of traced out density matrix: 3
# Eigenvector 315: reduced density matrix:
# [[ 0.01133931+0.j  0.00080751+0.j  0.01294335+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00080751+0.j  0.01052528+0.j -0.00941531+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.01294335+0.j -0.00941531+0.j  0.02826779+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 316: Rank of traced out density matrix: 3
# Eigenvector 316: reduced density matrix:
# [[0.01784171+0.j 0.00334943+0.j 0.00747388+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.00334943+0.j 0.00652698+0.j 0.00773402+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.00747388+0.j 0.00773402+0.j 0.01009548+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  ...
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]]
# Eigenvector 317: Rank of traced out density matrix: 3
# Eigenvector 317: reduced density matrix:
# [[0.01824925+0.j 0.006951  +0.j 0.01041319+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.006951  +0.j 0.00324445+0.j 0.00405666+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.01041319+0.j 0.00405666+0.j 0.00680996+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  ...
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]]
# Eigenvector 318: Rank of traced out density matrix: 3
# Eigenvector 318: reduced density matrix:
# [[0.01575008+0.j 0.00835912+0.j 0.00985768+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.00835912+0.j 0.00822216+0.j 0.00682969+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.00985768+0.j 0.00682969+0.j 0.00701261+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  ...
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]]
# Eigenvector 319: Rank of traced out density matrix: 3
# Eigenvector 319: reduced density matrix:
# [[ 0.00678491+0.j  0.0027774 +0.j  0.0076453 +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.0027774 +0.j  0.01779109+0.j -0.01332605+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.0076453 +0.j -0.01332605+0.j  0.02487475+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 320: Rank of traced out density matrix: 3
# Eigenvector 320: reduced density matrix:
# [[ 0.00658883+0.j  0.00422135+0.j  0.00486643+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00422135+0.j  0.00978483+0.j -0.00412456+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.00486643+0.j -0.00412456+0.j  0.01100252+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]]
# Eigenvector 321: Rank of traced out density matrix: 3
# Eigenvector 321: reduced density matrix:
# [[0.05593214+0.j 0.02944515+0.j 0.03687551+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.02944515+0.j 0.02027551+0.j 0.01821975+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.03687551+0.j 0.01821975+0.j 0.02461963+0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  ...
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j ... 0.        +0.j
#   0.        +0.j 0.        +0.j]]
# reduced space dim with pbc is 123
# reduced space dim with obc is 144
# complementary reduced space dim with obc is 3

# %%
# Compute the rank of the RDM for the scar points only

for i in np.where(highlight_between_curves_indices)[0]:
    full_hilbert_space_vector = full_hilbert_space_eigenvectors[:, i]
    
    # Construct the density matrix
    density_matrix = np.outer(full_hilbert_space_vector, full_hilbert_space_vector.conj())
    
    # Trace out some qubits (keep other qubits)
    dims = [2] * 12  # Assuming n_spins = 12
    keep_qubits = [0, 2, 4, 7, 9, 11]  # Indices of qubits to keep
    traced_out_density_matrix = partial_trace(density_matrix, keep_qubits, dims)
    
    # Diagonalize the traced out density matrix
    to_eigenvalues, to_eigenvectors = np.linalg.eigh(traced_out_density_matrix)
    
    # Print the minimum eigenvalue
    min_eigenvalue = np.min(to_eigenvalues)
    #print(f"Eigenvector {i}: Minimum eigenvalue: {min_eigenvalue}")
    
    # Print the rank of the traced out density matrix
    rank = np.linalg.matrix_rank(traced_out_density_matrix)
    print(f"Eigenvector {i}: Rank of traced out density matrix: {rank}")

print(f"reduced space dim with pbc is {fib_dim(len(keep_qubits), pbc=True)}")
print(f"reduced space dim with obc is {fib_dim(len(keep_qubits), pbc=False)}")
# Out:
# Eigenvector 0: Rank of traced out density matrix: 21
# Eigenvector 1: Rank of traced out density matrix: 20
# Eigenvector 2: Rank of traced out density matrix: 21
# Eigenvector 3: Rank of traced out density matrix: 20
# Eigenvector 4: Rank of traced out density matrix: 21
# Eigenvector 5: Rank of traced out density matrix: 21
# Eigenvector 6: Rank of traced out density matrix: 20
# Eigenvector 7: Rank of traced out density matrix: 20
# Eigenvector 9: Rank of traced out density matrix: 20
# Eigenvector 10: Rank of traced out density matrix: 21
# Eigenvector 16: Rank of traced out density matrix: 20
# Eigenvector 20: Rank of traced out density matrix: 20
# Eigenvector 42: Rank of traced out density matrix: 20
# Eigenvector 44: Rank of traced out density matrix: 21
# Eigenvector 57: Rank of traced out density matrix: 21
# Eigenvector 58: Rank of traced out density matrix: 21
# Eigenvector 95: Rank of traced out density matrix: 20
# Eigenvector 226: Rank of traced out density matrix: 20
# Eigenvector 263: Rank of traced out density matrix: 21
# Eigenvector 264: Rank of traced out density matrix: 21
# Eigenvector 277: Rank of traced out density matrix: 21
# Eigenvector 279: Rank of traced out density matrix: 20
# Eigenvector 301: Rank of traced out density matrix: 20
# Eigenvector 305: Rank of traced out density matrix: 20
# Eigenvector 311: Rank of traced out density matrix: 21
# Eigenvector 312: Rank of traced out density matrix: 20
# Eigenvector 314: Rank of traced out density matrix: 20
# Eigenvector 315: Rank of traced out density matrix: 20
# Eigenvector 316: Rank of traced out density matrix: 21
# Eigenvector 317: Rank of traced out density matrix: 21
# Eigenvector 318: Rank of traced out density matrix: 20
# Eigenvector 319: Rank of traced out density matrix: 21
# Eigenvector 320: Rank of traced out density matrix: 20
# Eigenvector 321: Rank of traced out density matrix: 21
# reduced space dim with pbc is 18
# reduced space dim with obc is 21

# %%
# Compute the rank of the RDM for the scar points only

for i in np.where(highlight_between_curves_indices)[0]:
    full_hilbert_space_vector = full_hilbert_space_eigenvectors[:, i]
    
    # Construct the density matrix
    density_matrix = np.outer(full_hilbert_space_vector, full_hilbert_space_vector.conj())
    
    # Trace out some qubits (keep other qubits)
    dims = [2] * 12  # Assuming n_spins = 12
    keep_qubits = [0, 1, 11]  # Indices of qubits to keep
    traced_out_density_matrix = partial_trace(density_matrix, keep_qubits, dims)
    
    # Diagonalize the traced out density matrix
    to_eigenvalues, to_eigenvectors = np.linalg.eigh(traced_out_density_matrix)
    
    # Print the minimum eigenvalue
    min_eigenvalue = np.min(to_eigenvalues)
    #print(f"Eigenvector {i}: Minimum eigenvalue: {min_eigenvalue}")
    
    # Print the rank of the traced out density matrix
    rank = np.linalg.matrix_rank(traced_out_density_matrix)
    print(f"Eigenvector {i}: Rank of traced out density matrix: {rank}")

print(f"reduced space dim with pbc is {fib_dim(len(keep_qubits), pbc=True)}")
print(f"reduced space dim with obc is {fib_dim(len(keep_qubits), pbc=False)}")
# Out:
# Eigenvector 0: Rank of traced out density matrix: 5
# Eigenvector 1: Rank of traced out density matrix: 5
# Eigenvector 2: Rank of traced out density matrix: 5
# Eigenvector 3: Rank of traced out density matrix: 5
# Eigenvector 4: Rank of traced out density matrix: 5
# Eigenvector 5: Rank of traced out density matrix: 5
# Eigenvector 6: Rank of traced out density matrix: 5
# Eigenvector 7: Rank of traced out density matrix: 5
# Eigenvector 9: Rank of traced out density matrix: 5
# Eigenvector 10: Rank of traced out density matrix: 5
# Eigenvector 16: Rank of traced out density matrix: 5
# Eigenvector 20: Rank of traced out density matrix: 5
# Eigenvector 42: Rank of traced out density matrix: 5
# Eigenvector 44: Rank of traced out density matrix: 5
# Eigenvector 57: Rank of traced out density matrix: 5
# Eigenvector 58: Rank of traced out density matrix: 5
# Eigenvector 95: Rank of traced out density matrix: 5
# Eigenvector 226: Rank of traced out density matrix: 5
# Eigenvector 263: Rank of traced out density matrix: 5
# Eigenvector 264: Rank of traced out density matrix: 5
# Eigenvector 277: Rank of traced out density matrix: 5
# Eigenvector 279: Rank of traced out density matrix: 5
# Eigenvector 301: Rank of traced out density matrix: 5
# Eigenvector 305: Rank of traced out density matrix: 5
# Eigenvector 311: Rank of traced out density matrix: 5
# Eigenvector 312: Rank of traced out density matrix: 5
# Eigenvector 314: Rank of traced out density matrix: 5
# Eigenvector 315: Rank of traced out density matrix: 5
# Eigenvector 316: Rank of traced out density matrix: 5
# Eigenvector 317: Rank of traced out density matrix: 5
# Eigenvector 318: Rank of traced out density matrix: 5
# Eigenvector 319: Rank of traced out density matrix: 5
# Eigenvector 320: Rank of traced out density matrix: 5
# Eigenvector 321: Rank of traced out density matrix: 5
# reduced space dim with pbc is 4
# reduced space dim with obc is 5

# %%
# Compute the rank of the RDM for all points

for i in range(2**n_spins):
    full_hilbert_space_vector = full_hilbert_space_eigenvectors[:, i]
    
    # Construct the density matrix
    density_matrix = np.outer(full_hilbert_space_vector, full_hilbert_space_vector.conj())
    
    # Trace out some qubits (keep other qubits)
    dims = [2] * 12  # Assuming n_spins = 12
    keep_qubits = [0, 1, 11]  # Indices of qubits to keep
    traced_out_density_matrix = partial_trace(density_matrix, keep_qubits, dims)
    
    # Diagonalize the traced out density matrix
    to_eigenvalues, to_eigenvectors = np.linalg.eigh(traced_out_density_matrix)
    
    # Print the minimum eigenvalue
    min_eigenvalue = np.min(to_eigenvalues)
    #print(f"Eigenvector {i}: Minimum eigenvalue: {min_eigenvalue}")
    
    # Print the rank of the traced out density matrix
    rank = np.linalg.matrix_rank(traced_out_density_matrix)
    print(f"Eigenvector {i}: Rank of traced out density matrix: {rank}")

print(f"reduced space dim with pbc is {fib_dim(len(keep_qubits), pbc=True)}")
print(f"reduced space dim with obc is {fib_dim(len(keep_qubits), pbc=False)}")
# Out:
# Eigenvector 0: Rank of traced out density matrix: 5
# Eigenvector 1: Rank of traced out density matrix: 5
# Eigenvector 2: Rank of traced out density matrix: 5
# Eigenvector 3: Rank of traced out density matrix: 5
# Eigenvector 4: Rank of traced out density matrix: 5
# Eigenvector 5: Rank of traced out density matrix: 5
# Eigenvector 6: Rank of traced out density matrix: 5
# Eigenvector 7: Rank of traced out density matrix: 5
# Eigenvector 8: Rank of traced out density matrix: 5
# Eigenvector 9: Rank of traced out density matrix: 5
# Eigenvector 10: Rank of traced out density matrix: 5
# Eigenvector 11: Rank of traced out density matrix: 5
# Eigenvector 12: Rank of traced out density matrix: 5
# Eigenvector 13: Rank of traced out density matrix: 5
# Eigenvector 14: Rank of traced out density matrix: 5
# Eigenvector 15: Rank of traced out density matrix: 5
# Eigenvector 16: Rank of traced out density matrix: 5
# Eigenvector 17: Rank of traced out density matrix: 5
# Eigenvector 18: Rank of traced out density matrix: 5
# Eigenvector 19: Rank of traced out density matrix: 5
# Eigenvector 20: Rank of traced out density matrix: 5
# Eigenvector 21: Rank of traced out density matrix: 5
# Eigenvector 22: Rank of traced out density matrix: 5
# Eigenvector 23: Rank of traced out density matrix: 5
# Eigenvector 24: Rank of traced out density matrix: 5
# Eigenvector 25: Rank of traced out density matrix: 5
# Eigenvector 26: Rank of traced out density matrix: 5
# Eigenvector 27: Rank of traced out density matrix: 5
# Eigenvector 28: Rank of traced out density matrix: 5
# Eigenvector 29: Rank of traced out density matrix: 5
# Eigenvector 30: Rank of traced out density matrix: 5
# Eigenvector 31: Rank of traced out density matrix: 5
# Eigenvector 32: Rank of traced out density matrix: 5
# Eigenvector 33: Rank of traced out density matrix: 5
# Eigenvector 34: Rank of traced out density matrix: 5
# Eigenvector 35: Rank of traced out density matrix: 5
# Eigenvector 36: Rank of traced out density matrix: 5
# Eigenvector 37: Rank of traced out density matrix: 5
# Eigenvector 38: Rank of traced out density matrix: 5
# Eigenvector 39: Rank of traced out density matrix: 5
# Eigenvector 40: Rank of traced out density matrix: 5
# Eigenvector 41: Rank of traced out density matrix: 5
# Eigenvector 42: Rank of traced out density matrix: 5
# Eigenvector 43: Rank of traced out density matrix: 5
# Eigenvector 44: Rank of traced out density matrix: 5
# Eigenvector 45: Rank of traced out density matrix: 5
# Eigenvector 46: Rank of traced out density matrix: 5
# Eigenvector 47: Rank of traced out density matrix: 5
# Eigenvector 48: Rank of traced out density matrix: 5
# Eigenvector 49: Rank of traced out density matrix: 5
# Eigenvector 50: Rank of traced out density matrix: 5
# Eigenvector 51: Rank of traced out density matrix: 5
# Eigenvector 52: Rank of traced out density matrix: 5
# Eigenvector 53: Rank of traced out density matrix: 5
# Eigenvector 54: Rank of traced out density matrix: 5
# Eigenvector 55: Rank of traced out density matrix: 5
# Eigenvector 56: Rank of traced out density matrix: 5
# Eigenvector 57: Rank of traced out density matrix: 5
# Eigenvector 58: Rank of traced out density matrix: 5
# Eigenvector 59: Rank of traced out density matrix: 5
# Eigenvector 60: Rank of traced out density matrix: 5
# Eigenvector 61: Rank of traced out density matrix: 5
# Eigenvector 62: Rank of traced out density matrix: 5
# Eigenvector 63: Rank of traced out density matrix: 5
# Eigenvector 64: Rank of traced out density matrix: 5
# Eigenvector 65: Rank of traced out density matrix: 5
# Eigenvector 66: Rank of traced out density matrix: 5
# Eigenvector 67: Rank of traced out density matrix: 5
# Eigenvector 68: Rank of traced out density matrix: 5
# Eigenvector 69: Rank of traced out density matrix: 5
# Eigenvector 70: Rank of traced out density matrix: 5
# Eigenvector 71: Rank of traced out density matrix: 5
# Eigenvector 72: Rank of traced out density matrix: 5
# Eigenvector 73: Rank of traced out density matrix: 5
# Eigenvector 74: Rank of traced out density matrix: 5
# Eigenvector 75: Rank of traced out density matrix: 5
# Eigenvector 76: Rank of traced out density matrix: 5
# Eigenvector 77: Rank of traced out density matrix: 5
# Eigenvector 78: Rank of traced out density matrix: 5
# Eigenvector 79: Rank of traced out density matrix: 5
# Eigenvector 80: Rank of traced out density matrix: 5
# Eigenvector 81: Rank of traced out density matrix: 5
# Eigenvector 82: Rank of traced out density matrix: 5
# Eigenvector 83: Rank of traced out density matrix: 5
# Eigenvector 84: Rank of traced out density matrix: 5
# Eigenvector 85: Rank of traced out density matrix: 5
# Eigenvector 86: Rank of traced out density matrix: 5
# Eigenvector 87: Rank of traced out density matrix: 5
# Eigenvector 88: Rank of traced out density matrix: 5
# Eigenvector 89: Rank of traced out density matrix: 5
# Eigenvector 90: Rank of traced out density matrix: 5
# Eigenvector 91: Rank of traced out density matrix: 5
# Eigenvector 92: Rank of traced out density matrix: 5
# Eigenvector 93: Rank of traced out density matrix: 5
# Eigenvector 94: Rank of traced out density matrix: 5
# Eigenvector 95: Rank of traced out density matrix: 5
# Eigenvector 96: Rank of traced out density matrix: 5
# Eigenvector 97: Rank of traced out density matrix: 5
# Eigenvector 98: Rank of traced out density matrix: 5
# Eigenvector 99: Rank of traced out density matrix: 5
# Eigenvector 100: Rank of traced out density matrix: 5
# Eigenvector 101: Rank of traced out density matrix: 5
# Eigenvector 102: Rank of traced out density matrix: 5
# Eigenvector 103: Rank of traced out density matrix: 5
# Eigenvector 104: Rank of traced out density matrix: 5
# Eigenvector 105: Rank of traced out density matrix: 5
# Eigenvector 106: Rank of traced out density matrix: 5
# Eigenvector 107: Rank of traced out density matrix: 5
# Eigenvector 108: Rank of traced out density matrix: 5
# Eigenvector 109: Rank of traced out density matrix: 5
# Eigenvector 110: Rank of traced out density matrix: 5
# Eigenvector 111: Rank of traced out density matrix: 5
# Eigenvector 112: Rank of traced out density matrix: 5
# Eigenvector 113: Rank of traced out density matrix: 5
# Eigenvector 114: Rank of traced out density matrix: 5
# Eigenvector 115: Rank of traced out density matrix: 5
# Eigenvector 116: Rank of traced out density matrix: 5
# Eigenvector 117: Rank of traced out density matrix: 5
# Eigenvector 118: Rank of traced out density matrix: 5
# Eigenvector 119: Rank of traced out density matrix: 5
# Eigenvector 120: Rank of traced out density matrix: 5
# Eigenvector 121: Rank of traced out density matrix: 5
# Eigenvector 122: Rank of traced out density matrix: 5
# Eigenvector 123: Rank of traced out density matrix: 5
# Eigenvector 124: Rank of traced out density matrix: 5
# Eigenvector 125: Rank of traced out density matrix: 5
# Eigenvector 126: Rank of traced out density matrix: 5
# Eigenvector 127: Rank of traced out density matrix: 5
# Eigenvector 128: Rank of traced out density matrix: 5
# Eigenvector 129: Rank of traced out density matrix: 5
# Eigenvector 130: Rank of traced out density matrix: 5
# Eigenvector 131: Rank of traced out density matrix: 5
# Eigenvector 132: Rank of traced out density matrix: 5
# Eigenvector 133: Rank of traced out density matrix: 5
# Eigenvector 134: Rank of traced out density matrix: 5
# Eigenvector 135: Rank of traced out density matrix: 5
# Eigenvector 136: Rank of traced out density matrix: 5
# Eigenvector 137: Rank of traced out density matrix: 5
# Eigenvector 138: Rank of traced out density matrix: 5
# Eigenvector 139: Rank of traced out density matrix: 5
# Eigenvector 140: Rank of traced out density matrix: 5
# Eigenvector 141: Rank of traced out density matrix: 5
# Eigenvector 142: Rank of traced out density matrix: 5
# Eigenvector 143: Rank of traced out density matrix: 5
# Eigenvector 144: Rank of traced out density matrix: 5
# Eigenvector 145: Rank of traced out density matrix: 5
# Eigenvector 146: Rank of traced out density matrix: 5
# Eigenvector 147: Rank of traced out density matrix: 5
# Eigenvector 148: Rank of traced out density matrix: 5
# Eigenvector 149: Rank of traced out density matrix: 5
# Eigenvector 150: Rank of traced out density matrix: 5
# Eigenvector 151: Rank of traced out density matrix: 5
# Eigenvector 152: Rank of traced out density matrix: 5
# Eigenvector 153: Rank of traced out density matrix: 5
# Eigenvector 154: Rank of traced out density matrix: 5
# Eigenvector 155: Rank of traced out density matrix: 5
# Eigenvector 156: Rank of traced out density matrix: 5
# Eigenvector 157: Rank of traced out density matrix: 5
# Eigenvector 158: Rank of traced out density matrix: 5
# Eigenvector 159: Rank of traced out density matrix: 5
# Eigenvector 160: Rank of traced out density matrix: 5
# Eigenvector 161: Rank of traced out density matrix: 5
# Eigenvector 162: Rank of traced out density matrix: 5
# Eigenvector 163: Rank of traced out density matrix: 5
# Eigenvector 164: Rank of traced out density matrix: 5
# Eigenvector 165: Rank of traced out density matrix: 5
# Eigenvector 166: Rank of traced out density matrix: 5
# Eigenvector 167: Rank of traced out density matrix: 5
# Eigenvector 168: Rank of traced out density matrix: 5
# Eigenvector 169: Rank of traced out density matrix: 5
# Eigenvector 170: Rank of traced out density matrix: 5
# Eigenvector 171: Rank of traced out density matrix: 5
# Eigenvector 172: Rank of traced out density matrix: 5
# Eigenvector 173: Rank of traced out density matrix: 5
# Eigenvector 174: Rank of traced out density matrix: 5
# Eigenvector 175: Rank of traced out density matrix: 5
# Eigenvector 176: Rank of traced out density matrix: 5
# Eigenvector 177: Rank of traced out density matrix: 5
# Eigenvector 178: Rank of traced out density matrix: 5
# Eigenvector 179: Rank of traced out density matrix: 5
# Eigenvector 180: Rank of traced out density matrix: 5
# Eigenvector 181: Rank of traced out density matrix: 5
# Eigenvector 182: Rank of traced out density matrix: 5
# Eigenvector 183: Rank of traced out density matrix: 5
# Eigenvector 184: Rank of traced out density matrix: 5
# Eigenvector 185: Rank of traced out density matrix: 5
# Eigenvector 186: Rank of traced out density matrix: 5
# Eigenvector 187: Rank of traced out density matrix: 5
# Eigenvector 188: Rank of traced out density matrix: 5
# Eigenvector 189: Rank of traced out density matrix: 5
# Eigenvector 190: Rank of traced out density matrix: 5
# Eigenvector 191: Rank of traced out density matrix: 5
# Eigenvector 192: Rank of traced out density matrix: 5
# Eigenvector 193: Rank of traced out density matrix: 5
# Eigenvector 194: Rank of traced out density matrix: 5
# Eigenvector 195: Rank of traced out density matrix: 5
# Eigenvector 196: Rank of traced out density matrix: 5
# Eigenvector 197: Rank of traced out density matrix: 5
# Eigenvector 198: Rank of traced out density matrix: 5
# Eigenvector 199: Rank of traced out density matrix: 5
# Eigenvector 200: Rank of traced out density matrix: 5
# Eigenvector 201: Rank of traced out density matrix: 5
# Eigenvector 202: Rank of traced out density matrix: 5
# Eigenvector 203: Rank of traced out density matrix: 5
# Eigenvector 204: Rank of traced out density matrix: 5
# Eigenvector 205: Rank of traced out density matrix: 5
# Eigenvector 206: Rank of traced out density matrix: 5
# Eigenvector 207: Rank of traced out density matrix: 5
# Eigenvector 208: Rank of traced out density matrix: 5
# Eigenvector 209: Rank of traced out density matrix: 5
# Eigenvector 210: Rank of traced out density matrix: 5
# Eigenvector 211: Rank of traced out density matrix: 5
# Eigenvector 212: Rank of traced out density matrix: 5
# Eigenvector 213: Rank of traced out density matrix: 5
# Eigenvector 214: Rank of traced out density matrix: 5
# Eigenvector 215: Rank of traced out density matrix: 5
# Eigenvector 216: Rank of traced out density matrix: 5
# Eigenvector 217: Rank of traced out density matrix: 5
# Eigenvector 218: Rank of traced out density matrix: 5
# Eigenvector 219: Rank of traced out density matrix: 5
# Eigenvector 220: Rank of traced out density matrix: 5
# Eigenvector 221: Rank of traced out density matrix: 5
# Eigenvector 222: Rank of traced out density matrix: 5
# Eigenvector 223: Rank of traced out density matrix: 5
# Eigenvector 224: Rank of traced out density matrix: 5
# Eigenvector 225: Rank of traced out density matrix: 5
# Eigenvector 226: Rank of traced out density matrix: 5
# Eigenvector 227: Rank of traced out density matrix: 5
# Eigenvector 228: Rank of traced out density matrix: 5
# Eigenvector 229: Rank of traced out density matrix: 5
# Eigenvector 230: Rank of traced out density matrix: 5
# Eigenvector 231: Rank of traced out density matrix: 5
# Eigenvector 232: Rank of traced out density matrix: 5
# Eigenvector 233: Rank of traced out density matrix: 5
# Eigenvector 234: Rank of traced out density matrix: 5
# Eigenvector 235: Rank of traced out density matrix: 5
# Eigenvector 236: Rank of traced out density matrix: 5
# Eigenvector 237: Rank of traced out density matrix: 5
# Eigenvector 238: Rank of traced out density matrix: 5
# Eigenvector 239: Rank of traced out density matrix: 5
# Eigenvector 240: Rank of traced out density matrix: 5
# Eigenvector 241: Rank of traced out density matrix: 5
# Eigenvector 242: Rank of traced out density matrix: 5
# Eigenvector 243: Rank of traced out density matrix: 5
# Eigenvector 244: Rank of traced out density matrix: 5
# Eigenvector 245: Rank of traced out density matrix: 5
# Eigenvector 246: Rank of traced out density matrix: 5
# Eigenvector 247: Rank of traced out density matrix: 5
# Eigenvector 248: Rank of traced out density matrix: 5
# Eigenvector 249: Rank of traced out density matrix: 5
# Eigenvector 250: Rank of traced out density matrix: 5
# Eigenvector 251: Rank of traced out density matrix: 5
# Eigenvector 252: Rank of traced out density matrix: 5
# Eigenvector 253: Rank of traced out density matrix: 5
# Eigenvector 254: Rank of traced out density matrix: 5
# Eigenvector 255: Rank of traced out density matrix: 5
# Eigenvector 256: Rank of traced out density matrix: 5
# Eigenvector 257: Rank of traced out density matrix: 5
# Eigenvector 258: Rank of traced out density matrix: 5
# Eigenvector 259: Rank of traced out density matrix: 5
# Eigenvector 260: Rank of traced out density matrix: 5
# Eigenvector 261: Rank of traced out density matrix: 5
# Eigenvector 262: Rank of traced out density matrix: 5
# Eigenvector 263: Rank of traced out density matrix: 5
# Eigenvector 264: Rank of traced out density matrix: 5
# Eigenvector 265: Rank of traced out density matrix: 5
# Eigenvector 266: Rank of traced out density matrix: 5
# Eigenvector 267: Rank of traced out density matrix: 5
# Eigenvector 268: Rank of traced out density matrix: 5
# Eigenvector 269: Rank of traced out density matrix: 5
# Eigenvector 270: Rank of traced out density matrix: 5
# Eigenvector 271: Rank of traced out density matrix: 5
# Eigenvector 272: Rank of traced out density matrix: 5
# Eigenvector 273: Rank of traced out density matrix: 5
# Eigenvector 274: Rank of traced out density matrix: 5
# Eigenvector 275: Rank of traced out density matrix: 5
# Eigenvector 276: Rank of traced out density matrix: 5
# Eigenvector 277: Rank of traced out density matrix: 5
# Eigenvector 278: Rank of traced out density matrix: 5
# Eigenvector 279: Rank of traced out density matrix: 5
# Eigenvector 280: Rank of traced out density matrix: 5
# Eigenvector 281: Rank of traced out density matrix: 5
# Eigenvector 282: Rank of traced out density matrix: 5
# Eigenvector 283: Rank of traced out density matrix: 5
# Eigenvector 284: Rank of traced out density matrix: 5
# Eigenvector 285: Rank of traced out density matrix: 5
# Eigenvector 286: Rank of traced out density matrix: 5
# Eigenvector 287: Rank of traced out density matrix: 5
# Eigenvector 288: Rank of traced out density matrix: 5
# Eigenvector 289: Rank of traced out density matrix: 5
# Eigenvector 290: Rank of traced out density matrix: 5
# Eigenvector 291: Rank of traced out density matrix: 5
# Eigenvector 292: Rank of traced out density matrix: 5
# Eigenvector 293: Rank of traced out density matrix: 5
# Eigenvector 294: Rank of traced out density matrix: 5
# Eigenvector 295: Rank of traced out density matrix: 5
# Eigenvector 296: Rank of traced out density matrix: 5
# Eigenvector 297: Rank of traced out density matrix: 5
# Eigenvector 298: Rank of traced out density matrix: 5
# Eigenvector 299: Rank of traced out density matrix: 5
# Eigenvector 300: Rank of traced out density matrix: 5
# Eigenvector 301: Rank of traced out density matrix: 5
# Eigenvector 302: Rank of traced out density matrix: 5
# Eigenvector 303: Rank of traced out density matrix: 5
# Eigenvector 304: Rank of traced out density matrix: 5
# Eigenvector 305: Rank of traced out density matrix: 5
# Eigenvector 306: Rank of traced out density matrix: 5
# Eigenvector 307: Rank of traced out density matrix: 5
# Eigenvector 308: Rank of traced out density matrix: 5
# Eigenvector 309: Rank of traced out density matrix: 5
# Eigenvector 310: Rank of traced out density matrix: 5
# Eigenvector 311: Rank of traced out density matrix: 5
# Eigenvector 312: Rank of traced out density matrix: 5
# Eigenvector 313: Rank of traced out density matrix: 5
# Eigenvector 314: Rank of traced out density matrix: 5
# Eigenvector 315: Rank of traced out density matrix: 5
# Eigenvector 316: Rank of traced out density matrix: 5
# Eigenvector 317: Rank of traced out density matrix: 5
# Eigenvector 318: Rank of traced out density matrix: 5
# Eigenvector 319: Rank of traced out density matrix: 5
# Eigenvector 320: Rank of traced out density matrix: 5
# Eigenvector 321: Rank of traced out density matrix: 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 4
#       1 # Compute the rank of the RDM for all points
#       3 for i in range(2**n_spins):
# ----> 4     full_hilbert_space_vector = full_hilbert_space_eigenvectors[:, i]
#       6     # Construct the density matrix
#       7     density_matrix = np.outer(full_hilbert_space_vector, full_hilbert_space_vector.conj())
#
# IndexError: index 322 is out of bounds for axis 1 with size 322
