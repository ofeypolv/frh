# %%
import numpy as np
from scipy.linalg import eigh, qr, null_space
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from scipy.sparse import kron, identity, csr_matrix, lil_matrix, dok_matrix
from scipy.sparse.linalg import eigsh, eigs
from scipy.optimize import curve_fit
from qutip import Qobj, ptrace, entropy_vn, qeye, tensor
from tqdm import tqdm
from itertools import product
from functools import reduce
import torch
import torch.optim as optim
from torch.autograd import Variable
import sympy as sp
from collections import Counter

# %%
def pauli_x():
    """Pauli X matrix."""
    return np.array([[0, 1], [1, 0]])

def pauli_z():
    """Pauli Z matrix."""
    return np.array([[1, 0], [0, -1]])

def icosahedral_bonds(): #12 vertices
    """
    Defines the connectivity of a true 12-vertex icosahedral molecular structure.
    
    Returns:
        list of tuples: Each tuple (i, j) represents a bond between spin i and spin j.
    """
    bonds = [
        (0, 2), (0, 4), (0, 5), (0, 8), (0, 9),
        (1, 3), (1, 6), (1, 7), (1, 10), (1, 11),
        (2, 6), (2, 7), (2, 8), (2, 9), (3, 4),
        (3, 5), (3, 10), (3, 11), (4, 5), (4, 8),
        (4, 10), (5, 9), (5, 11), (6, 7), (6, 8),
        (6, 10), (7, 9), (7, 11), (8, 10), (9, 11)
    ]
    return bonds

def icosahedral_bonds_next():
    """
    Defines the next nn connectivity of a true 12-vertex icosahedral molecular structure.
    
    Returns:
        list of tuples: Each tuple (i, j) represents a next nn bond between spin i and spin j.
    """
    bonds = [
        (0, 3), (0, 6), (0, 7), (0, 10), (0, 11),
        (1, 2), (1, 4), (1, 5), (1, 8), (1, 9),
        (2, 4), (2, 5), (2, 10), (2, 11), (3, 6),
        (3, 7), (3, 8), (3, 9), (4, 6), (4, 9),
        (4, 11), (5, 7), (5, 8), (5, 10), (6, 9),
        (6, 11), (7, 8), (7, 10), (8, 9), (10, 11)
    ]
    return bonds


def transverse_field_ising_icosahedral(N, J, h): #, bonds=None):
    """
    Constructs the Hamiltonian for the transverse field Ising model on an icosahedral molecular structure.
    
    Parameters:
        N (int): Number of spins (should match the icosahedral molecule, typically N=20).
        J (float): Interaction strength.
        h (float): Transverse field strength.
    
    Returns:
        H (scipy.sparse.csr_matrix): The Hamiltonian matrix in sparse format.
    """
    if N != 12:
        raise ValueError("Icosahedral molecules typically have N = 12 sites.")

    # Sparse identity matrix
    I = identity(2, format="csr")
    
    # Pauli matrices as sparse matrices
    X = csr_matrix(pauli_x())
    Z = csr_matrix(pauli_z())
    
    # Initialize the Hamiltonian
    H = csr_matrix((2**N, 2**N), dtype=np.float64)
    
    #if bonds == "single":
    #    # Get single bonds
    #    bonds = icosahedral_bonds()
    #elif bonds == "double":
    #    # Get next nn bonds
    #    bonds = icosahedral_bonds_next()

    bonds = icosahedral_bonds() + icosahedral_bonds_next()
    
    # Interaction term: J * sigma_i^x * sigma_j^x for icosahedral connectivity
    for i, j in bonds:
        term = 1
        for k in range(N):
            if k == i or k == j:
                term = kron(term, X, format="csr")
            else:
                term = kron(term, I, format="csr")
        H += -J * term
    
    # Transverse field term: -h * sigma_i^z
    for i in range(N):
        term = 1
        for j in range(N):
            if j == i:
                term = kron(term, Z, format="csr")
            else:
                term = kron(term, I, format="csr")
        H += -h * term
    
    return H

#######################################################################################################################

'''
def partial_trace_qubit(rho, keep, dims):
    """Compute the partial trace of a density matrix of qubits."""
    keep_dims = np.prod([dims[i] for i in keep])
    trace_dims = np.prod([dims[i] for i in range(len(dims)) if i not in keep])
    rho = rho.reshape([keep_dims, trace_dims, keep_dims, trace_dims])
    return np.trace(rho, axis1=1, axis2=3).reshape([keep_dims, keep_dims])

def partial_trace_qubit_torch(rho, keep, dims):
    """Compute the partial trace of a density matrix of qubits using PyTorch."""
    keep_dims = torch.prod(torch.tensor([dims[i] for i in keep]))
    trace_dims = torch.prod(torch.tensor([dims[i] for i in range(len(dims)) if i not in keep]))
    rho = rho.view(keep_dims, trace_dims, keep_dims, trace_dims)
    # Compute the partial trace
    traced_rho = torch.zeros((keep_dims, keep_dims), dtype=rho.dtype)
    for i in range(trace_dims):
        traced_rho += rho[:, i, :, i]
    #return traced_rho.view(keep_dims, keep_dims)
    return traced_rho'''

def isket_numpy(arr):
    """
    Check if a NumPy array is a ket (column vector).

    Parameters:
    - arr: np.ndarray, the array to check.

    Returns:
    - bool, True if the array is a ket, False otherwise.
    """
    if not isinstance(arr, np.ndarray):
        raise ValueError("Input must be a NumPy array")

    shape = arr.shape

    if len(shape) == 2 and shape[1] == 1:
        return True
    else:
        return False

def ptrace_numpy(Q, sel, dims): # numpy function adapted from ptrace of qutip
    """
    Compute the partial trace of a density matrix of qubits using NumPy.

    Parameters:
    - Q: numpy object, the quantum object (density matrix or state vector).
    - sel: list of int, indices of the subsystems to keep.
    - dims: list of int, dimensions of the subsystems.

    Returns:
    - numpy object, the reduced density matrix after tracing out the specified subsystems.
    """
    # Get the dimensions of the subsystems
    rd = np.asarray(dims[0], dtype=np.int32).ravel()
    nd = len(rd)
    
    # Ensure sel is a sorted array of indices
    if isinstance(sel, int):
        sel = np.array([sel])
    else:
        sel = np.asarray(sel)
    sel = list(np.sort(sel))
    
    # Dimensions of the subsystems to keep
    dkeep = (rd[sel]).tolist()
    
    # Indices of the subsystems to trace out
    qtrace = list(set(np.arange(nd)) - set(sel))
    
    # Dimensions of the subsystems to trace out
    dtrace = (rd[qtrace]).tolist()
    
    # Reshape the density matrix or state vector
    rd = list(rd)
    if isket_numpy(Q):
        # Reshape and transpose for state vector
        vmat = (Q
                .reshape(rd)
                .transpose(sel + qtrace)
                .reshape([np.prod(dkeep), np.prod(dtrace)]))
        # Compute the reduced density matrix
        rhomat = vmat.dot(vmat.conj().T)
    else:
        # Reshape and transpose for density matrix
        rhomat = np.trace(Q
                          .reshape(rd + rd)
                          .transpose(qtrace + [nd + q for q in qtrace] +
                                     sel + [nd + q for q in sel])
                          .reshape([np.prod(dtrace),
                                    np.prod(dtrace),
                                    np.prod(dkeep),
                                    np.prod(dkeep)]))
    return rhomat

def isket_torch(arr):
    """
    Check if a PyTorch tensor is a ket (column vector).

    Parameters:
    - arr: torch.Tensor, the array to check.

    Returns:
    - bool, True if the array is a ket, False otherwise.
    """
    if not isinstance(arr, torch.Tensor):
        raise ValueError("Input must be a PyTorch tensor")

    shape = arr.shape

    if len(shape) == 2 and shape[1] == 1:
        return True
    else:
        return False

def ptrace_torch(Q, sel, dims): # torch function adapted from ptrace of qutip
    """
    Compute the partial trace of a density matrix of qubits using PyTorch.

    Parameters:
    - Q: torch.Tensor, the quantum object (density matrix or state vector).
    - sel: list of int, indices of the subsystems to keep.
    - dims: list of int, dimensions of the subsystems.

    Returns:
    - torch.Tensor, the reduced density matrix after tracing out the specified subsystems.
    """
    # Get the dimensions of the subsystems
    rd = torch.tensor(dims[0], dtype=torch.int32).flatten()
    nd = len(rd)
    #print("rd", rd)
    #print("nd", nd)
    
    # Ensure sel is a sorted array of indices
    if isinstance(sel, int):
        sel = torch.tensor([sel])
    else:
        sel = torch.tensor(sel)
    sel = torch.sort(sel).values.tolist()
    
    # Dimensions of the subsystems to keep
    dkeep = rd[sel].tolist()
    
    # Indices of the subsystems to trace out
    qtrace = list(set(range(nd)) - set(sel))
    
    # Dimensions of the subsystems to trace out
    dtrace = rd[qtrace].tolist()
    
    # Reshape the density matrix or state vector
    rd = rd.tolist()
    if isket_torch(Q):
        # Reshape and transpose for state vector
        reshaped_Q = Q.reshape(rd)
        #print(reshaped_Q.shape)
        transposed_Q = reshaped_Q.permute(sel + qtrace)
        #print(transposed_Q.shape)
        vmat = transposed_Q.reshape([torch.prod(torch.tensor(dkeep)), torch.prod(torch.tensor(dtrace))])
        #print(vmat.shape)
        # Compute the reduced density matrix
        rhomat = vmat @ vmat.conj().T
        #print(rhomat.shape)
    else:
        # Reshape and transpose for density matrix
        reshaped_Q = Q.reshape(rd + rd)
        #print("reshaped_Q", reshaped_Q.shape)
        transposed_Q = reshaped_Q.permute(qtrace + [nd + q for q in qtrace] + sel + [nd + q for q in sel])
        #print("transposed_Q", transposed_Q.shape)
        reshaped_transposed_Q = transposed_Q.reshape([torch.prod(torch.tensor(dtrace)), torch.prod(torch.tensor(dtrace)), torch.prod(torch.tensor(dkeep)), torch.prod(torch.tensor(dkeep))])
        #print("reshaped_transposed_Q", reshaped_transposed_Q.shape)
        #rhomat = torch.trace(reshaped_transposed_Q)
        rhomat = torch.einsum('iikl->kl', reshaped_transposed_Q)
        # Trace out the first two dimensions
        #rhomat = torch.zeros((torch.prod(torch.tensor(dkeep)), torch.prod(torch.tensor(dkeep))), dtype=Q.dtype)
        #for i in range(reshaped_transposed_Q.shape[0]):
        #    for j in range(reshaped_transposed_Q.shape[1]):
        #        rhomat += reshaped_transposed_Q[i, j, :, :]
        #print("rhomat", rhomat.shape)
    return rhomat

def entanglement_entropy(psi, subsystem_size, total_size):

    '''Computes the bipartite entanglement entropy of a pure state.
    
    Parameters:
    psi : np.array
        The wavefunction (state vector) of the full system.
    subsystem_size : int
        The number of qubits in subsystem A.
    total_size : int
        The total number of qubits in the system.
    
    Returns:
    float
        The von Neumann entanglement entropy S_A.'''
    
    psi_matrix =  np.outer(psi, psi.conj())

    # Compute the reduced density matrix rho_A = Tr_B(|psi><psi|)
    rho_A = ptrace_numpy(psi_matrix, list(range(subsystem_size)), [[2]*total_size, [2]*total_size])  # Partial trace over B
    
    # Compute eigenvalues of rho_A
    eigenvalues = np.linalg.eigvalsh(rho_A)
    
    # Filter out zero eigenvalues to avoid numerical issues in log calculation
    eigenvalues = eigenvalues[eigenvalues > 0]
    
    # Compute von Neumann entropy S_A = -Tr(rho_A log rho_A)
    entropy = -np.sum(eigenvalues * np.log2(eigenvalues))
    
    return entropy

def entanglement_entropy_torch(psi, subsystem_size, total_size):
    """
    Computes the bipartite entanglement entropy of a pure state using PyTorch.

    Parameters:
    - psi: torch.Tensor (complex), the wavefunction (state vector) of the full system.
    - subsystem_size: int, the number of qubits in subsystem A.
    - total_size: int, the total number of qubits in the system.

    Returns:
    - torch.Tensor (scalar), the von Neumann entanglement entropy S_A.
    """

    if not isinstance(psi, torch.Tensor):
        psi = torch.tensor(psi, dtype=torch.complex64)
    
    # Ensure psi is normalized
    psi = psi / torch.norm(psi)

    # Compute the density matrix |psi><psi|
    psi_matrix = torch.outer(psi, psi.conj())

    # Compute the reduced density matrix rho_A = Tr_B(|psi><psi|)
    rho_A = ptrace_torch(psi_matrix, list(range(subsystem_size)), [[2] * total_size, [2] * total_size])  # Partial trace over B

    #rho_A = rho_A.to(dtype=torch.float64)
    
    # Compute eigenvalues of rho_A
    eigvals = torch.linalg.eigvalsh(rho_A)

    # Filter out zero eigenvalues to avoid numerical issues in log calculation
    eigvals = eigvals[eigvals > 0]

    # Compute von Neumann entropy S_A = -Tr(rho_A log rho_A)
    entropy = -torch.sum(eigvals * torch.log2(eigvals))

    return entropy


def entanglement_entropy_qutip(psi, subsystem_size, total_size):
    
    # Convert the wavefunction to a QuTiP Qobj
    density_matrix = np.outer(psi, psi.conj())
    density_matrix_qobj = Qobj(density_matrix, dims=[[2]*total_size, [2]*total_size])

    rho_A = ptrace(density_matrix_qobj, list(range(subsystem_size)))
    # Compute the von Neumann entropy S_A
    entropy = entropy_vn(rho_A, base=2)
    
    return entropy

def entanglement_entropy_np_ptrace(rdm):
    # rdm already computed and converted to numpy
    # Compute eigenvalues of rho_A
    eigenvalues = np.linalg.eigvalsh(rdm)
    
    # Filter out zero eigenvalues to avoid numerical issues in log calculation
    eigenvalues = eigenvalues[eigenvalues > 0]
    
    # Compute von Neumann entropy S_A = -Tr(rho_A log rho_A)
    entropy = -np.sum(eigenvalues * np.log2(eigenvalues))
    
    return entropy

def entanglement_entropy_torch_ptrace(rdm):

    eigvals = torch.linalg.eigvalsh(rdm)
    eigvals = eigvals[eigvals > 0]
    entropy = -torch.sum(eigvals * torch.log2(eigvals))
    return entropy


def entanglement_entropy_qutip_torch(psi, N):
    """
    Compute the von Neumann entanglement entropy using qutip.

    Parameters:
    - psi: torch.Tensor (complex), state vector of a quantum system.
    - N: int, total number of qubits.

    Returns:
    - torch.Tensor (scalar), von Neumann entropy.
    """
    # Ensure psi is normalized
    psi = psi / torch.norm(psi)

    # Convert PyTorch tensor to NumPy for QuTiP
    psi_np = psi.detach().numpy()

    rho_np = np.outer(psi_np, psi_np.conj())
    rho_qobj = Qobj(rho_np, dims=[[2] * N, [2] * N])

    rho_A = ptrace(rho_qobj, list(range(N // 2)))

    # Compute von Neumann entropy
    entropy = entropy_vn(rho_A, base=2)  # Compute in log base 2

    # Convert back to PyTorch tensor to allow gradient flow
    return torch.tensor(entropy, dtype=torch.float32, requires_grad=True)

#######################################################################################################################

# Define the linear combination function - numpy
def linear_combination_np(coeffs, psis):
    # Ensure psis are numpy tensors
    psi_np = [np.array(psi) for psi in psis]
    # Compute the linear combination in PyTorch
    psi = sum(c * psi for c, psi in zip(coeffs, psis))
    
    return psi

# Define the linear combination function - torch
def linear_combination(coeffs, psis):
    # Ensure psis are PyTorch tensors
    psis_torch = [torch.tensor(psi, dtype=torch.complex64) if not isinstance(psi, torch.Tensor) else psi for psi in psis]
    
    # Compute the linear combination in PyTorch
    psi_torch = sum(c * psi for c, psi in zip(coeffs, psis_torch))
    
    return psi_torch

# Define the linear combination function - torch but after computing the ptrace of outer products of scars
def linear_combination_outer(coeffs, outs):
    # Ensure outs are PyTorch tensors
    outs_torch = [torch.tensor(out, dtype=torch.complex64) if not isinstance(out, torch.Tensor) else out for out in outs]
    torch_coeffs = torch.tensor(coeffs, dtype=torch.complex64)

    # Compute the PyTorch tensor of out_coeffs which is the product of all possible combinations of c_i^* times c_j
    out_coeffs = torch.zeros((len(torch_coeffs), len(torch_coeffs)), dtype=torch.complex64)
    for i in range(len(torch_coeffs)):
        for j in range(len(torch_coeffs)):
            out_coeffs[i, j] = torch.conj(torch_coeffs[i]) * torch_coeffs[j]
    
    # Compute the linear combination in PyTorch
    lin_torch = sum(out_coeffs[i, j] * outs_torch[i] for i in range(len(coeffs)) for j in range(len(coeffs)))
    
    return lin_torch

######################################################

# Function to apply permutation to a given spin configuration
def apply_permutation(state_bits, N, perm):
    new_bits = [0] * N
    for i in range(N):
        new_bits[perm[i]] = state_bits[i]  # Map value at index i to perm[i]
    return new_bits

# Function to convert an index to its binary representation
def index_to_binary(index, num_qubits):
    return format(index, f'0{num_qubits}b')

# %%
N = 12  # Number of spins
J = 1.0  # Interaction strength
h = 3.0  # Transverse field strength # this is the value in the paper. maybe try  other values too, including the critical value one (h=J=1)

#bonds = "double"  # Use "single" for nearest neighbors, "double" for next nearest neighbors

#keep_qubits = [0, 4]
#keep_qubits = [0, 4, 5, 11] # 4 spins rdm full rank
#keep_qubits = [0, 4, 5, 9]  # 4 spins - 2 adjacent triangular plaquettes - this is when i observe exactly 5 degenerate scars
#keep_qubits = [3, 5, 7, 9, 11]  # 5 spins - 3 adjacent triangular plaquettes
keep_qubits = [0, 4, 5, 9, 11]  # 5 spins - 3 adjacent triangular plaquettes
#keep_qubits = [2, 8, 4, 5, 9] # 5 spins - pentagon around 0



# Assuming transverse_field_ising is defined and returns a sparse Hermitian matrix
H = transverse_field_ising_icosahedral(N, J, h) #, bonds=bonds)

#print(f"Hamiltonian shape: {H.shape}")
#print(f"Non-zero elements in H: {H.nnz}")

# Define the C5 permutation mapping for your case - around axis through vert 9 and 10
perm = {
    0: 2,
    2: 7,
    7: 11,
    11: 5,
    5: 0,
    1: 3,
    3: 4,
    4: 8,
    8: 6,
    6: 1,
    9: 9,   # Fixed
    10: 10  # Fixed
}

# %%
# All eigenvalues of H
# Compute all eigenvalues and corresponding eigenvectors
eigenvalues, eigenvectors = np.linalg.eigh(H.toarray())

print(f"Eigenvalues of H: {np.sort(eigenvalues)}")
# Out:
# Eigenvalues of H: [-65.41457401 -65.4142424  -46.92136085 ...  33.99626906  33.99626906
#   38.51803362]

# %%
##################### RDMS + EE #################################

# %%
'''# rdm - qutip

min_eigenvalues = []
min_rdms = []
rdm_eigenvalues = []

for i in tqdm(range(len(eigenvalues))):
    # Construct the density matrix for each eigenvector
    min_eigenvector = eigenvectors[:, i]
    density_matrix = np.outer(min_eigenvector, min_eigenvector.conj())
    density_matrix_qobj = Qobj(density_matrix, dims=[[2]*N, [2]*N])

    # Trace out qubits
    traced_out_density_matrix = ptrace(density_matrix_qobj, keep_qubits)

    # Convert the result back to a dense matrix if needed
    traced_out_density_matrix_dense = traced_out_density_matrix.full()
    # Check if the rank is not full and print it
    rank = np.linalg.matrix_rank(traced_out_density_matrix_dense)
    if rank < traced_out_density_matrix_dense.shape[0]:
        print(f"Traced-out density matrix rank: {rank}")
    # Diagonalize the traced-out density matrix
    eigenvalues_traced, eigenvectors_traced = np.linalg.eigh(traced_out_density_matrix_dense)

    # Find the minimum eigenvalue of the traced-out density matrix
    min_eigenvalue = np.min(eigenvalues_traced) 
    min_eigenvalues.append(min_eigenvalue)

    if min_eigenvalue < 1e-16:
      min_rdms.append(traced_out_density_matrix_dense) #store the scarred rdms - step needed for optimization
      rdm_eigenvalues.append(eigenvalues_traced) #store the eigenvalues of the scarred rdms# Define the threshold - qutip
threshold = 1e-16
min_eigenvalues = np.array(min_eigenvalues)

# Count points with y-component less than the threshold
count = sum(1 for y in min_eigenvalues if y < threshold)

# Highlight points with y-component less than the threshold in red
colors = ['red' if y < threshold else 'C0' for y in min_eigenvalues]

# Plot the minimum eigenvalue of the traced-out density matrix as a function of the eigenvalue of the Hamiltonian H
plt.scatter(eigenvalues, np.abs(min_eigenvalues), color=colors, s=1)

plt.xlabel('Eigenvalue of H')
plt.ylabel(r"$\lambda_{\text{min}}$")
plt.yscale("log")
plt.show()

# Find indices of red points - qutip
red_indices = [i for i, y in enumerate(min_eigenvalues) if y < threshold]
print(f'Indices of red points: {red_indices}')

red_eigenvectors = []

# Print eigenvalues, RDM minimum eigenvalues, and scalar products of eigenvectors for red points
for i,ind in enumerate(red_indices):
    print(i, ind)
    print(f'Eigenvalue: {eigenvalues[ind]}, rdm Minimum Eigenvalue: {min_eigenvalues[ind]}')
    print(f'Eigenvector {ind}: rdm rank: {np.linalg.matrix_rank(min_rdms[i])}')
    red_eigenvectors.append(eigenvectors[:, ind])

for i in range(len(red_indices)):
    for j in range(len(red_indices)):
        idx1, idx2 = red_indices[i], red_indices[j]
        dot_product = np.dot(eigenvectors[:, idx1], np.conj(eigenvectors[:, idx2]))
        print(f"Dot product between eigenvectors {idx1} and {idx2}: {dot_product}")

# Count entries of rdm_eigenvalues[i] - eigenvalues of the scarred rdms - that are non-zero
counts = [np.sum(eigenvalues > 1e-16) for eigenvalues in rdm_eigenvalues]
print(f'Counts of non-zero eigenvalues of the scarred rdms: {counts}')'''
# Out:
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# <>:45: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\camip\AppData\Local\Temp\ipykernel_12308\734414245.py:45: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel(r"$\lambda_{\text{min}}$")
# '# rdm - qutip\n\nmin_eigenvalues = []\nmin_rdms = []\nrdm_eigenvalues = []\n\nfor i in tqdm(range(len(eigenvalues))):\n    # Construct the density matrix for each eigenvector\n    min_eigenvector = eigenvectors[:, i]\n    density_matrix = np.outer(min_eigenvector, min_eigenvector.conj())\n    density_matrix_qobj = Qobj(density_matrix, dims=[[2]*N, [2]*N])\n\n    # Trace out qubits\n    traced_out_density_matrix = ptrace(density_matrix_qobj, keep_qubits)\n\n    # Convert the result back to a dense matrix if needed\n    traced_out_density_matrix_dense = traced_out_density_matrix.full()\n    # Check if the rank is not full and print it\n    rank = np.linalg.matrix_rank(traced_out_density_matrix_dense)\n    if rank < traced_out_density_matrix_dense.shape[0]:\n        print(f"Traced-out density matrix rank: {rank}")\n    # Diagonalize the traced-out density matrix\n    eigenvalues_traced, eigenvectors_traced = np.linalg.eigh(traced_out_density_matrix_dense)\n\n    # Find the minimum eigenvalue of the traced-out density matrix\n    min_eigenvalue = np.min(eigenvalues_traced) \n    min_eigenvalues.append(min_eigenvalue)\n\n    if min_eigenvalue < 1e-16:\n      min_rdms.append(traced_out_density_matrix_dense) #store the scarred rdms - step needed for optimization\n      rdm_eigenvalues.append(eigenvalues_traced) #store the eigenvalues of the scarred rdms# Define the threshold - qutip\nthreshold = 1e-16\nmin_eigenvalues = np.array(min_eigenvalues)\n\n# Count points with y-component less than the threshold\ncount = sum(1 for y in min_eigenvalues if y < threshold)\n\n# Highlight points with y-component less than the threshold in red\ncolors = [\'red\' if y < threshold else \'C0\' for y in min_eigenvalues]\n\n# Plot the minimum eigenvalue of the traced-out density matrix as a function of the eigenvalue of the Hamiltonian H\nplt.scatter(eigenvalues, np.abs(min_eigenvalues), color=colors, s=1)\n\nplt.xlabel(\'Eigenvalue of H\')\nplt.ylabel(r"$\\lambda_{\text{min}}$")\nplt.yscale("log")\nplt.show()\n\n# Find indices of red points - qutip\nred_indices = [i for i, y in enumerate(min_eigenvalues) if y < threshold]\nprint(f\'Indices of red points: {red_indices}\')\n\nred_eigenvectors = []\n\n# Print eigenvalues, RDM minimum eigenvalues, and scalar products of eigenvectors for red points\nfor i,ind in enumerate(red_indices):\n    print(i, ind)\n    print(f\'Eigenvalue: {eigenvalues[ind]}, rdm Minimum Eigenvalue: {min_eigenvalues[ind]}\')\n    print(f\'Eigenvector {ind}: rdm rank: {np.linalg.matrix_rank(min_rdms[i])}\')\n    red_eigenvectors.append(eigenvectors[:, ind])\n\nfor i in range(len(red_indices)):\n    for j in range(len(red_indices)):\n        idx1, idx2 = red_indices[i], red_indices[j]\n        dot_product = np.dot(eigenvectors[:, idx1], np.conj(eigenvectors[:, idx2]))\n        print(f"Dot product between eigenvectors {idx1} and {idx2}: {dot_product}")\n\n# Count entries of rdm_eigenvalues[i] - eigenvalues of the scarred rdms - that are non-zero\ncounts = [np.sum(eigenvalues > 1e-16) for eigenvalues in rdm_eigenvalues]\nprint(f\'Counts of non-zero eigenvalues of the scarred rdms: {counts}\')'

# %%
# rdm - numpy

min_eigenvalues_np = []
min_rdms_np = []
rdm_eigenvalues_np = []

for i in tqdm(range(len(eigenvalues))):
    # Construct the density matrix for each eigenvector
    min_eigenvector = eigenvectors[:, i]
    density_matrix = np.outer(min_eigenvector, min_eigenvector.conj())

    # Trace out qubits
    traced_out_density_matrix = ptrace_numpy(density_matrix, keep_qubits, [[2]*N, [2]*N])

    # Diagonalize the traced-out density matrix
    eigenvalues_traced, eigenvectors_traced = np.linalg.eigh(traced_out_density_matrix)

    # Find the minimum eigenvalue of the traced-out density matrix
    min_eigenvalue = np.min(eigenvalues_traced) 
    min_eigenvalues_np.append(min_eigenvalue)

    if min_eigenvalue < 1e-16:
        min_rdms_np.append(traced_out_density_matrix) #store the scarred rdms - step needed for optimization
        rdm_eigenvalues_np.append(eigenvalues_traced) #store the eigenvalues of the scarred rdms
# Out:
# 100%|██████████| 4096/4096 [07:53<00:00,  8.66it/s]

# %%
# Create a dictionary to store arrays of min_rdms_np for each unique non-full rank value
min_rdms_by_rank = {}

# Compute the rank for each RDM in min_rdms_np
red_ranks = [np.linalg.matrix_rank(rdm) for rdm in min_rdms_np]

# For each unique non-full rank, collect the corresponding RDMs
for rank in set(red_ranks):
    min_rdms_by_rank[rank] = [rdm for rdm, r in zip(min_rdms_np, red_ranks) if r == rank]

# Now min_rdms_by_rank[rank] is a list of RDMs with that rank
for rank, rdms in min_rdms_by_rank.items():
    print(f"Rank {rank}: {len(rdms)} RDMs")
# Out:
# Rank 26: 5 RDMs
# Rank 30: 150 RDMs

# %%
# numpy

# Define the threshold
threshold = 1e-16
min_eigenvalues_np = np.array(min_eigenvalues_np)

# Find indices of non-full-rank points (min_eigenvalue < threshold)
red_indices_np = [i for i, y in enumerate(min_eigenvalues_np) if y < threshold]
print(f'Indices of non-full-rank points: {red_indices_np}')

# Compute ranks for each non-full-rank RDM
red_ranks = [np.linalg.matrix_rank(rdm) for rdm in min_rdms_np]
if red_ranks:
    min_rank = min(red_ranks)
    other_ranks = sorted(set(red_ranks) - {min_rank})
else:
    min_rank = None
    other_ranks = []

# Save indices for each unique non-full rank (including min_rank)
rank_to_indices = {}
for idx, rank in enumerate(red_ranks):
    if rank not in rank_to_indices:
        rank_to_indices[rank] = []
    rank_to_indices[rank].append(red_indices_np[idx])

print("Indices for each non-full rank:")
for rank, indices in rank_to_indices.items():
    print(f"Rank {rank}: {len(rank_to_indices[rank])} states with indices {indices}")

# Build color list for all points:
# - smallest rank (min_rank) is red
# - other non-full-rank (but not min_rank) are colored by their rank
# - full rank are 'C0'
rank_to_color = {}
color_palette = ['yellow', 'orange', 'green', 'blue', 'purple', 'brown', 'pink', 'gray']
for idx, rank in enumerate(other_ranks):
    rank_to_color[rank] = color_palette[idx % len(color_palette)]

point_colors = []
red_counter = 0
for i, y in enumerate(min_eigenvalues_np):
    if y < threshold:
        rank = red_ranks[red_counter]
        if rank == min_rank:
            point_colors.append('red')
        else:
            point_colors.append(rank_to_color[rank])
        red_counter += 1
    else:
        point_colors.append('C0')

# Plot the minimum eigenvalue of the traced-out density matrix as a function of the eigenvalue of the Hamiltonian H
plt.figure(figsize=(8, 5))
plt.scatter(eigenvalues, np.abs(min_eigenvalues_np), color=point_colors, s=1)

plt.xlabel('Eigenvalue of H')
plt.ylabel(r"$\lambda_{\text{min}}$")
plt.yscale("log")

# Add legend
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label=f'rank={min_rank}', markerfacecolor='red', markersize=8)
]
for rank in other_ranks:
    legend_elements.append(
        Line2D([0], [0], marker='o', color='w',
               label=f'rank={rank}',
               markerfacecolor=rank_to_color[rank], markersize=8)
    )
legend_elements.append(
    Line2D([0], [0], marker='o', color='w', label='Full rank', markerfacecolor='C0', markersize=8)
)
plt.legend(handles=legend_elements, title="RDM Rank")

plt.show()

red_eigenvectors_np = []

# Print eigenvalues, RDM minimum eigenvalues, and scalar products of eigenvectors for non-full-rank points
for i, ind in enumerate(red_indices_np):
    print(i, ind)
    print(f'Eigenvalue: {eigenvalues[ind]}, rdm Minimum Eigenvalue: {min_eigenvalues_np[ind]}')
    print(f'Eigenvector {ind}: rdm rank: {np.linalg.matrix_rank(min_rdms_np[i])}')
    red_eigenvectors_np.append(eigenvectors[:, ind])

# Count entries of rdm_eigenvalues_np[i] - eigenvalues of the scarred rdms - that are non-zero
counts_np = [np.sum(eigenvalues > 1e-16) for eigenvalues in rdm_eigenvalues_np]
print(f'Counts of non-zero eigenvalues of the scarred rdms: {counts_np}')
# Out:
# Indices of non-full-rank points: [1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 2957, 2958, 2959, 2960, 2961, 3170, 3171, 3172, 3173, 3174, 3175, 3176, 3177, 3178, 3179, 3180, 3181, 3182, 3183, 3184, 3185, 3186, 3187, 3188, 3189, 3190, 3191, 3192, 3193, 3194, 3195, 3196, 3197, 3198, 3199, 3200, 3201, 3202, 3203, 3204, 3205, 3206, 3207, 3208, 3209, 3210, 3211, 3212, 3213, 3214, 3395, 3396, 3397, 3398, 3399, 3400, 3401, 3402, 3403, 3404, 3405, 3406, 3407, 3408, 3409, 3410, 3411, 3412, 3413, 3414, 3415, 3416, 3417, 3418, 3419, 3420, 3421, 3422, 3423, 3424]
# Indices for each non-full rank:
# Rank 30: 150 states with indices [1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 3170, 3171, 3172, 3173, 3174, 3175, 3176, 3177, 3178, 3179, 3180, 3181, 3182, 3183, 3184, 3185, 3186, 3187, 3188, 3189, 3190, 3191, 3192, 3193, 3194, 3195, 3196, 3197, 3198, 3199, 3200, 3201, 3202, 3203, 3204, 3205, 3206, 3207, 3208, 3209, 3210, 3211, 3212, 3213, 3214, 3395, 3396, 3397, 3398, 3399, 3400, 3401, 3402, 3403, 3404, 3405, 3406, 3407, 3408, 3409, 3410, 3411, 3412, 3413, 3414, 3415, 3416, 3417, 3418, 3419, 3420, 3421, 3422, 3423, 3424]
# Rank 26: 5 states with indices [2957, 2958, 2959, 2960, 2961]
# 0 1657
# Eigenvalue: -2.0000000000000058, rdm Minimum Eigenvalue: 5.204170255071638e-18
# Eigenvector 1657: rdm rank: 30
# 1 1658
# Eigenvalue: -2.0000000000000053, rdm Minimum Eigenvalue: 4.393233528377612e-21
# Eigenvector 1658: rdm rank: 30
# 2 1659
# Eigenvalue: -2.0000000000000044, rdm Minimum Eigenvalue: -3.070793768365179e-19
# Eigenvector 1659: rdm rank: 30
# 3 1660
# Eigenvalue: -2.000000000000004, rdm Minimum Eigenvalue: -2.7748964761618307e-17
# Eigenvector 1660: rdm rank: 30
# 4 1661
# Eigenvalue: -2.000000000000004, rdm Minimum Eigenvalue: -1.5421702269719583e-18
# Eigenvector 1661: rdm rank: 30
# 5 1662
# Eigenvalue: -2.000000000000003, rdm Minimum Eigenvalue: -5.664544443295282e-21
# Eigenvector 1662: rdm rank: 30
# 6 1663
# Eigenvalue: -2.000000000000002, rdm Minimum Eigenvalue: -2.4006983538342267e-17
# Eigenvector 1663: rdm rank: 30
# 7 1664
# Eigenvalue: -2.0000000000000018, rdm Minimum Eigenvalue: -5.18248912466839e-18
# Eigenvector 1664: rdm rank: 30
# 8 1665
# Eigenvalue: -2.0000000000000018, rdm Minimum Eigenvalue: -6.029486603881857e-18
# Eigenvector 1665: rdm rank: 30
# 9 1666
# Eigenvalue: -2.0000000000000018, rdm Minimum Eigenvalue: -4.694803573663165e-18
# Eigenvector 1666: rdm rank: 30
# 10 1667
# Eigenvalue: -2.0000000000000013, rdm Minimum Eigenvalue: -3.0336159782515034e-17
# Eigenvector 1667: rdm rank: 30
# 11 1668
# Eigenvalue: -2.0000000000000013, rdm Minimum Eigenvalue: -7.002349505018868e-19
# Eigenvector 1668: rdm rank: 30
# 12 1669
# Eigenvalue: -2.0000000000000013, rdm Minimum Eigenvalue: -9.762009473712151e-19
# Eigenvector 1669: rdm rank: 30
# 13 1670
# Eigenvalue: -2.0000000000000013, rdm Minimum Eigenvalue: -1.253909275136586e-19
# Eigenvector 1670: rdm rank: 30
# 14 1671
# Eigenvalue: -2.000000000000001, rdm Minimum Eigenvalue: -1.517605581094633e-17
# Eigenvector 1671: rdm rank: 30
# 15 1672
# Eigenvalue: -2.000000000000001, rdm Minimum Eigenvalue: -1.1290863085817597e-17
# Eigenvector 1672: rdm rank: 30
# 16 1673
# Eigenvalue: -2.000000000000001, rdm Minimum Eigenvalue: -9.143144243527288e-21
# Eigenvector 1673: rdm rank: 30
# 17 1674
# Eigenvalue: -2.0000000000000004, rdm Minimum Eigenvalue: -1.1588953387221112e-17
# Eigenvector 1674: rdm rank: 30
# 18 1675
# Eigenvalue: -2.0000000000000004, rdm Minimum Eigenvalue: -3.897413451926075e-20
# Eigenvector 1675: rdm rank: 30
# 19 1676
# Eigenvalue: -2.0000000000000004, rdm Minimum Eigenvalue: -1.985949898378547e-17
# Eigenvector 1676: rdm rank: 30
# 20 1677
# Eigenvalue: -2.0000000000000004, rdm Minimum Eigenvalue: -2.3687599759748933e-17
# Eigenvector 1677: rdm rank: 30
# 21 1678
# Eigenvalue: -2.0000000000000004, rdm Minimum Eigenvalue: -1.794197494990563e-18
# Eigenvector 1678: rdm rank: 30
# 22 1679
# Eigenvalue: -2.0000000000000004, rdm Minimum Eigenvalue: 2.8797883723704724e-18
# Eigenvector 1679: rdm rank: 30
# 23 1680
# Eigenvalue: -2.0000000000000004, rdm Minimum Eigenvalue: -2.5749993413625695e-19
# Eigenvector 1680: rdm rank: 30
# 24 1681
# Eigenvalue: -2.0000000000000004, rdm Minimum Eigenvalue: -1.9093272418581763e-17
# Eigenvector 1681: rdm rank: 30
# 25 1682
# Eigenvalue: -2.0, rdm Minimum Eigenvalue: -1.0863082654847277e-18
# Eigenvector 1682: rdm rank: 30
# 26 1683
# Eigenvalue: -2.0, rdm Minimum Eigenvalue: 6.21762486166972e-20
# Eigenvector 1683: rdm rank: 30
# 27 1684
# Eigenvalue: -1.9999999999999998, rdm Minimum Eigenvalue: -2.1002544933445706e-18
# Eigenvector 1684: rdm rank: 30
# 28 1685
# Eigenvalue: -1.9999999999999998, rdm Minimum Eigenvalue: -1.1973956305681403e-17
# Eigenvector 1685: rdm rank: 30
# 29 1686
# Eigenvalue: -1.9999999999999996, rdm Minimum Eigenvalue: -4.511526500540431e-18
# Eigenvector 1686: rdm rank: 30
# 30 1687
# Eigenvalue: -1.9999999999999996, rdm Minimum Eigenvalue: -1.2217578985905457e-24
# Eigenvector 1687: rdm rank: 30
# 31 1688
# Eigenvalue: -1.9999999999999993, rdm Minimum Eigenvalue: -9.492552063820929e-20
# Eigenvector 1688: rdm rank: 30
# 32 1689
# Eigenvalue: -1.9999999999999991, rdm Minimum Eigenvalue: -2.576061401118908e-21
# Eigenvector 1689: rdm rank: 30
# 33 1690
# Eigenvalue: -1.9999999999999991, rdm Minimum Eigenvalue: -5.679248590834409e-18
# Eigenvector 1690: rdm rank: 30
# 34 1691
# Eigenvalue: -1.999999999999999, rdm Minimum Eigenvalue: -5.42103681633074e-19
# Eigenvector 1691: rdm rank: 30
# 35 1692
# Eigenvalue: -1.9999999999999984, rdm Minimum Eigenvalue: 9.485928835479007e-20
# Eigenvector 1692: rdm rank: 30
# 36 1693
# Eigenvalue: -1.9999999999999982, rdm Minimum Eigenvalue: -3.468461987839678e-18
# Eigenvector 1693: rdm rank: 30
# 37 1694
# Eigenvalue: -1.999999999999998, rdm Minimum Eigenvalue: -1.6400165462545054e-18
# Eigenvector 1694: rdm rank: 30
# 38 1695
# Eigenvalue: -1.999999999999998, rdm Minimum Eigenvalue: -2.3042469616640985e-19
# Eigenvector 1695: rdm rank: 30
# 39 1696
# Eigenvalue: -1.9999999999999973, rdm Minimum Eigenvalue: -9.144041076504148e-18
# Eigenvector 1696: rdm rank: 30
# 40 1697
# Eigenvalue: -1.9999999999999971, rdm Minimum Eigenvalue: 1.626300811404353e-18
# Eigenvector 1697: rdm rank: 30
# 41 1698
# Eigenvalue: -1.9999999999999971, rdm Minimum Eigenvalue: 1.6922600843442355e-20
# Eigenvector 1698: rdm rank: 30
# 42 1699
# Eigenvalue: -1.9999999999999967, rdm Minimum Eigenvalue: -1.0842947947877781e-18
# Eigenvector 1699: rdm rank: 30
# 43 1700
# Eigenvalue: -1.999999999999995, rdm Minimum Eigenvalue: -8.460270886705334e-18
# Eigenvector 1700: rdm rank: 30
# 44 1701
# Eigenvalue: -1.9999999999999947, rdm Minimum Eigenvalue: -8.834131117275146e-20
# Eigenvector 1701: rdm rank: 30
# 45 1892
# Eigenvalue: -0.3245553203367637, rdm Minimum Eigenvalue: 5.908289445064361e-19
# Eigenvector 1892: rdm rank: 30
# 46 1893
# Eigenvalue: -0.32455532033676276, rdm Minimum Eigenvalue: -9.04327538183425e-18
# Eigenvector 1893: rdm rank: 30
# 47 1894
# Eigenvalue: -0.3245553203367623, rdm Minimum Eigenvalue: -5.4432853169306e-18
# Eigenvector 1894: rdm rank: 30
# 48 1895
# Eigenvalue: -0.32455532033676215, rdm Minimum Eigenvalue: -1.298072725790374e-18
# Eigenvector 1895: rdm rank: 30
# 49 1896
# Eigenvalue: -0.32455532033676204, rdm Minimum Eigenvalue: 7.839195557980237e-19
# Eigenvector 1896: rdm rank: 30
# 50 1897
# Eigenvalue: -0.3245553203367619, rdm Minimum Eigenvalue: -1.6175911400781938e-17
# Eigenvector 1897: rdm rank: 30
# 51 1898
# Eigenvalue: -0.32455532033676177, rdm Minimum Eigenvalue: -5.2384116550229634e-18
# Eigenvector 1898: rdm rank: 30
# 52 1899
# Eigenvalue: -0.3245553203367606, rdm Minimum Eigenvalue: -3.1194959094251786e-20
# Eigenvector 1899: rdm rank: 30
# 53 1900
# Eigenvalue: -0.32455532033675955, rdm Minimum Eigenvalue: 4.904111563611906e-19
# Eigenvector 1900: rdm rank: 30
# 54 1901
# Eigenvalue: -0.32455532033675927, rdm Minimum Eigenvalue: 7.916163191339992e-19
# Eigenvector 1901: rdm rank: 30
# 55 1902
# Eigenvalue: -0.3245553203367592, rdm Minimum Eigenvalue: -4.700694614830759e-19
# Eigenvector 1902: rdm rank: 30
# 56 1903
# Eigenvalue: -0.3245553203367591, rdm Minimum Eigenvalue: -8.516555367594756e-18
# Eigenvector 1903: rdm rank: 30
# 57 1904
# Eigenvalue: -0.32455532033675893, rdm Minimum Eigenvalue: -3.90777222545732e-18
# Eigenvector 1904: rdm rank: 30
# 58 1905
# Eigenvalue: -0.3245553203367589, rdm Minimum Eigenvalue: 1.010815740942652e-18
# Eigenvector 1905: rdm rank: 30
# 59 1906
# Eigenvalue: -0.32455532033675877, rdm Minimum Eigenvalue: -2.5865887889112192e-18
# Eigenvector 1906: rdm rank: 30
# 60 1907
# Eigenvalue: -0.3245553203367586, rdm Minimum Eigenvalue: -8.607532135000954e-19
# Eigenvector 1907: rdm rank: 30
# 61 1908
# Eigenvalue: -0.324555320336758, rdm Minimum Eigenvalue: 8.775279676493835e-19
# Eigenvector 1908: rdm rank: 30
# 62 1909
# Eigenvalue: -0.32455532033675794, rdm Minimum Eigenvalue: -3.1119782308697347e-18
# Eigenvector 1909: rdm rank: 30
# 63 1910
# Eigenvalue: -0.3245553203367578, rdm Minimum Eigenvalue: -2.9338051222513615e-18
# Eigenvector 1910: rdm rank: 30
# 64 1911
# Eigenvalue: -0.32455532033675777, rdm Minimum Eigenvalue: -3.268353332432683e-18
# Eigenvector 1911: rdm rank: 30
# 65 1912
# Eigenvalue: -0.32455532033675777, rdm Minimum Eigenvalue: -2.5357918891944706e-17
# Eigenvector 1912: rdm rank: 30
# 66 1913
# Eigenvalue: -0.32455532033675744, rdm Minimum Eigenvalue: 9.791213403411468e-20
# Eigenvector 1913: rdm rank: 30
# 67 1914
# Eigenvalue: -0.3245553203367574, rdm Minimum Eigenvalue: -1.2804773166081326e-17
# Eigenvector 1914: rdm rank: 30
# 68 1915
# Eigenvalue: -0.3245553203367573, rdm Minimum Eigenvalue: -4.3684393200763085e-19
# Eigenvector 1915: rdm rank: 30
# 69 1916
# Eigenvalue: -0.32455532033675716, rdm Minimum Eigenvalue: -1.4127068680625008e-18
# Eigenvector 1916: rdm rank: 30
# 70 1917
# Eigenvalue: -0.32455532033675716, rdm Minimum Eigenvalue: -1.64548916432007e-17
# Eigenvector 1917: rdm rank: 30
# 71 1918
# Eigenvalue: -0.32455532033675677, rdm Minimum Eigenvalue: 9.655798529786377e-19
# Eigenvector 1918: rdm rank: 30
# 72 1919
# Eigenvalue: -0.3245553203367565, rdm Minimum Eigenvalue: -2.0887626403522952e-17
# Eigenvector 1919: rdm rank: 30
# 73 1920
# Eigenvalue: -0.3245553203367541, rdm Minimum Eigenvalue: 6.113127143937334e-18
# Eigenvector 1920: rdm rank: 30
# 74 1921
# Eigenvalue: -0.32455532033675333, rdm Minimum Eigenvalue: -4.696148410641633e-19
# Eigenvector 1921: rdm rank: 30
# 75 2957
# Eigenvalue: 7.999999999999995, rdm Minimum Eigenvalue: -4.326423912298866e-17
# Eigenvector 2957: rdm rank: 26
# 76 2958
# Eigenvalue: 7.999999999999997, rdm Minimum Eigenvalue: -1.3645766211001912e-17
# Eigenvector 2958: rdm rank: 26
# 77 2959
# Eigenvalue: 8.0, rdm Minimum Eigenvalue: -6.603552812628559e-18
# Eigenvector 2959: rdm rank: 26
# 78 2960
# Eigenvalue: 8.000000000000007, rdm Minimum Eigenvalue: 2.390543683617767e-30
# Eigenvector 2960: rdm rank: 26
# 79 2961
# Eigenvalue: 8.00000000000001, rdm Minimum Eigenvalue: -6.887521776569927e-17
# Eigenvector 2961: rdm rank: 26
# 80 3170
# Eigenvalue: 9.999999999999986, rdm Minimum Eigenvalue: -8.89108218588622e-18
# Eigenvector 3170: rdm rank: 30
# 81 3171
# Eigenvalue: 9.99999999999999, rdm Minimum Eigenvalue: -4.762246326993224e-19
# Eigenvector 3171: rdm rank: 30
# 82 3172
# Eigenvalue: 9.999999999999991, rdm Minimum Eigenvalue: -3.22170128411958e-18
# Eigenvector 3172: rdm rank: 30
# 83 3173
# Eigenvalue: 9.999999999999991, rdm Minimum Eigenvalue: -5.630794448483437e-18
# Eigenvector 3173: rdm rank: 30
# 84 3174
# Eigenvalue: 9.999999999999993, rdm Minimum Eigenvalue: 1.1010783370522071e-31
# Eigenvector 3174: rdm rank: 30
# 85 3175
# Eigenvalue: 9.999999999999993, rdm Minimum Eigenvalue: 1.3564624532383718e-31
# Eigenvector 3175: rdm rank: 30
# 86 3176
# Eigenvalue: 9.999999999999993, rdm Minimum Eigenvalue: -8.783783182351226e-18
# Eigenvector 3176: rdm rank: 30
# 87 3177
# Eigenvalue: 9.999999999999993, rdm Minimum Eigenvalue: -2.6926734277996113e-18
# Eigenvector 3177: rdm rank: 30
# 88 3178
# Eigenvalue: 9.999999999999996, rdm Minimum Eigenvalue: 1.4314562556666933e-31
# Eigenvector 3178: rdm rank: 30
# 89 3179
# Eigenvalue: 9.999999999999996, rdm Minimum Eigenvalue: -4.1575187872588205e-18
# Eigenvector 3179: rdm rank: 30
# 90 3180
# Eigenvalue: 9.999999999999996, rdm Minimum Eigenvalue: -1.514722744690859e-18
# Eigenvector 3180: rdm rank: 30
# 91 3181
# Eigenvalue: 9.999999999999996, rdm Minimum Eigenvalue: 5.517079813566402e-32
# Eigenvector 3181: rdm rank: 30
# 92 3182
# Eigenvalue: 9.999999999999996, rdm Minimum Eigenvalue: -1.205583616218889e-17
# Eigenvector 3182: rdm rank: 30
# 93 3183
# Eigenvalue: 9.999999999999996, rdm Minimum Eigenvalue: 1.149942548615268e-31
# Eigenvector 3183: rdm rank: 30
# 94 3184
# Eigenvalue: 9.999999999999996, rdm Minimum Eigenvalue: 8.281964337473554e-32
# Eigenvector 3184: rdm rank: 30
# 95 3185
# Eigenvalue: 9.999999999999998, rdm Minimum Eigenvalue: -7.523301097619032e-18
# Eigenvector 3185: rdm rank: 30
# 96 3186
# Eigenvalue: 9.999999999999998, rdm Minimum Eigenvalue: -1.2481065712999273e-17
# Eigenvector 3186: rdm rank: 30
# 97 3187
# Eigenvalue: 9.999999999999998, rdm Minimum Eigenvalue: 7.175026649656101e-32
# Eigenvector 3187: rdm rank: 30
# 98 3188
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: 1.4702167043844327e-31
# Eigenvector 3188: rdm rank: 30
# 99 3189
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: 1.831815773697397e-31
# Eigenvector 3189: rdm rank: 30
# 100 3190
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: -1.2437043886146563e-22
# Eigenvector 3190: rdm rank: 30
# 101 3191
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: 8.874388949228393e-32
# Eigenvector 3191: rdm rank: 30
# 102 3192
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: -1.3121037431504231e-17
# Eigenvector 3192: rdm rank: 30
# 103 3193
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: -3.605759604361089e-18
# Eigenvector 3193: rdm rank: 30
# 104 3194
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: 5.960344859202596e-32
# Eigenvector 3194: rdm rank: 30
# 105 3195
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: -6.975735083714448e-18
# Eigenvector 3195: rdm rank: 30
# 106 3196
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: -3.5143646605482914e-20
# Eigenvector 3196: rdm rank: 30
# 107 3197
# Eigenvalue: 10.0, rdm Minimum Eigenvalue: 5.465304622658313e-31
# Eigenvector 3197: rdm rank: 30
# 108 3198
# Eigenvalue: 10.000000000000002, rdm Minimum Eigenvalue: 9.932224114478949e-32
# Eigenvector 3198: rdm rank: 30
# 109 3199
# Eigenvalue: 10.000000000000002, rdm Minimum Eigenvalue: -9.683145100816938e-18
# Eigenvector 3199: rdm rank: 30
# 110 3200
# Eigenvalue: 10.000000000000002, rdm Minimum Eigenvalue: -1.0651086702852003e-17
# Eigenvector 3200: rdm rank: 30
# 111 3201
# Eigenvalue: 10.000000000000002, rdm Minimum Eigenvalue: -6.860366484625177e-18
# Eigenvector 3201: rdm rank: 30
# 112 3202
# Eigenvalue: 10.000000000000002, rdm Minimum Eigenvalue: -4.8986870623757666e-18
# Eigenvector 3202: rdm rank: 30
# 113 3203
# Eigenvalue: 10.000000000000004, rdm Minimum Eigenvalue: 1.1148627950212382e-31
# Eigenvector 3203: rdm rank: 30
# 114 3204
# Eigenvalue: 10.000000000000004, rdm Minimum Eigenvalue: 2.1108625095500493e-31
# Eigenvector 3204: rdm rank: 30
# 115 3205
# Eigenvalue: 10.000000000000004, rdm Minimum Eigenvalue: -4.413023110153322e-21
# Eigenvector 3205: rdm rank: 30
# 116 3206
# Eigenvalue: 10.000000000000004, rdm Minimum Eigenvalue: 1.3367322283010682e-31
# Eigenvector 3206: rdm rank: 30
# 117 3207
# Eigenvalue: 10.000000000000004, rdm Minimum Eigenvalue: 1.7974546617076256e-31
# Eigenvector 3207: rdm rank: 30
# 118 3208
# Eigenvalue: 10.000000000000004, rdm Minimum Eigenvalue: -5.276750553671764e-18
# Eigenvector 3208: rdm rank: 30
# 119 3209
# Eigenvalue: 10.000000000000007, rdm Minimum Eigenvalue: 7.788032021832465e-32
# Eigenvector 3209: rdm rank: 30
# 120 3210
# Eigenvalue: 10.000000000000007, rdm Minimum Eigenvalue: 7.874691001389433e-32
# Eigenvector 3210: rdm rank: 30
# 121 3211
# Eigenvalue: 10.000000000000007, rdm Minimum Eigenvalue: -1.3965038056389342e-17
# Eigenvector 3211: rdm rank: 30
# 122 3212
# Eigenvalue: 10.000000000000009, rdm Minimum Eigenvalue: 5.747519837727245e-31
# Eigenvector 3212: rdm rank: 30
# 123 3213
# Eigenvalue: 10.000000000000009, rdm Minimum Eigenvalue: -5.560501660680305e-18
# Eigenvector 3213: rdm rank: 30
# 124 3214
# Eigenvalue: 10.000000000000021, rdm Minimum Eigenvalue: 1.2907251987230688e-31
# Eigenvector 3214: rdm rank: 30
# 125 3395
# Eigenvalue: 12.324555320336744, rdm Minimum Eigenvalue: -1.3139637222295409e-18
# Eigenvector 3395: rdm rank: 30
# 126 3396
# Eigenvalue: 12.324555320336744, rdm Minimum Eigenvalue: -8.387140281331182e-18
# Eigenvector 3396: rdm rank: 30
# 127 3397
# Eigenvalue: 12.324555320336746, rdm Minimum Eigenvalue: -4.166937197016517e-18
# Eigenvector 3397: rdm rank: 30
# 128 3398
# Eigenvalue: 12.32455532033675, rdm Minimum Eigenvalue: -1.7578247939494184e-18
# Eigenvector 3398: rdm rank: 30
# 129 3399
# Eigenvalue: 12.32455532033675, rdm Minimum Eigenvalue: -9.258246272878765e-19
# Eigenvector 3399: rdm rank: 30
# 130 3400
# Eigenvalue: 12.32455532033675, rdm Minimum Eigenvalue: -3.643582242706078e-19
# Eigenvector 3400: rdm rank: 30
# 131 3401
# Eigenvalue: 12.324555320336751, rdm Minimum Eigenvalue: 1.0040560055376643e-18
# Eigenvector 3401: rdm rank: 30
# 132 3402
# Eigenvalue: 12.324555320336751, rdm Minimum Eigenvalue: -1.773705459888379e-18
# Eigenvector 3402: rdm rank: 30
# 133 3403
# Eigenvalue: 12.324555320336751, rdm Minimum Eigenvalue: 1.300591810615814e-18
# Eigenvector 3403: rdm rank: 30
# 134 3404
# Eigenvalue: 12.324555320336751, rdm Minimum Eigenvalue: -4.698920500566038e-18
# Eigenvector 3404: rdm rank: 30
# 135 3405
# Eigenvalue: 12.324555320336751, rdm Minimum Eigenvalue: -6.337634267578605e-18
# Eigenvector 3405: rdm rank: 30
# 136 3406
# Eigenvalue: 12.324555320336755, rdm Minimum Eigenvalue: -4.850931490437774e-19
# Eigenvector 3406: rdm rank: 30
# 137 3407
# Eigenvalue: 12.324555320336756, rdm Minimum Eigenvalue: 6.537484369898646e-19
# Eigenvector 3407: rdm rank: 30
# 138 3408
# Eigenvalue: 12.324555320336758, rdm Minimum Eigenvalue: -3.849135689507981e-18
# Eigenvector 3408: rdm rank: 30
# 139 3409
# Eigenvalue: 12.324555320336758, rdm Minimum Eigenvalue: -7.880908868533093e-18
# Eigenvector 3409: rdm rank: 30
# 140 3410
# Eigenvalue: 12.324555320336758, rdm Minimum Eigenvalue: -2.1807367895120294e-18
# Eigenvector 3410: rdm rank: 30
# 141 3411
# Eigenvalue: 12.324555320336758, rdm Minimum Eigenvalue: -9.768728802046844e-18
# Eigenvector 3411: rdm rank: 30
# 142 3412
# Eigenvalue: 12.324555320336758, rdm Minimum Eigenvalue: 1.4269717727148857e-18
# Eigenvector 3412: rdm rank: 30
# 143 3413
# Eigenvalue: 12.32455532033676, rdm Minimum Eigenvalue: -5.320211172116572e-18
# Eigenvector 3413: rdm rank: 30
# 144 3414
# Eigenvalue: 12.32455532033676, rdm Minimum Eigenvalue: -3.611874519317144e-18
# Eigenvector 3414: rdm rank: 30
# 145 3415
# Eigenvalue: 12.324555320336762, rdm Minimum Eigenvalue: -1.7466866240425334e-17
# Eigenvector 3415: rdm rank: 30
# 146 3416
# Eigenvalue: 12.324555320336762, rdm Minimum Eigenvalue: -3.549230358119441e-18
# Eigenvector 3416: rdm rank: 30
# 147 3417
# Eigenvalue: 12.324555320336762, rdm Minimum Eigenvalue: -1.6076907433680468e-19
# Eigenvector 3417: rdm rank: 30
# 148 3418
# Eigenvalue: 12.324555320336765, rdm Minimum Eigenvalue: -3.529705446309314e-18
# Eigenvector 3418: rdm rank: 30
# 149 3419
# Eigenvalue: 12.324555320336767, rdm Minimum Eigenvalue: -2.3040631413197738e-18
# Eigenvector 3419: rdm rank: 30
# 150 3420
# Eigenvalue: 12.324555320336769, rdm Minimum Eigenvalue: -5.803804760348873e-18
# Eigenvector 3420: rdm rank: 30
# 151 3421
# Eigenvalue: 12.324555320336769, rdm Minimum Eigenvalue: -4.66092585004816e-19
# Eigenvector 3421: rdm rank: 30
# 152 3422
# Eigenvalue: 12.32455532033677, rdm Minimum Eigenvalue: -1.631168916539174e-17
# Eigenvector 3422: rdm rank: 30
# 153 3423
# Eigenvalue: 12.324555320336772, rdm Minimum Eigenvalue: -4.167844126893321e-18
# Eigenvector 3423: rdm rank: 30
# 154 3424
# Eigenvalue: 12.324555320336776, rdm Minimum Eigenvalue: 3.183383661335694e-18
# Eigenvector 3424: rdm rank: 30
# Counts of non-zero eigenvalues of the scarred rdms: [np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(26), np.int64(26), np.int64(26), np.int64(26), np.int64(26), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30), np.int64(30)]

# %%
# decide which non-full rank states to analyze
rank_indices_np = rank_to_indices[min_rank]

# %%
'''# rdm - torch

min_eigenvalues_to = []
min_rdms_to = []
rdm_eigenvalues_to = []

for i in tqdm(range(len(eigenvalues))):
    # Construct the density matrix for each eigenvector
    min_eigenvector = eigenvectors[:, i]
    min_eigenvector_torch = torch.tensor(min_eigenvector, dtype=torch.float64)
    density_matrix = torch.outer(min_eigenvector_torch, min_eigenvector_torch.conj())

    # Trace out qubits
    traced_out_density_matrix = ptrace_torch(density_matrix, keep_qubits, [[2] * N, [2] * N])
    traced_out_density_matrix = torch.tensor(traced_out_density_matrix, dtype=torch.float64) # necessary step to ensure that the scarred states have lambda_min of the correct order - <1e-16 

    # Diagonalize the traced-out density matrix
    eigenvalues_traced, eigenvectors_traced = torch.linalg.eigh(traced_out_density_matrix)

    # Find the minimum eigenvalue of the traced-out density matrix
    min_eigenvalue = torch.min(eigenvalues_traced).item()
    min_eigenvalues_to.append(min_eigenvalue)

    if min_eigenvalue < 1e-16:
        min_rdms_to.append(traced_out_density_matrix.detach().cpu().numpy())  # store the scarred rdms - step needed for optimization
        rdm_eigenvalues_to.append(eigenvalues_traced.detach().cpu().numpy()) # store the eigenvalues of the scarred rdms

# Define the threshold
threshold = 1e-16
min_eigenvalues_to = np.array(min_eigenvalues_to)

# Count points with y-component less than the threshold
count = sum(1 for y in min_eigenvalues_to if y < threshold)

# Highlight points with y-component less than the threshold in red
colors = ['red' if y < threshold else 'C0' for y in min_eigenvalues_to]

# Plot the minimum eigenvalue of the traced-out density matrix as a function of the eigenvalue of the Hamiltonian H
plt.scatter(eigenvalues, np.abs(min_eigenvalues_to), color=colors, s=1)

plt.xlabel('Eigenvalue of H')
plt.ylabel(r"$\lambda_{\text{min}}$")
plt.yscale("log")
plt.show()

# Find indices of red points - torch
red_indices_to = [i for i, y in enumerate(min_eigenvalues_to) if y < threshold]
print(f'Indices of red points: {red_indices_to}')

red_eigenvectors_to = []

# Print eigenvalues, RDM minimum eigenvalues, and scalar products of eigenvectors for red points
for i,ind in enumerate(red_indices_to):
    print(i, ind)
    print(f'Eigenvalue: {eigenvalues[ind]}, rdm Minimum Eigenvalue: {min_eigenvalues_to[ind]}')
    print(f'Eigenvector {ind}: rdm rank: {np.linalg.matrix_rank(min_rdms_to[i])}')
    red_eigenvectors_to.append(eigenvectors[:, ind])

for i in range(len(red_indices_to)):
    for j in range(len(red_indices_to)):
        idx1, idx2 = red_indices_to[i], red_indices_to[j]
        dot_product = np.dot(eigenvectors[:, idx1], np.conj(eigenvectors[:, idx2]))
        print(f"Dot product between eigenvectors {idx1} and {idx2}: {dot_product}")

# Count entries of rdm_eigenvalues_to[i] - eigenvalues of the scarred rdms - that are non-zero
counts_to = [np.sum(eigenvalues > 1e-15) for eigenvalues in rdm_eigenvalues_to]
print(f'Counts of non-zero eigenvalues of the scarred rdms: {counts_to}')'''
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\l'
# <>:42: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\camip\AppData\Local\Temp\ipykernel_12308\3775950558.py:42: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel(r"$\lambda_{\text{min}}$")
# '# rdm - torch\n\nmin_eigenvalues_to = []\nmin_rdms_to = []\nrdm_eigenvalues_to = []\n\nfor i in tqdm(range(len(eigenvalues))):\n    # Construct the density matrix for each eigenvector\n    min_eigenvector = eigenvectors[:, i]\n    min_eigenvector_torch = torch.tensor(min_eigenvector, dtype=torch.float64)\n    density_matrix = torch.outer(min_eigenvector_torch, min_eigenvector_torch.conj())\n\n    # Trace out qubits\n    traced_out_density_matrix = ptrace_torch(density_matrix, keep_qubits, [[2] * N, [2] * N])\n    traced_out_density_matrix = torch.tensor(traced_out_density_matrix, dtype=torch.float64) # necessary step to ensure that the scarred states have lambda_min of the correct order - <1e-16 \n\n    # Diagonalize the traced-out density matrix\n    eigenvalues_traced, eigenvectors_traced = torch.linalg.eigh(traced_out_density_matrix)\n\n    # Find the minimum eigenvalue of the traced-out density matrix\n    min_eigenvalue = torch.min(eigenvalues_traced).item()\n    min_eigenvalues_to.append(min_eigenvalue)\n\n    if min_eigenvalue < 1e-16:\n        min_rdms_to.append(traced_out_density_matrix.detach().cpu().numpy())  # store the scarred rdms - step needed for optimization\n        rdm_eigenvalues_to.append(eigenvalues_traced.detach().cpu().numpy()) # store the eigenvalues of the scarred rdms\n\n# Define the threshold\nthreshold = 1e-16\nmin_eigenvalues_to = np.array(min_eigenvalues_to)\n\n# Count points with y-component less than the threshold\ncount = sum(1 for y in min_eigenvalues_to if y < threshold)\n\n# Highlight points with y-component less than the threshold in red\ncolors = [\'red\' if y < threshold else \'C0\' for y in min_eigenvalues_to]\n\n# Plot the minimum eigenvalue of the traced-out density matrix as a function of the eigenvalue of the Hamiltonian H\nplt.scatter(eigenvalues, np.abs(min_eigenvalues_to), color=colors, s=1)\n\nplt.xlabel(\'Eigenvalue of H\')\nplt.ylabel(r"$\\lambda_{\text{min}}$")\nplt.yscale("log")\nplt.show()\n\n# Find indices of red points - torch\nred_indices_to = [i for i, y in enumerate(min_eigenvalues_to) if y < threshold]\nprint(f\'Indices of red points: {red_indices_to}\')\n\nred_eigenvectors_to = []\n\n# Print eigenvalues, RDM minimum eigenvalues, and scalar products of eigenvectors for red points\nfor i,ind in enumerate(red_indices_to):\n    print(i, ind)\n    print(f\'Eigenvalue: {eigenvalues[ind]}, rdm Minimum Eigenvalue: {min_eigenvalues_to[ind]}\')\n    print(f\'Eigenvector {ind}: rdm rank: {np.linalg.matrix_rank(min_rdms_to[i])}\')\n    red_eigenvectors_to.append(eigenvectors[:, ind])\n\nfor i in range(len(red_indices_to)):\n    for j in range(len(red_indices_to)):\n        idx1, idx2 = red_indices_to[i], red_indices_to[j]\n        dot_product = np.dot(eigenvectors[:, idx1], np.conj(eigenvectors[:, idx2]))\n        print(f"Dot product between eigenvectors {idx1} and {idx2}: {dot_product}")\n\n# Count entries of rdm_eigenvalues_to[i] - eigenvalues of the scarred rdms - that are non-zero\ncounts_to = [np.sum(eigenvalues > 1e-15) for eigenvalues in rdm_eigenvalues_to]\nprint(f\'Counts of non-zero eigenvalues of the scarred rdms: {counts_to}\')'

# %%
# Generate random complex coefficients
random_coeffs = np.random.rand(len(rank_indices_np)) + 1j* np.random.rand(len(rank_indices_np))

# Normalize the coefficients
random_coeffs /= np.linalg.norm(random_coeffs)
print(random_coeffs)

print("coeffs norm",sum(np.abs(random_coeffs)**2))

# Define random scar state from 5 scarred states using random coefficients
rnd_scar = np.sum(eigenvectors[:, rank_indices_np] * random_coeffs, axis=1)

print(len(rnd_scar))

# Save eigenvalues corresponding to red indices into a numpy array
red_eigenvalues = np.array([eigenvalues[i] for i in rank_indices_np])

# Count the number of zero entries
num_zeros = np.count_nonzero((rnd_scar.real < 1e-16) & (rnd_scar.imag < 1e-16))
print(f'Number of zero entries: {num_zeros}')

# RANDOM SCAR - RANDOM LINEAR COMBINATION OF SCARRED STATES
rank_eigenvectors_np = np.array([eigenvectors[:, i] for i in rank_indices_np])
rnd_scar = linear_combination_np(random_coeffs, rank_eigenvectors_np)
rnd_scar_entropy = entanglement_entropy(rnd_scar, N // 2, N)
#rnd_scar_entropy_qutip = entanglement_entropy_qutip(rnd_scar, N // 2, N)
#rnd_scar_entropy_torch = entanglement_entropy_torch(rnd_scar, N // 2, N)
print("Random scar coeffs", random_coeffs)
print(f"Entanglement entropy of random scar state: {rnd_scar_entropy}")
#print(f"Entanglement entropy of random scar state (Qutip): {rnd_scar_entropy_qutip}")
#print(f"Entanglement entropy of random scar state (PyTorch): {rnd_scar_entropy_torch}")
# Out:
# [0.44493252+0.05780941j 0.29562741+0.39300339j 0.29994565+0.35375865j
#  0.33075925+0.21962895j 0.26852412+0.3346484j ]
# coeffs norm 1.0
# 4096
# Number of zero entries: 2503
# Random scar coeffs [0.44493252+0.05780941j 0.29562741+0.39300339j 0.29994565+0.35375865j
#  0.33075925+0.21962895j 0.26852412+0.3346484j ]
# Entanglement entropy of random scar state: 4.439238583832642

# %%
# Compute bipartite entanglement entropy for all eigenstates in the full Hilbert space
numpy_entropies = [entanglement_entropy(eigenvectors[:, i], N // 2, N) for i in tqdm(range(eigenvectors.shape[1]))]
#qutip_entropies = [entanglement_entropy_qutip(eigenvectors[:, i], N // 2, N) for i in tqdm(range(eigenvectors.shape[1]))]
#torch_entropies = [entanglement_entropy_torch(eigenvectors[:, i], N // 2, N) for i in tqdm(range(eigenvectors.shape[1]))]
# Out:
# 100%|██████████| 4096/4096 [02:26<00:00, 28.04it/s]

# %%
# Print entropies of red points only
print("Entropies of red points:")
for i in rank_indices_np:
    print(f'Index: {i}, Entropy: {numpy_entropies[i]}')

print(f'Random scar entropy: {rnd_scar_entropy}')

# Plot entanglement entropy as a function of energy eigenvalues
plt.figure(figsize=(10, 6))

# Color only points with indices in rank_indices_np as red, all others as 'C0'
colors = ['red' if i in rank_indices_np else 'C0' for i in range(len(eigenvalues))]

# Plot entanglement entropy with highlighted points
for i, color in enumerate(colors):
    plt.plot(eigenvalues[i], numpy_entropies[i], 'o', color=color, markersize=2)

# Plot the maximum scar entropy in yellow
plt.plot(np.mean(red_eigenvalues), rnd_scar_entropy, 'x', color='yellow', markersize=7, label='Random Scar')

# Add legend for red points only with text "scars"
red_points = [i for i, color in enumerate(colors) if color == 'red']
if red_points:
    plt.plot([], [], 'o', color='red', label='Scars')

plt.xlabel('Eigenvalue of H')
plt.ylabel('Entanglement entropy')
plt.legend()
plt.show()
# Out:
# Entropies of red points:
# Index: 2957, Entropy: 4.176221972501163
# Index: 2958, Entropy: 4.374190368830662
# Index: 2959, Entropy: 3.123382916425103
# Index: 2960, Entropy: 4.078575643903054
# Index: 2961, Entropy: 3.3519939070724756
# Random scar entropy: 4.439238583832642

# %%
'''# Compute entanglement entropy for the rnd_scar wavefunction - qutip

# Print entropies of red points only
print("Entropies of red points:")
for i in red_indices:
    print(f'Index: {i}, Entropy: {qutip_entropies[i]}')

print(f'Random scar entropy: {rnd_scar_entropy_qutip}')

# Plot entanglement entropy as a function of energy eigenvalues
plt.figure(figsize=(10, 6))

# Highlight points with y-component less than the threshold in red
colors = ['red' if y < threshold else 'C0' for y in min_eigenvalues]

# Plot entanglement entropy with highlighted points
for i, color in enumerate(colors):
    plt.plot(eigenvalues[i], qutip_entropies[i], 'o', color=color, markersize=2)

# Plot the maximum scar entropy in yellow
plt.plot(np.mean(red_eigenvalues), rnd_scar_entropy_qutip, 'x', color='yellow', markersize=7, label='Random Scar')

# Add legend for red points only with text "scars"
red_points = [i for i, color in enumerate(colors) if color == 'red']
if red_points:
    plt.plot([], [], 'o', color='red', label='Scars')

plt.xlabel('Eigenvalue of H')
plt.ylabel('Entanglement entropy')
#plt.title('Entanglement entropy as a function of energy eigenvalues')
plt.legend()
plt.show()'''
# Out:
# '# Compute entanglement entropy for the rnd_scar wavefunction - qutip\n\n# Print entropies of red points only\nprint("Entropies of red points:")\nfor i in red_indices:\n    print(f\'Index: {i}, Entropy: {qutip_entropies[i]}\')\n\nprint(f\'Random scar entropy: {rnd_scar_entropy_qutip}\')\n\n# Plot entanglement entropy as a function of energy eigenvalues\nplt.figure(figsize=(10, 6))\n\n# Highlight points with y-component less than the threshold in red\ncolors = [\'red\' if y < threshold else \'C0\' for y in min_eigenvalues]\n\n# Plot entanglement entropy with highlighted points\nfor i, color in enumerate(colors):\n    plt.plot(eigenvalues[i], qutip_entropies[i], \'o\', color=color, markersize=2)\n\n# Plot the maximum scar entropy in yellow\nplt.plot(np.mean(red_eigenvalues), rnd_scar_entropy_qutip, \'x\', color=\'yellow\', markersize=7, label=\'Random Scar\')\n\n# Add legend for red points only with text "scars"\nred_points = [i for i, color in enumerate(colors) if color == \'red\']\nif red_points:\n    plt.plot([], [], \'o\', color=\'red\', label=\'Scars\')\n\nplt.xlabel(\'Eigenvalue of H\')\nplt.ylabel(\'Entanglement entropy\')\n#plt.title(\'Entanglement entropy as a function of energy eigenvalues\')\nplt.legend()\nplt.show()'

# %%
'''# Compute entanglement entropy for the rnd_scar wavefunction - torch

# Print entropies of red points only
print("Entropies of red points:")
for i in red_indices:
    print(f'Index: {i}, Entropy: {torch_entropies[i]}')

print(f'Random scar entropy: {rnd_scar_entropy_torch}')

# Plot entanglement entropy as a function of energy eigenvalues
plt.figure(figsize=(10, 6))

# Highlight points with y-component less than the threshold in red
colors = ['red' if y < threshold else 'C0' for y in min_eigenvalues]

# Plot entanglement entropy with highlighted points
for i, color in enumerate(colors):
    plt.plot(eigenvalues[i], torch_entropies[i], 'o', color=color, markersize=2)

# Plot the maximum scar entropy in yellow
plt.plot(np.mean(red_eigenvalues), rnd_scar_entropy_torch, 'x', color='yellow', markersize=7, label='Random Scar')

# Add legend for red points only with text "scars"
red_points = [i for i, color in enumerate(colors) if color == 'red']
if red_points:
    plt.plot([], [], 'o', color='red', label='Scars')

plt.xlabel('Eigenvalue of H')
plt.ylabel('Entanglement entropy')
#plt.title('Entanglement entropy as a function of energy eigenvalues')
plt.legend()
plt.show()'''
# Out:
# '# Compute entanglement entropy for the rnd_scar wavefunction - torch\n\n# Print entropies of red points only\nprint("Entropies of red points:")\nfor i in red_indices:\n    print(f\'Index: {i}, Entropy: {torch_entropies[i]}\')\n\nprint(f\'Random scar entropy: {rnd_scar_entropy_torch}\')\n\n# Plot entanglement entropy as a function of energy eigenvalues\nplt.figure(figsize=(10, 6))\n\n# Highlight points with y-component less than the threshold in red\ncolors = [\'red\' if y < threshold else \'C0\' for y in min_eigenvalues]\n\n# Plot entanglement entropy with highlighted points\nfor i, color in enumerate(colors):\n    plt.plot(eigenvalues[i], torch_entropies[i], \'o\', color=color, markersize=2)\n\n# Plot the maximum scar entropy in yellow\nplt.plot(np.mean(red_eigenvalues), rnd_scar_entropy_torch, \'x\', color=\'yellow\', markersize=7, label=\'Random Scar\')\n\n# Add legend for red points only with text "scars"\nred_points = [i for i, color in enumerate(colors) if color == \'red\']\nif red_points:\n    plt.plot([], [], \'o\', color=\'red\', label=\'Scars\')\n\nplt.xlabel(\'Eigenvalue of H\')\nplt.ylabel(\'Entanglement entropy\')\n#plt.title(\'Entanglement entropy as a function of energy eigenvalues\')\nplt.legend()\nplt.show()'

# %%
# Define a list of colors for red points
red_colors = plt.cm.rainbow(np.linspace(0, 1, len(rank_indices_np)))

# Print entropies of red points only
print("Entropies of red points:")
for i in rank_indices_np:
    print(f'Index: {i}, Entropy: {numpy_entropies[i]}')

print(f'Random scar entropy: {rnd_scar_entropy}')

# Plot entanglement entropy as a function of energy eigenvalues
fig, ax = plt.subplots(figsize=(11, 6))

# Color only points with indices in rank_indices_np as red, all others as 'C0'
colors = ['red' if i in rank_indices_np else 'C0' for i in range(len(eigenvalues))]

# Plot entanglement entropy with highlighted points
for i, color in enumerate(colors):
    ax.plot(eigenvalues[i], numpy_entropies[i], 'o', color=color, markersize=2)

# Collect handles and labels for the legend
handles = []
labels = []

# Plot each red point with a different color and collect handles and labels
for i, idx in enumerate(rank_indices_np):
    handle, = ax.plot(eigenvalues[idx], numpy_entropies[idx], 'o', color=red_colors[i], markersize=5)
    handles.append(handle)
    labels.append(f'λ_min: {float(min_eigenvalues_np[idx]):.2e}, Entropy: {numpy_entropies[idx]:.2f}')

# Plot the maximum scar entropy in yellow and add to handles and labels
max_scar_handle, = ax.plot(np.mean(red_eigenvalues), rnd_scar_entropy, 'x', color='yellow', markersize=7)
handles.append(max_scar_handle)
labels.append('Max Scar, Entropy: {:.2f}'.format(rnd_scar_entropy))

# Sort handles and labels by lambda min
sorted_handles_labels = sorted(zip(handles, labels), key=lambda hl: float(hl[1].split(': ')[1].split(',')[0]) if 'λ_min' in hl[1] else float('inf'))
sorted_handles, sorted_labels = zip(*sorted_handles_labels)

# Filter min_eigenvalues to include only those corresponding to red_indices
filtered_min_eigenvalues = [min_eigenvalues_np[idx] for idx in rank_indices_np]

# Create a color bar for the red points using filtered min_eigenvalues
norm = Normalize(vmin=min(filtered_min_eigenvalues), vmax=max(filtered_min_eigenvalues))
sm = ScalarMappable(cmap='rainbow', norm=norm)
sm.set_array([])

cbar = fig.colorbar(sm, ax=ax, label=r'$\lambda_{\mathrm{min}}$')

ax.set_xlabel('Eigenvalue of H')
ax.set_ylabel('Entanglement entropy')
#ax.set_title('Entanglement entropy as a function of energy eigenvalues')
plt.show()
# Out:
# Entropies of red points:
# Index: 2957, Entropy: 4.176221972501163
# Index: 2958, Entropy: 4.374190368830662
# Index: 2959, Entropy: 3.123382916425103
# Index: 2960, Entropy: 4.078575643903054
# Index: 2961, Entropy: 3.3519939070724756
# Random scar entropy: 4.439238583832642

# %%
#################### OPTIMAL LINEAR COMBINATION OF SCARS THAT  MINIMIZE/MAXIMIZE EE ##########################

# %%
# find entropy min coeffs - everything  has to be in torch

# Initialize parameters for the coefficients with all values equal
#params_real = torch.full((5,), 1/np.sqrt(10), requires_grad=True)
#params_imag = torch.full((5,), 1/np.sqrt(10), requires_grad=True)

# Initialize parameters for the coefficients with random values
params_real = torch.randn(5, requires_grad=True)
params_imag = torch.randn(5, requires_grad=True)

# Convert random_coeffs to PyTorch tensors
#params_real = torch.tensor(random_coeffs.real, dtype=torch.float, requires_grad=True)
#params_imag = torch.tensor(random_coeffs.imag, dtype=torch.float, requires_grad=True)

red_eigenvectors = [torch.tensor(vec, dtype=torch.complex64) for vec in rank_eigenvectors_np]



# Compute the linear combination using the defined function
psi = linear_combination(torch.complex(params_real, params_imag), red_eigenvectors)

# if the outer products between scarred states are computed before optimization loop
# ....

# Compute entanglement entropy
entropy = entanglement_entropy_torch(psi, N // 2, N) 
print(f'Initial Entropy: {entropy.item()}')

# Normalize the parameters to ensure the norm is 1
with torch.no_grad():
    norm = torch.norm(torch.complex(params_real, params_imag))
    params_real /= norm
    params_imag /= norm

# Define the optimizer
optimizer = optim.Adam([params_real, params_imag], lr=0.01)

# Lists to store the values of parameters and entropy
coeffs_history_min = []
entropy_history = []

# Optimization loop
num_iterations = 150
for _ in range(num_iterations):
    optimizer.zero_grad()
    
    # Combine real and imaginary parts for the coefficients
    coeffs = torch.complex(params_real, params_imag)
    
    # Normalize coefficients to project them onto the unit sphere
    coeffs = coeffs / torch.norm(coeffs)
    
    # Compute psi
    psi = linear_combination(coeffs, red_eigenvectors)
    
    # Compute entanglement entropy
    entropy = entanglement_entropy_torch(psi, N // 2, N) # it would be better to compute the outer product of the state before the optimization loop. but optimization is not taking too long so it's ok for now
    
    # Backpropagation
    entropy.backward()
    optimizer.step()
    
    # Normalize parameters again to ensure they stay on the unit sphere
    with torch.no_grad():
        norm = torch.norm(torch.complex(params_real, params_imag))
        params_real /= norm
        params_imag /= norm
    print("Coeffs norm:", torch.norm(torch.complex(params_real, params_imag)).detach().cpu().numpy())
    
    print(f'Entropy: {entropy.item()}')
    print(f'Coeffs: {coeffs.detach().cpu().numpy()}')

    # Store the values of parameters and entropy
    coeffs_history_min.append(coeffs.detach().cpu().numpy())
    entropy_history.append(entropy.item())

# Final optimized coefficients
optimized_coeffs = torch.complex(params_real, params_imag)
optimized_coeffs = optimized_coeffs / torch.norm(optimized_coeffs)

print("Optimized coefficients:", optimized_coeffs)

# Plot the value of parameters and entropy as a function of num_iterations
plt.figure(figsize=(12, 6))

# Plot entropy
plt.subplot(1, 2, 1)
plt.plot(entropy_history)
plt.xlabel('Iteration')
plt.ylabel('Entropy')
#plt.title('Entropy vs. Iterations')

# Plot coefficients
plt.subplot(1, 2, 2)
coeffs_history_min = np.array(coeffs_history_min)
for i in range(coeffs_history_min.shape[1]):
    plt.plot(coeffs_history_min[:, i].real, label=f'Coeff {i+1} Real')
    plt.plot(coeffs_history_min[:, i].imag, label=f'Coeff {i+1} Imag', linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Coefficient Value')
#plt.title('Coefficients vs. Iterations')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Initial Entropy: 4.436772346496582
# Coeffs norm: 0.99999994
# Entropy: 4.436771392822266
# Coeffs: [-0.3164324 -0.24137488j -0.27753595-0.07107923j  0.19928715+0.13912687j
#  -0.7592487 -0.19083983j  0.2688077 -0.12378431j]
# Coeffs norm: 1.0
# Entropy: 4.414591312408447
# Coeffs: [-0.3050839 -0.2303567j  -0.26635864-0.06081045j  0.20836617+0.14847063j
#  -0.76586354-0.18004403j  0.27758077-0.13319558j]
# Coeffs norm: 1.0
# Entropy: 4.390488147735596
# Coeffs: [-0.29348293-0.21915905j -0.25496435-0.05135579j  0.21720304+0.15762734j
#  -0.77167654-0.16911982j  0.28600368-0.14242572j]
# Coeffs norm: 1.0
# Entropy: 4.364545822143555
# Coeffs: [-0.2816266 -0.20778076j -0.24335322-0.04526257j  0.22577526+0.1665737j
#  -0.77661306-0.15806833j  0.29407012-0.15143366j]
# Coeffs norm: 0.99999994
# Entropy: 4.336627006530762
# Coeffs: [-0.26953158-0.19623685j -0.23154324-0.04488512j  0.23407269+0.17529555j
#  -0.7806327 -0.14690427j  0.30178764-0.16016953j]
# Coeffs norm: 0.99999994
# Entropy: 4.306683540344238
# Coeffs: [-0.25725576-0.18457383j -0.21958858-0.04841673j  0.24212244+0.18380934j
#  -0.78379637-0.13566625j  0.30920854-0.16860522j]
# Coeffs norm: 0.9999999
# Entropy: 4.274851322174072
# Coeffs: [-0.24485081-0.17283483j -0.20753789-0.05399302j  0.24995334+0.19213474j
#  -0.78612536-0.12438471j  0.31638566-0.17672634j]
# Coeffs norm: 1.0
# Entropy: 4.241344928741455
# Coeffs: [-0.23236485-0.16106284j -0.1954364 -0.06071587j  0.25759822+0.20029485j
#  -0.7875889 -0.11308286j  0.32337397-0.18453753j]
# Coeffs norm: 1.0
# Entropy: 4.206357955932617
# Coeffs: [-0.2198521 -0.14930879j -0.18333368-0.06815496j  0.2651058 +0.20832542j
#  -0.7881132 -0.10178405j  0.3302443 -0.19207127j]
# Coeffs norm: 1.0
# Entropy: 4.170106410980225
# Coeffs: [-0.20737638-0.13763493j -0.17128603-0.07608826j  0.27254975+0.21628217j
#  -0.78757787-0.09051488j  0.33709362-0.19939439j]
# Coeffs norm: 1.0
# Entropy: 4.132745265960693
# Coeffs: [-0.19500715-0.1261137j  -0.15935273-0.08439821j  0.28003085+0.2242434j
#  -0.78581405-0.07930349j  0.34404743-0.20660952j]
# Coeffs norm: 0.99999994
# Entropy: 4.094376564025879
# Coeffs: [-0.18280515-0.11482068j -0.14758374-0.09302266j  0.28766268+0.23229884j
#  -0.7826266 -0.06817311j  0.35124144-0.2138437j ]
# Coeffs norm: 0.99999994
# Entropy: 4.055057525634766
# Coeffs: [-0.17079894-0.10382491j -0.1360009 -0.10191947j  0.2955329 +0.2405185j
#  -0.7778526 -0.05713473j  0.35877472-0.22121765j]
# Coeffs norm: 1.0
# Entropy: 4.0148396492004395
# Coeffs: [-0.15897036-0.09318852j -0.12458754-0.11103542j  0.30366096+0.24891722j
#  -0.7714255 -0.04618756j  0.36665928-0.22881044j]
# Coeffs norm: 0.99999994
# Entropy: 3.9738540649414062
# Coeffs: [-0.14726669-0.0829861j  -0.11330013-0.12028881j  0.31199107+0.2574472j
#  -0.76339126-0.03533197j  0.37481323-0.23664872j]
# Coeffs norm: 0.99999994
# Entropy: 3.932304859161377
# Coeffs: [-0.13562915-0.07333343j -0.10209217-0.12956937j  0.32042423+0.266023j
#  -0.75386775-0.024586j    0.38310042-0.24472284j]
# Coeffs norm: 1.0
# Entropy: 3.8904504776000977
# Coeffs: [-0.12401424-0.06440816j -0.09093116-0.13874498j  0.32885608+0.2745524j
#  -0.7429974 -0.01399573j  0.39137593-0.25300604j]
# Coeffs norm: 0.99999994
# Entropy: 3.848573684692383
# Coeffs: [-0.11240062-0.05645248j -0.07980352-0.14766608j  0.33719915+0.28295553j
#  -0.73092526-0.00363888j  0.3995122 -0.26146373j]
# Coeffs norm: 0.99999994
# Entropy: 3.806932210922241
# Coeffs: [-0.10078707-0.04975215j -0.06871225-0.15616706j  0.3453906 +0.29117212j
#  -0.7177946 +0.00637574j  0.40740713-0.27005777j]
# Coeffs norm: 1.0000001
# Entropy: 3.765735387802124
# Coeffs: [-0.08918726-0.04458785j -0.05767257-0.1640683j   0.35339162+0.29916212j
#  -0.70374954+0.01591137j  0.41498253-0.27875155j]
# Coeffs norm: 0.9999999
# Entropy: 3.7251477241516113
# Coeffs: [-0.07762478-0.04116902j -0.04670788-0.17118381j  0.36118445+0.30690414j
#  -0.68893623+0.02481014j  0.42218018-0.28751487j]
# Coeffs norm: 1.0
# Entropy: 3.685326099395752
# Coeffs: [-0.06612867-0.03958003j -0.03584661-0.1773379j   0.368767  +0.31439188j
#  -0.6735004 +0.03290421j  0.42895594-0.29632193j]
# Coeffs norm: 0.99999994
# Entropy: 3.646456241607666
# Coeffs: [-0.05473028-0.03976887j -0.02512043-0.18239166j  0.37614793+0.3216303j
#  -0.6575834 +0.04003088j  0.4352739 -0.30513978j]
# Coeffs norm: 0.99999994
# Entropy: 3.60876727104187
# Coeffs: [-0.04346158-0.04157872j -0.01456358-0.18627387j  0.38334286+0.32863274j
#  -0.64131963+0.04604965j  0.44110373-0.31390652j]
# Coeffs norm: 0.99999994
# Entropy: 3.572582244873047
# Coeffs: [-0.03235448-0.04479611j -0.00421327-0.1890055j   0.39037386+0.3354209j
#  -0.62483907+0.05085883j  0.44642183-0.32249647j]
# Coeffs norm: 1.0
# Entropy: 3.5382535457611084
# Coeffs: [-0.02144095-0.04919145j  0.00588965-0.19070858j  0.39727533+0.34203044j
#  -0.6082781 +0.05440921j  0.4512206 -0.3306676j ]
# Coeffs norm: 1.0
# Entropy: 3.5061943531036377
# Coeffs: [-0.01075282-0.05454347j  0.0157005 -0.19159815j  0.40410674+0.34852326j
#  -0.5917983 +0.05671272j  0.45552608-0.33798936j]
# Coeffs norm: 1.0
# Entropy: 3.47678804397583
# Coeffs: [-3.2031082e-04-0.06065047j  2.5171297e-02-0.19195656j
#   4.1096696e-01+0.3550019j  -5.7560253e-01+0.05784441j
#   4.5941722e-01-0.34379068j]
# Coeffs norm: 1.0
# Entropy: 3.450368642807007
# Coeffs: [ 0.00982977-0.06733026j  0.03424965-0.19207887j  0.41798353+0.36160332j
#  -0.5599145 +0.05793494j  0.463017  -0.34726074j]
# Coeffs norm: 1.0
# Entropy: 3.427161931991577
# Coeffs: [ 0.01967139-0.07440694j  0.04286989-0.19218007j  0.4252517 +0.36844942j
#  -0.5448977 +0.05715355j  0.46642858-0.3478162j ]
# Coeffs norm: 1.0
# Entropy: 3.407388687133789
# Coeffs: [ 0.02916885-0.08169011j  0.05093688-0.1923041j   0.43276924+0.37559357j
#  -0.53058785+0.05569312j  0.46967047-0.34543493j]
# Coeffs norm: 0.99999994
# Entropy: 3.3912763595581055
# Coeffs: [ 0.0382665 -0.08896209j  0.05831464-0.19230051j  0.4404497 +0.38303393j
#  -0.51693684+0.05377157j  0.4727005 -0.34054306j]
# Coeffs norm: 0.99999994
# Entropy: 3.379192590713501
# Coeffs: [ 0.04688371-0.0959729j   0.06481924-0.1918635j   0.44817775+0.39076328j
#  -0.50390273+0.05164414j  0.47548962-0.3336818j ]
# Coeffs norm: 1.0
# Entropy: 3.3711390495300293
# Coeffs: [ 0.05490071-0.10244997j  0.07017297-0.1906632j   0.45581806+0.39878088j
#  -0.4915015 +0.04959498j  0.4780818 -0.3253021j ]
# Coeffs norm: 1.0
# Entropy: 3.365602731704712
# Coeffs: [ 0.0621835 -0.10824679j  0.07415877-0.18899228j  0.46322337+0.40703148j
#  -0.479753  +0.04778206j  0.48045656-0.31569493j]
# Coeffs norm: 1.0
# Entropy: 3.3612799644470215
# Coeffs: [ 0.06861291-0.11329512j  0.07671061-0.18717788j  0.47029954+0.41547763j
#  -0.46870148+0.04631507j  0.48251945-0.3050933j ]
# Coeffs norm: 1.0000001
# Entropy: 3.357121229171753
# Coeffs: [ 0.07409177-0.11761072j  0.07786182-0.18554889j  0.47699407+0.42409378j
#  -0.45839483+0.04523842j  0.48414007-0.29367423j]
# Coeffs norm: 1.0
# Entropy: 3.3524115085601807
# Coeffs: [ 0.07854109-0.1212834j   0.07771134-0.18432564j  0.48329306+0.43287334j
#  -0.4488897 +0.04454022j  0.48516294-0.2815781j ]
# Coeffs norm: 1.0
# Entropy: 3.346505641937256
# Coeffs: [ 0.08190843-0.1245293j   0.07638555-0.18348388j  0.4892191 +0.44182807j
#  -0.44024044+0.04410587j  0.48544532-0.26892546j]
# Coeffs norm: 1.0
# Entropy: 3.3388748168945312
# Coeffs: [ 0.08417989-0.12761499j  0.07400618-0.18284868j  0.49481407+0.45097667j
#  -0.4324596 +0.04377327j  0.48488933-0.2558157j ]
# Coeffs norm: 0.99999994
# Entropy: 3.329144239425659
# Coeffs: [ 0.0853712 -0.13078421j  0.07068636-0.18221642j  0.50012666+0.46033844j
#  -0.42551523+0.04339062j  0.48342717-0.24232626j]
# Coeffs norm: 1.0
# Entropy: 3.317070722579956
# Coeffs: [ 0.08551779-0.13423662j  0.06653141-0.18140352j  0.50520587+0.46992952j
#  -0.41933793+0.04283303j  0.4810082 -0.2285152j ]
# Coeffs norm: 1.0
# Entropy: 3.3024885654449463
# Coeffs: [ 0.08466759-0.13811919j  0.06163905-0.18027483j  0.51009583+0.47975922j
#  -0.4138259 +0.04200921j  0.47759312-0.21442388j]
# Coeffs norm: 1.0
# Entropy: 3.285320281982422
# Coeffs: [ 0.08287581-0.14252366j  0.05609964-0.17876j     0.51483274+0.48982733j
#  -0.40884933+0.04086436j  0.47315234-0.20007998j]
# Coeffs norm: 0.99999994
# Entropy: 3.2655415534973145
# Coeffs: [ 0.08020133-0.1474889j   0.04999697-0.17685719j  0.5194421 +0.50012225j
#  -0.40425408+0.03938054j  0.46766624-0.18550055j]
# Coeffs norm: 1.0
# Entropy: 3.243178606033325
# Coeffs: [ 0.0767044 -0.15300737j  0.04340933-0.17462528j  0.5239391 +0.51062137j
#  -0.39986655+0.03757504j  0.4611274 -0.17069577j]
# Coeffs norm: 1.0
# Entropy: 3.218303680419922
# Coeffs: [ 0.07244537-0.15903345j  0.03641069-0.17216757j  0.5283297 +0.52129287j
#  -0.39549902+0.03549759j  0.4535425 -0.15567234j]
# Coeffs norm: 0.99999994
# Entropy: 3.19098162651062
# Coeffs: [ 0.0674841 -0.1654925j   0.02907198-0.16960984j  0.5326133 +0.53209865j
#  -0.39095652+0.03322666j  0.44493392-0.14043649j]
# Coeffs norm: 1.0
# Entropy: 3.161283493041992
# Coeffs: [ 0.06187963-0.17228964j  0.02146195-0.16707464j  0.5367854 +0.54299784j
#  -0.38604477+0.03086504j  0.43533936-0.12499605j]
# Coeffs norm: 1.0
# Entropy: 3.1292619705200195
# Coeffs: [ 0.05568988-0.17931776j  0.01364786-0.16465513j  0.54084015+0.5539492j
#  -0.38057908+0.02853435j  0.42481032-0.10936179j]
# Coeffs norm: 1.0000001
# Entropy: 3.0949418544769287
# Coeffs: [ 0.04897131-0.18646538j  0.00569584-0.16239434j  0.5447713 +0.56491333j
#  -0.3743945 +0.02636779j  0.4134096 -0.09354782j]
# Coeffs norm: 0.9999999
# Entropy: 3.0583293437957764
# Coeffs: [ 0.04177834-0.19362396j -0.00232895-0.16027655j  0.5485719 +0.57585174j
#  -0.36735424+0.02450058j  0.40120712-0.0775712j ]
# Coeffs norm: 0.99999994
# Entropy: 3.019432306289673
# Coeffs: [ 0.03416286-0.20069548j -0.01036219-0.15823601j  0.5522318 +0.5867239j
#  -0.35935652+0.02305784j  0.38827616-0.0614513j ]
# Coeffs norm: 0.99999994
# Entropy: 2.978278636932373
# Coeffs: [ 0.02617387-0.20759921j -0.01834027-0.15618216j  0.555734  +0.59748286j
#  -0.35033762+0.02214105j  0.3746889 -0.04520921j]
# Coeffs norm: 1.0
# Entropy: 2.934933662414551
# Coeffs: [ 0.01785755-0.21427804j -0.02620001-0.15403545j  0.55905145+0.6080703j
#  -0.34027138+0.02181523j  0.36051473-0.02886754j]
# Coeffs norm: 0.9999999
# Entropy: 2.8895187377929688
# Coeffs: [ 0.00925768-0.22070208j -0.03387851-0.15176159j  0.5621446 +0.6184133j
#  -0.3291651 +0.02209992j  0.3458192 -0.01245075j]
# Coeffs norm: 1.0
# Entropy: 2.8422558307647705
# Coeffs: [ 4.1646196e-04-0.22686902j -4.1313235e-02-0.14939013j
#   5.6496167e-01+0.6284245j  -3.1705415e-01+0.02296651j
#   3.3066630e-01+0.0040141j ]
# Coeffs norm: 0.99999994
# Entropy: 2.7934231758117676
# Coeffs: [-0.00862467-0.23280022j -0.04844271-0.14700669j  0.56744266+0.6380065j
#  -0.30399644+0.02434298j  0.31512234+0.02049662j]
# Coeffs norm: 0.99999994
# Entropy: 2.743389844894409
# Coeffs: [-0.01782451-0.23853306j -0.05520804-0.14471576j  0.5695259 +0.6470613j
#  -0.29006815+0.02612538j  0.29926157+0.03696283j]
# Coeffs norm: 1.0
# Entropy: 2.6925764083862305
# Coeffs: [-0.02714212-0.24411023j -0.06155495-0.14258452j  0.5711558 +0.65550137j
#  -0.27536026+0.0281936j   0.2831716 +0.05337588j]
# Coeffs norm: 1.0
# Entropy: 2.641446828842163
# Coeffs: [-0.03653755-0.24956854j -0.0674367 -0.14058976j  0.57228976+0.66326076j
#  -0.2599753 +0.03042869j  0.26695752+0.06969766j]
# Coeffs norm: 0.99999994
# Entropy: 2.5904903411865234
# Coeffs: [-0.04597286-0.25492874j -0.0728167 -0.1385894j   0.57290137+0.67030144j
#  -0.2440235 +0.03272898j  0.25074425+0.08589088j]
# Coeffs norm: 1.0
# Entropy: 2.540226459503174
# Coeffs: [-0.05541332-0.26019317j -0.07767266-0.13638581j  0.57297486+0.6766079j
#  -0.22761686+0.0350132j   0.23467682+0.10192082j]
# Coeffs norm: 1.0
# Entropy: 2.49115252494812
# Coeffs: [-0.06482707-0.26534685j -0.0819967 -0.1338259j   0.5724968 +0.6821749j
#  -0.21086313+0.03721744j  0.2189196 +0.11775555j]
# Coeffs norm: 1.0
# Entropy: 2.4437553882598877
# Coeffs: [-0.07418416-0.27036142j -0.08579344-0.13089164j  0.5714496 +0.6869968j
#  -0.19386242+0.03929037j  0.20365748+0.13336515j]
# Coeffs norm: 1.0
# Entropy: 2.398466110229492
# Coeffs: [-0.08345564-0.27519754j -0.08907746-0.12770769j  0.56981224+0.6910663j
#  -0.17670734+0.04119587j  0.18909906+0.14872058j]
# Coeffs norm: 0.99999994
# Entropy: 2.3556463718414307
# Coeffs: [-0.09261335-0.27980748j -0.0918703 -0.12448609j  0.5675656 +0.6943807j
#  -0.15948479+0.04291945j  0.17547862+0.16379298j]
# Coeffs norm: 0.99999994
# Entropy: 2.3155410289764404
# Coeffs: [-0.10163108-0.28413713j -0.09419902-0.12140468j  0.56470144+0.6969554j
#  -0.14227906+0.04447968j  0.16305482+0.1785543j ]
# Coeffs norm: 1.0
# Entropy: 2.2782678604125977
# Coeffs: [-0.11048526-0.28812888j -0.096092  -0.11852168j  0.56122804+0.6988308j
#  -0.1251725 +0.04593273j  0.1520993 +0.19297749j]
# Coeffs norm: 1.0
# Entropy: 2.2438361644744873
# Coeffs: [-0.11915498-0.29173234j -0.09757559-0.11578183j  0.55716825+0.70006716j
#  -0.1082447 +0.0473601j   0.14287618+0.20703597j]
# Coeffs norm: 1.0
# Entropy: 2.2121422290802
# Coeffs: [-0.12762149-0.29491043j -0.09866963-0.11304454j  0.55255693+0.70073783j
#  -0.09157198+0.0488579j   0.1356142 +0.22070235j]
# Coeffs norm: 0.99999994
# Entropy: 2.18302059173584
# Coeffs: [-0.13586557-0.29765397j -0.09938294-0.11021971j  0.5474306 +0.7009086j
#  -0.07522626+0.05050717j  0.13047683+0.23394471j]
# Coeffs norm: 1.0
# Entropy: 2.156289577484131
# Coeffs: [-0.14386576-0.29998928j -0.09971124-0.10735118j  0.54182225+0.70062643j
#  -0.05927646+0.05235405j  0.12754078+0.24672364j]
# Coeffs norm: 1.0
# Entropy: 2.1318001747131348
# Coeffs: [-0.15159765-0.3019755j  -0.09963697-0.10459945j  0.535763  +0.69992083j
#  -0.04379097+0.05440526j  0.12678936+0.25899062j]
# Coeffs norm: 1.0
# Entropy: 2.1094651222229004
# Coeffs: [-0.15903544-0.30369505j -0.09913503-0.10213672j  0.5292879 +0.6988164j
#  -0.02884111+0.05663565j  0.12812354+0.27068868j]
# Coeffs norm: 1.0
# Entropy: 2.08927845954895
# Coeffs: [-0.16615357-0.30523613j -0.09817617-0.10001751j  0.5224434 +0.69734925j
#  -0.01450299+0.05900445j  0.1313826 +0.28175434j]
# Coeffs norm: 0.99999994
# Entropy: 2.0712907314300537
# Coeffs: [-0.17292719-0.30668014j -0.09673332-0.09814464j  0.5152896 +0.6955732j
#  -0.0008594 +0.06146217j  0.13636951+0.29211888j]
# Coeffs norm: 0.99999994
# Entropy: 2.0556447505950928
# Coeffs: [-0.17933029-0.3080869j  -0.09478361-0.09632427j  0.5078985 +0.6935593j
#   0.01199714+0.06395628j  0.14287402+0.30170888j]
# Coeffs norm: 1.0
# Entropy: 2.04241943359375
# Coeffs: [-0.18532747-0.3094979j  -0.09230917-0.09442313j  0.50034475+0.69138056j
#   0.02394611+0.06647817j  0.15070361+0.31043825j]
# Coeffs norm: 0.9999999
# Entropy: 2.0314016342163086
# Coeffs: [-0.19089206-0.31094924j -0.08932054-0.0925826j   0.49269605+0.68909746j
#   0.03489163+0.06903779j  0.15961558+0.31820688j]
# Coeffs norm: 0.9999999
# Entropy: 2.022657871246338
# Coeffs: [-0.19601431-0.31241113j -0.085861  -0.09103145j  0.48503795+0.68679565j
#   0.04476435+0.07144042j  0.16933997+0.3249387j ]
# Coeffs norm: 0.99999994
# Entropy: 2.016357421875
# Coeffs: [-0.2006952 -0.313808j   -0.08200344-0.08994731j  0.47747454+0.6845882j
#   0.05350349+0.0734266j   0.17959952+0.3305721j ]
# Coeffs norm: 0.99999994
# Entropy: 2.012647867202759
# Coeffs: [-0.2049419 -0.315032j   -0.07784093-0.08933086j  0.47013587+0.6826164j
#   0.06105489+0.07476627j  0.19009815+0.33506215j]
# Coeffs norm: 1.0
# Entropy: 2.0115060806274414
# Coeffs: [-0.20876303-0.31597796j -0.07348948-0.0890426j   0.46317258+0.68102413j
#   0.06737407+0.07533884j  0.20049964+0.33839145j]
# Coeffs norm: 1.0
# Entropy: 2.012460470199585
# Coeffs: [-0.21216601-0.3165754j  -0.06908134-0.08878244j  0.45674503+0.6799282j
#   0.07244658+0.07523184j  0.21042599+0.3405954j ]
# Coeffs norm: 1.0
# Entropy: 2.0147128105163574
# Coeffs: [-0.21516033-0.3168141j  -0.06475194-0.08824755j  0.4509869 +0.6793858j
#   0.07630503+0.07473712j  0.21951269+0.34176928j]
# Coeffs norm: 0.99999994
# Entropy: 2.0174639225006104
# Coeffs: [-0.21775746-0.31674448j -0.06062107-0.08741284j  0.4459758 +0.6793828j
#   0.07902107+0.07420696j  0.22746857+0.34203845j]
# Coeffs norm: 1.0
# Entropy: 2.0201382637023926
# Coeffs: [-0.21996816-0.31646642j -0.05678748-0.08662987j  0.44173372+0.67984533j
#   0.08068703+0.0739051j   0.23409289+0.34153098j]
# Coeffs norm: 0.99999994
# Entropy: 2.022341012954712
# Coeffs: [-0.22180225-0.3161123j  -0.05333357-0.08643352j  0.4382441 +0.68066764j
#   0.08140416+0.07393272j  0.23927101+0.34037027j]
# Coeffs norm: 1.0
# Entropy: 2.023834705352783
# Coeffs: [-0.22327481-0.31581014j -0.05033109-0.08707023j  0.43547893+0.68176115j
#   0.08127856+0.07425041j  0.24296957+0.33868015j]
# Coeffs norm: 1.0
# Entropy: 2.024533271789551
# Coeffs: [-0.22440746-0.31565675j -0.0478412 -0.08828159j  0.4334129 +0.68307817j
#   0.08041907+0.07472266j  0.24522565+0.33658704j]
# Coeffs norm: 1.0
# Entropy: 2.0244479179382324
# Coeffs: [-0.22522373-0.31570697j -0.04590904-0.08948256j  0.43202567+0.6846035j
#   0.07893562+0.07515986j  0.24612926+0.33421698j]
# Coeffs norm: 1.0
# Entropy: 2.023611068725586
# Coeffs: [-0.22574101-0.3159654j  -0.04456307-0.09022358j  0.4312893 +0.6863205j
#   0.07693527+0.07536209j  0.24580246+0.3316883j ]
# Coeffs norm: 1.0
# Entropy: 2.022106170654297
# Coeffs: [-0.22596802-0.31637782j -0.04381382-0.09052566j  0.43115658+0.6881839j
#   0.07451648+0.07517726j  0.24437942+0.32910532j]
# Coeffs norm: 1.0
# Entropy: 2.0200538635253906
# Coeffs: [-0.22590807-0.31685364j -0.0436491 -0.09079365j  0.43156338+0.6901211j
#   0.07176723+0.07453768j  0.24199523+0.32655537j]
# Coeffs norm: 1.0
# Entropy: 2.0175952911376953
# Coeffs: [-0.22556566-0.31729013j -0.04403438-0.09138486j  0.4324434 +0.6920626j
#   0.06876816+0.07349223j  0.23878887+0.3241122j ]
# Coeffs norm: 1.0
# Entropy: 2.0148940086364746
# Coeffs: [-0.2249523 -0.31758398j -0.04491847-0.09226557j  0.43374044+0.6939694j
#   0.06559521+0.07221834j  0.23490928+0.3218406j ]
# Coeffs norm: 1.0
# Entropy: 2.0121347904205322
# Coeffs: [-0.22408372-0.31765783j -0.04623307-0.09310532j  0.43540612+0.69582283j
#   0.06232096+0.07096893j  0.23051262+0.31979594j]
# Coeffs norm: 1.0
# Entropy: 2.009472131729126
# Coeffs: [-0.22297642-0.3174839j  -0.04790433-0.09358687j  0.43738547+0.69759613j
#   0.05901143+0.06998681j  0.22576098+0.318021j  ]
# Coeffs norm: 0.99999994
# Entropy: 2.0070691108703613
# Coeffs: [-0.221638  -0.31711283j -0.0498437 -0.09381326j  0.4396035 +0.69921505j
#   0.05572785+0.0693954j   0.22081201+0.3165415j ]
# Coeffs norm: 1.0
# Entropy: 2.005070686340332
# Coeffs: [-0.22007485-0.31664836j -0.05195775-0.0941058j   0.44197255+0.7005835j
#   0.05252793+0.06919298j  0.21582773+0.3153729j ]
# Coeffs norm: 1.0
# Entropy: 2.0035715103149414
# Coeffs: [-0.21830162-0.31620976j -0.05415278-0.09462037j  0.44440776+0.7016266j
#   0.04946894+0.06929775j  0.21098417+0.31452894j]
# Coeffs norm: 0.99999994
# Entropy: 2.0026254653930664
# Coeffs: [-0.21634898-0.31589675j -0.05634307-0.09514421j  0.44683552+0.702319j
#   0.04660834+0.06959582j  0.20647839+0.31402576j]
# Coeffs norm: 0.99999994
# Entropy: 2.0022130012512207
# Coeffs: [-0.21425934-0.3157782j  -0.05844486-0.09535641j  0.44918543+0.7026689j
#   0.04400425+0.06994797j  0.20251554+0.31387222j]
# Coeffs norm: 1.0
# Entropy: 2.0022003650665283
# Coeffs: [-0.21208233-0.31587732j -0.06037622-0.09515658j  0.45138383+0.70269865j
#   0.04171157+0.07021145j  0.19927692+0.31405276j]
# Coeffs norm: 0.99999994
# Entropy: 2.0024008750915527
# Coeffs: [-0.20986944-0.3161637j  -0.0620657 -0.09477459j  0.45336077+0.70243734j
#   0.03977317+0.07028377j  0.19687831+0.31452197j]
# Coeffs norm: 0.99999994
# Entropy: 2.0026495456695557
# Coeffs: [-0.20767151-0.31656054j -0.0634618 -0.09452847j  0.4550663 +0.7019289j
#   0.0382153 +0.07014839j  0.19535804+0.3152199j ]
# Coeffs norm: 0.99999994
# Entropy: 2.002838373184204
# Coeffs: [-0.20554042-0.31695938j -0.06453622-0.09449909j  0.4564799 +0.7012461j
#   0.03704989+0.06989335j  0.194693  +0.31608856j]
# Coeffs norm: 0.99999994
# Entropy: 2.0029354095458984
# Coeffs: [-0.20353019-0.31724527j -0.06528372-0.09446959j  0.4576062 +0.700485j
#   0.03627817+0.06967984j  0.19481556+0.31707627j]
# Coeffs norm: 1.0
# Entropy: 2.002922773361206
# Coeffs: [-0.2016911 -0.3173382j  -0.06571592-0.09421869j  0.45845672+0.69972974j
#   0.03589338+0.06967866j  0.19562015+0.31812993j]
# Coeffs norm: 1.0
# Entropy: 2.002819538116455
# Coeffs: [-0.20006302-0.31721896j -0.06585411-0.09379325j  0.4590351 +0.6990229j
#   0.03587465+0.06997716j  0.19697765+0.31919092j]
# Coeffs norm: 1.0000001
# Entropy: 2.002657890319824
# Coeffs: [-0.19867831-0.31692836j -0.06572534-0.09346996j  0.45933956+0.69837224j
#   0.03618583+0.07050445j  0.19874556+0.3202033j ]
# Coeffs norm: 1.0
# Entropy: 2.0024752616882324
# Coeffs: [-0.19756521-0.3165768j  -0.06536842-0.09341037j  0.45937365+0.6977773j
#   0.03678139+0.07105929j  0.20077941+0.3211176j ]
# Coeffs norm: 0.99999994
# Entropy: 2.002279758453369
# Coeffs: [-0.1967447 -0.31626529j -0.06483404-0.09351305j  0.45915914+0.6972564j
#   0.03761553+0.071457j    0.20294403+0.3218987j ]
# Coeffs norm: 0.99999994
# Entropy: 2.002089500427246
# Coeffs: [-0.19623001-0.31606132j -0.06417897-0.09353349j  0.45873022+0.69683987j
#   0.03864165+0.07160023j  0.2051133 +0.3225234j ]
# Coeffs norm: 0.99999994
# Entropy: 2.001904249191284
# Coeffs: [-0.19602364-0.31599453j -0.06346007-0.09333971j  0.4581222 +0.6965479j
#   0.03981113+0.07149208j  0.20716843+0.32297537j]
# Coeffs norm: 1.0
# Entropy: 2.0017192363739014
# Coeffs: [-0.19611393-0.316063j   -0.06272481-0.09306299j  0.45736626+0.69637656j
#   0.04107478+0.07121246j  0.20899719+0.32324308j]
# Coeffs norm: 1.0
# Entropy: 2.001542091369629
# Coeffs: [-0.1964791 -0.31623396j -0.062013  -0.09291731j  0.45649475+0.6963138j
#   0.04238373+0.070896j    0.2105031 +0.32332397j]
# Coeffs norm: 0.99999994
# Entropy: 2.0013556480407715
# Coeffs: [-0.19709188-0.31645378j -0.06135951-0.09298574j  0.45554727+0.696357j
#   0.04369091+0.070687j    0.21161588+0.3232294j ]
# Coeffs norm: 0.99999994
# Entropy: 2.0011539459228516
# Coeffs: [-0.19792117-0.31666595j -0.06079298-0.093174j    0.45457006+0.69651496j
#   0.0449525 +0.07067829j  0.21229687+0.32298565j]
# Coeffs norm: 1.0
# Entropy: 2.0009384155273438
# Coeffs: [-0.19893101-0.3168284j  -0.06033451-0.09332553j  0.45360866+0.6967949j
#   0.04612885+0.0708679j   0.21253896+0.3226292j ]
# Coeffs norm: 1.0
# Entropy: 2.0007214546203613
# Coeffs: [-0.2000793 -0.3169233j  -0.05999734-0.09337051j  0.4526996 +0.69718903j
#   0.04718413+0.07115632j  0.21236368+0.32219997j]
# Coeffs norm: 1.0000001
# Entropy: 2.00053071975708
# Coeffs: [-0.20131765-0.31695735j -0.05978616-0.09337685j  0.45186675+0.697669j
#   0.04808601+0.07139102j  0.21181849+0.3217361j ]
# Coeffs norm: 1.0000001
# Entropy: 2.000378131866455
# Coeffs: [-0.20259336-0.3169545j  -0.05969484-0.09346886j  0.4511229 +0.69819236j
#   0.04880704+0.07143906j  0.21097352+0.32127225j]
# Coeffs norm: 1.0
# Entropy: 2.0002851486206055
# Coeffs: [-0.20385255-0.31694058j -0.0597068 -0.09367442j  0.45047715+0.6987184j
#   0.04932398+0.07125363j  0.2099226 +0.32084033j]
# Coeffs norm: 0.99999994
# Entropy: 2.000255823135376
# Coeffs: [-0.20504442-0.31693837j -0.05979824-0.09387393j  0.4499345 +0.69921416j
#   0.04961916+0.07091894j  0.20877574+0.320466j  ]
# Coeffs norm: 1.0000001
# Entropy: 2.0002846717834473
# Coeffs: [-0.20612395-0.31696233j -0.05993936-0.09393697j  0.44949636+0.6996514j
#   0.0496968 +0.07060533j  0.20763102+0.32016632j]
# Coeffs norm: 1.0
# Entropy: 2.000345468521118
# Coeffs: [-0.20704861-0.31701246j -0.06010147-0.09390329j  0.44915718+0.69999915j
#   0.04957817+0.07045518j  0.20657474+0.31994992j]
# Coeffs norm: 1.0
# Entropy: 2.000417709350586
# Coeffs: [-0.20778413-0.3170808j  -0.06026123-0.0938896j   0.44890866+0.70023423j
#   0.04929381+0.07051801j  0.20568047+0.3198199j ]
# Coeffs norm: 1.0
# Entropy: 2.000476837158203
# Coeffs: [-0.20831093-0.31716725j -0.06039693-0.09399317j  0.44874263+0.7003467j
#   0.04887658+0.07072861j  0.20500113+0.31977597j]
# Coeffs norm: 1.0
# Entropy: 2.0005059242248535
# Coeffs: [-0.2086255 -0.31726456j -0.06049249-0.09411921j  0.4486595 +0.70035475j
#   0.0483611 +0.07097393j  0.20457028+0.31981826j]
# Coeffs norm: 1.0
# Entropy: 2.000495195388794
# Coeffs: [-0.20873594-0.31735864j -0.06053732-0.09412549j  0.4486617 +0.7002882j
#   0.0477816 +0.07114341j  0.20439918+0.31994382j]
# Coeffs norm: 1.0
# Entropy: 2.0004444122314453
# Coeffs: [-0.20865667-0.3174299j  -0.06052862-0.09399039j  0.4487454 +0.70017004j
#   0.04716979+0.07117173j  0.20447725+0.32014203j]
# Coeffs norm: 1.0
# Entropy: 2.000370740890503
# Coeffs: [-0.20840545-0.31745946j -0.0604686 -0.0938319j   0.448899  +0.70001024j
#   0.04655474+0.07106217j  0.20477279+0.32039356j]
# Coeffs norm: 0.99999994
# Entropy: 2.000278949737549
# Coeffs: [-0.20800489-0.31743464j -0.06036521-0.09376596j  0.4491085 +0.699816j
#   0.04596304+0.07088656j  0.20523906+0.32067403j]
# Coeffs norm: 1.0
# Entropy: 2.000196933746338
# Coeffs: [-0.20748298-0.3173551j  -0.06023146-0.09378862j  0.44936264+0.69960046j
#   0.04541904+0.07075149j  0.20581995+0.3209587j ]
# Coeffs norm: 1.0
# Entropy: 2.0001282691955566
# Coeffs: [-0.20687152-0.31723648j -0.06008128-0.09380248j  0.449654  +0.6993829j
#   0.044946  +0.07074172j  0.2064517 +0.3212237j ]
# Coeffs norm: 0.99999994
# Entropy: 2.0000905990600586
# Coeffs: [-0.20620617-0.3171096j  -0.05993574-0.09374359j  0.4499723 +0.69917864j
#   0.04456561+0.07087717j  0.20706643+0.32144743j]
# Coeffs norm: 0.99999994
# Entropy: 2.0000741481781006
# Coeffs: [-0.20552436-0.31700745j -0.05981391-0.09366126j  0.4503045 +0.69899684j
#   0.04429628+0.07107402j  0.2075961 +0.32161385j]
# Coeffs norm: 1.0
# Entropy: 2.00007700920105
# Coeffs: [-0.20485681-0.31695727j -0.05973517-0.09365235j  0.45063546+0.69884086j
#   0.04414392+0.07120275j  0.20799929+0.32171392j]
# Coeffs norm: 0.99999994
# Entropy: 2.0000863075256348
# Coeffs: [-0.20423608-0.31696793j -0.05971604-0.09367901j  0.45095298+0.698723j
#   0.04410626+0.07119416j  0.20825303+0.32174772j]
# Coeffs norm: 1.0
# Entropy: 2.000094175338745
# Coeffs: [-0.20368965-0.31702104j -0.05975975-0.09366026j  0.4512488 +0.6986578j
#   0.04417096+0.0710673j   0.20835228+0.3217209j ]
# Coeffs norm: 0.99999994
# Entropy: 2.0001003742218018
# Coeffs: [-0.20323886-0.31708136j -0.05986447-0.09360532j  0.45151043+0.69864845j
#   0.04432006+0.07090662j  0.20830493+0.32164156j]
# Coeffs norm: 1.0
# Entropy: 2.0001039505004883
# Coeffs: [-0.2028979 -0.31711605j -0.06002262-0.09356818j  0.45172495+0.69868976j
#   0.04453268+0.07080563j  0.20812996+0.32151952j]
# Coeffs norm: 1.0
# Entropy: 2.0000967979431152
# Coeffs: [-0.20267193-0.3171088j  -0.06022093-0.0936048j   0.45188162+0.6987699j
#   0.0447887 +0.07081442j  0.20785578+0.32136673j]
# Coeffs norm: 1.0
# Entropy: 2.0000905990600586
# Coeffs: [-0.2025582 -0.31706923j -0.06044357-0.09368714j  0.4519764 +0.698879j
#   0.04507066+0.07090946j  0.2075207 +0.3211974j ]
# Coeffs norm: 1.0
# Entropy: 2.000081777572632
# Coeffs: [-0.20255134-0.3170197j  -0.06067115-0.09376028j  0.45200866+0.6990061j
#   0.04535986+0.07101944j  0.2071643 +0.3210293j ]
# Coeffs norm: 1.0
# Entropy: 2.000075340270996
# Coeffs: [-0.2026404 -0.3169846j  -0.06088954-0.09377829j  0.45197922+0.69913983j
#   0.0456378 +0.07106721j  0.20682934+0.32087743j]
# Coeffs norm: 1.0
# Entropy: 2.0000691413879395
# Coeffs: [-0.20280942-0.31698054j -0.06107782-0.09377045j  0.45189118+0.69926375j
#   0.04588922+0.07101451j  0.20654695+0.32075274j]
# Coeffs norm: 1.0
# Entropy: 2.0000646114349365
# Coeffs: [-0.20303847-0.31700957j -0.06121714-0.09377979j  0.4517501 +0.6993626j
#   0.04609983+0.07089327j  0.20634252+0.3206614j ]
# Optimized coefficients: tensor([-0.2033-0.3171j, -0.0613-0.0938j,  0.4516+0.6994j,  0.0463+0.0708j,
#          0.2062+0.3206j], grad_fn=<DivBackward0>)

# %%
# Compute the max_scar wavefunction using the optimized coefficients (min entropy)
min_scar = linear_combination_np(coeffs_history_min[-1], rank_eigenvectors_np)
# Define a list of colors for red points
red_colors = plt.cm.rainbow(np.linspace(0, 1, len(rank_indices_np)))

# Compute entanglement entropy for the max_scar wavefunction
min_scar_entropy = entanglement_entropy(min_scar, N // 2, N)

# Print entropies of red points only
print("Entropies of red points:")
for i in red_indices_np:
    print(f'Index: {i}, Entropy: {numpy_entropies[i]}')

print(f'Min scar entropy: {min_scar_entropy}')

# Plot entanglement entropy as a function of energy eigenvalues
fig, ax = plt.subplots(figsize=(10, 6))

# Color only points with indices in rank_indices_np as red, all others as 'C0'
colors = ['red' if i in rank_indices_np else 'C0' for i in range(len(eigenvalues))]

# Plot entanglement entropy with highlighted points
for i, color in enumerate(colors):
    ax.plot(eigenvalues[i], numpy_entropies[i], 'o', color=color, markersize=2)

# Collect handles and labels for the legend
handles = []
labels = []

# Plot each red point with a different color and collect handles and labels
for i, idx in enumerate(rank_indices_np):
    handle, = ax.plot(eigenvalues[idx], numpy_entropies[idx], 'o', color=red_colors[i], markersize=5)
    handles.append(handle)
    labels.append(r'$\lambda_\mathrm{min}$: {float(min_eigenvalues[idx]):.2e}, Entropy: {naive_entropies[idx]:.2f}')

# Plot the maximum scar entropy in yellow and add to handles and labels
min_scar_handle, = ax.plot(np.mean(eigenvalues[rank_indices_np]), min_scar_entropy, 'x', color='black', markersize=7)
handles.append(min_scar_handle)
labels.append('Min Scar, Entropy: {:.2f}'.format(min_scar_entropy))

# Sort handles and labels by lambda min
sorted_handles_labels = sorted(zip(handles, labels), key=lambda hl: float(hl[1].split(': ')[1].split(',')[0]) if 'λ_min' in hl[1] else float('inf'))
sorted_handles, sorted_labels = zip(*sorted_handles_labels)

# Filter min_eigenvalues to include only those corresponding to red_indices
filtered_min_eigenvalues = [min_eigenvalues_np[idx] for idx in rank_indices_np]

# Create a color bar for the red points using filtered min_eigenvalues
norm = Normalize(vmin=min(filtered_min_eigenvalues), vmax=max(filtered_min_eigenvalues))
sm = ScalarMappable(cmap='rainbow', norm=norm)
sm.set_array([])

cbar = fig.colorbar(sm, ax=ax, label=r'$\lambda_{\mathrm{min}}$')

ax.set_xlabel('Eigenvalue of H')
ax.set_ylabel('Entanglement entropy')
plt.show()
# Out:
# Entropies of red points:
# Index: 1657, Entropy: 4.483221627069358
# Index: 1658, Entropy: 4.572218856637702
# Index: 1659, Entropy: 4.531279375932171
# Index: 1660, Entropy: 4.417158553924479
# Index: 1661, Entropy: 4.427124519507085
# Index: 1662, Entropy: 4.526438467597718
# Index: 1663, Entropy: 3.8024932733023444
# Index: 1664, Entropy: 4.325797882037353
# Index: 1665, Entropy: 4.696469702881059
# Index: 1666, Entropy: 4.4311861905344365
# Index: 1667, Entropy: 4.2972563607574985
# Index: 1668, Entropy: 4.227594093375242
# Index: 1669, Entropy: 4.484479903102301
# Index: 1670, Entropy: 4.5785998307993045
# Index: 1671, Entropy: 4.516587366726262
# Index: 1672, Entropy: 4.591157901267135
# Index: 1673, Entropy: 4.389345717102105
# Index: 1674, Entropy: 4.49356407342088
# Index: 1675, Entropy: 4.270094639154259
# Index: 1676, Entropy: 4.458042742257832
# Index: 1677, Entropy: 4.4167444231958175
# Index: 1678, Entropy: 4.362942323421351
# Index: 1679, Entropy: 4.600254286292383
# Index: 1680, Entropy: 4.36041981670371
# Index: 1681, Entropy: 4.59203768033351
# Index: 1682, Entropy: 4.579009839785965
# Index: 1683, Entropy: 4.380247273643493
# Index: 1684, Entropy: 4.227389232671224
# Index: 1685, Entropy: 4.671192096418328
# Index: 1686, Entropy: 4.486650464958888
# Index: 1687, Entropy: 4.593926516867507
# Index: 1688, Entropy: 4.3835045754272315
# Index: 1689, Entropy: 4.539967171109386
# Index: 1690, Entropy: 4.479267658489592
# Index: 1691, Entropy: 4.550722332696741
# Index: 1692, Entropy: 4.542159472486526
# Index: 1693, Entropy: 4.417416437357076
# Index: 1694, Entropy: 4.537142678170342
# Index: 1695, Entropy: 4.480547202215665
# Index: 1696, Entropy: 4.472131929868655
# Index: 1697, Entropy: 4.492175714212561
# Index: 1698, Entropy: 4.696081328397798
# Index: 1699, Entropy: 4.4147030213911735
# Index: 1700, Entropy: 4.272822131541767
# Index: 1701, Entropy: 4.530343153997826
# Index: 1892, Entropy: 4.569290664155203
# Index: 1893, Entropy: 4.0821113900144175
# Index: 1894, Entropy: 4.428764577500289
# Index: 1895, Entropy: 4.539316923332126
# Index: 1896, Entropy: 4.360213722622564
# Index: 1897, Entropy: 4.469679945240133
# Index: 1898, Entropy: 4.391226254255902
# Index: 1899, Entropy: 4.635304358306332
# Index: 1900, Entropy: 4.332004124176341
# Index: 1901, Entropy: 4.359650491202243
# Index: 1902, Entropy: 4.2627468283046825
# Index: 1903, Entropy: 4.5621588674194005
# Index: 1904, Entropy: 4.163752261222652
# Index: 1905, Entropy: 4.550348214015757
# Index: 1906, Entropy: 4.4504593483613455
# Index: 1907, Entropy: 4.071135028510184
# Index: 1908, Entropy: 4.454376398678749
# Index: 1909, Entropy: 4.420543655488669
# Index: 1910, Entropy: 4.398297716550093
# Index: 1911, Entropy: 4.438428056177207
# Index: 1912, Entropy: 4.4193295328801785
# Index: 1913, Entropy: 4.2687614734699295
# Index: 1914, Entropy: 4.353536251788411
# Index: 1915, Entropy: 4.317323057694425
# Index: 1916, Entropy: 4.425886662639918
# Index: 1917, Entropy: 4.341229380685065
# Index: 1918, Entropy: 4.28692126049909
# Index: 1919, Entropy: 4.404783156101571
# Index: 1920, Entropy: 4.537802027470471
# Index: 1921, Entropy: 4.465223600491283
# Index: 2957, Entropy: 4.176221972501163
# Index: 2958, Entropy: 4.374190368830662
# Index: 2959, Entropy: 3.123382916425103
# Index: 2960, Entropy: 4.078575643903054
# Index: 2961, Entropy: 3.3519939070724756
# Index: 3170, Entropy: 4.36297217652192
# Index: 3171, Entropy: 4.5792985354015
# Index: 3172, Entropy: 4.473941637983905
# Index: 3173, Entropy: 4.4686532598925215
# Index: 3174, Entropy: 4.645600803712706
# Index: 3175, Entropy: 4.206423576554159
# Index: 3176, Entropy: 4.465633618687047
# Index: 3177, Entropy: 4.477882291471716
# Index: 3178, Entropy: 4.372633245126589
# Index: 3179, Entropy: 4.393477414854339
# Index: 3180, Entropy: 4.513158530211209
# Index: 3181, Entropy: 4.021291207308796
# Index: 3182, Entropy: 4.530405337862388
# Index: 3183, Entropy: 4.4437122364657755
# Index: 3184, Entropy: 4.203577050011943
# Index: 3185, Entropy: 4.311478899523288
# Index: 3186, Entropy: 4.599586795266225
# Index: 3187, Entropy: 4.618993684542377
# Index: 3188, Entropy: 4.296063660830365
# Index: 3189, Entropy: 4.626561378992052
# Index: 3190, Entropy: 4.528568244792833
# Index: 3191, Entropy: 4.403156792728814
# Index: 3192, Entropy: 4.625821497664039
# Index: 3193, Entropy: 4.4534665362407075
# Index: 3194, Entropy: 4.527693610267548
# Index: 3195, Entropy: 4.278233403348835
# Index: 3196, Entropy: 4.673607169660798
# Index: 3197, Entropy: 4.42516542420231
# Index: 3198, Entropy: 4.637398692074787
# Index: 3199, Entropy: 4.521841090288426
# Index: 3200, Entropy: 4.591111148337882
# Index: 3201, Entropy: 4.286198661844765
# Index: 3202, Entropy: 4.2858216405572085
# Index: 3203, Entropy: 4.2193248375308325
# Index: 3204, Entropy: 4.465249295068203
# Index: 3205, Entropy: 4.4976990893440325
# Index: 3206, Entropy: 4.4775444411953105
# Index: 3207, Entropy: 4.50343053874378
# Index: 3208, Entropy: 4.2768338945233095
# Index: 3209, Entropy: 4.702905103209924
# Index: 3210, Entropy: 4.478792320492949
# Index: 3211, Entropy: 4.634237917195922
# Index: 3212, Entropy: 4.3854081778561484
# Index: 3213, Entropy: 4.118574598723554
# Index: 3214, Entropy: 4.423726227860792
# Index: 3395, Entropy: 4.365594729094141
# Index: 3396, Entropy: 4.370446590080884
# Index: 3397, Entropy: 4.532859694083175
# Index: 3398, Entropy: 4.436554473767885
# Index: 3399, Entropy: 4.383008389446818
# Index: 3400, Entropy: 4.432911922964883
# Index: 3401, Entropy: 4.6004436587815265
# Index: 3402, Entropy: 4.535200035536129
# Index: 3403, Entropy: 4.394507518918552
# Index: 3404, Entropy: 4.462074376832905
# Index: 3405, Entropy: 4.159721985027795
# Index: 3406, Entropy: 3.9974326855354465
# Index: 3407, Entropy: 4.08032606502554
# Index: 3408, Entropy: 4.26136583969109
# Index: 3409, Entropy: 4.451398731265483
# Index: 3410, Entropy: 4.334801050835083
# Index: 3411, Entropy: 4.479131735501755
# Index: 3412, Entropy: 4.530777242615087
# Index: 3413, Entropy: 4.4845594017484505
# Index: 3414, Entropy: 4.236676149438356
# Index: 3415, Entropy: 4.337394280256028
# Index: 3416, Entropy: 4.414535803769666
# Index: 3417, Entropy: 4.235537236802912
# Index: 3418, Entropy: 4.477196969259961
# Index: 3419, Entropy: 4.637583018437596
# Index: 3420, Entropy: 4.388405110658113
# Index: 3421, Entropy: 4.399518294969516
# Index: 3422, Entropy: 4.240459867492249
# Index: 3423, Entropy: 4.60522501966713
# Index: 3424, Entropy: 4.399056504874903
# Min scar entropy: 2.0000627268838493

# %%
# now find entropy max coeffs - everything  has to be in torch

# Initialize parameters for the coefficients with all values equal
#params_real = torch.full((5,), 1/np.sqrt(10), requires_grad=True)
#params_imag = torch.full((5,), 1/np.sqrt(10), requires_grad=True)

# Initialize parameters for the coefficients with random values
params_real = torch.randn(5, requires_grad=True)
params_imag = torch.randn(5, requires_grad=True)

# Convert random_coeffs to PyTorch tensors
#params_real = torch.tensor(random_coeffs.real, dtype=torch.float, requires_grad=True)
#params_imag = torch.tensor(random_coeffs.imag, dtype=torch.float, requires_grad=True)

print("Initial coeffs, real", params_real)
print("Initial coeffs imag",  params_imag)

# Compute psi
psi = linear_combination(torch.complex(params_real, params_imag), rank_eigenvectors_np)

# Compute entanglement entropy
entropy = entanglement_entropy_torch(psi, N // 2, N) 
print(f'Initial Entropy: {entropy.item()}')

# Normalize the parameters to ensure the norm is 1
with torch.no_grad():
    norm = torch.norm(torch.complex(params_real, params_imag))
    params_real /= norm
    params_imag /= norm

# Define the optimizer
optimizer = optim.Adam([params_real, params_imag], lr=0.01)

# Lists to store the values of parameters and entropy
coeffs_history_max = []
entropy_history_max = []

# Optimization loop
num_iterations = 150
for _ in range(num_iterations):
    optimizer.zero_grad()
    
    # Combine real and imaginary parts for the coefficients
    coeffs = torch.complex(params_real, params_imag)
    
    # Normalize coefficients to project them onto the unit sphere
    coeffs = coeffs / torch.norm(coeffs)
    
    # Compute psi
    psi = linear_combination(coeffs, rank_eigenvectors_np)
    
    # Compute - entanglement entropy
    entropy = - entanglement_entropy_torch(psi, N // 2, N) # it would be better to compute the outer product of the state before the optimization loop. but optimization is not taking too long so it's ok for now
    
    # Backpropagation
    entropy.backward()
    optimizer.step()
    
    # Normalize parameters again to ensure they stay on the unit sphere
    with torch.no_grad():
        norm = torch.norm(torch.complex(params_real, params_imag))
        params_real /= norm
        params_imag /= norm
    print("Coeffs norm:", torch.norm(torch.complex(params_real, params_imag)).detach().cpu().numpy())
    
    print(f'Entropy: {abs(entropy.item())}')
    print(f'Coeffs: {coeffs.detach().cpu().numpy()}')

    # Store the values of parameters and entropy
    coeffs_history_max.append(coeffs.detach().cpu().numpy())
    entropy_history_max.append(abs(entropy.item()))

# Final optimized coefficients
optimized_coeffs_max = torch.complex(params_real, params_imag)
optimized_coeffs_max = optimized_coeffs_max / torch.norm(optimized_coeffs_max)

print("Optimized coefficients:", optimized_coeffs_max)

# Plot the value of parameters and entropy as a function of num_iterations
plt.figure(figsize=(12, 6))

# Plot entropy
plt.subplot(1, 2, 1)
plt.plot(np.abs(entropy_history_max))
plt.xlabel('Iteration')
plt.ylabel('Entropy')
#plt.title('Entropy vs. Iterations')

# Plot coefficients
plt.subplot(1, 2, 2)
coeffs_history_max = np.array(coeffs_history_max)
for i in range(coeffs_history_max.shape[1]):
    plt.plot(coeffs_history_max[:, i].real, label=f'Coeff {i+1} Real')
    plt.plot(coeffs_history_max[:, i].imag, label=f'Coeff {i+1} Imag', linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Coefficient Value')
#plt.title('Coefficients vs. Iterations')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Initial coeffs, real tensor([ 0.4424, -0.8861, -1.2596, -0.8863,  0.3040], requires_grad=True)
# Initial coeffs imag tensor([-1.1098, -0.0949,  0.5150,  0.1622, -1.3734], requires_grad=True)
# Initial Entropy: 4.30262565612793
# Coeffs norm: 0.99999994
# Entropy: 4.302624225616455
# Coeffs: [ 0.16885431-0.42361605j -0.33822396-0.03622584j -0.48076868+0.19655193j
#  -0.33830205+0.06192393j  0.11604504-0.52422285j]
# Coeffs norm: 1.0
# Entropy: 4.331944465637207
# Coeffs: [ 0.15917674-0.43449616j -0.34893075-0.02627907j -0.4717242 +0.18693057j
#  -0.34900898+0.05202933j  0.12630089-0.5152666j ]
# Coeffs norm: 1.0
# Entropy: 4.3582844734191895
# Coeffs: [ 0.14948219-0.44350684j -0.3595662 -0.01634883j -0.46262348+0.17729849j
#  -0.35960528+0.04212415j  0.13644022-0.5062016j ]
# Coeffs norm: 1.0
# Entropy: 4.381798267364502
# Coeffs: [ 0.14002046-0.448014j   -0.37068334-0.00648126j -0.45422718+0.16796356j
#  -0.3706084 +0.03228328j  0.1465774 -0.497813j  ]
# Coeffs norm: 1.0
# Entropy: 4.402718544006348
# Coeffs: [ 0.13081893-0.44798237j -0.38234714+0.00332334j -0.44664794+0.1589819j
#  -0.38202053+0.02250612j  0.15661383-0.4901573j ]
# Coeffs norm: 1.0
# Entropy: 4.4210662841796875
# Coeffs: [ 0.1217756 -0.44523776j -0.3941951 +0.01305882j -0.4395415 +0.15025797j
#  -0.39338028+0.01277195j  0.16621833-0.4827628j ]
# Coeffs norm: 1.0
# Entropy: 4.4368696212768555
# Coeffs: [ 0.11287016-0.44087508j -0.40599683+0.02269875j -0.43279365+0.14179496j
#  -0.40433487+0.00308824j  0.1750483 -0.47538045j]
# Coeffs norm: 1.0
# Entropy: 4.450234413146973
# Coeffs: [ 0.10414127-0.4354344j  -0.4176404 +0.03220789j -0.42647526+0.13366695j
#  -0.41464606-0.00652367j  0.18277153-0.46793506j]
# Coeffs norm: 1.0
# Entropy: 4.4613542556762695
# Coeffs: [ 0.09565583-0.42921278j -0.42906502+0.04154653j -0.42074656+0.12597881j
#  -0.42414895-0.0160374j   0.18908672-0.4604257j ]
# Coeffs norm: 1.0
# Entropy: 4.470490455627441
# Coeffs: [ 0.08749458-0.42238897j -0.4402239 +0.05067099j -0.41579875+0.11884332j
#  -0.43274245-0.02542348j  0.1937695 -0.45287555j]
# Coeffs norm: 1.0
# Entropy: 4.47796630859375
# Coeffs: [ 0.07974526-0.41507092j -0.45106512+0.05953274j -0.41181117+0.11236624j
#  -0.44038928-0.03464874j  0.19671138-0.4453086j ]
# Coeffs norm: 0.99999994
# Entropy: 4.48408317565918
# Coeffs: [ 0.07249893-0.40731943j -0.46152484+0.06807816j -0.40891865+0.10663666j
#  -0.44711226-0.0436756j   0.19792464-0.437742j  ]
# Coeffs norm: 0.99999994
# Entropy: 4.489135265350342
# Coeffs: [ 0.06584716-0.39916644j -0.47153074+0.0762499j  -0.40719187+0.10172122j
#  -0.45298594-0.05246275j  0.19751441-0.4301887j ]
# Coeffs norm: 1.0
# Entropy: 4.493395805358887
# Coeffs: [ 0.05987796-0.39062905j -0.4810091 +0.08398992j -0.4066319 +0.09766164j
#  -0.4581241 -0.06096753j  0.19563834-0.42266217j]
# Coeffs norm: 1.0
# Entropy: 4.497081756591797
# Coeffs: [ 0.05467044-0.3817203j  -0.4898921 +0.09124346j -0.4071778 +0.09447484j
#  -0.462666  -0.06914927j  0.19247307-0.41518012j]
# Coeffs norm: 0.99999994
# Entropy: 4.500389099121094
# Coeffs: [ 0.0502888 -0.3724549j  -0.49812204+0.0979631j  -0.4087218 +0.09215495j
#  -0.46676177-0.07697272j  0.1881936 -0.40776438j]
# Coeffs norm: 1.0
# Entropy: 4.5034637451171875
# Coeffs: [ 0.04677708-0.36285272j -0.50565356+0.10411242j -0.41112632+0.09067672j
#  -0.47055852-0.08441104j  0.18296401-0.40043923j]
# Coeffs norm: 0.99999994
# Entropy: 4.50640344619751
# Coeffs: [ 0.04415572-0.3529407j  -0.5124548 +0.10966884j -0.41423866+0.08999966j
#  -0.4741882 -0.09144792j  0.17693545-0.39322892j]
# Coeffs norm: 0.99999994
# Entropy: 4.509272575378418
# Coeffs: [ 0.04242057-0.34275478j -0.51850903+0.11462573j -0.41790235+0.09007219j
#  -0.4777586 -0.09807891j  0.17024814-0.38615626j]
# Coeffs norm: 1.0
# Entropy: 4.512092113494873
# Coeffs: [ 0.04154405-0.33234042j -0.5238144 +0.11899316j -0.42196247+0.09083537j
#  -0.48134726-0.10431157j  0.16303462-0.3792407j ]
# Coeffs norm: 0.9999999
# Entropy: 4.514859676361084
# Coeffs: [ 0.04147815-0.32175362j -0.52838457+0.12279788j -0.42626905+0.09222606j
#  -0.48500097-0.11016493j  0.15542385-0.37249812j]
# Coeffs norm: 0.99999994
# Entropy: 4.517532825469971
# Coeffs: [ 0.04215843-0.311061j   -0.5322484 +0.12608224j -0.43067726+0.09417941j
#  -0.4887381 -0.11566807j  0.14754485-0.3659406j ]
# Coeffs norm: 1.0
# Entropy: 4.520059108734131
# Coeffs: [ 0.04350832-0.3003395j  -0.53544873+0.12890238j -0.43504664+0.09663085j
#  -0.49255326-0.12085817j  0.13953002-0.35957623j]
# Coeffs norm: 1.0
# Entropy: 4.522372722625732
# Coeffs: [ 0.04544325-0.28967586j -0.53804123+0.13132603j -0.4392408 +0.09951761j
#  -0.49642333-0.12577844j  0.13151789-0.35340977j]
# Coeffs norm: 1.0
# Entropy: 4.524431228637695
# Coeffs: [ 0.04787439-0.2791657j  -0.54009277+0.13343018j -0.44312832+0.10278001j
#  -0.5003128 -0.13047598j  0.12365486-0.3474434j ]
# Coeffs norm: 1.0
# Entropy: 4.526191711425781
# Coeffs: [ 0.05071187-0.2689117j  -0.54167926+0.13529836j -0.4465851 +0.10636229j
#  -0.5041778 -0.13499975j  0.11609522-0.3416771j ]
# Coeffs norm: 1.0
# Entropy: 4.527650833129883
# Coeffs: [ 0.05386762-0.2590211j  -0.5428827 +0.13701777j -0.449499  +0.11021328j
#  -0.5079691 -0.1393986j   0.10899861-0.33610895j]
# Coeffs norm: 1.0
# Entropy: 4.5288405418396
# Coeffs: [ 0.05725783-0.24960233j -0.543788  +0.13867636j -0.4517761 +0.11428679j
#  -0.511633  -0.14371961j  0.10252464-0.33073506j]
# Coeffs norm: 1.0
# Entropy: 4.5297980308532715
# Coeffs: [ 0.06080526-0.24076034j -0.54447925+0.14035958j -0.45334667+0.11854172j
#  -0.5151119 -0.14800657j  0.09682419-0.32554916j]
# Coeffs norm: 0.9999999
# Entropy: 4.5306077003479
# Coeffs: [ 0.06444128-0.23259175j -0.5450359 +0.14214723j -0.4541706 +0.12294201j
#  -0.5183445 -0.1522987j   0.09202873-0.32054245j]
# Coeffs norm: 1.0
# Entropy: 4.531347751617432
# Coeffs: [ 0.06810772-0.2251797j  -0.5455297 +0.14411056j -0.4542395 +0.12745649j
#  -0.5212663 -0.1566297j   0.08823951-0.31570342j]
# Coeffs norm: 0.99999994
# Entropy: 4.532101631164551
# Coeffs: [ 0.07175826-0.21858905j -0.5460222 +0.14630958j -0.45357496+0.13205859j
#  -0.523811  -0.16102694j  0.08551925-0.31101787j]
# Coeffs norm: 1.0
# Entropy: 4.532921314239502
# Coeffs: [ 0.07535936-0.21286269j -0.5465626 +0.14879109j -0.45222452+0.13672605j
#  -0.5259141 -0.165511j    0.08388843-0.3064691j ]
# Coeffs norm: 0.99999994
# Entropy: 4.533878803253174
# Coeffs: [ 0.0788905 -0.208019j   -0.54718715+0.15158726j -0.4502547 +0.14144054j
#  -0.527517  -0.17009532j  0.08332672-0.30203858j]
# Coeffs norm: 1.0
# Entropy: 4.534987449645996
# Coeffs: [ 0.08234359-0.20405112j -0.5479183 +0.15471497j -0.44774407+0.14618719j
#  -0.5285721 -0.17478585j  0.0837786 -0.29770586j]
# Coeffs norm: 0.99999994
# Entropy: 4.536251068115234
# Coeffs: [ 0.08572175-0.20092739j -0.5487647 +0.15817578j -0.44477615+0.15095404j
#  -0.52904695-0.17958096j  0.08516097-0.2934491j ]
# Coeffs norm: 0.99999994
# Entropy: 4.53765344619751
# Coeffs: [ 0.08903755-0.1985935j  -0.5497219 +0.16195665j -0.44143492+0.1557316j
#  -0.5289286 -0.18447149j  0.08737123-0.28924552j]
# Coeffs norm: 0.9999999
# Entropy: 4.539159297943115
# Coeffs: [ 0.09231079-0.1969752j  -0.55077374+0.16603114j -0.43780053+0.16051218j
#  -0.5282247 -0.18944106j  0.09029426-0.28507146j]
# Coeffs norm: 0.99999994
# Entropy: 4.540729999542236
# Coeffs: [ 0.09556611-0.195982j   -0.5518946 +0.17036127j -0.43394792+0.16528969j
#  -0.526965  -0.19446672j  0.0938081 -0.28090358j]
# Coeffs norm: 1.0
# Entropy: 4.542328357696533
# Coeffs: [ 0.09883054-0.19551075j -0.55305165+0.17489955j -0.42994544+0.17005907j
#  -0.52519983-0.19951993j  0.09778818-0.2767191j ]
# Coeffs norm: 1.0
# Entropy: 4.54390811920166
# Coeffs: [ 0.10213121-0.19544955j -0.55420786+0.17959145j -0.42585462+0.17481606j
#  -0.5229986 -0.20456772j  0.10211062-0.2724968j ]
# Coeffs norm: 1.0
# Entropy: 4.545429229736328
# Coeffs: [ 0.10549311-0.19568147j -0.55532455+0.18437785j -0.4217303 +0.17955665j
#  -0.5204471 -0.20957403j  0.10665476-0.2682176j ]
# Coeffs norm: 0.9999999
# Entropy: 4.546872138977051
# Coeffs: [ 0.10893729-0.19608837j -0.5563641 +0.18919778j -0.41762045+0.18427674j
#  -0.5176446 -0.2145012j   0.11130533-0.26386523j]
# Coeffs norm: 1.0
# Entropy: 4.54821252822876
# Coeffs: [ 0.11247939-0.19655481j -0.557292  +0.19399098j -0.41356617+0.18897146j
#  -0.51469946-0.21931146j  0.11595439-0.25942668j]
# Coeffs norm: 1.0
# Entropy: 4.549459934234619
# Coeffs: [ 0.11612865-0.196972j   -0.5580787 +0.19870059j -0.4096016 +0.1936346j
#  -0.5117241 -0.22396848j  0.12050299-0.25489265j]
# Coeffs norm: 1.0
# Entropy: 4.550601005554199
# Coeffs: [ 0.11988758-0.19724205j -0.5587018 +0.2032759j  -0.40575424+0.1982584j
#  -0.50882876-0.22843903j  0.12486273-0.25025815j]
# Coeffs norm: 1.0
# Entropy: 4.551652431488037
# Coeffs: [ 0.12375199-0.19728182j -0.5591472 +0.20767465j -0.40204495+0.20283303j
#  -0.5061143 -0.23269446j  0.12895691-0.24552284j]
# Coeffs norm: 1.0
# Entropy: 4.552626609802246
# Coeffs: [ 0.12771156-0.19702627j -0.5594101 +0.21186516j -0.39848846+0.2073465j
#  -0.5036649 -0.23671198j  0.13272147-0.24069151j]
# Coeffs norm: 0.99999994
# Entropy: 4.5535430908203125
# Coeffs: [ 0.13175084-0.19643097j -0.55949605+0.21582784j -0.39509392+0.2117848j
#  -0.50154203-0.24047568j  0.13610542-0.23577432j]
# Coeffs norm: 1.0
# Entropy: 4.554396152496338
# Coeffs: [ 0.13585028-0.19547315j -0.55942047+0.21955584j -0.39186528+0.2161319j
#  -0.49977976-0.24397701j  0.13907088-0.23078656j]
# Coeffs norm: 0.99999994
# Entropy: 4.555209636688232
# Coeffs: [ 0.13998748-0.19415127j -0.55920815+0.22305496j -0.3888018 +0.22037011j
#  -0.4983832 -0.24721472j  0.14159279-0.2257484j ]
# Coeffs norm: 1.0
# Entropy: 4.555968761444092
# Coeffs: [ 0.14413843-0.19248337j -0.558892  +0.22634278j -0.385899  +0.22448048j
#  -0.49732998-0.25019446j  0.14365815-0.22068436j]
# Coeffs norm: 0.99999994
# Entropy: 4.556678295135498
# Coeffs: [ 0.14827843-0.19050385j -0.558511  +0.22944678j -0.38314846+0.22844301j
#  -0.4965735 -0.25292766j  0.1452652 -0.21562213j]
# Coeffs norm: 0.99999994
# Entropy: 4.557337760925293
# Coeffs: [ 0.15238321-0.18825987j -0.5581084 +0.23240227j -0.38053903+0.23223747j
#  -0.49604905-0.2554305j   0.1464223 -0.21059175j]
# Coeffs norm: 1.0
# Entropy: 4.5579376220703125
# Coeffs: [ 0.15642959-0.18580684j -0.55772895+0.2352495j  -0.3780569 +0.23584361j
#  -0.49567983-0.2577222j   0.14714661-0.20562418j]
# Coeffs norm: 1.0
# Entropy: 4.558479309082031
# Coeffs: [ 0.16039613-0.18320416j -0.5574169 +0.238031j   -0.37568638+0.23924187j
#  -0.49538442-0.25982368j  0.14746287-0.20075022j]
# Coeffs norm: 1.0
# Entropy: 4.55896520614624
# Coeffs: [ 0.16426355-0.18051083j -0.5572135 +0.24078864j -0.37341014+0.24241385j
#  -0.49508423-0.26175612j  0.14740193-0.19599919j]
# Coeffs norm: 0.9999999
# Entropy: 4.559402942657471
# Coeffs: [ 0.1680149 -0.1777816j  -0.5571544 +0.2435608j  -0.37120962+0.24534261j
#  -0.4947095 -0.2635393j   0.14699912-0.19139759j]
# Coeffs norm: 1.0
# Entropy: 4.559799671173096
# Coeffs: [ 0.17163572-0.17506374j -0.55726784+0.24638003j -0.36906528+0.24801303j
#  -0.4942053 -0.26519075j  0.14629278-0.18696813j]
# Coeffs norm: 0.99999994
# Entropy: 4.560157299041748
# Coeffs: [ 0.17511402-0.17239486j -0.55757296+0.24927118j -0.36695713+0.25041217j
#  -0.49353516-0.26672468j  0.14532275-0.18272895j]
# Coeffs norm: 1.0
# Entropy: 4.560491561889648
# Coeffs: [ 0.17844027-0.16980144j -0.55807906+0.2522502j  -0.36486527+0.2525295j
#  -0.49268335-0.26815173j  0.14412889-0.17869295j]
# Coeffs norm: 1.0
# Entropy: 4.5608015060424805
# Coeffs: [ 0.18160737-0.16729872j -0.558785  +0.25532335j -0.36277068+0.25435728j
#  -0.49165443-0.26947883j  0.14274971-0.17486772j]
# Coeffs norm: 0.99999994
# Entropy: 4.561103343963623
# Coeffs: [ 0.18461071-0.16489148j -0.5596802 +0.25848776j -0.36065632+0.25589105j
#  -0.4904721 -0.2707097j   0.14122139-0.17125566j]
# Coeffs norm: 0.99999994
# Entropy: 4.561384677886963
# Coeffs: [ 0.18744823-0.16257574j -0.5607454 +0.2617319j  -0.35850802+0.25712988j
#  -0.4891758 -0.2718454j   0.13957675-0.16785432j]
# Coeffs norm: 1.0
# Entropy: 4.561660289764404
# Coeffs: [ 0.19012043-0.16034096j -0.56195396+0.26503694j -0.35631543+0.2580766j
#  -0.48781624-0.27288517j  0.13784455-0.16465695j]
# Coeffs norm: 0.99999994
# Entropy: 4.561919212341309
# Coeffs: [ 0.19263029-0.15817285j -0.56327415+0.26837847j -0.35407293+0.25873807j
#  -0.486451  -0.2738274j   0.1360491 -0.16165327j]
# Coeffs norm: 0.99999994
# Entropy: 4.562170505523682
# Coeffs: [ 0.1949835 -0.15605605j -0.5646709 +0.27172843j -0.3517801 +0.25912514j
#  -0.48513925-0.27467054j  0.13421017-0.15883029j]
# Coeffs norm: 1.0
# Entropy: 4.562401294708252
# Coeffs: [ 0.19718808-0.15397693j -0.5661079 +0.27505708j -0.34944206+0.25925237j
#  -0.48393655-0.27541375j  0.13234295-0.15617312j]
# Coeffs norm: 1.0
# Entropy: 4.562620162963867
# Coeffs: [ 0.19925441-0.1519259j  -0.5675496 +0.27833515j -0.34706947+0.25913787j
#  -0.48289037-0.2760577j   0.1304587 -0.15366584j]
# Coeffs norm: 0.99999994
# Entropy: 4.562826156616211
# Coeffs: [ 0.20119499-0.14989914j -0.56896305+0.2815356j  -0.34467807+0.2588027j
#  -0.48203635-0.27660504j  0.12856539-0.15129222j]
# Coeffs norm: 1.0
# Entropy: 4.5630035400390625
# Coeffs: [ 0.20302394-0.14789957j -0.5703194 +0.28463525j -0.34228805+0.25827017j
#  -0.48139572-0.27706048j  0.12666856-0.14903636j]
# Coeffs norm: 1.0
# Entropy: 4.56317138671875
# Coeffs: [ 0.20475659-0.1459371j  -0.5715947 +0.28761575j -0.33992285+0.25756484j
#  -0.48097396-0.27743074j  0.12477235-0.14688314j]
# Coeffs norm: 0.99999994
# Entropy: 4.563323974609375
# Coeffs: [ 0.20640902-0.14402817j -0.5727709 +0.2904646j  -0.33760813+0.2567119j
#  -0.48076168-0.27772456j  0.12288068-0.14481862j]
# Coeffs norm: 1.0
# Entropy: 4.563461780548096
# Coeffs: [ 0.20799719-0.14219442j -0.5738354 +0.29317504j -0.33537012+0.25573587j
#  -0.4807361 -0.27795193j  0.12099807-0.14283009j]
# Coeffs norm: 1.0
# Entropy: 4.563583850860596
# Coeffs: [ 0.20953645-0.14046097j -0.57478094+0.29574582j -0.3332343 +0.2546599j
#  -0.4808641 -0.27812365j  0.11913052-0.14090617j]
# Coeffs norm: 1.0
# Entropy: 4.563689708709717
# Coeffs: [ 0.21104096-0.13885437j -0.57560515+0.29818073j -0.33122408+0.25350472j
#  -0.48110634-0.27825087j  0.11728623-0.13903676j]
# Coeffs norm: 0.99999994
# Entropy: 4.563786029815674
# Coeffs: [ 0.21252297-0.13740031j -0.5763091 +0.3004874j  -0.3293593 +0.252288j
#  -0.48142084-0.27834427j  0.11547578-0.13721275j]
# Coeffs norm: 1.0
# Entropy: 4.563881874084473
# Coeffs: [ 0.21399254-0.13612159j -0.57689655+0.3026763j  -0.32765543+0.25102383j
#  -0.4817674 -0.2784136j   0.11371225-0.135426j  ]
# Coeffs norm: 0.99999994
# Entropy: 4.563961505889893
# Coeffs: [ 0.21545714-0.13503624j -0.5773726 +0.30475938j -0.3261228 +0.24972217j
#  -0.48211095-0.2784672j   0.11201087-0.13366903j]
# Coeffs norm: 0.99999994
# Entropy: 4.5640411376953125
# Coeffs: [ 0.21692173-0.13415636j -0.577743  +0.30674922j -0.32476622+0.24838895j
#  -0.4824248 -0.27851176j  0.11038858-0.13193497j]
# Coeffs norm: 1.0
# Entropy: 4.564122676849365
# Coeffs: [ 0.21838857-0.13348724j -0.5780128 +0.3086577j  -0.32358485+0.24702588j
#  -0.482692  -0.27855197j  0.10886304-0.13021736j]
# Coeffs norm: 0.99999994
# Entropy: 4.564199447631836
# Coeffs: [ 0.21985763-0.13302734j -0.57818615+0.31049538j -0.32257256+0.24563085j
#  -0.48290655-0.27859068j  0.10745186-0.12851024j]
# Coeffs norm: 1.0
# Entropy: 4.564270496368408
# Coeffs: [ 0.22132707-0.13276896j -0.5782658 +0.3122712j  -0.32171872+0.24419843j
#  -0.4830731 -0.27862906j  0.10617156-0.1268082j ]
# Coeffs norm: 0.99999994
# Entropy: 4.564361572265625
# Coeffs: [ 0.22279344-0.1326991j  -0.57825303+0.31399217j -0.32100877+0.24272013j
#  -0.48320526-0.2786667j   0.10503644-0.12510636j]
# Coeffs norm: 1.0
# Entropy: 4.564451217651367
# Coeffs: [ 0.22425272-0.13280119j -0.57814825+0.3156636j  -0.32042566+0.24118537j
#  -0.48332417-0.2787021j   0.10405785-0.12340064j]
# Coeffs norm: 1.0
# Entropy: 4.564543724060059
# Coeffs: [ 0.22570044-0.13305672j -0.57795066+0.3172894j  -0.3199506 +0.23958176j
#  -0.48345515-0.27873293j  0.10324322-0.12168775j]
# Coeffs norm: 0.99999994
# Entropy: 4.564640998840332
# Coeffs: [ 0.22713271-0.13344708j -0.57765955+0.31887272j -0.3195647 +0.23789603j
#  -0.48362526-0.27875653j  0.10259578-0.11996545j]
# Coeffs norm: 1.0
# Entropy: 4.564757347106934
# Coeffs: [ 0.2285465 -0.1339554j  -0.5772743 +0.32041642j -0.31924975+0.2361144j
#  -0.48386037-0.27877018j  0.1021141 -0.11823249j]
# Coeffs norm: 1.0
# Entropy: 4.564868450164795
# Coeffs: [ 0.22994001-0.13456781j -0.57679504+0.32192364j -0.31898922+0.23422298j
#  -0.4841823 -0.27877128j  0.10179219-0.1164886j ]
# Coeffs norm: 0.99999994
# Entropy: 4.564992904663086
# Coeffs: [ 0.2313132 -0.13527465j -0.576223  +0.32339847j -0.3187692 +0.2322083j
#  -0.48460755-0.2787578j   0.10161983-0.11473448j]
# Coeffs norm: 0.99999994
# Entropy: 4.5651326179504395
# Coeffs: [ 0.23266758-0.13607092j -0.5755605 +0.3248461j  -0.31857848+0.2300572j
#  -0.48514554-0.278728j    0.10158303-0.11297148j]
# Coeffs norm: 1.0
# Entropy: 4.565279483795166
# Coeffs: [ 0.23400636-0.13695635j -0.57481104+0.32627305j -0.31840888+0.22775698j
#  -0.48579875-0.27868062j  0.10166486-0.11120134j]
# Coeffs norm: 0.9999999
# Entropy: 4.56544303894043
# Coeffs: [ 0.23533422-0.13793494j -0.57397914+0.32768738j -0.31825504+0.2252953j
#  -0.4865631 -0.27861464j  0.10184632-0.10942588j]
# Coeffs norm: 1.0
# Entropy: 4.565624237060547
# Coeffs: [ 0.2366571 -0.13901408j -0.57307   +0.32909822j -0.31811407+0.2226601j
#  -0.4874294 -0.27852914j  0.10210741-0.10764658j]
# Coeffs norm: 0.99999994
# Entropy: 4.565821170806885
# Coeffs: [ 0.23798169-0.14020331j -0.5720889 +0.33051574j -0.31798482+0.21983916j
#  -0.48838484-0.27842313j  0.10242806-0.10586408j]
# Coeffs norm: 0.99999994
# Entropy: 4.5660400390625
# Coeffs: [ 0.23931515-0.14151292j -0.5710408 +0.33195072j -0.317867  +0.21682014j
#  -0.4894151 -0.2782952j   0.10278925-0.10407788j]
# Coeffs norm: 0.9999999
# Entropy: 4.566278457641602
# Coeffs: [ 0.24066465-0.1429525j  -0.5699301 +0.33341414j -0.3177606 +0.21359028j
#  -0.49050635-0.2781433j   0.10317378-0.10228588j]
# Coeffs norm: 1.0
# Entropy: 4.56654167175293
# Coeffs: [ 0.24203706-0.14452967j -0.56875986+0.33491692j -0.31766465+0.21013649j
#  -0.49164674-0.2779647j   0.10356704-0.10048418j]
# Coeffs norm: 0.99999994
# Entropy: 4.566842079162598
# Coeffs: [ 0.24343868-0.14624889j -0.5675321 +0.3364696j  -0.31757674+0.20644546j
#  -0.49282774-0.27775586j  0.10395747-0.09866682j]
# Coeffs norm: 1.0
# Entropy: 4.567173957824707
# Coeffs: [ 0.24487501-0.14811063j -0.5662476 +0.33808213j -0.31749213+0.20250404j
#  -0.49404457-0.2775123j   0.10433687-0.09682575j]
# Coeffs norm: 1.0
# Entropy: 4.567538261413574
# Coeffs: [ 0.24635074-0.15011087j -0.564906  +0.339764j   -0.31740347+0.19829981j
#  -0.4952962 -0.27722895j  0.10470027-0.09495094j]
# Coeffs norm: 1.0
# Entropy: 4.567942142486572
# Coeffs: [ 0.24786955-0.15224093j -0.56350636+0.34152386j -0.31730056+0.19382186j
#  -0.49658436-0.27689993j  0.10504568-0.09303057j]
# Coeffs norm: 0.9999999
# Entropy: 4.568388938903809
# Coeffs: [ 0.24943434-0.15448764j -0.562048  +0.34337002j -0.31717062+0.18906182j
#  -0.49791244-0.27651906j  0.10537357-0.09105146j]
# Coeffs norm: 1.0
# Entropy: 4.568875789642334
# Coeffs: [ 0.2510471 -0.15683375j -0.5605309 +0.34531015j -0.31699878+0.18401487j
#  -0.49928376-0.27607995j  0.1056862 -0.08899952j]
# Coeffs norm: 0.99999994
# Entropy: 4.569406509399414
# Coeffs: [ 0.25270897-0.1592586j  -0.5589562 +0.3473515j  -0.3167689 +0.17868079j
#  -0.5006997 -0.27557617j  0.10598683-0.08686043j]
# Coeffs norm: 0.99999994
# Entropy: 4.569976806640625
# Coeffs: [ 0.25442037-0.16173892j -0.5573274 +0.34950078j -0.3164649 +0.17306487j
#  -0.50215846-0.2750016j   0.106279  -0.08462024j]
# Coeffs norm: 0.99999994
# Entropy: 4.570579528808594
# Coeffs: [ 0.25618082-0.16424961j -0.55565006+0.3517639j  -0.31607166+0.16717856j
#  -0.50365335-0.27435035j  0.10656584-0.08226612j]
# Coeffs norm: 1.0
# Entropy: 4.571216106414795
# Coeffs: [ 0.25798887-0.16676465j -0.5539326 +0.3541459j  -0.3155767 +0.16103975j
#  -0.5051724 -0.27361703j  0.10684971-0.07978694j]
# Coeffs norm: 0.99999994
# Entropy: 4.5718817710876465
# Coeffs: [ 0.25984222-0.16925775j -0.55218613+0.3566506j  -0.31497115+0.15467294j
#  -0.506698  -0.27279702j  0.10713194-0.07717389j]
# Coeffs norm: 1.0
# Entropy: 4.572566509246826
# Coeffs: [ 0.26173738-0.1717028j  -0.55042416+0.3592801j  -0.3142506 +0.14810878j
#  -0.5082078 -0.27188626j  0.10741281-0.07442088j]
# Coeffs norm: 1.0
# Entropy: 4.573253154754639
# Coeffs: [ 0.26366955-0.17407434j -0.54866207+0.36203462j -0.31341553+0.14138359j
#  -0.5096751 -0.2708815j   0.10769171-0.07152481j]
# Coeffs norm: 1.0
# Entropy: 4.573936462402344
# Coeffs: [ 0.26563284-0.1763477j  -0.5469169 +0.3649121j  -0.31247184+0.13453862j
#  -0.5110711 -0.26978058j  0.10796759-0.06848586j]
# Coeffs norm: 0.99999994
# Entropy: 4.574611663818359
# Coeffs: [ 0.26761982-0.17849901j -0.5452061 +0.3679078j  -0.3114302 +0.12761916j
#  -0.51236635-0.26858225j  0.10823929-0.06530739j]
# Coeffs norm: 1.0
# Entropy: 4.57526969909668
# Coeffs: [ 0.26962176-0.18050528j -0.5435475 +0.3710141j  -0.31030574+0.1206736j
#  -0.5135327 -0.26728657j  0.10850596-0.061996j  ]
# Coeffs norm: 1.0
# Entropy: 4.5758867263793945
# Coeffs: [ 0.2716286 -0.18234438j -0.54195786+0.37422025j -0.30911726+0.11375245j
#  -0.51454484-0.26589477j  0.10876746-0.05856134j]
# Coeffs norm: 0.99999994
# Entropy: 4.576471328735352
# Coeffs: [ 0.27362904-0.18399534j -0.54045296+0.37751257j -0.30788627+0.10690743j
#  -0.51538223-0.26440975j  0.10902465-0.05501598j]
# Coeffs norm: 0.99999994
# Entropy: 4.5770111083984375
# Coeffs: [ 0.2756109 -0.1854386j  -0.53904676+0.38087454j -0.30663595+0.10019052j
#  -0.5160297 -0.26283598j  0.10927951-0.05137512j]
# Coeffs norm: 0.99999994
# Entropy: 4.577491760253906
# Coeffs: [ 0.27756122-0.18665653j -0.53775066+0.38428688j -0.30538988+0.0936529j
#  -0.5164779 -0.2611797j   0.10953499-0.04765636j]
# Coeffs norm: 0.99999994
# Entropy: 4.577918529510498
# Coeffs: [ 0.27946696-0.1876343j  -0.536574  +0.38772842j -0.30417147+0.08734428j
#  -0.5167236 -0.2594492j   0.10979494-0.04387939j]
# Coeffs norm: 0.99999994
# Entropy: 4.57828950881958
# Coeffs: [ 0.28131518-0.18836053j -0.53552365+0.39117655j -0.3030027 +0.08131177j
#  -0.5167688 -0.257655j    0.11006369-0.04006573j]
# Coeffs norm: 1.0
# Entropy: 4.578604221343994
# Coeffs: [ 0.2830938 -0.18882826j -0.534604  +0.39460793j -0.30190334+0.07559916j
#  -0.5166201 -0.2558096j   0.11034554-0.03623832j]
# Coeffs norm: 1.0
# Entropy: 4.578864574432373
# Coeffs: [ 0.28479195-0.18903558j -0.53381723+0.39799923j -0.30089054+0.07024605j
#  -0.5162873 -0.25392774j  0.11064436-0.03242113j]
# Coeffs norm: 1.0
# Entropy: 4.579082012176514
# Coeffs: [ 0.2864006 -0.18898638j -0.53316355+0.401328j   -0.29997814+0.06528714j
#  -0.5157829 -0.25202617j  0.110963  -0.02863873j]
# Coeffs norm: 1.0
# Entropy: 4.579252243041992
# Coeffs: [ 0.28791267-0.18869022j -0.532641  +0.4045728j  -0.2991762 +0.06075149j
#  -0.51512027-0.25012323j  0.11130282-0.02491573j]
# Coeffs norm: 0.99999994
# Entropy: 4.579380035400391
# Coeffs: [ 0.2893237 -0.18816255j -0.5322461 +0.40771416j -0.29849094+0.05666213j
#  -0.5143138 -0.24823868j  0.11166346-0.02127631j]
# Coeffs norm: 1.0
# Entropy: 4.579473495483398
# Coeffs: [ 0.29063156-0.18742405j -0.5319738 +0.41073447j -0.2979247 +0.05303558j
#  -0.5133781 -0.246393j    0.1120425 -0.0177436j ]
# Coeffs norm: 1.0
# Entropy: 4.579536437988281
# Coeffs: [ 0.2918368 -0.18649988j -0.53181714+0.41361824j -0.29747579+0.04988172j
#  -0.51232773-0.24460688j  0.11243552-0.01433919j]
# Coeffs norm: 1.0
# Entropy: 4.579582691192627
# Coeffs: [ 0.29294232-0.18541865j -0.531768  +0.4163523j  -0.29713896+0.04720384j
#  -0.51117796-0.24290077j  0.11283629-0.01108256j]
# Coeffs norm: 1.0
# Entropy: 4.579614639282227
# Coeffs: [ 0.29395306-0.18421118j -0.53181684+0.41892534j -0.29690552+0.04499877j
#  -0.5099443 -0.24129403j  0.11323702-0.00799065j]
# Coeffs norm: 0.99999994
# Entropy: 4.579632759094238
# Coeffs: [ 0.29487577-0.18290918j -0.53195256+0.42132804j -0.2967638 +0.04325733j
#  -0.5086435 -0.23980446j  0.11362889-0.00507755j]
# Coeffs norm: 0.99999994
# Entropy: 4.579641819000244
# Coeffs: [ 0.29571855-0.18154417j -0.5321632 +0.42355284j -0.29669985+0.04196477j
#  -0.5072932 -0.23844793j  0.11400255-0.00235423j]
# Coeffs norm: 1.0
# Entropy: 4.579647064208984
# Coeffs: [ 0.2964902 -1.8014626e-01j -0.53243566+4.2559364e-01j
#  -0.2966978 +4.1101389e-02j -0.5059122 -2.3723777e-01j
#   0.11434869+1.7153868e-04j]
# Coeffs norm: 0.99999994
# Entropy: 4.579652309417725
# Coeffs: [ 0.2971999-0.17874338j -0.5327564+0.42744613j -0.2967407+0.04064325j
#  -0.5045201-0.23618469j  0.1146588+0.00249516j]
# Coeffs norm: 0.99999994
# Entropy: 4.579659938812256
# Coeffs: [ 0.29785696-0.1773606j  -0.5331117 +0.42910773j -0.2968113 +0.04056291j
#  -0.5031373 -0.23529659j  0.11492559+0.00461504j]
# Coeffs norm: 0.99999994
# Entropy: 4.579661846160889
# Coeffs: [ 0.29847   -0.17601968j -0.53348804+0.43057737j -0.2968924 +0.04083009j
#  -0.50178355-0.2345783j   0.11514339+0.00653235j]
# Coeffs norm: 0.99999994
# Entropy: 4.579671859741211
# Coeffs: [ 0.2990469 -0.1747391j  -0.53387266+0.43185607j -0.29696774+0.04141245j
#  -0.5004777 -0.23403184j  0.11530862+0.00825067j]
# Coeffs norm: 1.0
# Entropy: 4.579683780670166
# Coeffs: [ 0.2995945 -0.17353377j -0.53425384+0.43294668j -0.29702252+0.04227623j
#  -0.4992365 -0.23365638j  0.1154199 +0.00977561j]
# Coeffs norm: 0.99999994
# Entropy: 4.579708099365234
# Coeffs: [ 0.30011836-0.1724154j  -0.5346214 +0.4338543j  -0.29704392+0.04338688j
#  -0.49807423-0.2334484j   0.11547817+0.01111446j]
# Coeffs norm: 1.0
# Entropy: 4.579721927642822
# Coeffs: [ 0.30062282-0.17139268j -0.5349671 +0.4345862j  -0.2970215 +0.04470969j
#  -0.4970017 -0.23340197j  0.11548652+0.01227574j]
# Coeffs norm: 1.0
# Entropy: 4.579745292663574
# Coeffs: [ 0.3011107 -0.17047137j -0.5352844 +0.4351514j  -0.2969474 +0.04621018j
#  -0.4960258 -0.23350868j  0.11544986+0.01326891j]
# Coeffs norm: 1.0
# Entropy: 4.579775333404541
# Coeffs: [ 0.30158368-0.16965474j -0.535569  +0.43556124j -0.29681668+0.04785471j
#  -0.49514997-0.23375814j  0.11537477+0.01410406j]
# Coeffs norm: 1.0
# Entropy: 4.579805374145508
# Coeffs: [ 0.302042  -0.16894367j -0.53581846+0.43582836j -0.29662725+0.04961073j
#  -0.4943739 -0.234138j    0.11526892+0.01479167j]
# Coeffs norm: 1.0
# Entropy: 4.579834938049316
# Coeffs: [ 0.3024849 -0.16833682j -0.53603226+0.43596685j -0.2963799 +0.05144721j
#  -0.49369428-0.23463428j  0.11514062+0.01534245j]
# Coeffs norm: 1.0
# Entropy: 4.579860210418701
# Coeffs: [ 0.30291057-0.16783082j -0.5362113 +0.4359916j  -0.29607803+0.05333482j
#  -0.49310538-0.23523153j  0.11499833+0.0157672j ]
# Coeffs norm: 0.99999994
# Entropy: 4.57988977432251
# Coeffs: [ 0.30331644-0.16742048j -0.53635776+0.43591785j -0.29572743+0.05524619j
#  -0.49259987-0.23591314j  0.11485013+0.01607675j]
# Coeffs norm: 1.0
# Entropy: 4.579914093017578
# Coeffs: [ 0.30369946-0.16709885j -0.53647476+0.435761j   -0.295336  +0.05715607j
#  -0.4921698 -0.23666164j  0.11470342+0.01628189j]
# Coeffs norm: 1.0
# Entropy: 4.5799384117126465
# Coeffs: [ 0.30405608-0.16685766j -0.5365659 +0.43553576j -0.29491317+0.05904137j
#  -0.4918069 -0.23745893j  0.11456433+0.0163933j ]
# Coeffs norm: 1.0
# Entropy: 4.579956531524658
# Coeffs: [ 0.30438277-0.16668747j -0.53663516+0.43525642j -0.2944696 +0.06088136j
#  -0.4915037 -0.23828684j  0.11443768+0.01642154j]
# Coeffs norm: 0.99999994
# Entropy: 4.579972267150879
# Coeffs: [ 0.3046761 -0.16657816j -0.53668654+0.4349361j  -0.29401657+0.06265756j
#  -0.49125344-0.23912734j  0.11432666+0.01637698j]
# Coeffs norm: 0.99999994
# Entropy: 4.579988479614258
# Coeffs: [ 0.304933  -0.16651922j -0.5367239 +0.43458688j -0.29356563+0.06435384j
#  -0.4910506 -0.23996304j  0.11423289+0.01626971j]
# Optimized coefficients: tensor([ 0.3052-0.1665j, -0.5368+0.4342j, -0.2931+0.0660j, -0.4909-0.2408j,
#          0.1142+0.0161j], grad_fn=<DivBackward0>)

# %%
# Compute the max_scar wavefunction using the optimized coefficients (min entropy)
max_scar = linear_combination_np(coeffs_history_max[-1], rank_eigenvectors_np)
# Define a list of colors for red points
red_colors = plt.cm.rainbow(np.linspace(0, 1, len(rank_indices_np)))

# Compute entanglement entropy for the max_scar wavefunction
max_scar_entropy = entanglement_entropy(max_scar, N // 2, N)

# Print entropies of red points only
print("Entropies of red points:")
for i in rank_indices_np:
    print(f'Index: {i}, Entropy: {numpy_entropies[i]}')

print(f'Max scar entropy: {max_scar_entropy}')

# Plot entanglement entropy as a function of energy eigenvalues
fig, ax = plt.subplots(figsize=(10, 6))

# Color only points with indices in rank_indices_np as red, all others as 'C0'
colors = ['red' if i in rank_indices_np else 'C0' for i in range(len(eigenvalues))]

# Plot entanglement entropy with highlighted points
for i, color in enumerate(colors):
    ax.plot(eigenvalues[i], numpy_entropies[i], 'o', color=color, markersize=2)

# Collect handles and labels for the legend
handles = []
labels = []

# Plot each red point with a different color and collect handles and labels
for i, idx in enumerate(rank_indices_np):
    handle, = ax.plot(eigenvalues[idx], numpy_entropies[idx], 'o', color=red_colors[i], markersize=5)
    handles.append(handle)
    labels.append(r'$\lambda_\mathrm{min}$: {float(min_eigenvalues[idx]):.2e}, Entropy: {naive_entropies[idx]:.2f}')

# Plot the maximum scar entropy in yellow and add to handles and labels
max_scar_handle, = ax.plot(np.mean(eigenvalues[rank_indices_np]), max_scar_entropy, 'x', color='black', markersize=7)
handles.append(max_scar_handle)
labels.append('Max Scar, Entropy: {:.2f}'.format(max_scar_entropy))

# Sort handles and labels by lambda min
sorted_handles_labels = sorted(zip(handles, labels), key=lambda hl: float(hl[1].split(': ')[1].split(',')[0]) if 'λ_min' in hl[1] else float('inf'))
sorted_handles, sorted_labels = zip(*sorted_handles_labels)

# Filter min_eigenvalues to include only those corresponding to red_indices
filtered_min_eigenvalues = [min_eigenvalues_np[idx] for idx in rank_indices_np]

# Create a color bar for the red points using filtered min_eigenvalues
norm = Normalize(vmin=min(filtered_min_eigenvalues), vmax=max(filtered_min_eigenvalues))
sm = ScalarMappable(cmap='rainbow', norm=norm)
sm.set_array([])

cbar = fig.colorbar(sm, ax=ax, label=r'$\lambda_{\mathrm{min}}$')

ax.set_xlabel('Eigenvalue of H')
ax.set_ylabel('Entanglement entropy')
#ax.set_title('Entanglement entropy as a function of energy eigenvalues')
#ax.legend(sorted_handles, sorted_labels)
plt.show()
# Out:
# Entropies of red points:
# Index: 2957, Entropy: 4.176221972501163
# Index: 2958, Entropy: 4.374190368830662
# Index: 2959, Entropy: 3.123382916425103
# Index: 2960, Entropy: 4.078575643903054
# Index: 2961, Entropy: 3.3519939070724756
# Max scar entropy: 4.579985737829519

# %%
################## PROPERTIES OF EACH SCARRED STATE AND THEIR RDM ######################

# %%
# List to store the null space information for each matrix
null_spaces_info = []

for idx, rdm in enumerate(min_rdms_by_rank[min_rank]): # CHANGE TO RANK CONSIDERED 
    print(f"RDM Index: {idx}")
    
    # Compute the null space of the RDM
    null_space_rdm = null_space(rdm)
    
    # Store the null space information
    null_spaces_info.append(null_space_rdm)
    
    # Print the null space dimensions and basis vectors
    print(f"Null space dimension: {null_space_rdm.shape[1]}")
    print(f"Null space basis vectors:\n{null_space_rdm}")
    print("-" * 50)

    # Apply the RDM to each null basis vector
    for i, basis_vector in enumerate(null_space_rdm.T):  # Transpose to iterate over columns
        result = np.dot(rdm, basis_vector)
        print(f"RDM {idx}, Null Basis Vector {i}:")
        print(f"Result: {result}")
        print(f"Norm of Result: {np.linalg.norm(result)}")

# Print the results
print("Null space information for each matrix computed.")
# Out:
# RDM Index: 0
# Null space dimension: 6
# Null space basis vectors:
# [[-4.69161318e-04  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -9.99999890e-01]
#  [ 2.59982742e-02 -2.82273861e-01 -9.00352565e-02 -3.33974864e-01
#   -2.57377596e-12 -1.21973859e-05]
#  [ 2.59982742e-02 -2.82273861e-01 -9.00352565e-02 -3.33974864e-01
#   -2.54626825e-12 -1.21973859e-05]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.02374897e-13  9.41020849e-05]
#  [ 2.59982742e-02 -2.82273861e-01 -9.00352565e-02 -3.33974864e-01
#   -2.57571169e-12 -1.21973859e-05]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.06454765e-13  9.41020849e-05]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.03684539e-13  9.41020849e-05]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    3.10396779e-13 -5.50879893e-06]
#  [ 2.59982742e-02 -2.82273861e-01 -9.00352565e-02 -3.33974864e-01
#   -2.58924128e-12 -1.21973859e-05]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.08127101e-13  9.41020849e-05]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.05008645e-13  9.41020849e-05]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    3.04611628e-13 -5.50879893e-06]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.08741563e-13  9.41020849e-05]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    2.88392954e-13 -5.50879893e-06]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    3.01461816e-13 -5.50879893e-06]
#  [ 3.44365461e-01 -1.84108835e-01  1.69852816e-01  1.36624891e-01
#    6.34417029e-13 -1.61562971e-04]
#  [ 2.59982742e-02 -2.82273861e-01 -9.00352565e-02 -3.33974864e-01
#   -2.57987566e-12 -1.21973859e-05]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.07071034e-13  9.41020849e-05]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.03607415e-13  9.41020849e-05]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    3.07534292e-13 -5.50879893e-06]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.05153632e-13  9.41020849e-05]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    2.89594450e-13 -5.50879893e-06]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    3.06391949e-13 -5.50879893e-06]
#  [ 3.44365461e-01 -1.84108835e-01  1.69852816e-01  1.36624891e-01
#    6.28578183e-13 -1.61562971e-04]
#  [-2.00575092e-01 -1.82200034e-01  1.24945037e-01  1.04697225e-01
#    8.08329637e-13  9.41020849e-05]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    2.85189628e-13 -5.50879893e-06]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    2.98475456e-13 -5.50879893e-06]
#  [ 3.44365461e-01 -1.84108835e-01  1.69852816e-01  1.36624891e-01
#    6.30818089e-13 -1.61562971e-04]
#  [ 1.17417999e-02 -1.00079217e-01 -2.56730548e-01  1.54711687e-01
#    2.87591360e-13 -5.50879892e-06]
#  [ 3.44365461e-01 -1.84108835e-01  1.69852816e-01  1.36624891e-01
#    6.47092756e-13 -1.61562971e-04]
#  [ 3.44365461e-01 -1.84108835e-01  1.69852816e-01  1.36624891e-01
#    6.38580309e-13 -1.61562971e-04]
#  [ 8.20917918e-13 -1.27957706e-12 -1.94024838e-12 -6.03563446e-12
#    1.00000000e+00 -3.85142975e-16]]
# --------------------------------------------------
# RDM 0, Null Basis Vector 0:
# Result: [ 1.04308366e-30  4.77048956e-18 -3.08997619e-18 -8.67361738e-19
#   1.13841228e-18 -4.33680869e-18  3.90312782e-18  2.22261445e-18
#  -5.75982404e-19  3.46944695e-18 -4.33680869e-18 -9.75781955e-19
#  -4.33680869e-19 -1.30104261e-18  2.14129929e-18 -8.67361738e-18
#  -2.38524478e-18  0.00000000e+00  3.03576608e-18 -4.06575815e-18
#  -1.73472348e-18  8.13151629e-19  2.22261445e-18  2.81892565e-18
#  -1.73472348e-18 -4.06575815e-19 -1.76182853e-18  3.03576608e-18
#   9.75781955e-19  1.73472348e-18  1.73472348e-18  1.60237371e-31]
# Norm of Result: 1.6050554065763797e-17
# RDM 0, Null Basis Vector 1:
# Result: [-7.29542263e-31  1.73472348e-18 -8.67361738e-19  0.00000000e+00
#   8.67361738e-18 -5.20417043e-18  6.07153217e-18  1.08420217e-17
#  -7.58941521e-19  2.60208521e-18 -3.79470760e-18 -8.67361738e-18
#  -5.20417043e-18 -1.17093835e-17  1.73472348e-18 -6.93889390e-18
#  -6.50521303e-18  1.73472348e-18  4.33680869e-19  2.38524478e-18
#  -8.67361738e-19  4.11996826e-18 -1.12757026e-17  2.22261445e-18
#   4.33680869e-19 -2.38524478e-18  9.97465999e-18 -3.03576608e-18
#   7.80625564e-18 -8.67361738e-19  8.67361738e-18 -4.31408308e-32]
# Norm of Result: 3.2020925051973836e-17
# RDM 0, Null Basis Vector 2:
# Result: [-7.24920031e-31  5.63785130e-18  4.28259858e-18  1.73472348e-18
#  -5.96311195e-18  1.30104261e-18 -8.67361738e-19  6.50521303e-18
#   4.17417836e-18 -2.60208521e-18  1.46367293e-18  0.00000000e+00
#  -2.60208521e-18  1.73472348e-18  2.60208521e-18 -2.16840434e-18
#  -6.93889390e-18  3.46944695e-18 -4.77048956e-18  1.30104261e-18
#  -3.03576608e-18  2.16840434e-19 -9.54097912e-18  0.00000000e+00
#   7.80625564e-18  1.73472348e-18  6.07153217e-18  3.03576608e-18
#   1.73472348e-18  1.40946282e-18 -2.60208521e-18 -2.14471559e-30]
# Norm of Result: 2.2085480346549658e-17
# RDM 0, Null Basis Vector 3:
# Result: [ 2.54222753e-31  0.00000000e+00  1.95156391e-18 -8.67361738e-19
#   6.07153217e-18  1.30104261e-18  1.51788304e-18  1.95156391e-18
#  -1.62630326e-18 -8.67361738e-19  7.04731412e-19  3.03576608e-18
#  -7.04731412e-18 -5.20417043e-18 -4.33680869e-18  0.00000000e+00
#  -6.07153217e-18  5.63785130e-18 -4.11996826e-18 -4.98732999e-18
#   1.73472348e-18  4.33680869e-19  6.93889390e-18  1.02999206e-18
#   3.90312782e-18  6.93889390e-18 -5.63785130e-18  3.03576608e-18
#  -2.16840434e-18 -1.19262239e-18 -3.03576608e-18  4.54519467e-32]
# Norm of Result: 2.0988625144168122e-17
# RDM 0, Null Basis Vector 4:
# Result: [ 3.15535900e-31 -2.52435490e-29  2.83989926e-29  6.31088724e-30
#   4.73316543e-29  7.88860905e-30 -1.57772181e-30  5.52202634e-29
#  -4.73316543e-30 -3.15544362e-30  3.94430453e-30  8.67746996e-30
#  -5.04870979e-29 -4.57539325e-29 -3.15544362e-30 -2.36658272e-29
#  -3.78653235e-29  3.78653235e-29 -2.68212708e-29 -2.16936749e-29
#   1.26217745e-29  2.09048140e-29 -3.94430453e-29  4.93038066e-30
#   3.47098798e-29  2.52435490e-29 -3.94430453e-30  3.54987407e-29
#   7.88860905e-30 -5.12759588e-30 -1.26217745e-29  1.63163555e-29]
# Norm of Result: 1.4845636460597168e-28
# RDM 0, Null Basis Vector 5:
# Result: [-1.31712318e-30 -5.04683406e-18 -5.49994375e-18 -8.44915365e-19
#   5.64090062e-17 -1.34191195e-18  1.64917315e-18  5.66119764e-18
#  -1.02681503e-17 -4.32240913e-18 -2.33039940e-18  3.31671632e-17
#   5.97634684e-18 -4.18023994e-18 -3.07633234e-17  1.01660894e-17
#  -3.55940979e-17  2.31896445e-18 -3.83324760e-18  2.20098600e-17
#   7.21799126e-18 -2.43809864e-17 -4.46836349e-18 -8.30409926e-19
#  -4.48863935e-18  9.20887603e-18 -3.73097234e-17  1.93716435e-17
#   3.10558013e-17  9.99509466e-18 -3.87026294e-17 -4.76384790e-31]
# Norm of Result: 1.1171674018598704e-16
# RDM Index: 1
# Null space dimension: 6
# Null space basis vectors:
# [[ 6.37635798e-04  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  9.99999797e-01]
#  [ 4.01460804e-01 -1.42813712e-01 -1.15045651e-01 -2.21942451e-12
#    7.20964550e-02 -2.55985832e-04]
#  [ 4.01460804e-01 -1.42813712e-01 -1.15045651e-01 -2.18325513e-12
#    7.20964550e-02 -2.55985832e-04]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -6.95275215e-13
#    1.95724098e-01  1.96673175e-07]
#  [ 4.01460804e-01 -1.42813712e-01 -1.15045651e-01 -2.22163746e-12
#    7.20964550e-02 -2.55985832e-04]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -7.01520911e-13
#    1.95724098e-01  1.96673183e-07]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -6.93536451e-13
#    1.95724098e-01  1.96673167e-07]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.92236956e-12
#   -9.10601985e-02  6.03877310e-05]
#  [ 4.01460804e-01 -1.42813712e-01 -1.15045651e-01 -2.21308193e-12
#    7.20964550e-02 -2.55985832e-04]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -7.07512164e-13
#    1.95724098e-01  1.96673178e-07]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -6.96087386e-13
#    1.95724098e-01  1.96673175e-07]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.92476454e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -7.02544314e-13
#    1.95724098e-01  1.96673180e-07]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.94003062e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.91609580e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-1.44535903e-01 -2.75824932e-01  3.77840585e-02 -1.05752909e-11
#    3.18751214e-01  9.21612843e-05]
#  [ 4.01460804e-01 -1.42813712e-01 -1.15045651e-01 -2.24381757e-12
#    7.20964550e-02 -2.55985832e-04]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -6.95549668e-13
#    1.95724098e-01  1.96673182e-07]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -6.94752274e-13
#    1.95724098e-01  1.96673179e-07]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.93763417e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -7.01452513e-13
#    1.95724098e-01  1.96673190e-07]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.96025008e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.93442651e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-1.44535903e-01 -2.75824932e-01  3.77840585e-02 -1.05810305e-11
#    3.18751214e-01  9.21612843e-05]
#  [-3.08441182e-04  2.07684123e-01 -1.36232476e-01 -6.96013471e-13
#    1.95724098e-01  1.96673182e-07]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.94345380e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.93561369e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-1.44535903e-01 -2.75824932e-01  3.77840585e-02 -1.05751312e-11
#    3.18751214e-01  9.21612843e-05]
#  [-9.47056594e-02 -9.28963431e-02 -2.72229947e-01 -1.95503156e-12
#   -9.10601985e-02  6.03877310e-05]
#  [-1.44535903e-01 -2.75824932e-01  3.77840585e-02 -1.05557745e-11
#    3.18751214e-01  9.21612843e-05]
#  [-1.44535903e-01 -2.75824932e-01  3.77840585e-02 -1.06030121e-11
#    3.18751214e-01  9.21612843e-05]
#  [-5.03243597e-12 -1.65198512e-11 -5.50092312e-12  1.00000000e+00
#    1.72609233e-11  3.20886198e-15]]
# --------------------------------------------------
# RDM 1, Null Basis Vector 0:
# Result: [-2.34686119e-29 -4.33680869e-19 -4.33680869e-18 -6.91178885e-19
#   1.67034897e-18 -8.00361432e-18 -4.56593110e-18  4.55364912e-18
#  -3.46944695e-18 -6.83365006e-18 -4.87721571e-18 -1.08420217e-19
#   1.03922472e-17 -1.84314369e-18 -1.95156391e-18 -2.05998413e-18
#   9.97465999e-18  1.68449442e-17  1.46536700e-19 -6.07153217e-18
#   8.37715585e-18  1.95156391e-18 -7.58941521e-19 -1.95156391e-18
#  -1.08022112e-17  9.75781955e-19  6.28837260e-18  5.30920251e-18
#  -3.46944695e-18 -3.90312782e-18  1.73472348e-18 -1.37064582e-29]
# Norm of Result: 3.2311620580576314e-17
# RDM 1, Null Basis Vector 1:
# Result: [-6.66833984e-29 -8.67361738e-19 -4.11996826e-18  4.33680869e-18
#  -1.60258634e-18  3.03576608e-18  4.33680869e-19  6.28837260e-18
#   7.04731412e-18  2.92734587e-18 -8.67361738e-19  3.14418630e-18
#  -4.33680869e-19 -3.25260652e-19 -5.63785130e-18  6.50521303e-19
#  -7.58941521e-19 -1.04083409e-17  3.90312782e-18 -1.08420217e-18
#  -3.90312782e-18  2.38524478e-18 -5.42101086e-19 -3.25260652e-18
#   1.17093835e-17  1.08420217e-19  2.16840434e-19  1.18245799e-18
#  -2.60208521e-18  2.16840434e-19  2.16840434e-18  1.46062527e-29]
# Norm of Result: 2.2285150375228856e-17
# RDM 1, Null Basis Vector 2:
# Result: [ 2.36966420e-29 -1.08420217e-18  2.87313576e-18 -2.60208521e-18
#  -1.21295118e-18  1.73472348e-18  1.30104261e-18  8.67361738e-18
#   1.68051337e-18 -3.57786717e-18  1.30104261e-17  1.56125113e-17
#  -4.98732999e-18 -5.63785130e-18 -1.21430643e-17  7.31836466e-19
#  -2.38524478e-18  8.67361738e-19 -6.72205347e-18  3.03576608e-18
#   1.40946282e-18  6.07153217e-18 -4.66206934e-18  1.38235777e-18
#  -6.72205347e-18 -2.16840434e-18  3.46944695e-18  1.00161646e-18
#   1.73472348e-18  3.25260652e-19 -3.36102673e-18 -6.51303285e-29]
# Norm of Result: 3.052180880756446e-17
# RDM 1, Null Basis Vector 3:
# Result: [-1.85579905e-30 -3.31321580e-29 -1.41994963e-29 -6.94197597e-29
#  -4.02565581e-29  2.05103835e-29  3.23432971e-29  8.20415341e-29
#   5.20648197e-29  1.02551918e-29  1.05707361e-28  1.73549399e-28
#  -3.47098798e-29 -1.04129639e-28 -3.78653235e-29 -5.04870979e-29
#   1.89326617e-29  9.46633086e-30 -3.70764625e-29  7.25752033e-29
#   3.15544362e-30 -5.04870979e-29  1.49883572e-29 -8.83524214e-29
#   7.88860905e-30  1.04129639e-28  0.00000000e+00 -3.34772847e-29
#   2.52435490e-29  1.89326617e-29  6.31088724e-29  2.80555209e-28]
# Norm of Result: 4.352873620521289e-28
# RDM 1, Null Basis Vector 4:
# Result: [ 7.18602981e-30  5.42101086e-19 -4.01154804e-18 -2.60208521e-18
#   1.54414106e-18  1.73472348e-18  6.50521303e-19  5.63785130e-18
#   1.62630326e-18 -2.16840434e-19 -3.46944695e-18 -2.16840434e-19
#  -2.16840434e-18  1.30104261e-18 -5.42101086e-18  1.19262239e-17
#   4.87890978e-19 -2.60208521e-18  6.50521303e-18 -1.30104261e-18
#  -4.33680869e-19  1.95156391e-18 -1.62630326e-19 -1.08420217e-18
#   6.93889390e-18  1.08420217e-18 -2.16840434e-19  2.00407995e-18
#  -1.30104261e-18 -6.07153217e-18 -3.25260652e-18 -3.38809596e-29]
# Norm of Result: 2.0305000121841355e-17
# RDM 1, Null Basis Vector 5:
# Result: [ 2.52389651e-29  4.53120275e-18 -7.31794115e-18  5.67409256e-18
#   1.20637410e-17  1.68588053e-18 -5.88910637e-18 -2.64818498e-17
#  -1.20064803e-17 -1.93335549e-18  3.47530505e-18  7.10115365e-18
#  -5.71476338e-19  3.09362902e-17 -1.05430191e-17 -1.38638118e-18
#   2.72786961e-18  1.58280597e-19  4.11340954e-18  3.75421943e-17
#  -2.99215609e-18  2.24035979e-17 -3.75960338e-17  5.20194697e-18
#  -3.72086933e-18 -7.29481715e-17  3.27134712e-17 -5.93934705e-18
#   1.68705670e-17  3.78464909e-18 -1.66050221e-18 -4.85093605e-31]
# Norm of Result: 1.1135126581539983e-16
# RDM Index: 2
# Null space dimension: 6
# Null space basis vectors:
# [[ 1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 4.58179584e-16  2.44125349e-02  4.16055915e-01 -1.44178471e-01
#    5.52095484e-15 -7.42568003e-02]
#  [ 8.78742228e-16  2.44125349e-02  4.16055915e-01 -1.44178471e-01
#    3.91174993e-15 -7.42568003e-02]
#  [-1.11791307e-15 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.58564336e-13  1.54016834e-03]
#  [-3.60049379e-15  2.44125349e-02  4.16055915e-01 -1.44178471e-01
#    9.84193681e-15 -7.42568003e-02]
#  [-1.97518976e-15 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.56357773e-13  1.54016834e-03]
#  [-1.00434299e-15 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.57665496e-13  1.54016834e-03]
#  [-3.27189131e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.13083702e-13  3.67852547e-02]
#  [-2.90790335e-16  2.44125349e-02  4.16055915e-01 -1.44178471e-01
#    3.17978037e-15 -7.42568003e-02]
#  [-2.56237298e-16 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.57563042e-13  1.54016834e-03]
#  [ 1.62287374e-16 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.58820862e-13  1.54016834e-03]
#  [ 3.84545690e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.17396898e-13  3.67852547e-02]
#  [-1.97288009e-15 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.56461784e-13  1.54016834e-03]
#  [-3.34444608e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.12889419e-13  3.67852547e-02]
#  [-3.58979706e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.12885387e-13  3.67852547e-02]
#  [ 1.70217890e-15 -4.34073537e-02  7.95613853e-02 -3.30366166e-03
#   -1.70244020e-13  4.37921081e-01]
#  [ 2.55436232e-15  2.44125349e-02  4.16055915e-01 -1.44178471e-01
#   -5.60322302e-15 -7.42568003e-02]
#  [ 8.28196925e-16 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.58543537e-13  1.54016834e-03]
#  [ 1.69626624e-15 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.58070279e-13  1.54016834e-03]
#  [ 1.83736258e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.20076324e-13  3.67852547e-02]
#  [ 1.77630463e-15 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.57322334e-13  1.54016834e-03]
#  [ 1.47548532e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.17006314e-13  3.67852547e-02]
#  [ 1.84409808e-16  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.17715528e-13  3.67852547e-02]
#  [-7.91024174e-17 -4.34073537e-02  7.95613853e-02 -3.30366166e-03
#   -1.66307184e-13  4.37921081e-01]
#  [ 1.86350803e-15 -1.25166955e-01 -8.82543349e-02 -2.76662310e-01
#   -5.57857607e-13  1.54016834e-03]
#  [ 2.77079155e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.20504069e-13  3.67852547e-02]
#  [ 2.76587365e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.20685468e-13  3.67852547e-02]
#  [-2.63995027e-15 -4.34073537e-02  7.95613853e-02 -3.30366166e-03
#   -1.68762785e-13  4.37921081e-01]
#  [-2.67324537e-15  2.88258822e-01 -4.99490057e-02 -1.14275079e-01
#   -3.17818099e-13  3.67852547e-02]
#  [ 3.24053332e-16 -4.34073537e-02  7.95613853e-02 -3.30366166e-03
#   -1.66549854e-13  4.37921081e-01]
#  [ 6.92820463e-16 -4.34073537e-02  7.95613853e-02 -3.30366166e-03
#   -1.65588628e-13  4.37921081e-01]
#  [ 1.16201826e-28  1.78950605e-13 -5.90938032e-13 -1.90560459e-12
#    1.00000000e+00  4.93190785e-13]]
# --------------------------------------------------
# RDM 2, Null Basis Vector 0:
# Result: [ 1.09420516e-30  1.21248898e-17  3.14399040e-18 -5.28940040e-18
#  -3.03991227e-17  1.59036308e-18  4.15712945e-18 -3.50772823e-17
#  -1.89190410e-18  1.86742870e-18  5.78238290e-18  4.95820086e-17
#  -9.38054790e-19 -3.77135848e-17 -3.64226445e-17  1.22480799e-17
#   1.70221466e-17 -5.74430323e-18 -2.49874572e-18  1.37434492e-17
#   5.64147083e-18  1.83573669e-17  4.84960279e-18 -3.34279035e-19
#  -4.56827082e-18  2.56493297e-17  2.67674841e-17 -2.40119989e-17
#  -2.97357297e-17  4.96309297e-18  7.13510514e-18  1.06115132e-30]
# Norm of Result: 1.0770245613916436e-16
# RDM 2, Null Basis Vector 1:
# Result: [ 4.12149008e-31 -1.11130723e-17  2.00577402e-18  7.58941521e-18
#  -1.89735380e-19 -1.51788304e-18 -2.71050543e-18  4.33680869e-18
#   8.40256684e-19  3.14418630e-18 -4.77048956e-18  1.40946282e-17
#   1.95156391e-18  2.16840434e-17 -1.73472348e-18 -3.68628739e-18
#   8.38901431e-18  2.16840434e-18 -3.90312782e-18 -2.16840434e-18
#   4.55364912e-18 -1.73472348e-17 -1.23599048e-17  2.43945489e-18
#  -2.38524478e-18 -1.12757026e-17  3.46944695e-18 -1.76182853e-18
#  -1.51788304e-18  4.06575815e-18 -1.08420217e-18  2.19979718e-30]
# Norm of Result: 4.0982996736785695e-17
# RDM 2, Null Basis Vector 2:
# Result: [ 6.16297582e-33 -8.67361738e-19 -1.73472348e-18 -1.68051337e-18
#  -3.14418630e-18 -4.77048956e-18  1.95156391e-18 -6.01732206e-18
#   1.69135539e-17  9.54097912e-18 -3.25260652e-18 -6.50521303e-19
#  -1.73472348e-18 -1.08420217e-19  2.60208521e-18  4.06575815e-19
#  -4.77048956e-18 -1.73472348e-18 -6.61363325e-18  2.05998413e-18
#   2.16840434e-19  1.08420217e-18  2.81892565e-18 -3.14418630e-18
#   1.06251813e-17  1.84314369e-18 -1.40946282e-18  1.58564568e-18
#  -1.87024875e-18 -1.08420217e-18  3.03576608e-18 -1.09392821e-31]
# Norm of Result: 2.65479063504735e-17
# RDM 2, Null Basis Vector 3:
# Result: [ 2.72711680e-31 -2.16840434e-19  5.85469173e-18  3.25260652e-18
#   1.05709712e-18  2.60208521e-18  7.58941521e-18  1.00830802e-17
#  -8.02309608e-18  2.16840434e-19 -5.20417043e-18  3.25260652e-19
#  -3.46944695e-18 -9.32413868e-18 -3.68628739e-18 -3.01543729e-18
#   3.25260652e-19  8.67361738e-19  3.46944695e-18 -9.10729825e-18
#   3.90312782e-18 -8.67361738e-18  4.77048956e-18  8.12474003e-18
#  -4.98732999e-18  1.42030485e-17 -4.11996826e-18 -1.40946282e-18
#   5.74627151e-18 -4.14368518e-18  4.13352078e-19 -7.43408959e-31]
# Norm of Result: 3.1564518929898486e-17
# RDM 2, Null Basis Vector 4:
# Result: [ 9.05537347e-32 -4.06756404e-31  1.25663077e-29  8.67746996e-30
#   2.29262701e-30  7.88860905e-30  3.15544362e-30  2.52435490e-29
#  -1.00271617e-29  1.18329136e-30 -1.57772181e-30  0.00000000e+00
#  -1.57772181e-30 -1.77493704e-29 -1.34106354e-29 -5.22620350e-30
#  -3.96895643e-30  1.57772181e-30  6.31088724e-30 -1.93270922e-29
#   9.46633086e-30 -1.18329136e-29  1.02551918e-29  1.85382313e-29
#  -3.15544362e-30  2.87934230e-29 -3.15544362e-30 -3.59917788e-30
#   1.34106354e-29 -1.24245593e-29  2.76101317e-30  1.26063423e-29]
# Norm of Result: 6.363915325705244e-29
# RDM 2, Null Basis Vector 5:
# Result: [ 1.67281460e-30  1.73472348e-18  1.62630326e-18  2.04304347e-18
#   8.53809211e-19  5.72594272e-19  1.99052743e-18 -6.77626358e-19
#  -1.19262239e-18 -2.34628126e-18 -1.71439469e-18 -6.17995238e-18
#  -1.22819777e-18  1.95156391e-18  1.08420217e-18  3.25260652e-18
#  -3.74049750e-18  1.06048525e-18  1.12824789e-18 -2.27682456e-18
#   5.91228997e-19 -2.16840434e-18 -8.67361738e-19  4.33680869e-19
#  -2.17348654e-18 -4.87890978e-19  5.42101086e-19  3.68628739e-18
#   7.86046575e-18  8.67361738e-19 -4.33680869e-18  2.11984702e-31]
# Norm of Result: 1.442890540374578e-17
# RDM Index: 3
# Null space dimension: 6
# Null space basis vectors:
# [[-2.99956502e-03  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -9.99995501e-01]
#  [ 3.97541565e-01 -3.76799353e-02 -6.12860758e-02  7.09094848e-14
#    1.91790306e-01 -1.19245714e-03]
#  [ 3.97541565e-01 -3.76799353e-02 -6.12860758e-02  1.72749803e-14
#    1.91790306e-01 -1.19245714e-03]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  6.21629308e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [ 3.97541565e-01 -3.76799353e-02 -6.12860758e-02  4.31980013e-14
#    1.91790306e-01 -1.19245714e-03]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  5.43532336e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  5.90981442e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -3.78687994e-13
#    1.58847729e-01  8.69844451e-05]
#  [ 3.97541565e-01 -3.76799353e-02 -6.12860758e-02  1.96502680e-14
#    1.91790306e-01 -1.19245714e-03]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  6.49222413e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  5.95321722e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -3.89655576e-13
#    1.58847729e-01  8.69844451e-05]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  6.68610069e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -3.74760642e-13
#    1.58847729e-01  8.69844451e-05]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -4.01744165e-13
#    1.58847729e-01  8.69844451e-05]
#  [ 5.84233934e-02 -3.73232409e-01  2.00785275e-01 -7.96549513e-14
#   -1.30267104e-01 -1.75245555e-04]
#  [ 3.97541565e-01 -3.76799353e-02 -6.12860758e-02 -1.21039616e-15
#    1.91790306e-01 -1.19245714e-03]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  5.37389703e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  6.31630187e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -3.96094156e-13
#    1.58847729e-01  8.69844451e-05]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  6.61569292e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -3.87766274e-13
#    1.58847729e-01  8.69844451e-05]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -4.15371786e-13
#    1.58847729e-01  8.69844451e-05]
#  [ 5.84233934e-02 -3.73232409e-01  2.00785275e-01 -7.86679195e-14
#   -1.30267104e-01 -1.75245555e-04]
#  [ 1.35764024e-01  1.52527059e-01  1.02042056e-01  6.82259899e-15
#   -2.18839848e-01 -4.07234850e-04]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -3.98915776e-13
#    1.58847729e-01  8.69844451e-05]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -4.30363599e-13
#    1.58847729e-01  8.69844451e-05]
#  [ 5.84233934e-02 -3.73232409e-01  2.00785275e-01 -7.95165027e-14
#   -1.30267104e-01 -1.75245555e-04]
#  [-2.89988892e-02  7.98397881e-02  2.59907799e-01 -4.11747976e-13
#    1.58847729e-01  8.69844451e-05]
#  [ 5.84233934e-02 -3.73232409e-01  2.00785275e-01 -7.95838386e-14
#   -1.30267104e-01 -1.75245555e-04]
#  [ 5.84233934e-02 -3.73232409e-01  2.00785275e-01 -7.47195133e-14
#   -1.30267104e-01 -1.75245555e-04]
#  [-1.60607133e-13  1.68025649e-13  1.11737075e-12  1.00000000e+00
#    5.66736579e-13  4.81753704e-16]]
# --------------------------------------------------
# RDM 3, Null Basis Vector 0:
# Result: [-4.76089882e-31 -1.84314369e-18 -6.28837260e-18 -4.77048956e-18
#   4.60785923e-18 -1.84314369e-18 -2.16840434e-18 -5.58364119e-18
#   2.65629532e-18  8.67361738e-19  5.85469173e-18  8.13151629e-19
#  -3.46944695e-18  5.47522097e-18  5.57008866e-18  3.08319993e-18
#   8.40256684e-19 -9.75781955e-19 -3.90312782e-18 -1.89735380e-19
#   4.33680869e-19  4.87890978e-19 -7.48099499e-18  1.96511644e-18
#   1.78893358e-18  1.30104261e-18  2.43945489e-18  1.89735380e-19
#  -2.49366500e-18 -4.01154804e-18 -1.24683250e-18 -1.11241714e-30]
# Norm of Result: 1.9063787706105505e-17
# RDM 3, Null Basis Vector 1:
# Result: [-3.57298523e-30 -3.36102673e-18  5.27870933e-18  8.67361738e-19
#  -2.07353665e-18 -2.71050543e-18  2.60208521e-18 -8.13151629e-20
#   1.13841228e-18 -2.16840434e-18 -4.33680869e-19 -3.25260652e-18
#  -1.08420217e-18  0.00000000e+00  2.24971951e-18 -1.02999206e-18
#  -1.65002018e-18 -1.08420217e-19  0.00000000e+00  4.33680869e-19
#  -2.16840434e-18  1.08420217e-19  2.60208521e-18  2.16840434e-19
#  -3.25260652e-19  8.67361738e-19  1.13841228e-18 -2.76471554e-18
#  -3.03576608e-18 -2.16840434e-19  1.30104261e-18 -6.60208785e-31]
# Norm of Result: 1.0844717601439436e-17
# RDM 3, Null Basis Vector 2:
# Result: [ 7.02579244e-31 -1.66696084e-18  1.39591030e-18 -1.30104261e-18
#  -2.24971951e-18  1.40946282e-18 -6.50521303e-19  5.96311195e-18
#   2.11419424e-18 -1.73472348e-18 -3.25260652e-19 -2.16840434e-17
#   8.67361738e-19  3.03576608e-18  2.49366500e-18  2.20906193e-18
#  -3.25260652e-19 -3.52365706e-19  1.95156391e-18 -3.46944695e-18
#  -2.16840434e-18 -2.16840434e-18  5.20417043e-18 -3.60497222e-18
#  -1.46367293e-18  1.30104261e-17  6.93889390e-18  3.33392168e-18
#  -8.67361738e-18 -1.40946282e-18  9.75781955e-19  6.42798378e-30]
# Norm of Result: 3.037605704647875e-17
# RDM 3, Null Basis Vector 3:
# Result: [-1.41014375e-31  7.27231147e-31  2.71170936e-31 -1.03537994e-30
#   3.79639311e-30 -1.97215226e-30  6.28623534e-31 -6.50810247e-30
#  -6.29856129e-30  1.04770589e-30  1.70098133e-30  2.52435490e-29
#  -1.15247648e-30  3.15544362e-30  3.54987407e-30  2.16936749e-30
#   5.54667824e-31  2.00450789e-30 -4.03058619e-30  5.91645679e-30
#  -2.15704154e-31 -1.57772181e-30 -4.73316543e-30  3.01985815e-30
#  -3.05067303e-31 -7.09974815e-30 -7.88860905e-31 -2.20634534e-30
#   4.73316543e-30  2.31727891e-30 -2.03378202e-31  1.99583900e-29]
# Norm of Result: 3.666080065567973e-29
# RDM 3, Null Basis Vector 4:
# Result: [-2.46519033e-32  1.32814766e-18  1.51788304e-18 -1.73472348e-18
#   3.52365706e-19  2.38524478e-18  4.33680869e-19  6.61363325e-18
#  -9.48676901e-19  3.46944695e-18 -4.33680869e-19 -7.37257477e-18
#   1.95156391e-18 -4.33680869e-19  1.24683250e-18 -2.24971951e-18
#   9.48676901e-19 -3.27971157e-18  7.37257477e-18 -3.46944695e-18
#   3.46944695e-18  2.38524478e-18 -6.50521303e-18 -1.97866896e-18
#   1.08420217e-19  2.60208521e-18  2.60208521e-18  3.23905399e-18
#   1.73472348e-18  7.04731412e-19 -8.13151629e-19  2.82264293e-30]
# Norm of Result: 1.7468008868717562e-17
# RDM 3, Null Basis Vector 5:
# Result: [-2.38917628e-30 -4.36137265e-18  3.08345404e-17  3.03237795e-18
#  -3.45525915e-18 -9.66168131e-18 -9.82219406e-18  6.74383810e-18
#   3.85459283e-17  1.49586018e-17  2.67996989e-17  5.80217569e-19
#   4.51256803e-18 -5.89344349e-18 -1.44922043e-18  1.06445439e-17
#  -6.15675427e-17 -6.81220954e-18 -2.45639555e-18 -7.97100355e-18
#  -2.36237489e-17 -2.50958922e-17  7.53986378e-18 -7.45613987e-18
#   3.08531751e-18  3.20862433e-17 -3.72171983e-17 -1.50877744e-20
#   3.06765687e-17 -3.94336189e-18  7.68960332e-19 -1.11987711e-30]
# Norm of Result: 1.114139426266386e-16
# RDM Index: 4
# Null space dimension: 6
# Null space basis vectors:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -1.00000000e+00  0.00000000e+00]
#  [ 2.00171748e-02 -7.70222011e-02  4.39942262e-01 -3.81931073e-11
#   -3.67574183e-16  1.08489338e-02]
#  [ 2.00171748e-02 -7.70222011e-02  4.39942262e-01 -3.81930483e-11
#    6.70072132e-16  1.08489338e-02]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.65987348e-12
#    2.62132340e-14  7.04027161e-02]
#  [ 2.00171748e-02 -7.70222011e-02  4.39942262e-01 -3.81582098e-11
#    9.23921101e-15  1.08489338e-02]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.65830842e-12
#    3.27380553e-14  7.04027161e-02]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.65481289e-12
#    1.79353728e-14  7.04027161e-02]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -1.77125461e-13
#    2.72967490e-15 -2.98025175e-01]
#  [ 2.00171748e-02 -7.70222011e-02  4.39942262e-01 -3.82411940e-11
#    5.90198750e-15  1.08489338e-02]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.66036884e-12
#    6.22268964e-15  7.04027161e-02]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.65869413e-12
#    1.31985695e-14  7.04027161e-02]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -2.15093942e-13
#    1.39803136e-15 -2.98025175e-01]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.65697516e-12
#    2.04731350e-14  7.04027161e-02]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -1.96401087e-13
#   -4.41425795e-16 -2.98025175e-01]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -2.10307408e-13
#    8.26685827e-16 -2.98025175e-01]
#  [ 3.37892945e-01  2.68906755e-01  3.44428340e-02  8.12041220e-12
#   -1.54482762e-14 -1.11045963e-01]
#  [ 2.00171748e-02 -7.70222011e-02  4.39942262e-01 -3.84421473e-11
#   -1.54436965e-14  1.08489338e-02]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.66671414e-12
#   -3.38107577e-14  7.04027161e-02]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.66550365e-12
#   -2.56128896e-14  7.04027161e-02]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -3.20662827e-13
#   -1.85019436e-15 -2.98025175e-01]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.66253358e-12
#   -1.87606800e-14  7.04027161e-02]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -3.03762610e-13
#   -1.94902899e-15 -2.98025175e-01]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -3.15449834e-13
#   -1.51625304e-15 -2.98025175e-01]
#  [ 3.37892945e-01  2.68906755e-01  3.44428340e-02  8.14614601e-12
#   -8.54149784e-16 -1.11045963e-01]
#  [-1.78200444e-01  2.46642676e-01  4.95524952e-02 -4.66573144e-12
#   -3.85967289e-14  7.04027161e-02]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -3.64217325e-13
#    4.48826070e-17 -2.98025175e-01]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -3.41282705e-13
#    6.17185383e-16 -2.98025175e-01]
#  [ 3.37892945e-01  2.68906755e-01  3.44428340e-02  8.17050262e-12
#    6.39861110e-15 -1.11045963e-01]
#  [-1.04682554e-01  6.76454654e-03  1.32965735e-02 -3.23766395e-13
#    1.40442098e-16 -2.98025175e-01]
#  [ 3.37892945e-01  2.68906755e-01  3.44428340e-02  8.16153322e-12
#    5.23764198e-15 -1.11045963e-01]
#  [ 3.37892945e-01  2.68906755e-01  3.44428340e-02  8.15176988e-12
#    4.66617289e-15 -1.11045963e-01]
#  [-1.85370270e-11 -1.41722066e-11  8.50720155e-11  1.00000000e+00
#   -5.93011573e-27  9.05626220e-12]]
# --------------------------------------------------
# RDM 4, Null Basis Vector 0:
# Result: [ 3.15051324e-29 -4.98732999e-18  8.40256684e-19 -2.60208521e-18
#   7.58941521e-19  2.60208521e-18  3.03576608e-18 -2.16840434e-19
#   3.93023288e-18 -2.60208521e-18  3.03576608e-18 -3.90312782e-18
#  -9.54097912e-18  2.81892565e-18  2.16840434e-18  6.50521303e-19
#  -4.74338450e-19  5.20417043e-18 -1.30104261e-18  0.00000000e+00
#   4.33680869e-19 -8.67361738e-19 -8.67361738e-19  1.30104261e-18
#  -4.33680869e-19  4.33680869e-19 -2.60208521e-18 -1.30104261e-18
#   1.73472348e-18  0.00000000e+00  1.73472348e-18 -1.20794326e-30]
# Norm of Result: 1.5715421900624622e-17
# RDM 4, Null Basis Vector 1:
# Result: [-1.47911420e-30  8.67361738e-18 -5.20417043e-18 -1.73472348e-18
#  -3.36102673e-18  0.00000000e+00 -3.46944695e-18  5.06864516e-18
#  -4.33680869e-19  1.73472348e-18  3.46944695e-18  1.49077799e-18
#   1.04083409e-17 -2.88668828e-18  1.27393755e-18  2.38524478e-18
#   4.87890978e-19 -6.93889390e-18 -2.16840434e-18 -2.73761049e-18
#   8.67361738e-19  7.07441918e-18 -5.71916646e-18 -4.33680869e-19
#   8.67361738e-19  2.98155597e-18 -1.49077799e-18  3.03576608e-18
#  -5.17706537e-18 -1.30104261e-18 -1.73472348e-18  9.29376754e-30]
# Norm of Result: 2.2195684191587214e-17
# RDM 4, Null Basis Vector 2:
# Result: [-3.19858445e-30 -6.93889390e-18 -7.80625564e-18  4.77048956e-18
#   4.33680869e-18 -4.33680869e-19 -2.16840434e-18 -9.21571847e-19
#   3.46944695e-18 -2.60208521e-18 -2.16840434e-18 -1.40946282e-18
#   1.60461922e-17 -1.19262239e-18 -1.89735380e-18 -1.32814766e-18
#  -4.33680869e-19  5.42101086e-18 -3.79470760e-18 -3.25260652e-19
#  -1.40946282e-17 -2.05998413e-18  2.33103467e-18 -1.08420217e-18
#  -1.08420217e-18  1.02999206e-18  3.19839641e-18  0.00000000e+00
#   1.30104261e-18 -1.13841228e-18  3.68628739e-18  1.31148125e-29]
# Norm of Result: 2.6996103418429208e-17
# RDM 4, Null Basis Vector 3:
# Result: [-4.26064844e-30  6.05845175e-28  3.02922588e-28 -1.00974196e-28
#  -3.53409686e-28 -2.77679039e-28  4.54383881e-28 -2.91878535e-29
#  -4.54383881e-28  1.26217745e-28 -2.01948392e-28  2.39813715e-28
#  -1.16120325e-27  1.44361546e-28  2.64268403e-28  9.46633086e-29
#   2.52435490e-29 -5.55358077e-28  5.80601626e-28 -1.90904339e-28
#   7.95171792e-28  3.51831964e-28 -2.27191941e-28  1.76704843e-28
#   3.40787911e-28 -1.04129639e-28  2.05103835e-29 -1.38839519e-28
#  -4.10207671e-28  1.00974196e-28 -1.00974196e-28  2.59460168e-28]
# Norm of Result: 2.1380486160786225e-27
# RDM 4, Null Basis Vector 4:
# Result: [-1.85148420e-29  4.77557207e-18 -3.87491357e-17  7.95701969e-18
#   5.22763014e-18 -6.00880823e-18  3.29359719e-18  4.06264489e-17
#   5.08672386e-17 -3.71757239e-18  4.56354349e-18  1.57215143e-17
#  -9.47560507e-18 -2.96327674e-17 -9.25293356e-18  4.37426544e-18
#  -2.21213051e-17  4.48068428e-19  8.77417177e-18 -2.15460876e-17
#  -4.62642109e-18 -3.80071002e-17 -1.87573061e-17 -9.74449922e-18
#  -1.20799378e-18  3.47870652e-17  2.28061493e-17 -1.10307795e-17
#   3.25501719e-18  1.76342784e-17 -1.23326512e-18  1.12815856e-30]
# Norm of Result: 1.1123993298308907e-16
# RDM 4, Null Basis Vector 5:
# Result: [-1.56539586e-30 -1.89735380e-18  2.52212530e-17 -9.75781955e-18
#  -4.41812385e-18  6.72205347e-18 -3.68628739e-18 -2.60208521e-17
#  -3.35425047e-17  4.33680869e-19 -6.50521303e-19 -1.12757026e-17
#   1.12757026e-17  2.16840434e-17  5.20417043e-18 -3.79470760e-18
#   1.45350854e-17 -1.73472348e-18 -8.67361738e-18  1.12757026e-17
#   6.28837260e-18  3.81639165e-17  6.93889390e-18  3.90312782e-18
#   1.30104261e-18 -2.42861287e-17 -1.90819582e-17  8.89045781e-18
#  -6.93889390e-18 -1.56125113e-17  5.20417043e-18 -1.53827877e-29]
# Norm of Result: 8.19249338981169e-17
# Null space information for each matrix computed.

# %%
# List to store the null space information for each matrix
null_spaces_info = []

for idx, rdm in enumerate(min_rdms_by_rank[min_rank]): # CHANGE TO RANK CONSIDERED
    print(f"RDM Index: {idx}")
    
    # Compute the null space of the RDM
    null_space_rdm = null_space(rdm)
    
    # Store the null space information
    null_spaces_info.append(null_space_rdm)
    
    # Print the null space dimensions and basis vectors
    print(f"Null space dimension: {null_space_rdm.shape[1]}")
    #print(f"Null space basis vectors:\n{null_space_rdm}")
    print("-" * 50)

    # Apply the RDM to each null basis vector
    #for i, basis_vector in enumerate(null_space_rdm.T):  # Transpose to iterate over columns
        #result = np.dot(rdm, basis_vector)
        #print(f"RDM {idx}, Null Basis Vector {i}:")
        #print(f"Result: {result}")
        #print(f"Norm of Result: {np.linalg.norm(result)}")
    
    # Check for repeating rows in the null space basis vectors
    print(f"Repeating rows in the null space basis vectors for RDM {idx}:")
    for i in range(null_space_rdm.shape[0]):
        for j in range(i + 1, null_space_rdm.shape[0]):
            if np.allclose(null_space_rdm[i, :], null_space_rdm[j, :], atol=1e-12):  # Compare rows with a tolerance
                print(f"Row {i} is identical to Row {j}")
    print("-" * 50)
# Out:
# RDM Index: 0
# Null space dimension: 6
# --------------------------------------------------
# Repeating rows in the null space basis vectors for RDM 0:
# Row 1 is identical to Row 2
# Row 1 is identical to Row 4
# Row 1 is identical to Row 8
# Row 1 is identical to Row 16
# Row 2 is identical to Row 4
# Row 2 is identical to Row 8
# Row 2 is identical to Row 16
# Row 3 is identical to Row 5
# Row 3 is identical to Row 6
# Row 3 is identical to Row 9
# Row 3 is identical to Row 10
# Row 3 is identical to Row 12
# Row 3 is identical to Row 17
# Row 3 is identical to Row 18
# Row 3 is identical to Row 20
# Row 3 is identical to Row 24
# Row 4 is identical to Row 8
# Row 4 is identical to Row 16
# Row 5 is identical to Row 6
# Row 5 is identical to Row 9
# Row 5 is identical to Row 10
# Row 5 is identical to Row 12
# Row 5 is identical to Row 17
# Row 5 is identical to Row 18
# Row 5 is identical to Row 20
# Row 5 is identical to Row 24
# Row 6 is identical to Row 9
# Row 6 is identical to Row 10
# Row 6 is identical to Row 12
# Row 6 is identical to Row 17
# Row 6 is identical to Row 18
# Row 6 is identical to Row 20
# Row 6 is identical to Row 24
# Row 7 is identical to Row 11
# Row 7 is identical to Row 13
# Row 7 is identical to Row 14
# Row 7 is identical to Row 19
# Row 7 is identical to Row 21
# Row 7 is identical to Row 22
# Row 7 is identical to Row 25
# Row 7 is identical to Row 26
# Row 7 is identical to Row 28
# Row 8 is identical to Row 16
# Row 9 is identical to Row 10
# Row 9 is identical to Row 12
# Row 9 is identical to Row 17
# Row 9 is identical to Row 18
# Row 9 is identical to Row 20
# Row 9 is identical to Row 24
# Row 10 is identical to Row 12
# Row 10 is identical to Row 17
# Row 10 is identical to Row 18
# Row 10 is identical to Row 20
# Row 10 is identical to Row 24
# Row 11 is identical to Row 13
# Row 11 is identical to Row 14
# Row 11 is identical to Row 19
# Row 11 is identical to Row 21
# Row 11 is identical to Row 22
# Row 11 is identical to Row 25
# Row 11 is identical to Row 26
# Row 11 is identical to Row 28
# Row 12 is identical to Row 17
# Row 12 is identical to Row 18
# Row 12 is identical to Row 20
# Row 12 is identical to Row 24
# Row 13 is identical to Row 14
# Row 13 is identical to Row 19
# Row 13 is identical to Row 21
# Row 13 is identical to Row 22
# Row 13 is identical to Row 25
# Row 13 is identical to Row 26
# Row 13 is identical to Row 28
# Row 14 is identical to Row 19
# Row 14 is identical to Row 21
# Row 14 is identical to Row 22
# Row 14 is identical to Row 25
# Row 14 is identical to Row 26
# Row 14 is identical to Row 28
# Row 15 is identical to Row 23
# Row 15 is identical to Row 27
# Row 15 is identical to Row 29
# Row 15 is identical to Row 30
# Row 17 is identical to Row 18
# Row 17 is identical to Row 20
# Row 17 is identical to Row 24
# Row 18 is identical to Row 20
# Row 18 is identical to Row 24
# Row 19 is identical to Row 21
# Row 19 is identical to Row 22
# Row 19 is identical to Row 25
# Row 19 is identical to Row 26
# Row 19 is identical to Row 28
# Row 20 is identical to Row 24
# Row 21 is identical to Row 22
# Row 21 is identical to Row 25
# Row 21 is identical to Row 26
# Row 21 is identical to Row 28
# Row 22 is identical to Row 25
# Row 22 is identical to Row 26
# Row 22 is identical to Row 28
# Row 23 is identical to Row 27
# Row 23 is identical to Row 29
# Row 23 is identical to Row 30
# Row 25 is identical to Row 26
# Row 25 is identical to Row 28
# Row 26 is identical to Row 28
# Row 27 is identical to Row 29
# Row 27 is identical to Row 30
# Row 29 is identical to Row 30
# --------------------------------------------------
# RDM Index: 1
# Null space dimension: 6
# --------------------------------------------------
# Repeating rows in the null space basis vectors for RDM 1:
# Row 1 is identical to Row 2
# Row 1 is identical to Row 4
# Row 1 is identical to Row 8
# Row 1 is identical to Row 16
# Row 2 is identical to Row 4
# Row 2 is identical to Row 8
# Row 2 is identical to Row 16
# Row 3 is identical to Row 5
# Row 3 is identical to Row 6
# Row 3 is identical to Row 9
# Row 3 is identical to Row 10
# Row 3 is identical to Row 12
# Row 3 is identical to Row 17
# Row 3 is identical to Row 18
# Row 3 is identical to Row 20
# Row 3 is identical to Row 24
# Row 4 is identical to Row 8
# Row 4 is identical to Row 16
# Row 5 is identical to Row 6
# Row 5 is identical to Row 9
# Row 5 is identical to Row 10
# Row 5 is identical to Row 12
# Row 5 is identical to Row 17
# Row 5 is identical to Row 18
# Row 5 is identical to Row 20
# Row 5 is identical to Row 24
# Row 6 is identical to Row 9
# Row 6 is identical to Row 10
# Row 6 is identical to Row 12
# Row 6 is identical to Row 17
# Row 6 is identical to Row 18
# Row 6 is identical to Row 20
# Row 6 is identical to Row 24
# Row 7 is identical to Row 11
# Row 7 is identical to Row 13
# Row 7 is identical to Row 14
# Row 7 is identical to Row 19
# Row 7 is identical to Row 21
# Row 7 is identical to Row 22
# Row 7 is identical to Row 25
# Row 7 is identical to Row 26
# Row 7 is identical to Row 28
# Row 8 is identical to Row 16
# Row 9 is identical to Row 10
# Row 9 is identical to Row 12
# Row 9 is identical to Row 17
# Row 9 is identical to Row 18
# Row 9 is identical to Row 20
# Row 9 is identical to Row 24
# Row 10 is identical to Row 12
# Row 10 is identical to Row 17
# Row 10 is identical to Row 18
# Row 10 is identical to Row 20
# Row 10 is identical to Row 24
# Row 11 is identical to Row 13
# Row 11 is identical to Row 14
# Row 11 is identical to Row 19
# Row 11 is identical to Row 21
# Row 11 is identical to Row 22
# Row 11 is identical to Row 25
# Row 11 is identical to Row 26
# Row 11 is identical to Row 28
# Row 12 is identical to Row 17
# Row 12 is identical to Row 18
# Row 12 is identical to Row 20
# Row 12 is identical to Row 24
# Row 13 is identical to Row 14
# Row 13 is identical to Row 19
# Row 13 is identical to Row 21
# Row 13 is identical to Row 22
# Row 13 is identical to Row 25
# Row 13 is identical to Row 26
# Row 13 is identical to Row 28
# Row 14 is identical to Row 19
# Row 14 is identical to Row 21
# Row 14 is identical to Row 22
# Row 14 is identical to Row 25
# Row 14 is identical to Row 26
# Row 14 is identical to Row 28
# Row 15 is identical to Row 23
# Row 15 is identical to Row 27
# Row 15 is identical to Row 29
# Row 15 is identical to Row 30
# Row 17 is identical to Row 18
# Row 17 is identical to Row 20
# Row 17 is identical to Row 24
# Row 18 is identical to Row 20
# Row 18 is identical to Row 24
# Row 19 is identical to Row 21
# Row 19 is identical to Row 22
# Row 19 is identical to Row 25
# Row 19 is identical to Row 26
# Row 19 is identical to Row 28
# Row 20 is identical to Row 24
# Row 21 is identical to Row 22
# Row 21 is identical to Row 25
# Row 21 is identical to Row 26
# Row 21 is identical to Row 28
# Row 22 is identical to Row 25
# Row 22 is identical to Row 26
# Row 22 is identical to Row 28
# Row 23 is identical to Row 27
# Row 23 is identical to Row 29
# Row 23 is identical to Row 30
# Row 25 is identical to Row 26
# Row 25 is identical to Row 28
# Row 26 is identical to Row 28
# Row 27 is identical to Row 29
# Row 27 is identical to Row 30
# Row 29 is identical to Row 30
# --------------------------------------------------
# RDM Index: 2
# Null space dimension: 6
# --------------------------------------------------
# Repeating rows in the null space basis vectors for RDM 2:
# Row 1 is identical to Row 2
# Row 1 is identical to Row 4
# Row 1 is identical to Row 8
# Row 1 is identical to Row 16
# Row 2 is identical to Row 4
# Row 2 is identical to Row 8
# Row 2 is identical to Row 16
# Row 3 is identical to Row 5
# Row 3 is identical to Row 6
# Row 3 is identical to Row 9
# Row 3 is identical to Row 10
# Row 3 is identical to Row 12
# Row 3 is identical to Row 17
# Row 3 is identical to Row 18
# Row 3 is identical to Row 20
# Row 3 is identical to Row 24
# Row 4 is identical to Row 8
# Row 4 is identical to Row 16
# Row 5 is identical to Row 6
# Row 5 is identical to Row 9
# Row 5 is identical to Row 10
# Row 5 is identical to Row 12
# Row 5 is identical to Row 17
# Row 5 is identical to Row 18
# Row 5 is identical to Row 20
# Row 5 is identical to Row 24
# Row 6 is identical to Row 9
# Row 6 is identical to Row 10
# Row 6 is identical to Row 12
# Row 6 is identical to Row 17
# Row 6 is identical to Row 18
# Row 6 is identical to Row 20
# Row 6 is identical to Row 24
# Row 7 is identical to Row 11
# Row 7 is identical to Row 13
# Row 7 is identical to Row 14
# Row 7 is identical to Row 19
# Row 7 is identical to Row 21
# Row 7 is identical to Row 22
# Row 7 is identical to Row 25
# Row 7 is identical to Row 26
# Row 7 is identical to Row 28
# Row 8 is identical to Row 16
# Row 9 is identical to Row 10
# Row 9 is identical to Row 12
# Row 9 is identical to Row 17
# Row 9 is identical to Row 18
# Row 9 is identical to Row 20
# Row 9 is identical to Row 24
# Row 10 is identical to Row 12
# Row 10 is identical to Row 17
# Row 10 is identical to Row 18
# Row 10 is identical to Row 20
# Row 10 is identical to Row 24
# Row 11 is identical to Row 13
# Row 11 is identical to Row 14
# Row 11 is identical to Row 19
# Row 11 is identical to Row 21
# Row 11 is identical to Row 22
# Row 11 is identical to Row 25
# Row 11 is identical to Row 26
# Row 11 is identical to Row 28
# Row 12 is identical to Row 17
# Row 12 is identical to Row 18
# Row 12 is identical to Row 20
# Row 12 is identical to Row 24
# Row 13 is identical to Row 14
# Row 13 is identical to Row 19
# Row 13 is identical to Row 21
# Row 13 is identical to Row 22
# Row 13 is identical to Row 25
# Row 13 is identical to Row 26
# Row 13 is identical to Row 28
# Row 14 is identical to Row 19
# Row 14 is identical to Row 21
# Row 14 is identical to Row 22
# Row 14 is identical to Row 25
# Row 14 is identical to Row 26
# Row 14 is identical to Row 28
# Row 15 is identical to Row 23
# Row 15 is identical to Row 27
# Row 15 is identical to Row 29
# Row 15 is identical to Row 30
# Row 17 is identical to Row 18
# Row 17 is identical to Row 20
# Row 17 is identical to Row 24
# Row 18 is identical to Row 20
# Row 18 is identical to Row 24
# Row 19 is identical to Row 21
# Row 19 is identical to Row 22
# Row 19 is identical to Row 25
# Row 19 is identical to Row 26
# Row 19 is identical to Row 28
# Row 20 is identical to Row 24
# Row 21 is identical to Row 22
# Row 21 is identical to Row 25
# Row 21 is identical to Row 26
# Row 21 is identical to Row 28
# Row 22 is identical to Row 25
# Row 22 is identical to Row 26
# Row 22 is identical to Row 28
# Row 23 is identical to Row 27
# Row 23 is identical to Row 29
# Row 23 is identical to Row 30
# Row 25 is identical to Row 26
# Row 25 is identical to Row 28
# Row 26 is identical to Row 28
# Row 27 is identical to Row 29
# Row 27 is identical to Row 30
# Row 29 is identical to Row 30
# --------------------------------------------------
# RDM Index: 3
# Null space dimension: 6
# --------------------------------------------------
# Repeating rows in the null space basis vectors for RDM 3:
# Row 1 is identical to Row 2
# Row 1 is identical to Row 4
# Row 1 is identical to Row 8
# Row 1 is identical to Row 16
# Row 2 is identical to Row 4
# Row 2 is identical to Row 8
# Row 2 is identical to Row 16
# Row 3 is identical to Row 5
# Row 3 is identical to Row 6
# Row 3 is identical to Row 9
# Row 3 is identical to Row 10
# Row 3 is identical to Row 12
# Row 3 is identical to Row 17
# Row 3 is identical to Row 18
# Row 3 is identical to Row 20
# Row 3 is identical to Row 24
# Row 4 is identical to Row 8
# Row 4 is identical to Row 16
# Row 5 is identical to Row 6
# Row 5 is identical to Row 9
# Row 5 is identical to Row 10
# Row 5 is identical to Row 12
# Row 5 is identical to Row 17
# Row 5 is identical to Row 18
# Row 5 is identical to Row 20
# Row 5 is identical to Row 24
# Row 6 is identical to Row 9
# Row 6 is identical to Row 10
# Row 6 is identical to Row 12
# Row 6 is identical to Row 17
# Row 6 is identical to Row 18
# Row 6 is identical to Row 20
# Row 6 is identical to Row 24
# Row 7 is identical to Row 11
# Row 7 is identical to Row 13
# Row 7 is identical to Row 14
# Row 7 is identical to Row 19
# Row 7 is identical to Row 21
# Row 7 is identical to Row 22
# Row 7 is identical to Row 25
# Row 7 is identical to Row 26
# Row 7 is identical to Row 28
# Row 8 is identical to Row 16
# Row 9 is identical to Row 10
# Row 9 is identical to Row 12
# Row 9 is identical to Row 17
# Row 9 is identical to Row 18
# Row 9 is identical to Row 20
# Row 9 is identical to Row 24
# Row 10 is identical to Row 12
# Row 10 is identical to Row 17
# Row 10 is identical to Row 18
# Row 10 is identical to Row 20
# Row 10 is identical to Row 24
# Row 11 is identical to Row 13
# Row 11 is identical to Row 14
# Row 11 is identical to Row 19
# Row 11 is identical to Row 21
# Row 11 is identical to Row 22
# Row 11 is identical to Row 25
# Row 11 is identical to Row 26
# Row 11 is identical to Row 28
# Row 12 is identical to Row 17
# Row 12 is identical to Row 18
# Row 12 is identical to Row 20
# Row 12 is identical to Row 24
# Row 13 is identical to Row 14
# Row 13 is identical to Row 19
# Row 13 is identical to Row 21
# Row 13 is identical to Row 22
# Row 13 is identical to Row 25
# Row 13 is identical to Row 26
# Row 13 is identical to Row 28
# Row 14 is identical to Row 19
# Row 14 is identical to Row 21
# Row 14 is identical to Row 22
# Row 14 is identical to Row 25
# Row 14 is identical to Row 26
# Row 14 is identical to Row 28
# Row 15 is identical to Row 23
# Row 15 is identical to Row 27
# Row 15 is identical to Row 29
# Row 15 is identical to Row 30
# Row 17 is identical to Row 18
# Row 17 is identical to Row 20
# Row 17 is identical to Row 24
# Row 18 is identical to Row 20
# Row 18 is identical to Row 24
# Row 19 is identical to Row 21
# Row 19 is identical to Row 22
# Row 19 is identical to Row 25
# Row 19 is identical to Row 26
# Row 19 is identical to Row 28
# Row 20 is identical to Row 24
# Row 21 is identical to Row 22
# Row 21 is identical to Row 25
# Row 21 is identical to Row 26
# Row 21 is identical to Row 28
# Row 22 is identical to Row 25
# Row 22 is identical to Row 26
# Row 22 is identical to Row 28
# Row 23 is identical to Row 27
# Row 23 is identical to Row 29
# Row 23 is identical to Row 30
# Row 25 is identical to Row 26
# Row 25 is identical to Row 28
# Row 26 is identical to Row 28
# Row 27 is identical to Row 29
# Row 27 is identical to Row 30
# Row 29 is identical to Row 30
# --------------------------------------------------
# RDM Index: 4
# Null space dimension: 6
# --------------------------------------------------
# Repeating rows in the null space basis vectors for RDM 4:
# Row 1 is identical to Row 2
# Row 1 is identical to Row 4
# Row 1 is identical to Row 8
# Row 1 is identical to Row 16
# Row 2 is identical to Row 4
# Row 2 is identical to Row 8
# Row 2 is identical to Row 16
# Row 3 is identical to Row 5
# Row 3 is identical to Row 6
# Row 3 is identical to Row 9
# Row 3 is identical to Row 10
# Row 3 is identical to Row 12
# Row 3 is identical to Row 17
# Row 3 is identical to Row 18
# Row 3 is identical to Row 20
# Row 3 is identical to Row 24
# Row 4 is identical to Row 8
# Row 4 is identical to Row 16
# Row 5 is identical to Row 6
# Row 5 is identical to Row 9
# Row 5 is identical to Row 10
# Row 5 is identical to Row 12
# Row 5 is identical to Row 17
# Row 5 is identical to Row 18
# Row 5 is identical to Row 20
# Row 5 is identical to Row 24
# Row 6 is identical to Row 9
# Row 6 is identical to Row 10
# Row 6 is identical to Row 12
# Row 6 is identical to Row 17
# Row 6 is identical to Row 18
# Row 6 is identical to Row 20
# Row 6 is identical to Row 24
# Row 7 is identical to Row 11
# Row 7 is identical to Row 13
# Row 7 is identical to Row 14
# Row 7 is identical to Row 19
# Row 7 is identical to Row 21
# Row 7 is identical to Row 22
# Row 7 is identical to Row 25
# Row 7 is identical to Row 26
# Row 7 is identical to Row 28
# Row 8 is identical to Row 16
# Row 9 is identical to Row 10
# Row 9 is identical to Row 12
# Row 9 is identical to Row 17
# Row 9 is identical to Row 18
# Row 9 is identical to Row 20
# Row 9 is identical to Row 24
# Row 10 is identical to Row 12
# Row 10 is identical to Row 17
# Row 10 is identical to Row 18
# Row 10 is identical to Row 20
# Row 10 is identical to Row 24
# Row 11 is identical to Row 13
# Row 11 is identical to Row 14
# Row 11 is identical to Row 19
# Row 11 is identical to Row 21
# Row 11 is identical to Row 22
# Row 11 is identical to Row 25
# Row 11 is identical to Row 26
# Row 11 is identical to Row 28
# Row 12 is identical to Row 17
# Row 12 is identical to Row 18
# Row 12 is identical to Row 20
# Row 12 is identical to Row 24
# Row 13 is identical to Row 14
# Row 13 is identical to Row 19
# Row 13 is identical to Row 21
# Row 13 is identical to Row 22
# Row 13 is identical to Row 25
# Row 13 is identical to Row 26
# Row 13 is identical to Row 28
# Row 14 is identical to Row 19
# Row 14 is identical to Row 21
# Row 14 is identical to Row 22
# Row 14 is identical to Row 25
# Row 14 is identical to Row 26
# Row 14 is identical to Row 28
# Row 15 is identical to Row 23
# Row 15 is identical to Row 27
# Row 15 is identical to Row 29
# Row 15 is identical to Row 30
# Row 17 is identical to Row 18
# Row 17 is identical to Row 20
# Row 17 is identical to Row 24
# Row 18 is identical to Row 20
# Row 18 is identical to Row 24
# Row 19 is identical to Row 21
# Row 19 is identical to Row 22
# Row 19 is identical to Row 25
# Row 19 is identical to Row 26
# Row 19 is identical to Row 28
# Row 20 is identical to Row 24
# Row 21 is identical to Row 22
# Row 21 is identical to Row 25
# Row 21 is identical to Row 26
# Row 21 is identical to Row 28
# Row 22 is identical to Row 25
# Row 22 is identical to Row 26
# Row 22 is identical to Row 28
# Row 23 is identical to Row 27
# Row 23 is identical to Row 29
# Row 23 is identical to Row 30
# Row 25 is identical to Row 26
# Row 25 is identical to Row 28
# Row 26 is identical to Row 28
# Row 27 is identical to Row 29
# Row 27 is identical to Row 30
# Row 29 is identical to Row 30
# --------------------------------------------------

# %%
# Iterate over scarred eigenvectors
for i, eigenvector in enumerate(rank_eigenvectors_np):
    # Print the entire eigenvector
    non_zero_count = 0  # Counter for non-zero components
    print(f"Full Eigenvector {i}:")
    for index, component in enumerate(eigenvector):
        # Set components of the order 10^-12 or smaller to zero
        if np.abs(component) < 1e-12: # I noticed that  most components are of the order 10^-13 or smaller - only a handful are mucgh larger
            eigenvector[index] = 0.0
        else:
            non_zero_count += 1
        binary_basis = index_to_binary(index, N)
        #print(f"{binary_basis}: {eigenvector[index]}")

    print(f"Total Non-Zero Components in Scarred Eigenvector {i}: {non_zero_count}")
    print("=" * 50)
# Out:
# Full Eigenvector 0:
# Total Non-Zero Components in Scarred Eigenvector 0: 360
# ==================================================
# Full Eigenvector 1:
# Total Non-Zero Components in Scarred Eigenvector 1: 360
# ==================================================
# Full Eigenvector 2:
# Total Non-Zero Components in Scarred Eigenvector 2: 360
# ==================================================
# Full Eigenvector 3:
# Total Non-Zero Components in Scarred Eigenvector 3: 360
# ==================================================
# Full Eigenvector 4:
# Total Non-Zero Components in Scarred Eigenvector 4: 360
# ==================================================

# %%
# Iterate over scarred eigenvectors and print, for each unique nonzero value (by value, tol=1e-12, sign matters),
# the positions and binary representations where it appears
for i, eigenvector in enumerate(rank_eigenvectors_np):
    # Prepare list of (index, value, binary) for nonzero components
    nonzero_info = []
    for index, component in enumerate(eigenvector):
        if np.abs(component) >= 1e-12:
            nonzero_info.append((index, component, index_to_binary(index, N)))
    # Find unique values (within tolerance, sign matters)
    unique_vals = []
    unique_positions = []
    for idx, val, bin_str in nonzero_info:
        found = False
        for u, pos_list in zip(unique_vals, unique_positions):
            if np.abs(val - u) < 1e-12:
                pos_list.append((idx, bin_str))
                found = True
                break
        if not found:
            unique_vals.append(val)
            unique_positions.append([(idx, bin_str)])
    print(f"Eigenvector {i}:")
    print(f"Number of unique nonzero components (tol=1e-12, sign matters): {len(unique_vals)}")
    for uval, pos_list in zip(unique_vals, unique_positions):
        print(f"  Value ≈ {uval:.5g} appears at positions:")
        for idx, bin_str in pos_list:
            print(f"    Index {idx}, Binary {bin_str}")
    print("=" * 50)
# Out:
# Eigenvector 0:
# Number of unique nonzero components (tol=1e-12, sign matters): 15
#   Value ≈ -0.04292 appears at positions:
#     Index 63, Binary 000000111111
#     Index 95, Binary 000001011111
#     Index 175, Binary 000010101111
#     Index 207, Binary 000011001111
#     Index 243, Binary 000011110011
#     Index 245, Binary 000011110101
#     Index 250, Binary 000011111010
#     Index 252, Binary 000011111100
#     Index 1295, Binary 010100001111
#     Index 1520, Binary 010111110000
#     Index 1551, Binary 011000001111
#     Index 1776, Binary 011011110000
#     Index 2319, Binary 100100001111
#     Index 2544, Binary 100111110000
#     Index 2575, Binary 101000001111
#     Index 2800, Binary 101011110000
#     Index 3843, Binary 111100000011
#     Index 3845, Binary 111100000101
#     Index 3850, Binary 111100001010
#     Index 3852, Binary 111100001100
#     Index 3888, Binary 111100110000
#     Index 3920, Binary 111101010000
#     Index 4000, Binary 111110100000
#     Index 4032, Binary 111111000000
#   Value ≈ 0.09574 appears at positions:
#     Index 119, Binary 000001110111
#     Index 126, Binary 000001111110
#     Index 187, Binary 000010111011
#     Index 189, Binary 000010111101
#     Index 219, Binary 000011011011
#     Index 221, Binary 000011011101
#     Index 231, Binary 000011100111
#     Index 238, Binary 000011101110
#     Index 1382, Binary 010101100110
#     Index 1433, Binary 010110011001
#     Index 1638, Binary 011001100110
#     Index 1689, Binary 011010011001
#     Index 2406, Binary 100101100110
#     Index 2457, Binary 100110011001
#     Index 2662, Binary 101001100110
#     Index 2713, Binary 101010011001
#     Index 3857, Binary 111100010001
#     Index 3864, Binary 111100011000
#     Index 3874, Binary 111100100010
#     Index 3876, Binary 111100100100
#     Index 3906, Binary 111101000010
#     Index 3908, Binary 111101000100
#     Index 3969, Binary 111110000001
#     Index 3976, Binary 111110001000
#   Value ≈ -0.05282 appears at positions:
#     Index 123, Binary 000001111011
#     Index 125, Binary 000001111101
#     Index 183, Binary 000010110111
#     Index 190, Binary 000010111110
#     Index 215, Binary 000011010111
#     Index 222, Binary 000011011110
#     Index 235, Binary 000011101011
#     Index 237, Binary 000011101101
#     Index 1385, Binary 010101101001
#     Index 1430, Binary 010110010110
#     Index 1641, Binary 011001101001
#     Index 1686, Binary 011010010110
#     Index 2409, Binary 100101101001
#     Index 2454, Binary 100110010110
#     Index 2665, Binary 101001101001
#     Index 2710, Binary 101010010110
#     Index 3858, Binary 111100010010
#     Index 3860, Binary 111100010100
#     Index 3873, Binary 111100100001
#     Index 3880, Binary 111100101000
#     Index 3905, Binary 111101000001
#     Index 3912, Binary 111101001000
#     Index 3970, Binary 111110000010
#     Index 3972, Binary 111110000100
#   Value ≈ -0.01613 appears at positions:
#     Index 287, Binary 000100011111
#     Index 399, Binary 000110001111
#     Index 543, Binary 001000011111
#     Index 655, Binary 001010001111
#     Index 915, Binary 001110010011
#     Index 917, Binary 001110010101
#     Index 922, Binary 001110011010
#     Index 924, Binary 001110011100
#     Index 1071, Binary 010000101111
#     Index 1103, Binary 010001001111
#     Index 1968, Binary 011110110000
#     Index 2000, Binary 011111010000
#     Index 2095, Binary 100000101111
#     Index 2127, Binary 100001001111
#     Index 2992, Binary 101110110000
#     Index 3024, Binary 101111010000
#     Index 3171, Binary 110001100011
#     Index 3173, Binary 110001100101
#     Index 3178, Binary 110001101010
#     Index 3180, Binary 110001101100
#     Index 3440, Binary 110101110000
#     Index 3552, Binary 110111100000
#     Index 3696, Binary 111001110000
#     Index 3808, Binary 111011100000
#   Value ≈ 0.05905 appears at positions:
#     Index 303, Binary 000100101111
#     Index 335, Binary 000101001111
#     Index 559, Binary 001000101111
#     Index 591, Binary 001001001111
#     Index 867, Binary 001101100011
#     Index 869, Binary 001101100101
#     Index 874, Binary 001101101010
#     Index 876, Binary 001101101100
#     Index 1055, Binary 010000011111
#     Index 1167, Binary 010010001111
#     Index 1904, Binary 011101110000
#     Index 2016, Binary 011111100000
#     Index 2079, Binary 100000011111
#     Index 2191, Binary 100010001111
#     Index 2928, Binary 101101110000
#     Index 3040, Binary 101111100000
#     Index 3219, Binary 110010010011
#     Index 3221, Binary 110010010101
#     Index 3226, Binary 110010011010
#     Index 3228, Binary 110010011100
#     Index 3504, Binary 110110110000
#     Index 3536, Binary 110111010000
#     Index 3760, Binary 111010110000
#     Index 3792, Binary 111011010000
#   Value ≈ -0.09091 appears at positions:
#     Index 359, Binary 000101100111
#     Index 366, Binary 000101101110
#     Index 615, Binary 001001100111
#     Index 622, Binary 001001101110
#     Index 811, Binary 001100101011
#     Index 813, Binary 001100101101
#     Index 843, Binary 001101001011
#     Index 845, Binary 001101001101
#     Index 1142, Binary 010001110110
#     Index 1254, Binary 010011100110
#     Index 1817, Binary 011100011001
#     Index 1929, Binary 011110001001
#     Index 2166, Binary 100001110110
#     Index 2278, Binary 100011100110
#     Index 2841, Binary 101100011001
#     Index 2953, Binary 101110001001
#     Index 3250, Binary 110010110010
#     Index 3252, Binary 110010110100
#     Index 3282, Binary 110011010010
#     Index 3284, Binary 110011010100
#     Index 3473, Binary 110110010001
#     Index 3480, Binary 110110011000
#     Index 3729, Binary 111010010001
#     Index 3736, Binary 111010011000
#   Value ≈ 0.031861 appears at positions:
#     Index 363, Binary 000101101011
#     Index 365, Binary 000101101101
#     Index 619, Binary 001001101011
#     Index 621, Binary 001001101101
#     Index 807, Binary 001100100111
#     Index 814, Binary 001100101110
#     Index 839, Binary 001101000111
#     Index 846, Binary 001101001110
#     Index 1145, Binary 010001111001
#     Index 1257, Binary 010011101001
#     Index 1814, Binary 011100010110
#     Index 1926, Binary 011110000110
#     Index 2169, Binary 100001111001
#     Index 2281, Binary 100011101001
#     Index 2838, Binary 101100010110
#     Index 2950, Binary 101110000110
#     Index 3249, Binary 110010110001
#     Index 3256, Binary 110010111000
#     Index 3281, Binary 110011010001
#     Index 3288, Binary 110011011000
#     Index 3474, Binary 110110010010
#     Index 3476, Binary 110110010100
#     Index 3730, Binary 111010010010
#     Index 3732, Binary 111010010100
#   Value ≈ -0.0048298 appears at positions:
#     Index 374, Binary 000101110110
#     Index 486, Binary 000111100110
#     Index 630, Binary 001001110110
#     Index 742, Binary 001011100110
#     Index 946, Binary 001110110010
#     Index 948, Binary 001110110100
#     Index 978, Binary 001111010010
#     Index 980, Binary 001111010100
#     Index 1127, Binary 010001100111
#     Index 1134, Binary 010001101110
#     Index 1937, Binary 011110010001
#     Index 1944, Binary 011110011000
#     Index 2151, Binary 100001100111
#     Index 2158, Binary 100001101110
#     Index 2961, Binary 101110010001
#     Index 2968, Binary 101110011000
#     Index 3115, Binary 110000101011
#     Index 3117, Binary 110000101101
#     Index 3147, Binary 110001001011
#     Index 3149, Binary 110001001101
#     Index 3353, Binary 110100011001
#     Index 3465, Binary 110110001001
#     Index 3609, Binary 111000011001
#     Index 3721, Binary 111010001001
#   Value ≈ 0.02096 appears at positions:
#     Index 377, Binary 000101111001
#     Index 489, Binary 000111101001
#     Index 633, Binary 001001111001
#     Index 745, Binary 001011101001
#     Index 945, Binary 001110110001
#     Index 952, Binary 001110111000
#     Index 977, Binary 001111010001
#     Index 984, Binary 001111011000
#     Index 1131, Binary 010001101011
#     Index 1133, Binary 010001101101
#     Index 1938, Binary 011110010010
#     Index 1940, Binary 011110010100
#     Index 2155, Binary 100001101011
#     Index 2157, Binary 100001101101
#     Index 2962, Binary 101110010010
#     Index 2964, Binary 101110010100
#     Index 3111, Binary 110000100111
#     Index 3118, Binary 110000101110
#     Index 3143, Binary 110001000111
#     Index 3150, Binary 110001001110
#     Index 3350, Binary 110100010110
#     Index 3462, Binary 110110000110
#     Index 3606, Binary 111000010110
#     Index 3718, Binary 111010000110
#   Value ≈ 0.023614 appears at positions:
#     Index 407, Binary 000110010111
#     Index 414, Binary 000110011110
#     Index 663, Binary 001010010111
#     Index 670, Binary 001010011110
#     Index 795, Binary 001100011011
#     Index 797, Binary 001100011101
#     Index 907, Binary 001110001011
#     Index 909, Binary 001110001101
#     Index 1206, Binary 010010110110
#     Index 1238, Binary 010011010110
#     Index 1833, Binary 011100101001
#     Index 1865, Binary 011101001001
#     Index 2230, Binary 100010110110
#     Index 2262, Binary 100011010110
#     Index 2857, Binary 101100101001
#     Index 2889, Binary 101101001001
#     Index 3186, Binary 110001110010
#     Index 3188, Binary 110001110100
#     Index 3298, Binary 110011100010
#     Index 3300, Binary 110011100100
#     Index 3425, Binary 110101100001
#     Index 3432, Binary 110101101000
#     Index 3681, Binary 111001100001
#     Index 3688, Binary 111001101000
#   Value ≈ -0.0074838 appears at positions:
#     Index 411, Binary 000110011011
#     Index 413, Binary 000110011101
#     Index 667, Binary 001010011011
#     Index 669, Binary 001010011101
#     Index 791, Binary 001100010111
#     Index 798, Binary 001100011110
#     Index 903, Binary 001110000111
#     Index 910, Binary 001110001110
#     Index 1209, Binary 010010111001
#     Index 1241, Binary 010011011001
#     Index 1830, Binary 011100100110
#     Index 1862, Binary 011101000110
#     Index 2233, Binary 100010111001
#     Index 2265, Binary 100011011001
#     Index 2854, Binary 101100100110
#     Index 2886, Binary 101101000110
#     Index 3185, Binary 110001110001
#     Index 3192, Binary 110001111000
#     Index 3297, Binary 110011100001
#     Index 3304, Binary 110011101000
#     Index 3426, Binary 110101100010
#     Index 3428, Binary 110101100100
#     Index 3682, Binary 111001100010
#     Index 3684, Binary 111001100100
#   Value ≈ 0.029207 appears at positions:
#     Index 438, Binary 000110110110
#     Index 470, Binary 000111010110
#     Index 694, Binary 001010110110
#     Index 726, Binary 001011010110
#     Index 882, Binary 001101110010
#     Index 884, Binary 001101110100
#     Index 994, Binary 001111100010
#     Index 996, Binary 001111100100
#     Index 1175, Binary 010010010111
#     Index 1182, Binary 010010011110
#     Index 1889, Binary 011101100001
#     Index 1896, Binary 011101101000
#     Index 2199, Binary 100010010111
#     Index 2206, Binary 100010011110
#     Index 2913, Binary 101101100001
#     Index 2920, Binary 101101101000
#     Index 3099, Binary 110000011011
#     Index 3101, Binary 110000011101
#     Index 3211, Binary 110010001011
#     Index 3213, Binary 110010001101
#     Index 3369, Binary 110100101001
#     Index 3401, Binary 110101001001
#     Index 3625, Binary 111000101001
#     Index 3657, Binary 111001001001
#   Value ≈ -0.088256 appears at positions:
#     Index 441, Binary 000110111001
#     Index 473, Binary 000111011001
#     Index 697, Binary 001010111001
#     Index 729, Binary 001011011001
#     Index 881, Binary 001101110001
#     Index 888, Binary 001101111000
#     Index 993, Binary 001111100001
#     Index 1000, Binary 001111101000
#     Index 1179, Binary 010010011011
#     Index 1181, Binary 010010011101
#     Index 1890, Binary 011101100010
#     Index 1892, Binary 011101100100
#     Index 2203, Binary 100010011011
#     Index 2205, Binary 100010011101
#     Index 2914, Binary 101101100010
#     Index 2916, Binary 101101100100
#     Index 3095, Binary 110000010111
#     Index 3102, Binary 110000011110
#     Index 3207, Binary 110010000111
#     Index 3214, Binary 110010001110
#     Index 3366, Binary 110100100110
#     Index 3398, Binary 110101000110
#     Index 3622, Binary 111000100110
#     Index 3654, Binary 111001000110
#   Value ≈ 0.067297 appears at positions:
#     Index 497, Binary 000111110001
#     Index 504, Binary 000111111000
#     Index 753, Binary 001011110001
#     Index 760, Binary 001011111000
#     Index 825, Binary 001100111001
#     Index 857, Binary 001101011001
#     Index 937, Binary 001110101001
#     Index 969, Binary 001111001001
#     Index 1266, Binary 010011110010
#     Index 1268, Binary 010011110100
#     Index 1803, Binary 011100001011
#     Index 1805, Binary 011100001101
#     Index 2290, Binary 100011110010
#     Index 2292, Binary 100011110100
#     Index 2827, Binary 101100001011
#     Index 2829, Binary 101100001101
#     Index 3126, Binary 110000110110
#     Index 3158, Binary 110001010110
#     Index 3238, Binary 110010100110
#     Index 3270, Binary 110011000110
#     Index 3335, Binary 110100000111
#     Index 3342, Binary 110100001110
#     Index 3591, Binary 111000000111
#     Index 3598, Binary 111000001110
#   Value ≈ -0.024377 appears at positions:
#     Index 498, Binary 000111110010
#     Index 500, Binary 000111110100
#     Index 754, Binary 001011110010
#     Index 756, Binary 001011110100
#     Index 822, Binary 001100110110
#     Index 854, Binary 001101010110
#     Index 934, Binary 001110100110
#     Index 966, Binary 001111000110
#     Index 1265, Binary 010011110001
#     Index 1272, Binary 010011111000
#     Index 1799, Binary 011100000111
#     Index 1806, Binary 011100001110
#     Index 2289, Binary 100011110001
#     Index 2296, Binary 100011111000
#     Index 2823, Binary 101100000111
#     Index 2830, Binary 101100001110
#     Index 3129, Binary 110000111001
#     Index 3161, Binary 110001011001
#     Index 3241, Binary 110010101001
#     Index 3273, Binary 110011001001
#     Index 3339, Binary 110100001011
#     Index 3341, Binary 110100001101
#     Index 3595, Binary 111000001011
#     Index 3597, Binary 111000001101
# ==================================================
# Eigenvector 1:
# Number of unique nonzero components (tol=1e-12, sign matters): 15
#   Value ≈ -0.096438 appears at positions:
#     Index 63, Binary 000000111111
#     Index 95, Binary 000001011111
#     Index 175, Binary 000010101111
#     Index 207, Binary 000011001111
#     Index 243, Binary 000011110011
#     Index 245, Binary 000011110101
#     Index 250, Binary 000011111010
#     Index 252, Binary 000011111100
#     Index 1295, Binary 010100001111
#     Index 1520, Binary 010111110000
#     Index 1551, Binary 011000001111
#     Index 1776, Binary 011011110000
#     Index 2319, Binary 100100001111
#     Index 2544, Binary 100111110000
#     Index 2575, Binary 101000001111
#     Index 2800, Binary 101011110000
#     Index 3843, Binary 111100000011
#     Index 3845, Binary 111100000101
#     Index 3850, Binary 111100001010
#     Index 3852, Binary 111100001100
#     Index 3888, Binary 111100110000
#     Index 3920, Binary 111101010000
#     Index 4000, Binary 111110100000
#     Index 4032, Binary 111111000000
#   Value ≈ 0.0011619 appears at positions:
#     Index 119, Binary 000001110111
#     Index 126, Binary 000001111110
#     Index 187, Binary 000010111011
#     Index 189, Binary 000010111101
#     Index 219, Binary 000011011011
#     Index 221, Binary 000011011101
#     Index 231, Binary 000011100111
#     Index 238, Binary 000011101110
#     Index 1382, Binary 010101100110
#     Index 1433, Binary 010110011001
#     Index 1638, Binary 011001100110
#     Index 1689, Binary 011010011001
#     Index 2406, Binary 100101100110
#     Index 2457, Binary 100110011001
#     Index 2662, Binary 101001100110
#     Index 2713, Binary 101010011001
#     Index 3857, Binary 111100010001
#     Index 3864, Binary 111100011000
#     Index 3874, Binary 111100100010
#     Index 3876, Binary 111100100100
#     Index 3906, Binary 111101000010
#     Index 3908, Binary 111101000100
#     Index 3969, Binary 111110000001
#     Index 3976, Binary 111110001000
#   Value ≈ 0.095276 appears at positions:
#     Index 123, Binary 000001111011
#     Index 125, Binary 000001111101
#     Index 183, Binary 000010110111
#     Index 190, Binary 000010111110
#     Index 215, Binary 000011010111
#     Index 222, Binary 000011011110
#     Index 235, Binary 000011101011
#     Index 237, Binary 000011101101
#     Index 1385, Binary 010101101001
#     Index 1430, Binary 010110010110
#     Index 1641, Binary 011001101001
#     Index 1686, Binary 011010010110
#     Index 2409, Binary 100101101001
#     Index 2454, Binary 100110010110
#     Index 2665, Binary 101001101001
#     Index 2710, Binary 101010010110
#     Index 3858, Binary 111100010010
#     Index 3860, Binary 111100010100
#     Index 3873, Binary 111100100001
#     Index 3880, Binary 111100101000
#     Index 3905, Binary 111101000001
#     Index 3912, Binary 111101001000
#     Index 3970, Binary 111110000010
#     Index 3972, Binary 111110000100
#   Value ≈ 0.03079 appears at positions:
#     Index 287, Binary 000100011111
#     Index 399, Binary 000110001111
#     Index 543, Binary 001000011111
#     Index 655, Binary 001010001111
#     Index 915, Binary 001110010011
#     Index 917, Binary 001110010101
#     Index 922, Binary 001110011010
#     Index 924, Binary 001110011100
#     Index 1071, Binary 010000101111
#     Index 1103, Binary 010001001111
#     Index 1968, Binary 011110110000
#     Index 2000, Binary 011111010000
#     Index 2095, Binary 100000101111
#     Index 2127, Binary 100001001111
#     Index 2992, Binary 101110110000
#     Index 3024, Binary 101111010000
#     Index 3171, Binary 110001100011
#     Index 3173, Binary 110001100101
#     Index 3178, Binary 110001101010
#     Index 3180, Binary 110001101100
#     Index 3440, Binary 110101110000
#     Index 3552, Binary 110111100000
#     Index 3696, Binary 111001110000
#     Index 3808, Binary 111011100000
#   Value ≈ 0.065647 appears at positions:
#     Index 303, Binary 000100101111
#     Index 335, Binary 000101001111
#     Index 559, Binary 001000101111
#     Index 591, Binary 001001001111
#     Index 867, Binary 001101100011
#     Index 869, Binary 001101100101
#     Index 874, Binary 001101101010
#     Index 876, Binary 001101101100
#     Index 1055, Binary 010000011111
#     Index 1167, Binary 010010001111
#     Index 1904, Binary 011101110000
#     Index 2016, Binary 011111100000
#     Index 2079, Binary 100000011111
#     Index 2191, Binary 100010001111
#     Index 2928, Binary 101101110000
#     Index 3040, Binary 101111100000
#     Index 3219, Binary 110010010011
#     Index 3221, Binary 110010010101
#     Index 3226, Binary 110010011010
#     Index 3228, Binary 110010011100
#     Index 3504, Binary 110110110000
#     Index 3536, Binary 110111010000
#     Index 3760, Binary 111010110000
#     Index 3792, Binary 111011010000
#   Value ≈ -0.026724 appears at positions:
#     Index 359, Binary 000101100111
#     Index 366, Binary 000101101110
#     Index 615, Binary 001001100111
#     Index 622, Binary 001001101110
#     Index 811, Binary 001100101011
#     Index 813, Binary 001100101101
#     Index 843, Binary 001101001011
#     Index 845, Binary 001101001101
#     Index 1142, Binary 010001110110
#     Index 1254, Binary 010011100110
#     Index 1817, Binary 011100011001
#     Index 1929, Binary 011110001001
#     Index 2166, Binary 100001110110
#     Index 2278, Binary 100011100110
#     Index 2841, Binary 101100011001
#     Index 2953, Binary 101110001001
#     Index 3250, Binary 110010110010
#     Index 3252, Binary 110010110100
#     Index 3282, Binary 110011010010
#     Index 3284, Binary 110011010100
#     Index 3473, Binary 110110010001
#     Index 3480, Binary 110110011000
#     Index 3729, Binary 111010010001
#     Index 3736, Binary 111010011000
#   Value ≈ -0.038924 appears at positions:
#     Index 363, Binary 000101101011
#     Index 365, Binary 000101101101
#     Index 619, Binary 001001101011
#     Index 621, Binary 001001101101
#     Index 807, Binary 001100100111
#     Index 814, Binary 001100101110
#     Index 839, Binary 001101000111
#     Index 846, Binary 001101001110
#     Index 1145, Binary 010001111001
#     Index 1257, Binary 010011101001
#     Index 1814, Binary 011100010110
#     Index 1926, Binary 011110000110
#     Index 2169, Binary 100001111001
#     Index 2281, Binary 100011101001
#     Index 2838, Binary 101100010110
#     Index 2950, Binary 101110000110
#     Index 3249, Binary 110010110001
#     Index 3256, Binary 110010111000
#     Index 3281, Binary 110011010001
#     Index 3288, Binary 110011011000
#     Index 3474, Binary 110110010010
#     Index 3476, Binary 110110010100
#     Index 3730, Binary 111010010010
#     Index 3732, Binary 111010010100
#   Value ≈ 0.025562 appears at positions:
#     Index 374, Binary 000101110110
#     Index 486, Binary 000111100110
#     Index 630, Binary 001001110110
#     Index 742, Binary 001011100110
#     Index 946, Binary 001110110010
#     Index 948, Binary 001110110100
#     Index 978, Binary 001111010010
#     Index 980, Binary 001111010100
#     Index 1127, Binary 010001100111
#     Index 1134, Binary 010001101110
#     Index 1937, Binary 011110010001
#     Index 1944, Binary 011110011000
#     Index 2151, Binary 100001100111
#     Index 2158, Binary 100001101110
#     Index 2961, Binary 101110010001
#     Index 2968, Binary 101110011000
#     Index 3115, Binary 110000101011
#     Index 3117, Binary 110000101101
#     Index 3147, Binary 110001001011
#     Index 3149, Binary 110001001101
#     Index 3353, Binary 110100011001
#     Index 3465, Binary 110110001001
#     Index 3609, Binary 111000011001
#     Index 3721, Binary 111010001001
#   Value ≈ -0.056352 appears at positions:
#     Index 377, Binary 000101111001
#     Index 489, Binary 000111101001
#     Index 633, Binary 001001111001
#     Index 745, Binary 001011101001
#     Index 945, Binary 001110110001
#     Index 952, Binary 001110111000
#     Index 977, Binary 001111010001
#     Index 984, Binary 001111011000
#     Index 1131, Binary 010001101011
#     Index 1133, Binary 010001101101
#     Index 1938, Binary 011110010010
#     Index 1940, Binary 011110010100
#     Index 2155, Binary 100001101011
#     Index 2157, Binary 100001101101
#     Index 2962, Binary 101110010010
#     Index 2964, Binary 101110010100
#     Index 3111, Binary 110000100111
#     Index 3118, Binary 110000101110
#     Index 3143, Binary 110001000111
#     Index 3150, Binary 110001001110
#     Index 3350, Binary 110100010110
#     Index 3462, Binary 110110000110
#     Index 3606, Binary 111000010110
#     Index 3718, Binary 111010000110
#   Value ≈ -0.014524 appears at positions:
#     Index 407, Binary 000110010111
#     Index 414, Binary 000110011110
#     Index 663, Binary 001010010111
#     Index 670, Binary 001010011110
#     Index 795, Binary 001100011011
#     Index 797, Binary 001100011101
#     Index 907, Binary 001110001011
#     Index 909, Binary 001110001101
#     Index 1206, Binary 010010110110
#     Index 1238, Binary 010011010110
#     Index 1833, Binary 011100101001
#     Index 1865, Binary 011101001001
#     Index 2230, Binary 100010110110
#     Index 2262, Binary 100011010110
#     Index 2857, Binary 101100101001
#     Index 2889, Binary 101101001001
#     Index 3186, Binary 110001110010
#     Index 3188, Binary 110001110100
#     Index 3298, Binary 110011100010
#     Index 3300, Binary 110011100100
#     Index 3425, Binary 110101100001
#     Index 3432, Binary 110101101000
#     Index 3681, Binary 111001100001
#     Index 3688, Binary 111001101000
#   Value ≈ -0.016266 appears at positions:
#     Index 411, Binary 000110011011
#     Index 413, Binary 000110011101
#     Index 667, Binary 001010011011
#     Index 669, Binary 001010011101
#     Index 791, Binary 001100010111
#     Index 798, Binary 001100011110
#     Index 903, Binary 001110000111
#     Index 910, Binary 001110001110
#     Index 1209, Binary 010010111001
#     Index 1241, Binary 010011011001
#     Index 1830, Binary 011100100110
#     Index 1862, Binary 011101000110
#     Index 2233, Binary 100010111001
#     Index 2265, Binary 100011011001
#     Index 2854, Binary 101100100110
#     Index 2886, Binary 101101000110
#     Index 3185, Binary 110001110001
#     Index 3192, Binary 110001111000
#     Index 3297, Binary 110011100001
#     Index 3304, Binary 110011101000
#     Index 3426, Binary 110101100010
#     Index 3428, Binary 110101100100
#     Index 3682, Binary 111001100010
#     Index 3684, Binary 111001100100
#   Value ≈ -0.080752 appears at positions:
#     Index 438, Binary 000110110110
#     Index 470, Binary 000111010110
#     Index 694, Binary 001010110110
#     Index 726, Binary 001011010110
#     Index 882, Binary 001101110010
#     Index 884, Binary 001101110100
#     Index 994, Binary 001111100010
#     Index 996, Binary 001111100100
#     Index 1175, Binary 010010010111
#     Index 1182, Binary 010010011110
#     Index 1889, Binary 011101100001
#     Index 1896, Binary 011101101000
#     Index 2199, Binary 100010010111
#     Index 2206, Binary 100010011110
#     Index 2913, Binary 101101100001
#     Index 2920, Binary 101101101000
#     Index 3099, Binary 110000011011
#     Index 3101, Binary 110000011101
#     Index 3211, Binary 110010001011
#     Index 3213, Binary 110010001101
#     Index 3369, Binary 110100101001
#     Index 3401, Binary 110101001001
#     Index 3625, Binary 111000101001
#     Index 3657, Binary 111001001001
#   Value ≈ 0.015105 appears at positions:
#     Index 441, Binary 000110111001
#     Index 473, Binary 000111011001
#     Index 697, Binary 001010111001
#     Index 729, Binary 001011011001
#     Index 881, Binary 001101110001
#     Index 888, Binary 001101111000
#     Index 993, Binary 001111100001
#     Index 1000, Binary 001111101000
#     Index 1179, Binary 010010011011
#     Index 1181, Binary 010010011101
#     Index 1890, Binary 011101100010
#     Index 1892, Binary 011101100100
#     Index 2203, Binary 100010011011
#     Index 2205, Binary 100010011101
#     Index 2914, Binary 101101100010
#     Index 2916, Binary 101101100100
#     Index 3095, Binary 110000010111
#     Index 3102, Binary 110000011110
#     Index 3207, Binary 110010000111
#     Index 3214, Binary 110010001110
#     Index 3366, Binary 110100100110
#     Index 3398, Binary 110101000110
#     Index 3622, Binary 111000100110
#     Index 3654, Binary 111001000110
#   Value ≈ 0.041247 appears at positions:
#     Index 497, Binary 000111110001
#     Index 504, Binary 000111111000
#     Index 753, Binary 001011110001
#     Index 760, Binary 001011111000
#     Index 825, Binary 001100111001
#     Index 857, Binary 001101011001
#     Index 937, Binary 001110101001
#     Index 969, Binary 001111001001
#     Index 1266, Binary 010011110010
#     Index 1268, Binary 010011110100
#     Index 1803, Binary 011100001011
#     Index 1805, Binary 011100001101
#     Index 2290, Binary 100011110010
#     Index 2292, Binary 100011110100
#     Index 2827, Binary 101100001011
#     Index 2829, Binary 101100001101
#     Index 3126, Binary 110000110110
#     Index 3158, Binary 110001010110
#     Index 3238, Binary 110010100110
#     Index 3270, Binary 110011000110
#     Index 3335, Binary 110100000111
#     Index 3342, Binary 110100001110
#     Index 3591, Binary 111000000111
#     Index 3598, Binary 111000001110
#   Value ≈ 0.05519 appears at positions:
#     Index 498, Binary 000111110010
#     Index 500, Binary 000111110100
#     Index 754, Binary 001011110010
#     Index 756, Binary 001011110100
#     Index 822, Binary 001100110110
#     Index 854, Binary 001101010110
#     Index 934, Binary 001110100110
#     Index 966, Binary 001111000110
#     Index 1265, Binary 010011110001
#     Index 1272, Binary 010011111000
#     Index 1799, Binary 011100000111
#     Index 1806, Binary 011100001110
#     Index 2289, Binary 100011110001
#     Index 2296, Binary 100011111000
#     Index 2823, Binary 101100000111
#     Index 2830, Binary 101100001110
#     Index 3129, Binary 110000111001
#     Index 3161, Binary 110001011001
#     Index 3241, Binary 110010101001
#     Index 3273, Binary 110011001001
#     Index 3339, Binary 110100001011
#     Index 3341, Binary 110100001101
#     Index 3595, Binary 111000001011
#     Index 3597, Binary 111000001101
# ==================================================
# Eigenvector 2:
# Number of unique nonzero components (tol=1e-12, sign matters): 15
#   Value ≈ -0.037257 appears at positions:
#     Index 63, Binary 000000111111
#     Index 95, Binary 000001011111
#     Index 175, Binary 000010101111
#     Index 207, Binary 000011001111
#     Index 243, Binary 000011110011
#     Index 245, Binary 000011110101
#     Index 250, Binary 000011111010
#     Index 252, Binary 000011111100
#     Index 1295, Binary 010100001111
#     Index 1520, Binary 010111110000
#     Index 1551, Binary 011000001111
#     Index 1776, Binary 011011110000
#     Index 2319, Binary 100100001111
#     Index 2544, Binary 100111110000
#     Index 2575, Binary 101000001111
#     Index 2800, Binary 101011110000
#     Index 3843, Binary 111100000011
#     Index 3845, Binary 111100000101
#     Index 3850, Binary 111100001010
#     Index 3852, Binary 111100001100
#     Index 3888, Binary 111100110000
#     Index 3920, Binary 111101010000
#     Index 4000, Binary 111110100000
#     Index 4032, Binary 111111000000
#   Value ≈ 0.02963 appears at positions:
#     Index 119, Binary 000001110111
#     Index 126, Binary 000001111110
#     Index 187, Binary 000010111011
#     Index 189, Binary 000010111101
#     Index 219, Binary 000011011011
#     Index 221, Binary 000011011101
#     Index 231, Binary 000011100111
#     Index 238, Binary 000011101110
#     Index 1382, Binary 010101100110
#     Index 1433, Binary 010110011001
#     Index 1638, Binary 011001100110
#     Index 1689, Binary 011010011001
#     Index 2406, Binary 100101100110
#     Index 2457, Binary 100110011001
#     Index 2662, Binary 101001100110
#     Index 2713, Binary 101010011001
#     Index 3857, Binary 111100010001
#     Index 3864, Binary 111100011000
#     Index 3874, Binary 111100100010
#     Index 3876, Binary 111100100100
#     Index 3906, Binary 111101000010
#     Index 3908, Binary 111101000100
#     Index 3969, Binary 111110000001
#     Index 3976, Binary 111110001000
#   Value ≈ 0.0076267 appears at positions:
#     Index 123, Binary 000001111011
#     Index 125, Binary 000001111101
#     Index 183, Binary 000010110111
#     Index 190, Binary 000010111110
#     Index 215, Binary 000011010111
#     Index 222, Binary 000011011110
#     Index 235, Binary 000011101011
#     Index 237, Binary 000011101101
#     Index 1385, Binary 010101101001
#     Index 1430, Binary 010110010110
#     Index 1641, Binary 011001101001
#     Index 1686, Binary 011010010110
#     Index 2409, Binary 100101101001
#     Index 2454, Binary 100110010110
#     Index 2665, Binary 101001101001
#     Index 2710, Binary 101010010110
#     Index 3858, Binary 111100010010
#     Index 3860, Binary 111100010100
#     Index 3873, Binary 111100100001
#     Index 3880, Binary 111100101000
#     Index 3905, Binary 111101000001
#     Index 3912, Binary 111101001000
#     Index 3970, Binary 111110000010
#     Index 3972, Binary 111110000100
#   Value ≈ 0.015189 appears at positions:
#     Index 287, Binary 000100011111
#     Index 399, Binary 000110001111
#     Index 543, Binary 001000011111
#     Index 655, Binary 001010001111
#     Index 915, Binary 001110010011
#     Index 917, Binary 001110010101
#     Index 922, Binary 001110011010
#     Index 924, Binary 001110011100
#     Index 1071, Binary 010000101111
#     Index 1103, Binary 010001001111
#     Index 1968, Binary 011110110000
#     Index 2000, Binary 011111010000
#     Index 2095, Binary 100000101111
#     Index 2127, Binary 100001001111
#     Index 2992, Binary 101110110000
#     Index 3024, Binary 101111010000
#     Index 3171, Binary 110001100011
#     Index 3173, Binary 110001100101
#     Index 3178, Binary 110001101010
#     Index 3180, Binary 110001101100
#     Index 3440, Binary 110101110000
#     Index 3552, Binary 110111100000
#     Index 3696, Binary 111001110000
#     Index 3808, Binary 111011100000
#   Value ≈ 0.022067 appears at positions:
#     Index 303, Binary 000100101111
#     Index 335, Binary 000101001111
#     Index 559, Binary 001000101111
#     Index 591, Binary 001001001111
#     Index 867, Binary 001101100011
#     Index 869, Binary 001101100101
#     Index 874, Binary 001101101010
#     Index 876, Binary 001101101100
#     Index 1055, Binary 010000011111
#     Index 1167, Binary 010010001111
#     Index 1904, Binary 011101110000
#     Index 2016, Binary 011111100000
#     Index 2079, Binary 100000011111
#     Index 2191, Binary 100010001111
#     Index 2928, Binary 101101110000
#     Index 3040, Binary 101111100000
#     Index 3219, Binary 110010010011
#     Index 3221, Binary 110010010101
#     Index 3226, Binary 110010011010
#     Index 3228, Binary 110010011100
#     Index 3504, Binary 110110110000
#     Index 3536, Binary 110111010000
#     Index 3760, Binary 111010110000
#     Index 3792, Binary 111011010000
#   Value ≈ 0.065811 appears at positions:
#     Index 359, Binary 000101100111
#     Index 366, Binary 000101101110
#     Index 615, Binary 001001100111
#     Index 622, Binary 001001101110
#     Index 811, Binary 001100101011
#     Index 813, Binary 001100101101
#     Index 843, Binary 001101001011
#     Index 845, Binary 001101001101
#     Index 1142, Binary 010001110110
#     Index 1254, Binary 010011100110
#     Index 1817, Binary 011100011001
#     Index 1929, Binary 011110001001
#     Index 2166, Binary 100001110110
#     Index 2278, Binary 100011100110
#     Index 2841, Binary 101100011001
#     Index 2953, Binary 101110001001
#     Index 3250, Binary 110010110010
#     Index 3252, Binary 110010110100
#     Index 3282, Binary 110011010010
#     Index 3284, Binary 110011010100
#     Index 3473, Binary 110110010001
#     Index 3480, Binary 110110011000
#     Index 3729, Binary 111010010001
#     Index 3736, Binary 111010011000
#   Value ≈ -0.087878 appears at positions:
#     Index 363, Binary 000101101011
#     Index 365, Binary 000101101101
#     Index 619, Binary 001001101011
#     Index 621, Binary 001001101101
#     Index 807, Binary 001100100111
#     Index 814, Binary 001100101110
#     Index 839, Binary 001101000111
#     Index 846, Binary 001101001110
#     Index 1145, Binary 010001111001
#     Index 1257, Binary 010011101001
#     Index 1814, Binary 011100010110
#     Index 1926, Binary 011110000110
#     Index 2169, Binary 100001111001
#     Index 2281, Binary 100011101001
#     Index 2838, Binary 101100010110
#     Index 2950, Binary 101110000110
#     Index 3249, Binary 110010110001
#     Index 3256, Binary 110010111000
#     Index 3281, Binary 110011010001
#     Index 3288, Binary 110011011000
#     Index 3474, Binary 110110010010
#     Index 3476, Binary 110110010100
#     Index 3730, Binary 111010010010
#     Index 3732, Binary 111010010100
#   Value ≈ -0.095441 appears at positions:
#     Index 374, Binary 000101110110
#     Index 486, Binary 000111100110
#     Index 630, Binary 001001110110
#     Index 742, Binary 001011100110
#     Index 946, Binary 001110110010
#     Index 948, Binary 001110110100
#     Index 978, Binary 001111010010
#     Index 980, Binary 001111010100
#     Index 1127, Binary 010001100111
#     Index 1134, Binary 010001101110
#     Index 1937, Binary 011110010001
#     Index 1944, Binary 011110011000
#     Index 2151, Binary 100001100111
#     Index 2158, Binary 100001101110
#     Index 2961, Binary 101110010001
#     Index 2968, Binary 101110011000
#     Index 3115, Binary 110000101011
#     Index 3117, Binary 110000101101
#     Index 3147, Binary 110001001011
#     Index 3149, Binary 110001001101
#     Index 3353, Binary 110100011001
#     Index 3465, Binary 110110001001
#     Index 3609, Binary 111000011001
#     Index 3721, Binary 111010001001
#   Value ≈ 0.080251 appears at positions:
#     Index 377, Binary 000101111001
#     Index 489, Binary 000111101001
#     Index 633, Binary 001001111001
#     Index 745, Binary 001011101001
#     Index 945, Binary 001110110001
#     Index 952, Binary 001110111000
#     Index 977, Binary 001111010001
#     Index 984, Binary 001111011000
#     Index 1131, Binary 010001101011
#     Index 1133, Binary 010001101101
#     Index 1938, Binary 011110010010
#     Index 1940, Binary 011110010100
#     Index 2155, Binary 100001101011
#     Index 2157, Binary 100001101101
#     Index 2962, Binary 101110010010
#     Index 2964, Binary 101110010100
#     Index 3111, Binary 110000100111
#     Index 3118, Binary 110000101110
#     Index 3143, Binary 110001000111
#     Index 3150, Binary 110001001110
#     Index 3350, Binary 110100010110
#     Index 3462, Binary 110110000110
#     Index 3606, Binary 111000010110
#     Index 3718, Binary 111010000110
#   Value ≈ -0.04114 appears at positions:
#     Index 407, Binary 000110010111
#     Index 414, Binary 000110011110
#     Index 663, Binary 001010010111
#     Index 670, Binary 001010011110
#     Index 795, Binary 001100011011
#     Index 797, Binary 001100011101
#     Index 907, Binary 001110001011
#     Index 909, Binary 001110001101
#     Index 1206, Binary 010010110110
#     Index 1238, Binary 010011010110
#     Index 1833, Binary 011100101001
#     Index 1865, Binary 011101001001
#     Index 2230, Binary 100010110110
#     Index 2262, Binary 100011010110
#     Index 2857, Binary 101100101001
#     Index 2889, Binary 101101001001
#     Index 3186, Binary 110001110010
#     Index 3188, Binary 110001110100
#     Index 3298, Binary 110011100010
#     Index 3300, Binary 110011100100
#     Index 3425, Binary 110101100001
#     Index 3432, Binary 110101101000
#     Index 3681, Binary 111001100001
#     Index 3688, Binary 111001101000
#   Value ≈ 0.025951 appears at positions:
#     Index 411, Binary 000110011011
#     Index 413, Binary 000110011101
#     Index 667, Binary 001010011011
#     Index 669, Binary 001010011101
#     Index 791, Binary 001100010111
#     Index 798, Binary 001100011110
#     Index 903, Binary 001110000111
#     Index 910, Binary 001110001110
#     Index 1209, Binary 010010111001
#     Index 1241, Binary 010011011001
#     Index 1830, Binary 011100100110
#     Index 1862, Binary 011101000110
#     Index 2233, Binary 100010111001
#     Index 2265, Binary 100011011001
#     Index 2854, Binary 101100100110
#     Index 2886, Binary 101101000110
#     Index 3185, Binary 110001110001
#     Index 3192, Binary 110001111000
#     Index 3297, Binary 110011100001
#     Index 3304, Binary 110011101000
#     Index 3426, Binary 110101100010
#     Index 3428, Binary 110101100100
#     Index 3682, Binary 111001100010
#     Index 3684, Binary 111001100100
#   Value ≈ 0.033514 appears at positions:
#     Index 438, Binary 000110110110
#     Index 470, Binary 000111010110
#     Index 694, Binary 001010110110
#     Index 726, Binary 001011010110
#     Index 882, Binary 001101110010
#     Index 884, Binary 001101110100
#     Index 994, Binary 001111100010
#     Index 996, Binary 001111100100
#     Index 1175, Binary 010010010111
#     Index 1182, Binary 010010011110
#     Index 1889, Binary 011101100001
#     Index 1896, Binary 011101101000
#     Index 2199, Binary 100010010111
#     Index 2206, Binary 100010011110
#     Index 2913, Binary 101101100001
#     Index 2920, Binary 101101101000
#     Index 3099, Binary 110000011011
#     Index 3101, Binary 110000011101
#     Index 3211, Binary 110010001011
#     Index 3213, Binary 110010001101
#     Index 3369, Binary 110100101001
#     Index 3401, Binary 110101001001
#     Index 3625, Binary 111000101001
#     Index 3657, Binary 111001001001
#   Value ≈ -0.055581 appears at positions:
#     Index 441, Binary 000110111001
#     Index 473, Binary 000111011001
#     Index 697, Binary 001010111001
#     Index 729, Binary 001011011001
#     Index 881, Binary 001101110001
#     Index 888, Binary 001101111000
#     Index 993, Binary 001111100001
#     Index 1000, Binary 001111101000
#     Index 1179, Binary 010010011011
#     Index 1181, Binary 010010011101
#     Index 1890, Binary 011101100010
#     Index 1892, Binary 011101100100
#     Index 2203, Binary 100010011011
#     Index 2205, Binary 100010011101
#     Index 2914, Binary 101101100010
#     Index 2916, Binary 101101100100
#     Index 3095, Binary 110000010111
#     Index 3102, Binary 110000011110
#     Index 3207, Binary 110010000111
#     Index 3214, Binary 110010001110
#     Index 3366, Binary 110100100110
#     Index 3398, Binary 110101000110
#     Index 3622, Binary 111000100110
#     Index 3654, Binary 111001000110
#   Value ≈ -0.02467 appears at positions:
#     Index 497, Binary 000111110001
#     Index 504, Binary 000111111000
#     Index 753, Binary 001011110001
#     Index 760, Binary 001011111000
#     Index 825, Binary 001100111001
#     Index 857, Binary 001101011001
#     Index 937, Binary 001110101001
#     Index 969, Binary 001111001001
#     Index 1266, Binary 010011110010
#     Index 1268, Binary 010011110100
#     Index 1803, Binary 011100001011
#     Index 1805, Binary 011100001101
#     Index 2290, Binary 100011110010
#     Index 2292, Binary 100011110100
#     Index 2827, Binary 101100001011
#     Index 2829, Binary 101100001101
#     Index 3126, Binary 110000110110
#     Index 3158, Binary 110001010110
#     Index 3238, Binary 110010100110
#     Index 3270, Binary 110011000110
#     Index 3335, Binary 110100000111
#     Index 3342, Binary 110100001110
#     Index 3591, Binary 111000000111
#     Index 3598, Binary 111000001110
#   Value ≈ 0.061927 appears at positions:
#     Index 498, Binary 000111110010
#     Index 500, Binary 000111110100
#     Index 754, Binary 001011110010
#     Index 756, Binary 001011110100
#     Index 822, Binary 001100110110
#     Index 854, Binary 001101010110
#     Index 934, Binary 001110100110
#     Index 966, Binary 001111000110
#     Index 1265, Binary 010011110001
#     Index 1272, Binary 010011111000
#     Index 1799, Binary 011100000111
#     Index 1806, Binary 011100001110
#     Index 2289, Binary 100011110001
#     Index 2296, Binary 100011111000
#     Index 2823, Binary 101100000111
#     Index 2830, Binary 101100001110
#     Index 3129, Binary 110000111001
#     Index 3161, Binary 110001011001
#     Index 3241, Binary 110010101001
#     Index 3273, Binary 110011001001
#     Index 3339, Binary 110100001011
#     Index 3341, Binary 110100001101
#     Index 3595, Binary 111000001011
#     Index 3597, Binary 111000001101
# ==================================================
# Eigenvector 3:
# Number of unique nonzero components (tol=1e-12, sign matters): 15
#   Value ≈ -0.032313 appears at positions:
#     Index 63, Binary 000000111111
#     Index 95, Binary 000001011111
#     Index 175, Binary 000010101111
#     Index 207, Binary 000011001111
#     Index 243, Binary 000011110011
#     Index 245, Binary 000011110101
#     Index 250, Binary 000011111010
#     Index 252, Binary 000011111100
#     Index 1295, Binary 010100001111
#     Index 1520, Binary 010111110000
#     Index 1551, Binary 011000001111
#     Index 1776, Binary 011011110000
#     Index 2319, Binary 100100001111
#     Index 2544, Binary 100111110000
#     Index 2575, Binary 101000001111
#     Index 2800, Binary 101011110000
#     Index 3843, Binary 111100000011
#     Index 3845, Binary 111100000101
#     Index 3850, Binary 111100001010
#     Index 3852, Binary 111100001100
#     Index 3888, Binary 111100110000
#     Index 3920, Binary 111101010000
#     Index 4000, Binary 111110100000
#     Index 4032, Binary 111111000000
#   Value ≈ 0.059558 appears at positions:
#     Index 119, Binary 000001110111
#     Index 126, Binary 000001111110
#     Index 187, Binary 000010111011
#     Index 189, Binary 000010111101
#     Index 219, Binary 000011011011
#     Index 221, Binary 000011011101
#     Index 231, Binary 000011100111
#     Index 238, Binary 000011101110
#     Index 1382, Binary 010101100110
#     Index 1433, Binary 010110011001
#     Index 1638, Binary 011001100110
#     Index 1689, Binary 011010011001
#     Index 2406, Binary 100101100110
#     Index 2457, Binary 100110011001
#     Index 2662, Binary 101001100110
#     Index 2713, Binary 101010011001
#     Index 3857, Binary 111100010001
#     Index 3864, Binary 111100011000
#     Index 3874, Binary 111100100010
#     Index 3876, Binary 111100100100
#     Index 3906, Binary 111101000010
#     Index 3908, Binary 111101000100
#     Index 3969, Binary 111110000001
#     Index 3976, Binary 111110001000
#   Value ≈ -0.027245 appears at positions:
#     Index 123, Binary 000001111011
#     Index 125, Binary 000001111101
#     Index 183, Binary 000010110111
#     Index 190, Binary 000010111110
#     Index 215, Binary 000011010111
#     Index 222, Binary 000011011110
#     Index 235, Binary 000011101011
#     Index 237, Binary 000011101101
#     Index 1385, Binary 010101101001
#     Index 1430, Binary 010110010110
#     Index 1641, Binary 011001101001
#     Index 1686, Binary 011010010110
#     Index 2409, Binary 100101101001
#     Index 2454, Binary 100110010110
#     Index 2665, Binary 101001101001
#     Index 2710, Binary 101010010110
#     Index 3858, Binary 111100010010
#     Index 3860, Binary 111100010100
#     Index 3873, Binary 111100100001
#     Index 3880, Binary 111100101000
#     Index 3905, Binary 111101000001
#     Index 3912, Binary 111101001000
#     Index 3970, Binary 111110000010
#     Index 3972, Binary 111110000100
#   Value ≈ 0.093617 appears at positions:
#     Index 287, Binary 000100011111
#     Index 399, Binary 000110001111
#     Index 543, Binary 001000011111
#     Index 655, Binary 001010001111
#     Index 915, Binary 001110010011
#     Index 917, Binary 001110010101
#     Index 922, Binary 001110011010
#     Index 924, Binary 001110011100
#     Index 1071, Binary 010000101111
#     Index 1103, Binary 010001001111
#     Index 1968, Binary 011110110000
#     Index 2000, Binary 011111010000
#     Index 2095, Binary 100000101111
#     Index 2127, Binary 100001001111
#     Index 2992, Binary 101110110000
#     Index 3024, Binary 101111010000
#     Index 3171, Binary 110001100011
#     Index 3173, Binary 110001100101
#     Index 3178, Binary 110001101010
#     Index 3180, Binary 110001101100
#     Index 3440, Binary 110101110000
#     Index 3552, Binary 110111100000
#     Index 3696, Binary 111001110000
#     Index 3808, Binary 111011100000
#   Value ≈ -0.061304 appears at positions:
#     Index 303, Binary 000100101111
#     Index 335, Binary 000101001111
#     Index 559, Binary 001000101111
#     Index 591, Binary 001001001111
#     Index 867, Binary 001101100011
#     Index 869, Binary 001101100101
#     Index 874, Binary 001101101010
#     Index 876, Binary 001101101100
#     Index 1055, Binary 010000011111
#     Index 1167, Binary 010010001111
#     Index 1904, Binary 011101110000
#     Index 2016, Binary 011111100000
#     Index 2079, Binary 100000011111
#     Index 2191, Binary 100010001111
#     Index 2928, Binary 101101110000
#     Index 3040, Binary 101111100000
#     Index 3219, Binary 110010010011
#     Index 3221, Binary 110010010101
#     Index 3226, Binary 110010011010
#     Index 3228, Binary 110010011100
#     Index 3504, Binary 110110110000
#     Index 3536, Binary 110111010000
#     Index 3760, Binary 111010110000
#     Index 3792, Binary 111011010000
#   Value ≈ 0.0041691 appears at positions:
#     Index 359, Binary 000101100111
#     Index 366, Binary 000101101110
#     Index 615, Binary 001001100111
#     Index 622, Binary 001001101110
#     Index 811, Binary 001100101011
#     Index 813, Binary 001100101101
#     Index 843, Binary 001101001011
#     Index 845, Binary 001101001101
#     Index 1142, Binary 010001110110
#     Index 1254, Binary 010011100110
#     Index 1817, Binary 011100011001
#     Index 1929, Binary 011110001001
#     Index 2166, Binary 100001110110
#     Index 2278, Binary 100011100110
#     Index 2841, Binary 101100011001
#     Index 2953, Binary 101110001001
#     Index 3250, Binary 110010110010
#     Index 3252, Binary 110010110100
#     Index 3282, Binary 110011010010
#     Index 3284, Binary 110011010100
#     Index 3473, Binary 110110010001
#     Index 3480, Binary 110110011000
#     Index 3729, Binary 111010010001
#     Index 3736, Binary 111010011000
#   Value ≈ 0.057135 appears at positions:
#     Index 363, Binary 000101101011
#     Index 365, Binary 000101101101
#     Index 619, Binary 001001101011
#     Index 621, Binary 001001101101
#     Index 807, Binary 001100100111
#     Index 814, Binary 001100101110
#     Index 839, Binary 001101000111
#     Index 846, Binary 001101001110
#     Index 1145, Binary 010001111001
#     Index 1257, Binary 010011101001
#     Index 1814, Binary 011100010110
#     Index 1926, Binary 011110000110
#     Index 2169, Binary 100001111001
#     Index 2281, Binary 100011101001
#     Index 2838, Binary 101100010110
#     Index 2950, Binary 101110000110
#     Index 3249, Binary 110010110001
#     Index 3256, Binary 110010111000
#     Index 3281, Binary 110011010001
#     Index 3288, Binary 110011011000
#     Index 3474, Binary 110110010010
#     Index 3476, Binary 110110010100
#     Index 3730, Binary 111010010010
#     Index 3732, Binary 111010010100
#   Value ≈ -0.063727 appears at positions:
#     Index 374, Binary 000101110110
#     Index 486, Binary 000111100110
#     Index 630, Binary 001001110110
#     Index 742, Binary 001011100110
#     Index 946, Binary 001110110010
#     Index 948, Binary 001110110100
#     Index 978, Binary 001111010010
#     Index 980, Binary 001111010100
#     Index 1127, Binary 010001100111
#     Index 1134, Binary 010001101110
#     Index 1937, Binary 011110010001
#     Index 1944, Binary 011110011000
#     Index 2151, Binary 100001100111
#     Index 2158, Binary 100001101110
#     Index 2961, Binary 101110010001
#     Index 2968, Binary 101110011000
#     Index 3115, Binary 110000101011
#     Index 3117, Binary 110000101101
#     Index 3147, Binary 110001001011
#     Index 3149, Binary 110001001101
#     Index 3353, Binary 110100011001
#     Index 3465, Binary 110110001001
#     Index 3609, Binary 111000011001
# ...
#     Index 1181, Binary 010010011101
#     Index 1890, Binary 011101100010
#     Index 1892, Binary 011101100100
#     Index 2203, Binary 100010011011
#     Index 2205, Binary 100010011101
#     Index 2914, Binary 101101100010
#     Index 2916, Binary 101101100100
#     Index 3095, Binary 110000010111
#     Index 3102, Binary 110000011110
#     Index 3207, Binary 110010000111
#     Index 3214, Binary 110010001110
#     Index 3366, Binary 110100100110
#     Index 3398, Binary 110101000110
#     Index 3622, Binary 111000100110
#     Index 3654, Binary 111001000110
#   Value ≈ -0.014511 appears at positions:
#     Index 497, Binary 000111110001
#     Index 504, Binary 000111111000
#     Index 753, Binary 001011110001
#     Index 760, Binary 001011111000
#     Index 825, Binary 001100111001
#     Index 857, Binary 001101011001
#     Index 937, Binary 001110101001
#     Index 969, Binary 001111001001
#     Index 1266, Binary 010011110010
#     Index 1268, Binary 010011110100
#     Index 1803, Binary 011100001011
#     Index 1805, Binary 011100001101
#     Index 2290, Binary 100011110010
#     Index 2292, Binary 100011110100
#     Index 2827, Binary 101100001011
#     Index 2829, Binary 101100001101
#     Index 3126, Binary 110000110110
#     Index 3158, Binary 110001010110
#     Index 3238, Binary 110010100110
#     Index 3270, Binary 110011000110
#     Index 3335, Binary 110100000111
#     Index 3342, Binary 110100001110
#     Index 3591, Binary 111000000111
#     Index 3598, Binary 111000001110
#   Value ≈ 0.046824 appears at positions:
#     Index 498, Binary 000111110010
#     Index 500, Binary 000111110100
#     Index 754, Binary 001011110010
#     Index 756, Binary 001011110100
#     Index 822, Binary 001100110110
#     Index 854, Binary 001101010110
#     Index 934, Binary 001110100110
#     Index 966, Binary 001111000110
#     Index 1265, Binary 010011110001
#     Index 1272, Binary 010011111000
#     Index 1799, Binary 011100000111
#     Index 1806, Binary 011100001110
#     Index 2289, Binary 100011110001
#     Index 2296, Binary 100011111000
#     Index 2823, Binary 101100000111
#     Index 2830, Binary 101100001110
#     Index 3129, Binary 110000111001
#     Index 3161, Binary 110001011001
#     Index 3241, Binary 110010101001
#     Index 3273, Binary 110011001001
#     Index 3339, Binary 110100001011
#     Index 3341, Binary 110100001101
#     Index 3595, Binary 111000001011
#     Index 3597, Binary 111000001101
# ==================================================
# Eigenvector 4:
# Number of unique nonzero components (tol=1e-12, sign matters): 15
#   Value ≈ 0.01773 appears at positions:
#     Index 63, Binary 000000111111
#     Index 95, Binary 000001011111
#     Index 175, Binary 000010101111
#     Index 207, Binary 000011001111
#     Index 243, Binary 000011110011
#     Index 245, Binary 000011110101
#     Index 250, Binary 000011111010
#     Index 252, Binary 000011111100
#     Index 1295, Binary 010100001111
#     Index 1520, Binary 010111110000
#     Index 1551, Binary 011000001111
#     Index 1776, Binary 011011110000
#     Index 2319, Binary 100100001111
#     Index 2544, Binary 100111110000
#     Index 2575, Binary 101000001111
#     Index 2800, Binary 101011110000
#     Index 3843, Binary 111100000011
#     Index 3845, Binary 111100000101
#     Index 3850, Binary 111100001010
#     Index 3852, Binary 111100001100
#     Index 3888, Binary 111100110000
#     Index 3920, Binary 111101010000
#     Index 4000, Binary 111110100000
#     Index 4032, Binary 111111000000
#   Value ≈ 0.017212 appears at positions:
#     Index 119, Binary 000001110111
#     Index 126, Binary 000001111110
#     Index 187, Binary 000010111011
#     Index 189, Binary 000010111101
#     Index 219, Binary 000011011011
#     Index 221, Binary 000011011101
#     Index 231, Binary 000011100111
#     Index 238, Binary 000011101110
#     Index 1382, Binary 010101100110
#     Index 1433, Binary 010110011001
#     Index 1638, Binary 011001100110
#     Index 1689, Binary 011010011001
#     Index 2406, Binary 100101100110
#     Index 2457, Binary 100110011001
#     Index 2662, Binary 101001100110
#     Index 2713, Binary 101010011001
#     Index 3857, Binary 111100010001
#     Index 3864, Binary 111100011000
#     Index 3874, Binary 111100100010
#     Index 3876, Binary 111100100100
#     Index 3906, Binary 111101000010
#     Index 3908, Binary 111101000100
#     Index 3969, Binary 111110000001
#     Index 3976, Binary 111110001000
#   Value ≈ -0.034943 appears at positions:
#     Index 123, Binary 000001111011
#     Index 125, Binary 000001111101
#     Index 183, Binary 000010110111
#     Index 190, Binary 000010111110
#     Index 215, Binary 000011010111
#     Index 222, Binary 000011011110
#     Index 235, Binary 000011101011
#     Index 237, Binary 000011101101
#     Index 1385, Binary 010101101001
#     Index 1430, Binary 010110010110
#     Index 1641, Binary 011001101001
#     Index 1686, Binary 011010010110
#     Index 2409, Binary 100101101001
#     Index 2454, Binary 100110010110
#     Index 2665, Binary 101001101001
#     Index 2710, Binary 101010010110
#     Index 3858, Binary 111100010010
#     Index 3860, Binary 111100010100
#     Index 3873, Binary 111100100001
#     Index 3880, Binary 111100101000
#     Index 3905, Binary 111101000001
#     Index 3912, Binary 111101001000
#     Index 3970, Binary 111110000010
#     Index 3972, Binary 111110000100
#   Value ≈ -0.060711 appears at positions:
#     Index 287, Binary 000100011111
#     Index 399, Binary 000110001111
#     Index 543, Binary 001000011111
#     Index 655, Binary 001010001111
#     Index 915, Binary 001110010011
#     Index 917, Binary 001110010101
#     Index 922, Binary 001110011010
#     Index 924, Binary 001110011100
#     Index 1071, Binary 010000101111
#     Index 1103, Binary 010001001111
#     Index 1968, Binary 011110110000
#     Index 2000, Binary 011111010000
#     Index 2095, Binary 100000101111
#     Index 2127, Binary 100001001111
#     Index 2992, Binary 101110110000
#     Index 3024, Binary 101111010000
#     Index 3171, Binary 110001100011
#     Index 3173, Binary 110001100101
#     Index 3178, Binary 110001101010
#     Index 3180, Binary 110001101100
#     Index 3440, Binary 110101110000
#     Index 3552, Binary 110111100000
#     Index 3696, Binary 111001110000
#     Index 3808, Binary 111011100000
#   Value ≈ 0.042981 appears at positions:
#     Index 303, Binary 000100101111
#     Index 335, Binary 000101001111
#     Index 559, Binary 001000101111
#     Index 591, Binary 001001001111
#     Index 867, Binary 001101100011
#     Index 869, Binary 001101100101
#     Index 874, Binary 001101101010
#     Index 876, Binary 001101101100
#     Index 1055, Binary 010000011111
#     Index 1167, Binary 010010001111
#     Index 1904, Binary 011101110000
#     Index 2016, Binary 011111100000
#     Index 2079, Binary 100000011111
#     Index 2191, Binary 100010001111
#     Index 2928, Binary 101101110000
#     Index 3040, Binary 101111100000
#     Index 3219, Binary 110010010011
#     Index 3221, Binary 110010010101
#     Index 3226, Binary 110010011010
#     Index 3228, Binary 110010011100
#     Index 3504, Binary 110110110000
#     Index 3536, Binary 110111010000
#     Index 3760, Binary 111010110000
#     Index 3792, Binary 111011010000
#   Value ≈ -0.023698 appears at positions:
#     Index 359, Binary 000101100111
#     Index 366, Binary 000101101110
#     Index 615, Binary 001001100111
#     Index 622, Binary 001001101110
#     Index 811, Binary 001100101011
#     Index 813, Binary 001100101101
#     Index 843, Binary 001101001011
#     Index 845, Binary 001101001101
#     Index 1142, Binary 010001110110
#     Index 1254, Binary 010011100110
#     Index 1817, Binary 011100011001
#     Index 1929, Binary 011110001001
#     Index 2166, Binary 100001110110
#     Index 2278, Binary 100011100110
#     Index 2841, Binary 101100011001
#     Index 2953, Binary 101110001001
#     Index 3250, Binary 110010110010
#     Index 3252, Binary 110010110100
#     Index 3282, Binary 110011010010
#     Index 3284, Binary 110011010100
#     Index 3473, Binary 110110010001
#     Index 3480, Binary 110110011000
#     Index 3729, Binary 111010010001
#     Index 3736, Binary 111010011000
#   Value ≈ -0.019283 appears at positions:
#     Index 363, Binary 000101101011
#     Index 365, Binary 000101101101
#     Index 619, Binary 001001101011
#     Index 621, Binary 001001101101
#     Index 807, Binary 001100100111
#     Index 814, Binary 001100101110
#     Index 839, Binary 001101000111
#     Index 846, Binary 001101001110
#     Index 1145, Binary 010001111001
#     Index 1257, Binary 010011101001
#     Index 1814, Binary 011100010110
#     Index 1926, Binary 011110000110
#     Index 2169, Binary 100001111001
#     Index 2281, Binary 100011101001
#     Index 2838, Binary 101100010110
#     Index 2950, Binary 101110000110
#     Index 3249, Binary 110010110001
#     Index 3256, Binary 110010111000
#     Index 3281, Binary 110011010001
#     Index 3288, Binary 110011011000
#     Index 3474, Binary 110110010010
#     Index 3476, Binary 110110010100
#     Index 3730, Binary 111010010010
#     Index 3732, Binary 111010010100
#   Value ≈ 0.0064862 appears at positions:
#     Index 374, Binary 000101110110
#     Index 486, Binary 000111100110
#     Index 630, Binary 001001110110
#     Index 742, Binary 001011100110
#     Index 946, Binary 001110110010
#     Index 948, Binary 001110110100
#     Index 978, Binary 001111010010
#     Index 980, Binary 001111010100
#     Index 1127, Binary 010001100111
#     Index 1134, Binary 010001101110
#     Index 1937, Binary 011110010001
#     Index 1944, Binary 011110011000
#     Index 2151, Binary 100001100111
#     Index 2158, Binary 100001101110
#     Index 2961, Binary 101110010001
#     Index 2968, Binary 101110011000
#     Index 3115, Binary 110000101011
#     Index 3117, Binary 110000101101
#     Index 3147, Binary 110001001011
#     Index 3149, Binary 110001001101
#     Index 3353, Binary 110100011001
#     Index 3465, Binary 110110001001
#     Index 3609, Binary 111000011001
#     Index 3721, Binary 111010001001
#   Value ≈ 0.054225 appears at positions:
#     Index 377, Binary 000101111001
#     Index 489, Binary 000111101001
#     Index 633, Binary 001001111001
#     Index 745, Binary 001011101001
#     Index 945, Binary 001110110001
#     Index 952, Binary 001110111000
#     Index 977, Binary 001111010001
#     Index 984, Binary 001111011000
#     Index 1131, Binary 010001101011
#     Index 1133, Binary 010001101101
#     Index 1938, Binary 011110010010
#     Index 1940, Binary 011110010100
#     Index 2155, Binary 100001101011
#     Index 2157, Binary 100001101101
#     Index 2962, Binary 101110010010
#     Index 2964, Binary 101110010100
#     Index 3111, Binary 110000100111
#     Index 3118, Binary 110000101110
#     Index 3143, Binary 110001000111
#     Index 3150, Binary 110001001110
#     Index 3350, Binary 110100010110
#     Index 3462, Binary 110110000110
#     Index 3606, Binary 111000010110
#     Index 3718, Binary 111010000110
#   Value ≈ 0.1064 appears at positions:
#     Index 407, Binary 000110010111
#     Index 414, Binary 000110011110
#     Index 663, Binary 001010010111
#     Index 670, Binary 001010011110
#     Index 795, Binary 001100011011
#     Index 797, Binary 001100011101
#     Index 907, Binary 001110001011
#     Index 909, Binary 001110001101
#     Index 1206, Binary 010010110110
#     Index 1238, Binary 010011010110
#     Index 1833, Binary 011100101001
#     Index 1865, Binary 011101001001
#     Index 2230, Binary 100010110110
#     Index 2262, Binary 100011010110
#     Index 2857, Binary 101100101001
#     Index 2889, Binary 101101001001
#     Index 3186, Binary 110001110010
#     Index 3188, Binary 110001110100
#     Index 3298, Binary 110011100010
#     Index 3300, Binary 110011100100
#     Index 3425, Binary 110101100001
#     Index 3432, Binary 110101101000
#     Index 3681, Binary 111001100001
#     Index 3688, Binary 111001101000
#   Value ≈ -0.045688 appears at positions:
#     Index 411, Binary 000110011011
#     Index 413, Binary 000110011101
#     Index 667, Binary 001010011011
#     Index 669, Binary 001010011101
#     Index 791, Binary 001100010111
#     Index 798, Binary 001100011110
#     Index 903, Binary 001110000111
#     Index 910, Binary 001110001110
#     Index 1209, Binary 010010111001
#     Index 1241, Binary 010011011001
#     Index 1830, Binary 011100100110
#     Index 1862, Binary 011101000110
#     Index 2233, Binary 100010111001
#     Index 2265, Binary 100011011001
#     Index 2854, Binary 101100100110
#     Index 2886, Binary 101101000110
#     Index 3185, Binary 110001110001
#     Index 3192, Binary 110001111000
#     Index 3297, Binary 110011100001
#     Index 3304, Binary 110011101000
#     Index 3426, Binary 110101100010
#     Index 3428, Binary 110101100100
#     Index 3682, Binary 111001100010
#     Index 3684, Binary 111001100100
#   Value ≈ -0.071457 appears at positions:
#     Index 438, Binary 000110110110
#     Index 470, Binary 000111010110
#     Index 694, Binary 001010110110
#     Index 726, Binary 001011010110
#     Index 882, Binary 001101110010
#     Index 884, Binary 001101110100
#     Index 994, Binary 001111100010
#     Index 996, Binary 001111100100
#     Index 1175, Binary 010010010111
#     Index 1182, Binary 010010011110
#     Index 1889, Binary 011101100001
#     Index 1896, Binary 011101101000
#     Index 2199, Binary 100010010111
#     Index 2206, Binary 100010011110
#     Index 2913, Binary 101101100001
#     Index 2920, Binary 101101101000
#     Index 3099, Binary 110000011011
#     Index 3101, Binary 110000011101
#     Index 3211, Binary 110010001011
#     Index 3213, Binary 110010001101
#     Index 3369, Binary 110100101001
#     Index 3401, Binary 110101001001
#     Index 3625, Binary 111000101001
#     Index 3657, Binary 111001001001
#   Value ≈ 0.028476 appears at positions:
#     Index 441, Binary 000110111001
#     Index 473, Binary 000111011001
#     Index 697, Binary 001010111001
#     Index 729, Binary 001011011001
#     Index 881, Binary 001101110001
#     Index 888, Binary 001101111000
#     Index 993, Binary 001111100001
#     Index 1000, Binary 001111101000
#     Index 1179, Binary 010010011011
#     Index 1181, Binary 010010011101
#     Index 1890, Binary 011101100010
#     Index 1892, Binary 011101100100
#     Index 2203, Binary 100010011011
#     Index 2205, Binary 100010011101
#     Index 2914, Binary 101101100010
#     Index 2916, Binary 101101100100
#     Index 3095, Binary 110000010111
#     Index 3102, Binary 110000011110
#     Index 3207, Binary 110010000111
#     Index 3214, Binary 110010001110
#     Index 3366, Binary 110100100110
#     Index 3398, Binary 110101000110
#     Index 3622, Binary 111000100110
#     Index 3654, Binary 111001000110
#   Value ≈ -0.082701 appears at positions:
#     Index 497, Binary 000111110001
#     Index 504, Binary 000111111000
#     Index 753, Binary 001011110001
#     Index 760, Binary 001011111000
#     Index 825, Binary 001100111001
#     Index 857, Binary 001101011001
#     Index 937, Binary 001110101001
#     Index 969, Binary 001111001001
#     Index 1266, Binary 010011110010
#     Index 1268, Binary 010011110100
#     Index 1803, Binary 011100001011
#     Index 1805, Binary 011100001101
#     Index 2290, Binary 100011110010
#     Index 2292, Binary 100011110100
#     Index 2827, Binary 101100001011
#     Index 2829, Binary 101100001101
#     Index 3126, Binary 110000110110
#     Index 3158, Binary 110001010110
#     Index 3238, Binary 110010100110
#     Index 3270, Binary 110011000110
#     Index 3335, Binary 110100000111
#     Index 3342, Binary 110100001110
#     Index 3591, Binary 111000000111
#     Index 3598, Binary 111000001110
#   Value ≈ 0.064971 appears at positions:
#     Index 498, Binary 000111110010
#     Index 500, Binary 000111110100
#     Index 754, Binary 001011110010
#     Index 756, Binary 001011110100
#     Index 822, Binary 001100110110
#     Index 854, Binary 001101010110
#     Index 934, Binary 001110100110
#     Index 966, Binary 001111000110
#     Index 1265, Binary 010011110001
#     Index 1272, Binary 010011111000
#     Index 1799, Binary 011100000111
#     Index 1806, Binary 011100001110
#     Index 2289, Binary 100011110001
#     Index 2296, Binary 100011111000
#     Index 2823, Binary 101100000111
#     Index 2830, Binary 101100001110
#     Index 3129, Binary 110000111001
#     Index 3161, Binary 110001011001
#     Index 3241, Binary 110010101001
#     Index 3273, Binary 110011001001
#     Index 3339, Binary 110100001011
#     Index 3341, Binary 110100001101
#     Index 3595, Binary 111000001011
#     Index 3597, Binary 111000001101
# ==================================================

# %%
# min_scar

non_zero_count = 0  # Counter for non-zero components

for index, component in enumerate(min_scar):
    # Set components of the order 10^-12 or smaller to zero
    if np.abs(component) < 1e-12: # I noticed that  most components are of the order 10^-13 or smaller - only a handful are mucgh larger
        min_scar[index] = 0.0
    else:
        non_zero_count += 1
    binary_basis = index_to_binary(index, N)
    print(f"{binary_basis}: {np.real(min_scar[index])}")

print(f"Total Non-Zero Components in min_scar: {non_zero_count}")
print("=" * 50)
# Out:
# 000000000000: 0.0
# 000000000001: 0.0
# 000000000010: 0.0
# 000000000011: 0.0
# 000000000100: 0.0
# 000000000101: 0.0
# 000000000110: 0.0
# 000000000111: 0.0
# 000000001000: 0.0
# 000000001001: 0.0
# 000000001010: 0.0
# 000000001011: 0.0
# 000000001100: 0.0
# 000000001101: 0.0
# 000000001110: 0.0
# 000000001111: 0.0
# 000000010000: 0.0
# 000000010001: 0.0
# 000000010010: 0.0
# 000000010011: 0.0
# 000000010100: 0.0
# 000000010101: 0.0
# 000000010110: 0.0
# 000000010111: 0.0
# 000000011000: 0.0
# 000000011001: 0.0
# 000000011010: 0.0
# 000000011011: 0.0
# 000000011100: 0.0
# 000000011101: 0.0
# 000000011110: 0.0
# 000000011111: 0.0
# 000000100000: 0.0
# 000000100001: 0.0
# 000000100010: 0.0
# 000000100011: 0.0
# 000000100100: 0.0
# 000000100101: 0.0
# 000000100110: 0.0
# 000000100111: 0.0
# 000000101000: 0.0
# 000000101001: 0.0
# 000000101010: 0.0
# 000000101011: 0.0
# 000000101100: 0.0
# 000000101101: 0.0
# 000000101110: 0.0
# 000000101111: 0.0
# 000000110000: 0.0
# 000000110001: 0.0
# 000000110010: 0.0
# 000000110011: 0.0
# 000000110100: 0.0
# 000000110101: 0.0
# 000000110110: 0.0
# 000000110111: 0.0
# 000000111000: 0.0
# 000000111001: 0.0
# 000000111010: 0.0
# 000000111011: 0.0
# 000000111100: 0.0
# 000000111101: 0.0
# 000000111110: 0.0
# 000000111111: -4.388273538345972e-05
# 000001000000: 0.0
# 000001000001: 0.0
# 000001000010: 0.0
# 000001000011: 0.0
# 000001000100: 0.0
# 000001000101: 0.0
# 000001000110: 0.0
# 000001000111: 0.0
# 000001001000: 0.0
# 000001001001: 0.0
# 000001001010: 0.0
# 000001001011: 0.0
# 000001001100: 0.0
# 000001001101: 0.0
# 000001001110: 0.0
# 000001001111: 0.0
# 000001010000: 0.0
# 000001010001: 0.0
# 000001010010: 0.0
# 000001010011: 0.0
# 000001010100: 0.0
# 000001010101: 0.0
# 000001010110: 0.0
# 000001010111: 0.0
# 000001011000: 0.0
# 000001011001: 0.0
# 000001011010: 0.0
# 000001011011: 0.0
# 000001011100: 0.0
# 000001011101: 0.0
# 000001011110: 0.0
# 000001011111: -4.3882735383444105e-05
# 000001100000: 0.0
# 000001100001: 0.0
# 000001100010: 0.0
# 000001100011: 0.0
# 000001100100: 0.0
# 000001100101: 0.0
# 000001100110: 0.0
# 000001100111: 0.0
# 000001101000: 0.0
# 000001101001: 0.0
# 000001101010: 0.0
# 000001101011: 0.0
# 000001101100: 0.0
# 000001101101: 0.0
# 000001101110: 0.0
# 000001101111: 0.0
# 000001110000: 0.0
# 000001110001: 0.0
# 000001110010: 0.0
# 000001110011: 0.0
# 000001110100: 0.0
# 000001110101: 0.0
# 000001110110: 0.0
# 000001110111: 0.00017256586652851036
# 000001111000: 0.0
# 000001111001: 0.0
# 000001111010: 0.0
# 000001111011: -0.00012868313114261856
# 000001111100: 0.0
# 000001111101: -0.00012868313114264372
# 000001111110: 0.0001725658665283885
# 000001111111: 0.0
# 000010000000: 0.0
# 000010000001: 0.0
# 000010000010: 0.0
# 000010000011: 0.0
# 000010000100: 0.0
# 000010000101: 0.0
# 000010000110: 0.0
# 000010000111: 0.0
# 000010001000: 0.0
# 000010001001: 0.0
# 000010001010: 0.0
# 000010001011: 0.0
# 000010001100: 0.0
# 000010001101: 0.0
# 000010001110: 0.0
# 000010001111: 0.0
# 000010010000: 0.0
# 000010010001: 0.0
# 000010010010: 0.0
# 000010010011: 0.0
# 000010010100: 0.0
# 000010010101: 0.0
# 000010010110: 0.0
# 000010010111: 0.0
# 000010011000: 0.0
# 000010011001: 0.0
# 000010011010: 0.0
# 000010011011: 0.0
# 000010011100: 0.0
# 000010011101: 0.0
# 000010011110: 0.0
# 000010011111: 0.0
# 000010100000: 0.0
# 000010100001: 0.0
# 000010100010: 0.0
# 000010100011: 0.0
# 000010100100: 0.0
# 000010100101: 0.0
# 000010100110: 0.0
# 000010100111: 0.0
# 000010101000: 0.0
# 000010101001: 0.0
# 000010101010: 0.0
# 000010101011: 0.0
# 000010101100: 0.0
# 000010101101: 0.0
# 000010101110: 0.0
# 000010101111: -4.38827353834762e-05
# 000010110000: 0.0
# 000010110001: 0.0
# 000010110010: 0.0
# 000010110011: 0.0
# 000010110100: 0.0
# 000010110101: 0.0
# 000010110110: 0.0
# 000010110111: -0.00012868313114414512
# 000010111000: 0.0
# 000010111001: 0.0
# 000010111010: 0.0
# 000010111011: 0.00017256586652772757
# 000010111100: 0.0
# 000010111101: 0.0001725658665278052
# 000010111110: -0.0001286831311441694
# 000010111111: 0.0
# 000011000000: 0.0
# 000011000001: 0.0
# 000011000010: 0.0
# 000011000011: 0.0
# 000011000100: 0.0
# 000011000101: 0.0
# 000011000110: 0.0
# 000011000111: 0.0
# 000011001000: 0.0
# 000011001001: 0.0
# 000011001010: 0.0
# 000011001011: 0.0
# 000011001100: 0.0
# 000011001101: 0.0
# 000011001110: 0.0
# 000011001111: -4.3882735383560766e-05
# 000011010000: 0.0
# 000011010001: 0.0
# 000011010010: 0.0
# 000011010011: 0.0
# 000011010100: 0.0
# 000011010101: 0.0
# 000011010110: 0.0
# 000011010111: -0.00012868313114413905
# 000011011000: 0.0
# 000011011001: 0.0
# 000011011010: 0.0
# 000011011011: 0.00017256586652772106
# 000011011100: 0.0
# 000011011101: 0.00017256586652779175
# 000011011110: -0.00012868313114424833
# 000011011111: 0.0
# 000011100000: 0.0
# 000011100001: 0.0
# 000011100010: 0.0
# 000011100011: 0.0
# 000011100100: 0.0
# 000011100101: 0.0
# 000011100110: 0.0
# 000011100111: 0.0001725658665284388
# 000011101000: 0.0
# 000011101001: 0.0
# 000011101010: 0.0
# 000011101011: -0.00012868313114272004
# 000011101100: 0.0
# 000011101101: -0.00012868313114267407
# 000011101110: 0.00017256586652838937
# 000011101111: 0.0
# 000011110000: 0.0
# 000011110001: 0.0
# 000011110010: 0.0
# 000011110011: -4.388273538521699e-05
# 000011110100: 0.0
# 000011110101: -4.388273538519271e-05
# 000011110110: 0.0
# 000011110111: 0.0
# 000011111000: 0.0
# 000011111001: 0.0
# 000011111010: -4.3882735385240845e-05
# 000011111011: 0.0
# 000011111100: -4.388273538521656e-05
# 000011111101: 0.0
# 000011111110: 0.0
# 000011111111: 0.0
# 000100000000: 0.0
# 000100000001: 0.0
# 000100000010: 0.0
# 000100000011: 0.0
# 000100000100: 0.0
# 000100000101: 0.0
# 000100000110: 0.0
# 000100000111: 0.0
# 000100001000: 0.0
# 000100001001: 0.0
# 000100001010: 0.0
# 000100001011: 0.0
# 000100001100: 0.0
# 000100001101: 0.0
# 000100001110: 0.0
# 000100001111: 0.0
# 000100010000: 0.0
# 000100010001: 0.0
# 000100010010: 0.0
# 000100010011: 0.0
# 000100010100: 0.0
# 000100010101: 0.0
# 000100010110: 0.0
# 000100010111: 0.0
# 000100011000: 0.0
# 000100011001: 0.0
# 000100011010: 0.0
# 000100011011: 0.0
# 000100011100: 0.0
# 000100011101: 0.0
# 000100011110: 0.0
# 000100011111: 4.0321276241298346e-05
# 000100100000: 0.0
# 000100100001: 0.0
# 000100100010: 0.0
# 000100100011: 0.0
# 000100100100: 0.0
# 000100100101: 0.0
# 000100100110: 0.0
# 000100100111: 0.0
# 000100101000: 0.0
# 000100101001: 0.0
# 000100101010: 0.0
# 000100101011: 0.0
# 000100101100: 0.0
# 000100101101: 0.0
# 000100101110: 0.0
# 000100101111: 3.561459144331078e-06
# 000100110000: 0.0
# 000100110001: 0.0
# 000100110010: 0.0
# 000100110011: 0.0
# 000100110100: 0.0
# 000100110101: 0.0
# 000100110110: 0.0
# 000100110111: 0.0
# 000100111000: 0.0
# 000100111001: 0.0
# 000100111010: 0.0
# 000100111011: 0.0
# 000100111100: 0.0
# 000100111101: 0.0
# 000100111110: 0.0
# 000100111111: 0.0
# 000101000000: 0.0
# 000101000001: 0.0
# 000101000010: 0.0
# 000101000011: 0.0
# 000101000100: 0.0
# 000101000101: 0.0
# 000101000110: 0.0
# 000101000111: 0.0
# 000101001000: 0.0
# 000101001001: 0.0
# 000101001010: 0.0
# 000101001011: 0.0
# 000101001100: 0.0
# 000101001101: 0.0
# 000101001110: 0.0
# 000101001111: 3.561459144305057e-06
# 000101010000: 0.0
# 000101010001: 0.0
# 000101010010: 0.0
# 000101010011: 0.0
# 000101010100: 0.0
# 000101010101: 0.0
# 000101010110: 0.0
# 000101010111: 0.0
# 000101011000: 0.0
# 000101011001: 0.0
# 000101011010: 0.0
# 000101011011: 0.0
# 000101011100: 0.0
# 000101011101: 0.0
# 000101011110: 0.0
# 000101011111: 0.0
# 000101100000: 0.0
# 000101100001: 0.0
# 000101100010: 0.0
# 000101100011: 0.0
# 000101100100: 0.0
# 000101100101: 0.0
# 000101100110: 0.0
# 000101100111: 0.04512644314228858
# 000101101000: 0.0
# 000101101001: 0.0
# 000101101010: 0.0
# 000101101011: -0.04513000460143045
# 000101101100: 0.0
# 000101101101: -0.04513000460143029
# 000101101110: 0.04512644314228868
# 000101101111: 0.0
# 000101110000: 0.0
# 000101110001: 0.0
# 000101110010: 0.0
# 000101110011: 0.0
# 000101110100: 0.0
# 000101110101: 0.0
# 000101110110: -0.04529900900881668
# 000101110111: 0.0
# 000101111000: 0.0
# 000101111001: 0.045258687732573424
# 000101111010: 0.0
# 000101111011: 0.0
# 000101111100: 0.0
# 000101111101: 0.0
# 000101111110: 0.0
# 000101111111: 0.0
# 000110000000: 0.0
# 000110000001: 0.0
# 000110000010: 0.0
# 000110000011: 0.0
# 000110000100: 0.0
# 000110000101: 0.0
# 000110000110: 0.0
# 000110000111: 0.0
# 000110001000: 0.0
# 000110001001: 0.0
# 000110001010: 0.0
# 000110001011: 0.0
# 000110001100: 0.0
# 000110001101: 0.0
# 000110001110: 0.0
# 000110001111: 4.0321276241143955e-05
# 000110010000: 0.0
# 000110010001: 0.0
# 000110010010: 0.0
# 000110010011: 0.0
# 000110010100: 0.0
# 000110010101: 0.0
# 000110010110: 0.0
# 000110010111: -5.8979896917114166e-05
# 000110011000: 0.0
# 000110011001: 0.0
# 000110011010: 0.0
# 000110011011: 1.865862067689482e-05
# 000110011100: 0.0
# 000110011101: 1.8658620676867063e-05
# 000110011110: -5.897989691714192e-05
# 000110011111: 0.0
# 000110100000: 0.0
# 000110100001: 0.0
# 000110100010: 0.0
# 000110100011: 0.0
# 000110100100: 0.0
# 000110100101: 0.0
# 000110100110: 0.0
# 000110100111: 0.0
# 000110101000: 0.0
# 000110101001: 0.0
# 000110101010: 0.0
# 000110101011: 0.0
# 000110101100: 0.0
# 000110101101: 0.0
# 000110101110: 0.0
# 000110101111: 0.0
# 000110110000: 0.0
# 000110110001: 0.0
# 000110110010: 0.0
# 000110110011: 0.0
# 000110110100: 0.0
# 000110110101: 0.0
# 000110110110: 0.00018766302806309115
# 000110110111: 0.0
# 000110111000: 0.0
# 000110111001: -0.00019122448720578552
# 000110111010: 0.0
# 000110111011: 0.0
# 000110111100: 0.0
# 000110111101: 0.0
# 000110111110: 0.0
# 000110111111: 0.0
# 000111000000: 0.0
# 000111000001: 0.0
# 000111000010: 0.0
# 000111000011: 0.0
# 000111000100: 0.0
# 000111000101: 0.0
# 000111000110: 0.0
# 000111000111: 0.0
# 000111001000: 0.0
# 000111001001: 0.0
# 000111001010: 0.0
# 000111001011: 0.0
# 000111001100: 0.0
# 000111001101: 0.0
# 000111001110: 0.0
# 000111001111: 0.0
# 000111010000: 0.0
# 000111010001: 0.0
# 000111010010: 0.0
# 000111010011: 0.0
# 000111010100: 0.0
# 000111010101: 0.0
# 000111010110: 0.00018766302806311023
# 000111010111: 0.0
# 000111011000: 0.0
# 000111011001: -0.0001912244872059139
# 000111011010: 0.0
# 000111011011: 0.0
# 000111011100: 0.0
# 000111011101: 0.0
# 000111011110: 0.0
# 000111011111: 0.0
# 000111100000: 0.0
# 000111100001: 0.0
# 000111100010: 0.0
# 000111100011: 0.0
# 000111100100: 0.0
# 000111100101: 0.0
# 000111100110: -0.0452990090088168
# 000111100111: 0.0
# 000111101000: 0.0
# 000111101001: 0.0452586877325735
# 000111101010: 0.0
# 000111101011: 0.0
# 000111101100: 0.0
# 000111101101: 0.0
# 000111101110: 0.0
# 000111101111: 0.0
# 000111110000: 0.0
# 000111110001: -0.04506746324536911
# 000111110010: 0.04511134598075209
# 000111110011: 0.0
# 000111110100: 0.04511134598075208
# 000111110101: 0.0
# 000111110110: 0.0
# 000111110111: 0.0
# 000111111000: -0.04506746324536915
# 000111111001: 0.0
# 000111111010: 0.0
# 000111111011: 0.0
# 000111111100: 0.0
# 000111111101: 0.0
# 000111111110: 0.0
# 000111111111: 0.0
# 001000000000: 0.0
# 001000000001: 0.0
# 001000000010: 0.0
# 001000000011: 0.0
# 001000000100: 0.0
# 001000000101: 0.0
# 001000000110: 0.0
# 001000000111: 0.0
# 001000001000: 0.0
# 001000001001: 0.0
# 001000001010: 0.0
# 001000001011: 0.0
# 001000001100: 0.0
# 001000001101: 0.0
# 001000001110: 0.0
# 001000001111: 0.0
# 001000010000: 0.0
# 001000010001: 0.0
# 001000010010: 0.0
# 001000010011: 0.0
# 001000010100: 0.0
# 001000010101: 0.0
# 001000010110: 0.0
# 001000010111: 0.0
# 001000011000: 0.0
# 001000011001: 0.0
# 001000011010: 0.0
# 001000011011: 0.0
# 001000011100: 0.0
# 001000011101: 0.0
# 001000011110: 0.0
# 001000011111: 4.03212762413261e-05
# 001000100000: 0.0
# 001000100001: 0.0
# 001000100010: 0.0
# 001000100011: 0.0
# 001000100100: 0.0
# 001000100101: 0.0
# 001000100110: 0.0
# 001000100111: 0.0
# 001000101000: 0.0
# 001000101001: 0.0
# 001000101010: 0.0
# 001000101011: 0.0
# 001000101100: 0.0
# 001000101101: 0.0
# 001000101110: 0.0
# 001000101111: 3.5614591442634236e-06
# 001000110000: 0.0
# 001000110001: 0.0
# 001000110010: 0.0
# 001000110011: 0.0
# 001000110100: 0.0
# 001000110101: 0.0
# 001000110110: 0.0
# 001000110111: 0.0
# 001000111000: 0.0
# 001000111001: 0.0
# 001000111010: 0.0
# 001000111011: 0.0
# 001000111100: 0.0
# 001000111101: 0.0
# 001000111110: 0.0
# 001000111111: 0.0
# 001001000000: 0.0
# 001001000001: 0.0
# 001001000010: 0.0
# 001001000011: 0.0
# 001001000100: 0.0
# 001001000101: 0.0
# 001001000110: 0.0
# 001001000111: 0.0
# 001001001000: 0.0
# 001001001001: 0.0
# 001001001010: 0.0
# 001001001011: 0.0
# 001001001100: 0.0
# 001001001101: 0.0
# 001001001110: 0.0
# 001001001111: 3.5614591443033222e-06
# 001001010000: 0.0
# 001001010001: 0.0
# 001001010010: 0.0
# 001001010011: 0.0
# 001001010100: 0.0
# 001001010101: 0.0
# 001001010110: 0.0
# 001001010111: 0.0
# 001001011000: 0.0
# 001001011001: 0.0
# 001001011010: 0.0
# 001001011011: 0.0
# 001001011100: 0.0
# 001001011101: 0.0
# 001001011110: 0.0
# 001001011111: 0.0
# 001001100000: 0.0
# 001001100001: 0.0
# 001001100010: 0.0
# 001001100011: 0.0
# 001001100100: 0.0
# 001001100101: 0.0
# 001001100110: 0.0
# 001001100111: 0.04512644314228856
# 001001101000: 0.0
# 001001101001: 0.0
# 001001101010: 0.0
# 001001101011: -0.04513000460143033
# 001001101100: 0.0
# 001001101101: -0.04513000460143024
# 001001101110: 0.04512644314228867
# 001001101111: 0.0
# 001001110000: 0.0
# 001001110001: 0.0
# 001001110010: 0.0
# 001001110011: 0.0
# 001001110100: 0.0
# 001001110101: 0.0
# 001001110110: -0.04529900900881658
# 001001110111: 0.0
# 001001111000: 0.0
# 001001111001: 0.0452586877325735
# 001001111010: 0.0
# 001001111011: 0.0
# 001001111100: 0.0
# 001001111101: 0.0
# 001001111110: 0.0
# 001001111111: 0.0
# 001010000000: 0.0
# 001010000001: 0.0
# 001010000010: 0.0
# 001010000011: 0.0
# 001010000100: 0.0
# 001010000101: 0.0
# 001010000110: 0.0
# 001010000111: 0.0
# 001010001000: 0.0
# 001010001001: 0.0
# 001010001010: 0.0
# 001010001011: 0.0
# 001010001100: 0.0
# 001010001101: 0.0
# 001010001110: 0.0
# 001010001111: 4.032127624131569e-05
# 001010010000: 0.0
# 001010010001: 0.0
# 001010010010: 0.0
# 001010010011: 0.0
# 001010010100: 0.0
# 001010010101: 0.0
# 001010010110: 0.0
# 001010010111: -5.8979896917128044e-05
# 001010011000: 0.0
# 001010011001: 0.0
# 001010011010: 0.0
# 001010011011: 1.8658620676804613e-05
# 001010011100: 0.0
# 001010011101: 1.8658620676853185e-05
# 001010011110: -5.897989691713845e-05
# 001010011111: 0.0
# 001010100000: 0.0
# 001010100001: 0.0
# 001010100010: 0.0
# 001010100011: 0.0
# 001010100100: 0.0
# 001010100101: 0.0
# 001010100110: 0.0
# 001010100111: 0.0
# 001010101000: 0.0
# 001010101001: 0.0
# 001010101010: 0.0
# 001010101011: 0.0
# 001010101100: 0.0
# 001010101101: 0.0
# 001010101110: 0.0
# 001010101111: 0.0
# 001010110000: 0.0
# 001010110001: 0.0
# 001010110010: 0.0
# 001010110011: 0.0
# 001010110100: 0.0
# 001010110101: 0.0
# 001010110110: 0.0001876630280630929
# 001010110111: 0.0
# 001010111000: 0.0
# 001010111001: -0.0001912244872058098
# 001010111010: 0.0
# 001010111011: 0.0
# 001010111100: 0.0
# 001010111101: 0.0
# 001010111110: 0.0
# 001010111111: 0.0
# 001011000000: 0.0
# 001011000001: 0.0
# 001011000010: 0.0
# 001011000011: 0.0
# 001011000100: 0.0
# 001011000101: 0.0
# 001011000110: 0.0
# 001011000111: 0.0
# 001011001000: 0.0
# 001011001001: 0.0
# 001011001010: 0.0
# 001011001011: 0.0
# 001011001100: 0.0
# 001011001101: 0.0
# 001011001110: 0.0
# 001011001111: 0.0
# 001011010000: 0.0
# 001011010001: 0.0
# 001011010010: 0.0
# 001011010011: 0.0
# 001011010100: 0.0
# 001011010101: 0.0
# 001011010110: 0.0001876630280631432
# 001011010111: 0.0
# 001011011000: 0.0
# 001011011001: -0.00019122448720584623
# 001011011010: 0.0
# 001011011011: 0.0
# 001011011100: 0.0
# 001011011101: 0.0
# 001011011110: 0.0
# 001011011111: 0.0
# 001011100000: 0.0
# 001011100001: 0.0
# 001011100010: 0.0
# 001011100011: 0.0
# 001011100100: 0.0
# 001011100101: 0.0
# 001011100110: -0.04529900900881654
# 001011100111: 0.0
# 001011101000: 0.0
# 001011101001: 0.0452586877325734
# 001011101010: 0.0
# 001011101011: 0.0
# 001011101100: 0.0
# 001011101101: 0.0
# 001011101110: 0.0
# 001011101111: 0.0
# 001011110000: 0.0
# 001011110001: -0.04506746324536917
# 001011110010: 0.04511134598075221
# 001011110011: 0.0
# 001011110100: 0.04511134598075216
# 001011110101: 0.0
# 001011110110: 0.0
# 001011110111: 0.0
# 001011111000: -0.045067463245369054
# 001011111001: 0.0
# 001011111010: 0.0
# 001011111011: 0.0
# 001011111100: 0.0
# 001011111101: 0.0
# 001011111110: 0.0
# 001011111111: 0.0
# 001100000000: 0.0
# 001100000001: 0.0
# 001100000010: 0.0
# 001100000011: 0.0
# 001100000100: 0.0
# 001100000101: 0.0
# 001100000110: 0.0
# 001100000111: 0.0
# 001100001000: 0.0
# 001100001001: 0.0
# 001100001010: 0.0
# 001100001011: 0.0
# 001100001100: 0.0
# 001100001101: 0.0
# 001100001110: 0.0
# 001100001111: 0.0
# 001100010000: 0.0
# 001100010001: 0.0
# 001100010010: 0.0
# 001100010011: 0.0
# 001100010100: 0.0
# 001100010101: 0.0
# 001100010110: 0.0
# 001100010111: 1.8658620679979157e-05
# 001100011000: 0.0
# 001100011001: 0.0
# 001100011010: 0.0
# 001100011011: -5.8979896920639124e-05
# 001100011100: 0.0
# 001100011101: -5.897989692061484e-05
# 001100011110: 1.865862067992191e-05
# 001100011111: 0.0
# 001100100000: 0.0
# 001100100001: 0.0
# 001100100010: 0.0
# 001100100011: 0.0
# 001100100100: 0.0
# 001100100101: 0.0
# 001100100110: 0.0
# 001100100111: -0.04513000460143297
# 001100101000: 0.0
# 001100101001: 0.0
# 001100101010: 0.0
# 001100101011: 0.045126443142288794
# 001100101100: 0.0
# 001100101101: 0.04512644314228893
# 001100101110: -0.045130004601432974
# 001100101111: 0.0
# 001100110000: 0.0
# 001100110001: 0.0
# 001100110010: 0.0
# 001100110011: 0.0
# 001100110100: 0.0
# 001100110101: 0.0
# 001100110110: 0.04511134598075452
# 001100110111: 0.0
# 001100111000: 0.0
# 001100111001: -0.04506746324536902
# 001100111010: 0.0
# 001100111011: 0.0
# 001100111100: 0.0
# 001100111101: 0.0
# 001100111110: 0.0
# 001100111111: 0.0
# 001101000000: 0.0
# 001101000001: 0.0
# 001101000010: 0.0
# 001101000011: 0.0
# 001101000100: 0.0
# 001101000101: 0.0
# 001101000110: 0.0
# 001101000111: -0.045130004601432835
# 001101001000: 0.0
# 001101001001: 0.0
# 001101001010: 0.0
# 001101001011: 0.04512644314228883
# 001101001100: 0.0
# 001101001101: 0.04512644314228897
# 001101001110: -0.04513000460143293
# 001101001111: 0.0
# 001101010000: 0.0
# 001101010001: 0.0
# 001101010010: 0.0
# 001101010011: 0.0
# 001101010100: 0.0
# 001101010101: 0.0
# 001101010110: 0.045111345980754725
# 001101010111: 0.0
# 001101011000: 0.0
# 001101011001: -0.045067463245369
# 001101011010: 0.0
# 001101011011: 0.0
# 001101011100: 0.0
# 001101011101: 0.0
# 001101011110: 0.0
# 001101011111: 0.0
# 001101100000: 0.0
# 001101100001: 0.0
# 001101100010: 0.0
# 001101100011: 3.5614591429086045e-06
# 001101100100: 0.0
# 001101100101: 3.561459142979728e-06
# 001101100110: 0.0
# 001101100111: 0.0
# 001101101000: 0.0
# 001101101001: 0.0
# 001101101010: 3.5614591429086045e-06
# 001101101011: 0.0
# 001101101100: 3.5614591430022796e-06
# 001101101101: 0.0
# 001101101110: 0.0
# 001101101111: 0.0
# 001101110000: 0.0
# 001101110001: -0.00019122448720467356
# 001101110010: 0.00018766302805993396
# 001101110011: 0.0
# 001101110100: 0.00018766302805988018
# 001101110101: 0.0
# 001101110110: 0.0
# 001101110111: 0.0
# 001101111000: -0.00019122448720474815
# 001101111001: 0.0
# 001101111010: 0.0
# 001101111011: 0.0
# 001101111100: 0.0
# 001101111101: 0.0
# 001101111110: 0.0
# 001101111111: 0.0
# 001110000000: 0.0
# 001110000001: 0.0
# 001110000010: 0.0
# 001110000011: 0.0
# 001110000100: 0.0
# 001110000101: 0.0
# 001110000110: 0.0
# 001110000111: 1.8658620680005178e-05
# 001110001000: 0.0
# 001110001001: 0.0
# 001110001010: 0.0
# 001110001011: -5.897989692054892e-05
# 001110001100: 0.0
# 001110001101: -5.897989692058361e-05
# 001110001110: 1.8658620679847318e-05
# 001110001111: 0.0
# 001110010000: 0.0
# 001110010001: 0.0
# 001110010010: 0.0
# 001110010011: 4.032127624228367e-05
# 001110010100: 0.0
# 001110010101: 4.032127624232357e-05
# 001110010110: 0.0
# 001110010111: 0.0
# 001110011000: 0.0
# 001110011001: 0.0
# 001110011010: 4.03212762422802e-05
# 001110011011: 0.0
# 001110011100: 4.032127624226112e-05
# 001110011101: 0.0
# 001110011110: 0.0
# 001110011111: 0.0
# 001110100000: 0.0
# 001110100001: 0.0
# 001110100010: 0.0
# 001110100011: 0.0
# 001110100100: 0.0
# 001110100101: 0.0
# 001110100110: 0.04511134598075454
# 001110100111: 0.0
# 001110101000: 0.0
# 001110101001: -0.04506746324536905
# 001110101010: 0.0
# 001110101011: 0.0
# 001110101100: 0.0
# 001110101101: 0.0
# 001110101110: 0.0
# 001110101111: 0.0
# 001110110000: 0.0
# 001110110001: 0.04525868773257116
# 001110110010: -0.045299009008813736
# 001110110011: 0.0
# 001110110100: -0.04529900900881371
# 001110110101: 0.0
# 001110110110: 0.0
# 001110110111: 0.0
# 001110111000: 0.04525868773257109
# 001110111001: 0.0
# 001110111010: 0.0
# 001110111011: 0.0
# 001110111100: 0.0
# 001110111101: 0.0
# 001110111110: 0.0
# 001110111111: 0.0
# 001111000000: 0.0
# 001111000001: 0.0
# 001111000010: 0.0
# 001111000011: 0.0
# 001111000100: 0.0
# 001111000101: 0.0
# 001111000110: 0.045111345980754614
# 001111000111: 0.0
# 001111001000: 0.0
# 001111001001: -0.04506746324536895
# 001111001010: 0.0
# 001111001011: 0.0
# 001111001100: 0.0
# 001111001101: 0.0
# 001111001110: 0.0
# 001111001111: 0.0
# 001111010000: 0.0
# 001111010001: 0.04525868773257116
# 001111010010: -0.04529900900881387
# 001111010011: 0.0
# 001111010100: -0.04529900900881364
# 001111010101: 0.0
# 001111010110: 0.0
# 001111010111: 0.0
# 001111011000: 0.045258687732571176
# 001111011001: 0.0
# 001111011010: 0.0
# 001111011011: 0.0
# 001111011100: 0.0
# 001111011101: 0.0
# 001111011110: 0.0
# 001111011111: 0.0
# 001111100000: 0.0
# 001111100001: -0.0001912244872046224
# 001111100010: 0.0001876630280598906
# 001111100011: 0.0
# 001111100100: 0.00018766302805994783
# 001111100101: 0.0
# 001111100110: 0.0
# 001111100111: 0.0
# 001111101000: -0.00019122448720470392
# 001111101001: 0.0
# 001111101010: 0.0
# 001111101011: 0.0
# 001111101100: 0.0
# 001111101101: 0.0
# 001111101110: 0.0
# 001111101111: 0.0
# 001111110000: 0.0
# 001111110001: 0.0
# 001111110010: 0.0
# 001111110011: 0.0
# 001111110100: 0.0
# 001111110101: 0.0
# 001111110110: 0.0
# 001111110111: 0.0
# 001111111000: 0.0
# 001111111001: 0.0
# 001111111010: 0.0
# 001111111011: 0.0
# 001111111100: 0.0
# 001111111101: 0.0
# 001111111110: 0.0
# 001111111111: 0.0
# 010000000000: 0.0
# 010000000001: 0.0
# 010000000010: 0.0
# 010000000011: 0.0
# 010000000100: 0.0
# 010000000101: 0.0
# 010000000110: 0.0
# 010000000111: 0.0
# 010000001000: 0.0
# 010000001001: 0.0
# 010000001010: 0.0
# 010000001011: 0.0
# 010000001100: 0.0
# 010000001101: 0.0
# 010000001110: 0.0
# 010000001111: 0.0
# 010000010000: 0.0
# 010000010001: 0.0
# 010000010010: 0.0
# 010000010011: 0.0
# 010000010100: 0.0
# 010000010101: 0.0
# 010000010110: 0.0
# 010000010111: 0.0
# 010000011000: 0.0
# 010000011001: 0.0
# 010000011010: 0.0
# 010000011011: 0.0
# 010000011100: 0.0
# 010000011101: 0.0
# 010000011110: 0.0
# 010000011111: 3.561459142348289e-06
# 010000100000: 0.0
# 010000100001: 0.0
# 010000100010: 0.0
# 010000100011: 0.0
# 010000100100: 0.0
# 010000100101: 0.0
# 010000100110: 0.0
# 010000100111: 0.0
# 010000101000: 0.0
# 010000101001: 0.0
# 010000101010: 0.0
# 010000101011: 0.0
# 010000101100: 0.0
# 010000101101: 0.0
# 010000101110: 0.0
# 010000101111: 4.032127624198009e-05
# 010000110000: 0.0
# 010000110001: 0.0
# 010000110010: 0.0
# 010000110011: 0.0
# 010000110100: 0.0
# 010000110101: 0.0
# 010000110110: 0.0
# 010000110111: 0.0
# 010000111000: 0.0
# 010000111001: 0.0
# 010000111010: 0.0
# 010000111011: 0.0
# 010000111100: 0.0
# 010000111101: 0.0
# 010000111110: 0.0
# 010000111111: 0.0
# 010001000000: 0.0
# 010001000001: 0.0
# 010001000010: 0.0
# 010001000011: 0.0
# 010001000100: 0.0
# 010001000101: 0.0
# 010001000110: 0.0
# 010001000111: 0.0
# 010001001000: 0.0
# 010001001001: 0.0
# 010001001010: 0.0
# 010001001011: 0.0
# 010001001100: 0.0
# 010001001101: 0.0
# 010001001110: 0.0
# 010001001111: 4.0321276241999174e-05
# 010001010000: 0.0
# 010001010001: 0.0
# 010001010010: 0.0
# 010001010011: 0.0
# 010001010100: 0.0
# 010001010101: 0.0
# 010001010110: 0.0
# 010001010111: 0.0
# 010001011000: 0.0
# 010001011001: 0.0
# 010001011010: 0.0
# 010001011011: 0.0
# 010001011100: 0.0
# 010001011101: 0.0
# 010001011110: 0.0
# 010001011111: 0.0
# 010001100000: 0.0
# 010001100001: 0.0
# 010001100010: 0.0
# 010001100011: 0.0
# 010001100100: 0.0
# 010001100101: 0.0
# 010001100110: 0.0
# 010001100111: -0.04529900900881476
# 010001101000: 0.0
# 010001101001: 0.0
# 010001101010: 0.0
# 010001101011: 0.04525868773257675
# 010001101100: 0.0
# 010001101101: 0.045258687732576804
# 010001101110: -0.04529900900881467
# 010001101111: 0.0
# 010001110000: 0.0
# 010001110001: 0.0
# 010001110010: 0.0
# 010001110011: 0.0
# 010001110100: 0.0
# 010001110101: 0.0
# 010001110110: 0.04512644314228635
# 010001110111: 0.0
# 010001111000: 0.0
# 010001111001: -0.045130004601429796
# 010001111010: 0.0
# 010001111011: 0.0
# 010001111100: 0.0
# 010001111101: 0.0
# 010001111110: 0.0
# 010001111111: 0.0
# 010010000000: 0.0
# 010010000001: 0.0
# 010010000010: 0.0
# 010010000011: 0.0
# 010010000100: 0.0
# 010010000101: 0.0
# 010010000110: 0.0
# 010010000111: 0.0
# 010010001000: 0.0
# 010010001001: 0.0
# 010010001010: 0.0
# 010010001011: 0.0
# 010010001100: 0.0
# 010010001101: 0.0
# 010010001110: 0.0
# 010010001111: 3.561459142379514e-06
# 010010010000: 0.0
# 010010010001: 0.0
# 010010010010: 0.0
# 010010010011: 0.0
# 010010010100: 0.0
# 010010010101: 0.0
# 010010010110: 0.0
# 010010010111: 0.00018766302806183868
# 010010011000: 0.0
# 010010011001: 0.0
# 010010011010: 0.0
# 010010011011: -0.0001912244872055791
# 010010011100: 0.0
# 010010011101: -0.0001912244872056745
# 010010011110: 0.00018766302806184042
# 010010011111: 0.0
# 010010100000: 0.0
# 010010100001: 0.0
# 010010100010: 0.0
# 010010100011: 0.0
# 010010100100: 0.0
# 010010100101: 0.0
# 010010100110: 0.0
# 010010100111: 0.0
# 010010101000: 0.0
# 010010101001: 0.0
# 010010101010: 0.0
# 010010101011: 0.0
# 010010101100: 0.0
# 010010101101: 0.0
# 010010101110: 0.0
# 010010101111: 0.0
# 010010110000: 0.0
# 010010110001: 0.0
# 010010110010: 0.0
# 010010110011: 0.0
# 010010110100: 0.0
# 010010110101: 0.0
# 010010110110: -5.8979896919879315e-05
# 010010110111: 0.0
# 010010111000: 0.0
# 010010111001: 1.8658620676789e-05
# 010010111010: 0.0
# 010010111011: 0.0
# 010010111100: 0.0
# 010010111101: 0.0
# 010010111110: 0.0
# 010010111111: 0.0
# 010011000000: 0.0
# 010011000001: 0.0
# 010011000010: 0.0
# 010011000011: 0.0
# 010011000100: 0.0
# 010011000101: 0.0
# 010011000110: 0.0
# 010011000111: 0.0
# 010011001000: 0.0
# 010011001001: 0.0
# 010011001010: 0.0
# 010011001011: 0.0
# 010011001100: 0.0
# 010011001101: 0.0
# 010011001110: 0.0
# 010011001111: 0.0
# 010011010000: 0.0
# 010011010001: 0.0
# 010011010010: 0.0
# 010011010011: 0.0
# 010011010100: 0.0
# 010011010101: 0.0
# 010011010110: -5.8979896919827274e-05
# 010011010111: 0.0
# 010011011000: 0.0
# 010011011001: 1.8658620676709203e-05
# 010011011010: 0.0
# 010011011011: 0.0
# 010011011100: 0.0
# 010011011101: 0.0
# 010011011110: 0.0
# 010011011111: 0.0
# 010011100000: 0.0
# 010011100001: 0.0
# 010011100010: 0.0
# 010011100011: 0.0
# 010011100100: 0.0
# 010011100101: 0.0
# 010011100110: 0.045126443142286324
# 010011100111: 0.0
# 010011101000: 0.0
# 010011101001: -0.04513000460142986
# 010011101010: 0.0
# 010011101011: 0.0
# 010011101100: 0.0
# 010011101101: 0.0
# 010011101110: 0.0
# 010011101111: 0.0
# 010011110000: 0.0
# 010011110001: 0.04511134598075344
# 010011110010: -0.045067463245369116
# 010011110011: 0.0
# 010011110100: -0.04506746324536921
# 010011110101: 0.0
# 010011110110: 0.0
# 010011110111: 0.0
# 010011111000: 0.045111345980753365
# 010011111001: 0.0
# 010011111010: 0.0
# 010011111011: 0.0
# 010011111100: 0.0
# 010011111101: 0.0
# 010011111110: 0.0
# 010011111111: 0.0
# 010100000000: 0.0
# 010100000001: 0.0
# 010100000010: 0.0
# 010100000011: 0.0
# 010100000100: 0.0
# 010100000101: 0.0
# 010100000110: 0.0
# 010100000111: 0.0
# 010100001000: 0.0
# 010100001001: 0.0
# 010100001010: 0.0
# 010100001011: 0.0
# 010100001100: 0.0
# 010100001101: 0.0
# 010100001110: 0.0
# 010100001111: -4.388273538577774e-05
# 010100010000: 0.0
# 010100010001: 0.0
# 010100010010: 0.0
# 010100010011: 0.0
# 010100010100: 0.0
# 010100010101: 0.0
# 010100010110: 0.0
# 010100010111: 0.0
# 010100011000: 0.0
# 010100011001: 0.0
# 010100011010: 0.0
# 010100011011: 0.0
# 010100011100: 0.0
# 010100011101: 0.0
# 010100011110: 0.0
# 010100011111: 0.0
# 010100100000: 0.0
# 010100100001: 0.0
# 010100100010: 0.0
# 010100100011: 0.0
# 010100100100: 0.0
# 010100100101: 0.0
# 010100100110: 0.0
# 010100100111: 0.0
# 010100101000: 0.0
# 010100101001: 0.0
# 010100101010: 0.0
# 010100101011: 0.0
# 010100101100: 0.0
# 010100101101: 0.0
# 010100101110: 0.0
# 010100101111: 0.0
# 010100110000: 0.0
# 010100110001: 0.0
# 010100110010: 0.0
# 010100110011: 0.0
# 010100110100: 0.0
# 010100110101: 0.0
# 010100110110: 0.0
# 010100110111: 0.0
# 010100111000: 0.0
# 010100111001: 0.0
# 010100111010: 0.0
# 010100111011: 0.0
# 010100111100: 0.0
# 010100111101: 0.0
# 010100111110: 0.0
# 010100111111: 0.0
# 010101000000: 0.0
# 010101000001: 0.0
# 010101000010: 0.0
# 010101000011: 0.0
# 010101000100: 0.0
# 010101000101: 0.0
# 010101000110: 0.0
# 010101000111: 0.0
# 010101001000: 0.0
# 010101001001: 0.0
# 010101001010: 0.0
# 010101001011: 0.0
# 010101001100: 0.0
# 010101001101: 0.0
# 010101001110: 0.0
# 010101001111: 0.0
# 010101010000: 0.0
# 010101010001: 0.0
# 010101010010: 0.0
# 010101010011: 0.0
# 010101010100: 0.0
# 010101010101: 0.0
# 010101010110: 0.0
# 010101010111: 0.0
# 010101011000: 0.0
# 010101011001: 0.0
# 010101011010: 0.0
# 010101011011: 0.0
# 010101011100: 0.0
# 010101011101: 0.0
# 010101011110: 0.0
# 010101011111: 0.0
# 010101100000: 0.0
# 010101100001: 0.0
# 010101100010: 0.0
# 010101100011: 0.0
# 010101100100: 0.0
# 010101100101: 0.0
# 010101100110: 0.00017256586652522263
# 010101100111: 0.0
# 010101101000: 0.0
# 010101101001: -0.0001286831311407277
# 010101101010: 0.0
# 010101101011: 0.0
# 010101101100: 0.0
# 010101101101: 0.0
# 010101101110: 0.0
# 010101101111: 0.0
# 010101110000: 0.0
# 010101110001: 0.0
# 010101110010: 0.0
# 010101110011: 0.0
# 010101110100: 0.0
# 010101110101: 0.0
# 010101110110: 0.0
# 010101110111: 0.0
# 010101111000: 0.0
# 010101111001: 0.0
# 010101111010: 0.0
# 010101111011: 0.0
# 010101111100: 0.0
# 010101111101: 0.0
# 010101111110: 0.0
# 010101111111: 0.0
# 010110000000: 0.0
# 010110000001: 0.0
# 010110000010: 0.0
# 010110000011: 0.0
# 010110000100: 0.0
# 010110000101: 0.0
# 010110000110: 0.0
# 010110000111: 0.0
# 010110001000: 0.0
# 010110001001: 0.0
# 010110001010: 0.0
# 010110001011: 0.0
# 010110001100: 0.0
# 010110001101: 0.0
# 010110001110: 0.0
# 010110001111: 0.0
# 010110010000: 0.0
# 010110010001: 0.0
# 010110010010: 0.0
# 010110010011: 0.0
# 010110010100: 0.0
# 010110010101: 0.0
# 010110010110: -0.00012868313114030618
# 010110010111: 0.0
# 010110011000: 0.0
# 010110011001: 0.00017256586652547937
# 010110011010: 0.0
# 010110011011: 0.0
# 010110011100: 0.0
# 010110011101: 0.0
# 010110011110: 0.0
# 010110011111: 0.0
# 010110100000: 0.0
# 010110100001: 0.0
# 010110100010: 0.0
# 010110100011: 0.0
# 010110100100: 0.0
# 010110100101: 0.0
# 010110100110: 0.0
# 010110100111: 0.0
# 010110101000: 0.0
# 010110101001: 0.0
# 010110101010: 0.0
# 010110101011: 0.0
# 010110101100: 0.0
# 010110101101: 0.0
# 010110101110: 0.0
# 010110101111: 0.0
# 010110110000: 0.0
# 010110110001: 0.0
# 010110110010: 0.0
# 010110110011: 0.0
# 010110110100: 0.0
# 010110110101: 0.0
# 010110110110: 0.0
# 010110110111: 0.0
# 010110111000: 0.0
# 010110111001: 0.0
# 010110111010: 0.0
# 010110111011: 0.0
# 010110111100: 0.0
# 010110111101: 0.0
# 010110111110: 0.0
# 010110111111: 0.0
# 010111000000: 0.0
# 010111000001: 0.0
# 010111000010: 0.0
# 010111000011: 0.0
# 010111000100: 0.0
# 010111000101: 0.0
# 010111000110: 0.0
# 010111000111: 0.0
# 010111001000: 0.0
# 010111001001: 0.0
# 010111001010: 0.0
# 010111001011: 0.0
# 010111001100: 0.0
# 010111001101: 0.0
# 010111001110: 0.0
# 010111001111: 0.0
# 010111010000: 0.0
# 010111010001: 0.0
# 010111010010: 0.0
# 010111010011: 0.0
# 010111010100: 0.0
# 010111010101: 0.0
# 010111010110: 0.0
# 010111010111: 0.0
# 010111011000: 0.0
# 010111011001: 0.0
# 010111011010: 0.0
# 010111011011: 0.0
# 010111011100: 0.0
# 010111011101: 0.0
# 010111011110: 0.0
# 010111011111: 0.0
# 010111100000: 0.0
# 010111100001: 0.0
# 010111100010: 0.0
# 010111100011: 0.0
# 010111100100: 0.0
# 010111100101: 0.0
# 010111100110: 0.0
# 010111100111: 0.0
# 010111101000: 0.0
# 010111101001: 0.0
# 010111101010: 0.0
# 010111101011: 0.0
# 010111101100: 0.0
# 010111101101: 0.0
# 010111101110: 0.0
# 010111101111: 0.0
# 010111110000: -4.388273538544901e-05
# 010111110001: 0.0
# 010111110010: 0.0
# 010111110011: 0.0
# 010111110100: 0.0
# 010111110101: 0.0
# 010111110110: 0.0
# 010111110111: 0.0
# 010111111000: 0.0
# 010111111001: 0.0
# 010111111010: 0.0
# 010111111011: 0.0
# 010111111100: 0.0
# 010111111101: 0.0
# 010111111110: 0.0
# 010111111111: 0.0
# 011000000000: 0.0
# 011000000001: 0.0
# 011000000010: 0.0
# 011000000011: 0.0
# 011000000100: 0.0
# 011000000101: 0.0
# 011000000110: 0.0
# 011000000111: 0.0
# 011000001000: 0.0
# 011000001001: 0.0
# 011000001010: 0.0
# 011000001011: 0.0
# 011000001100: 0.0
# 011000001101: 0.0
# 011000001110: 0.0
# 011000001111: -4.3882735385815906e-05
# 011000010000: 0.0
# 011000010001: 0.0
# 011000010010: 0.0
# 011000010011: 0.0
# 011000010100: 0.0
# 011000010101: 0.0
# 011000010110: 0.0
# 011000010111: 0.0
# 011000011000: 0.0
# 011000011001: 0.0
# 011000011010: 0.0
# 011000011011: 0.0
# 011000011100: 0.0
# 011000011101: 0.0
# 011000011110: 0.0
# 011000011111: 0.0
# 011000100000: 0.0
# 011000100001: 0.0
# 011000100010: 0.0
# 011000100011: 0.0
# 011000100100: 0.0
# 011000100101: 0.0
# 011000100110: 0.0
# 011000100111: 0.0
# 011000101000: 0.0
# 011000101001: 0.0
# 011000101010: 0.0
# 011000101011: 0.0
# 011000101100: 0.0
# 011000101101: 0.0
# 011000101110: 0.0
# 011000101111: 0.0
# 011000110000: 0.0
# 011000110001: 0.0
# 011000110010: 0.0
# 011000110011: 0.0
# 011000110100: 0.0
# 011000110101: 0.0
# 011000110110: 0.0
# 011000110111: 0.0
# 011000111000: 0.0
# 011000111001: 0.0
# 011000111010: 0.0
# 011000111011: 0.0
# 011000111100: 0.0
# 011000111101: 0.0
# 011000111110: 0.0
# 011000111111: 0.0
# 011001000000: 0.0
# 011001000001: 0.0
# 011001000010: 0.0
# 011001000011: 0.0
# 011001000100: 0.0
# 011001000101: 0.0
# 011001000110: 0.0
# 011001000111: 0.0
# 011001001000: 0.0
# 011001001001: 0.0
# 011001001010: 0.0
# 011001001011: 0.0
# 011001001100: 0.0
# 011001001101: 0.0
# 011001001110: 0.0
# 011001001111: 0.0
# 011001010000: 0.0
# 011001010001: 0.0
# 011001010010: 0.0
# 011001010011: 0.0
# 011001010100: 0.0
# 011001010101: 0.0
# 011001010110: 0.0
# 011001010111: 0.0
# 011001011000: 0.0
# 011001011001: 0.0
# 011001011010: 0.0
# 011001011011: 0.0
# 011001011100: 0.0
# 011001011101: 0.0
# 011001011110: 0.0
# 011001011111: 0.0
# 011001100000: 0.0
# 011001100001: 0.0
# 011001100010: 0.0
# 011001100011: 0.0
# 011001100100: 0.0
# 011001100101: 0.0
# 011001100110: 0.00017256586652506303
# 011001100111: 0.0
# 011001101000: 0.0
# 011001101001: -0.00012868313114085175
# 011001101010: 0.0
# 011001101011: 0.0
# 011001101100: 0.0
# 011001101101: 0.0
# 011001101110: 0.0
# 011001101111: 0.0
# 011001110000: 0.0
# 011001110001: 0.0
# 011001110010: 0.0
# 011001110011: 0.0
# 011001110100: 0.0
# 011001110101: 0.0
# 011001110110: 0.0
# 011001110111: 0.0
# 011001111000: 0.0
# 011001111001: 0.0
# 011001111010: 0.0
# 011001111011: 0.0
# 011001111100: 0.0
# 011001111101: 0.0
# 011001111110: 0.0
# 011001111111: 0.0
# 011010000000: 0.0
# 011010000001: 0.0
# 011010000010: 0.0
# 011010000011: 0.0
# 011010000100: 0.0
# 011010000101: 0.0
# 011010000110: 0.0
# 011010000111: 0.0
# 011010001000: 0.0
# 011010001001: 0.0
# 011010001010: 0.0
# 011010001011: 0.0
# 011010001100: 0.0
# 011010001101: 0.0
# 011010001110: 0.0
# 011010001111: 0.0
# 011010010000: 0.0
# 011010010001: 0.0
# 011010010010: 0.0
# 011010010011: 0.0
# 011010010100: 0.0
# 011010010101: 0.0
# 011010010110: -0.00012868313114020643
# 011010010111: 0.0
# 011010011000: 0.0
# 011010011001: 0.00017256586652553184
# 011010011010: 0.0
# 011010011011: 0.0
# 011010011100: 0.0
# 011010011101: 0.0
# 011010011110: 0.0
# 011010011111: 0.0
# 011010100000: 0.0
# 011010100001: 0.0
# 011010100010: 0.0
# 011010100011: 0.0
# 011010100100: 0.0
# 011010100101: 0.0
# 011010100110: 0.0
# 011010100111: 0.0
# 011010101000: 0.0
# 011010101001: 0.0
# 011010101010: 0.0
# 011010101011: 0.0
# 011010101100: 0.0
# 011010101101: 0.0
# 011010101110: 0.0
# 011010101111: 0.0
# 011010110000: 0.0
# 011010110001: 0.0
# 011010110010: 0.0
# 011010110011: 0.0
# 011010110100: 0.0
# 011010110101: 0.0
# 011010110110: 0.0
# 011010110111: 0.0
# 011010111000: 0.0
# 011010111001: 0.0
# 011010111010: 0.0
# 011010111011: 0.0
# 011010111100: 0.0
# 011010111101: 0.0
# 011010111110: 0.0
# 011010111111: 0.0
# 011011000000: 0.0
# 011011000001: 0.0
# 011011000010: 0.0
# 011011000011: 0.0
# 011011000100: 0.0
# 011011000101: 0.0
# 011011000110: 0.0
# 011011000111: 0.0
# 011011001000: 0.0
# 011011001001: 0.0
# 011011001010: 0.0
# 011011001011: 0.0
# 011011001100: 0.0
# 011011001101: 0.0
# 011011001110: 0.0
# 011011001111: 0.0
# 011011010000: 0.0
# 011011010001: 0.0
# 011011010010: 0.0
# 011011010011: 0.0
# 011011010100: 0.0
# 011011010101: 0.0
# 011011010110: 0.0
# 011011010111: 0.0
# 011011011000: 0.0
# 011011011001: 0.0
# 011011011010: 0.0
# 011011011011: 0.0
# 011011011100: 0.0
# 011011011101: 0.0
# 011011011110: 0.0
# 011011011111: 0.0
# 011011100000: 0.0
# 011011100001: 0.0
# 011011100010: 0.0
# 011011100011: 0.0
# 011011100100: 0.0
# 011011100101: 0.0
# 011011100110: 0.0
# 011011100111: 0.0
# 011011101000: 0.0
# 011011101001: 0.0
# 011011101010: 0.0
# 011011101011: 0.0
# 011011101100: 0.0
# 011011101101: 0.0
# 011011101110: 0.0
# 011011101111: 0.0
# 011011110000: -4.388273538545075e-05
# 011011110001: 0.0
# 011011110010: 0.0
# 011011110011: 0.0
# 011011110100: 0.0
# 011011110101: 0.0
# 011011110110: 0.0
# 011011110111: 0.0
# 011011111000: 0.0
# 011011111001: 0.0
# 011011111010: 0.0
# 011011111011: 0.0
# 011011111100: 0.0
# 011011111101: 0.0
# 011011111110: 0.0
# 011011111111: 0.0
# 011100000000: 0.0
# 011100000001: 0.0
# 011100000010: 0.0
# 011100000011: 0.0
# 011100000100: 0.0
# 011100000101: 0.0
# 011100000110: 0.0
# 011100000111: 0.04511134598075276
# 011100001000: 0.0
# 011100001001: 0.0
# 011100001010: 0.0
# 011100001011: -0.045067463245369185
# 011100001100: 0.0
# 011100001101: -0.04506746324536921
# 011100001110: 0.045111345980752886
# 011100001111: 0.0
# 011100010000: 0.0
# 011100010001: 0.0
# 011100010010: 0.0
# 011100010011: 0.0
# 011100010100: 0.0
# 011100010101: 0.0
# 011100010110: -0.04513000460142927
# 011100010111: 0.0
# 011100011000: 0.0
# 011100011001: 0.045126443142286365
# 011100011010: 0.0
# 011100011011: 0.0
# 011100011100: 0.0
# 011100011101: 0.0
# 011100011110: 0.0
# 011100011111: 0.0
# 011100100000: 0.0
# 011100100001: 0.0
# 011100100010: 0.0
# 011100100011: 0.0
# 011100100100: 0.0
# 011100100101: 0.0
# 011100100110: 1.865862067648716e-05
# 011100100111: 0.0
# 011100101000: 0.0
# 011100101001: -5.89798969191542e-05
# 011100101010: 0.0
# 011100101011: 0.0
# 011100101100: 0.0
# 011100101101: 0.0
# 011100101110: 0.0
# 011100101111: 0.0
# 011100110000: 0.0
# 011100110001: 0.0
# 011100110010: 0.0
# 011100110011: 0.0
# 011100110100: 0.0
# 011100110101: 0.0
# 011100110110: 0.0
# 011100110111: 0.0
# 011100111000: 0.0
# 011100111001: 0.0
# 011100111010: 0.0
# 011100111011: 0.0
# 011100111100: 0.0
# 011100111101: 0.0
# 011100111110: 0.0
# 011100111111: 0.0
# 011101000000: 0.0
# 011101000001: 0.0
# 011101000010: 0.0
# 011101000011: 0.0
# 011101000100: 0.0
# 011101000101: 0.0
# 011101000110: 1.865862067644379e-05
# 011101000111: 0.0
# 011101001000: 0.0
# 011101001001: -5.897989691916808e-05
# 011101001010: 0.0
# 011101001011: 0.0
# 011101001100: 0.0
# 011101001101: 0.0
# 011101001110: 0.0
# 011101001111: 0.0
# 011101010000: 0.0
# 011101010001: 0.0
# 011101010010: 0.0
# 011101010011: 0.0
# 011101010100: 0.0
# 011101010101: 0.0
# 011101010110: 0.0
# 011101010111: 0.0
# 011101011000: 0.0
# 011101011001: 0.0
# 011101011010: 0.0
# 011101011011: 0.0
# 011101011100: 0.0
# 011101011101: 0.0
# 011101011110: 0.0
# 011101011111: 0.0
# 011101100000: 0.0
# 011101100001: 0.00018766302806255686
# 011101100010: -0.00019122448720586358
# 011101100011: 0.0
# 011101100100: -0.00019122448720584797
# 011101100101: 0.0
# 011101100110: 0.0
# 011101100111: 0.0
# 011101101000: 0.00018766302806261757
# 011101101001: 0.0
# 011101101010: 0.0
# 011101101011: 0.0
# 011101101100: 0.0
# 011101101101: 0.0
# 011101101110: 0.0
# 011101101111: 0.0
# 011101110000: 3.5614591427715614e-06
# 011101110001: 0.0
# 011101110010: 0.0
# 011101110011: 0.0
# 011101110100: 0.0
# 011101110101: 0.0
# 011101110110: 0.0
# 011101110111: 0.0
# 011101111000: 0.0
# 011101111001: 0.0
# 011101111010: 0.0
# 011101111011: 0.0
# 011101111100: 0.0
# 011101111101: 0.0
# 011101111110: 0.0
# 011101111111: 0.0
# 011110000000: 0.0
# 011110000001: 0.0
# 011110000010: 0.0
# 011110000011: 0.0
# 011110000100: 0.0
# 011110000101: 0.0
# 011110000110: -0.045130004601429255
# 011110000111: 0.0
# 011110001000: 0.0
# 011110001001: 0.04512644314228637
# 011110001010: 0.0
# 011110001011: 0.0
# 011110001100: 0.0
# 011110001101: 0.0
# 011110001110: 0.0
# 011110001111: 0.0
# 011110010000: 0.0
# 011110010001: -0.04529900900881548
# 011110010010: 0.045258687732577164
# 011110010011: 0.0
# 011110010100: 0.045258687732577116
# 011110010101: 0.0
# 011110010110: 0.0
# 011110010111: 0.0
# 011110011000: -0.045299009008815554
# 011110011001: 0.0
# 011110011010: 0.0
# 011110011011: 0.0
# 011110011100: 0.0
# 011110011101: 0.0
# 011110011110: 0.0
# 011110011111: 0.0
# 011110100000: 0.0
# 011110100001: 0.0
# 011110100010: 0.0
# 011110100011: 0.0
# 011110100100: 0.0
# 011110100101: 0.0
# 011110100110: 0.0
# 011110100111: 0.0
# 011110101000: 0.0
# 011110101001: 0.0
# 011110101010: 0.0
# 011110101011: 0.0
# 011110101100: 0.0
# 011110101101: 0.0
# 011110101110: 0.0
# 011110101111: 0.0
# 011110110000: 4.032127624169213e-05
# 011110110001: 0.0
# 011110110010: 0.0
# 011110110011: 0.0
# 011110110100: 0.0
# 011110110101: 0.0
# 011110110110: 0.0
# 011110110111: 0.0
# 011110111000: 0.0
# 011110111001: 0.0
# 011110111010: 0.0
# 011110111011: 0.0
# 011110111100: 0.0
# 011110111101: 0.0
# 011110111110: 0.0
# 011110111111: 0.0
# 011111000000: 0.0
# 011111000001: 0.0
# 011111000010: 0.0
# 011111000011: 0.0
# 011111000100: 0.0
# 011111000101: 0.0
# 011111000110: 0.0
# 011111000111: 0.0
# 011111001000: 0.0
# 011111001001: 0.0
# 011111001010: 0.0
# 011111001011: 0.0
# 011111001100: 0.0
# 011111001101: 0.0
# 011111001110: 0.0
# 011111001111: 0.0
# 011111010000: 4.032127624163141e-05
# 011111010001: 0.0
# 011111010010: 0.0
# 011111010011: 0.0
# 011111010100: 0.0
# 011111010101: 0.0
# 011111010110: 0.0
# 011111010111: 0.0
# 011111011000: 0.0
# 011111011001: 0.0
# 011111011010: 0.0
# 011111011011: 0.0
# 011111011100: 0.0
# 011111011101: 0.0
# 011111011110: 0.0
# 011111011111: 0.0
# 011111100000: 3.5614591426397224e-06
# 011111100001: 0.0
# 011111100010: 0.0
# 011111100011: 0.0
# 011111100100: 0.0
# 011111100101: 0.0
# 011111100110: 0.0
# 011111100111: 0.0
# 011111101000: 0.0
# 011111101001: 0.0
# 011111101010: 0.0
# 011111101011: 0.0
# 011111101100: 0.0
# 011111101101: 0.0
# 011111101110: 0.0
# 011111101111: 0.0
# 011111110000: 0.0
# 011111110001: 0.0
# 011111110010: 0.0
# 011111110011: 0.0
# 011111110100: 0.0
# 011111110101: 0.0
# 011111110110: 0.0
# 011111110111: 0.0
# 011111111000: 0.0
# 011111111001: 0.0
# 011111111010: 0.0
# 011111111011: 0.0
# 011111111100: 0.0
# 011111111101: 0.0
# 011111111110: 0.0
# 011111111111: 0.0
# 100000000000: 0.0
# 100000000001: 0.0
# 100000000010: 0.0
# 100000000011: 0.0
# 100000000100: 0.0
# 100000000101: 0.0
# 100000000110: 0.0
# 100000000111: 0.0
# 100000001000: 0.0
# 100000001001: 0.0
# 100000001010: 0.0
# 100000001011: 0.0
# 100000001100: 0.0
# 100000001101: 0.0
# 100000001110: 0.0
# 100000001111: 0.0
# 100000010000: 0.0
# 100000010001: 0.0
# 100000010010: 0.0
# 100000010011: 0.0
# 100000010100: 0.0
# 100000010101: 0.0
# 100000010110: 0.0
# 100000010111: 0.0
# 100000011000: 0.0
# 100000011001: 0.0
# 100000011010: 0.0
# 100000011011: 0.0
# 100000011100: 0.0
# 100000011101: 0.0
# 100000011110: 0.0
# 100000011111: 3.5614591423118597e-06
# 100000100000: 0.0
# 100000100001: 0.0
# 100000100010: 0.0
# 100000100011: 0.0
# 100000100100: 0.0
# 100000100101: 0.0
# 100000100110: 0.0
# 100000100111: 0.0
# 100000101000: 0.0
# 100000101001: 0.0
# 100000101010: 0.0
# 100000101011: 0.0
# 100000101100: 0.0
# 100000101101: 0.0
# 100000101110: 0.0
# 100000101111: 4.0321276242021725e-05
# 100000110000: 0.0
# 100000110001: 0.0
# 100000110010: 0.0
# 100000110011: 0.0
# 100000110100: 0.0
# 100000110101: 0.0
# 100000110110: 0.0
# 100000110111: 0.0
# 100000111000: 0.0
# 100000111001: 0.0
# 100000111010: 0.0
# 100000111011: 0.0
# 100000111100: 0.0
# 100000111101: 0.0
# 100000111110: 0.0
# 100000111111: 0.0
# 100001000000: 0.0
# 100001000001: 0.0
# 100001000010: 0.0
# 100001000011: 0.0
# 100001000100: 0.0
# 100001000101: 0.0
# 100001000110: 0.0
# 100001000111: 0.0
# 100001001000: 0.0
# 100001001001: 0.0
# 100001001010: 0.0
# 100001001011: 0.0
# 100001001100: 0.0
# 100001001101: 0.0
# 100001001110: 0.0
# 100001001111: 4.032127624204601e-05
# 100001010000: 0.0
# 100001010001: 0.0
# 100001010010: 0.0
# 100001010011: 0.0
# 100001010100: 0.0
# 100001010101: 0.0
# 100001010110: 0.0
# 100001010111: 0.0
# 100001011000: 0.0
# 100001011001: 0.0
# 100001011010: 0.0
# 100001011011: 0.0
# 100001011100: 0.0
# 100001011101: 0.0
# 100001011110: 0.0
# 100001011111: 0.0
# 100001100000: 0.0
# 100001100001: 0.0
# 100001100010: 0.0
# 100001100011: 0.0
# 100001100100: 0.0
# 100001100101: 0.0
# 100001100110: 0.0
# 100001100111: -0.04529900900881483
# 100001101000: 0.0
# 100001101001: 0.0
# 100001101010: 0.0
# 100001101011: 0.04525868773257674
# 100001101100: 0.0
# 100001101101: 0.045258687732576776
# 100001101110: -0.04529900900881477
# 100001101111: 0.0
# 100001110000: 0.0
# 100001110001: 0.0
# 100001110010: 0.0
# 100001110011: 0.0
# 100001110100: 0.0
# 100001110101: 0.0
# 100001110110: 0.04512644314228647
# 100001110111: 0.0
# 100001111000: 0.0
# 100001111001: -0.04513000460142981
# 100001111010: 0.0
# 100001111011: 0.0
# 100001111100: 0.0
# 100001111101: 0.0
# 100001111110: 0.0
# 100001111111: 0.0
# 100010000000: 0.0
# 100010000001: 0.0
# 100010000010: 0.0
# 100010000011: 0.0
# 100010000100: 0.0
# 100010000101: 0.0
# 100010000110: 0.0
# 100010000111: 0.0
# 100010001000: 0.0
# 100010001001: 0.0
# 100010001010: 0.0
# 100010001011: 0.0
# 100010001100: 0.0
# 100010001101: 0.0
# 100010001110: 0.0
# 100010001111: 3.5614591423881875e-06
# 100010010000: 0.0
# 100010010001: 0.0
# 100010010010: 0.0
# 100010010011: 0.0
# 100010010100: 0.0
# 100010010101: 0.0
# 100010010110: 0.0
# 100010010111: 0.00018766302806192195
# 100010011000: 0.0
# 100010011001: 0.0
# 100010011010: 0.0
# 100010011011: -0.00019122448720559817
# 100010011100: 0.0
# 100010011101: -0.0001912244872056502
# 100010011110: 0.00018766302806187338
# 100010011111: 0.0
# 100010100000: 0.0
# 100010100001: 0.0
# 100010100010: 0.0
# 100010100011: 0.0
# 100010100100: 0.0
# 100010100101: 0.0
# 100010100110: 0.0
# 100010100111: 0.0
# 100010101000: 0.0
# 100010101001: 0.0
# 100010101010: 0.0
# 100010101011: 0.0
# 100010101100: 0.0
# 100010101101: 0.0
# 100010101110: 0.0
# 100010101111: 0.0
# 100010110000: 0.0
# 100010110001: 0.0
# 100010110010: 0.0
# 100010110011: 0.0
# 100010110100: 0.0
# 100010110101: 0.0
# 100010110110: -5.8979896919754415e-05
# 100010110111: 0.0
# 100010111000: 0.0
# 100010111001: 1.8658620676823695e-05
# 100010111010: 0.0
# 100010111011: 0.0
# 100010111100: 0.0
# 100010111101: 0.0
# 100010111110: 0.0
# 100010111111: 0.0
# 100011000000: 0.0
# 100011000001: 0.0
# 100011000010: 0.0
# 100011000011: 0.0
# 100011000100: 0.0
# 100011000101: 0.0
# 100011000110: 0.0
# 100011000111: 0.0
# 100011001000: 0.0
# 100011001001: 0.0
# 100011001010: 0.0
# 100011001011: 0.0
# 100011001100: 0.0
# 100011001101: 0.0
# 100011001110: 0.0
# 100011001111: 0.0
# 100011010000: 0.0
# 100011010001: 0.0
# 100011010010: 0.0
# 100011010011: 0.0
# 100011010100: 0.0
# 100011010101: 0.0
# 100011010110: -5.8979896919750946e-05
# 100011010111: 0.0
# 100011011000: 0.0
# 100011011001: 1.865862067684798e-05
# 100011011010: 0.0
# 100011011011: 0.0
# 100011011100: 0.0
# 100011011101: 0.0
# 100011011110: 0.0
# 100011011111: 0.0
# 100011100000: 0.0
# 100011100001: 0.0
# 100011100010: 0.0
# 100011100011: 0.0
# 100011100100: 0.0
# 100011100101: 0.0
# 100011100110: 0.04512644314228649
# 100011100111: 0.0
# 100011101000: 0.0
# 100011101001: -0.04513000460142985
# 100011101010: 0.0
# 100011101011: 0.0
# 100011101100: 0.0
# 100011101101: 0.0
# 100011101110: 0.0
# 100011101111: 0.0
# 100011110000: 0.0
# 100011110001: 0.0451113459807535
# 100011110010: -0.045067463245369116
# 100011110011: 0.0
# 100011110100: -0.045067463245369144
# 100011110101: 0.0
# 100011110110: 0.0
# 100011110111: 0.0
# 100011111000: 0.04511134598075343
# 100011111001: 0.0
# 100011111010: 0.0
# 100011111011: 0.0
# 100011111100: 0.0
# 100011111101: 0.0
# 100011111110: 0.0
# 100011111111: 0.0
# 100100000000: 0.0
# 100100000001: 0.0
# 100100000010: 0.0
# 100100000011: 0.0
# 100100000100: 0.0
# 100100000101: 0.0
# 100100000110: 0.0
# 100100000111: 0.0
# 100100001000: 0.0
# 100100001001: 0.0
# 100100001010: 0.0
# 100100001011: 0.0
# 100100001100: 0.0
# 100100001101: 0.0
# 100100001110: 0.0
# 100100001111: -4.388273538591912e-05
# 100100010000: 0.0
# 100100010001: 0.0
# 100100010010: 0.0
# 100100010011: 0.0
# 100100010100: 0.0
# 100100010101: 0.0
# 100100010110: 0.0
# 100100010111: 0.0
# 100100011000: 0.0
# 100100011001: 0.0
# 100100011010: 0.0
# 100100011011: 0.0
# 100100011100: 0.0
# 100100011101: 0.0
# 100100011110: 0.0
# 100100011111: 0.0
# 100100100000: 0.0
# 100100100001: 0.0
# 100100100010: 0.0
# 100100100011: 0.0
# 100100100100: 0.0
# 100100100101: 0.0
# 100100100110: 0.0
# 100100100111: 0.0
# 100100101000: 0.0
# 100100101001: 0.0
# 100100101010: 0.0
# 100100101011: 0.0
# 100100101100: 0.0
# 100100101101: 0.0
# 100100101110: 0.0
# 100100101111: 0.0
# 100100110000: 0.0
# 100100110001: 0.0
# 100100110010: 0.0
# 100100110011: 0.0
# 100100110100: 0.0
# 100100110101: 0.0
# 100100110110: 0.0
# 100100110111: 0.0
# 100100111000: 0.0
# 100100111001: 0.0
# 100100111010: 0.0
# 100100111011: 0.0
# 100100111100: 0.0
# 100100111101: 0.0
# 100100111110: 0.0
# 100100111111: 0.0
# 100101000000: 0.0
# 100101000001: 0.0
# 100101000010: 0.0
# 100101000011: 0.0
# 100101000100: 0.0
# 100101000101: 0.0
# 100101000110: 0.0
# 100101000111: 0.0
# 100101001000: 0.0
# 100101001001: 0.0
# 100101001010: 0.0
# 100101001011: 0.0
# 100101001100: 0.0
# 100101001101: 0.0
# 100101001110: 0.0
# 100101001111: 0.0
# 100101010000: 0.0
# 100101010001: 0.0
# 100101010010: 0.0
# 100101010011: 0.0
# 100101010100: 0.0
# 100101010101: 0.0
# 100101010110: 0.0
# 100101010111: 0.0
# 100101011000: 0.0
# 100101011001: 0.0
# 100101011010: 0.0
# 100101011011: 0.0
# 100101011100: 0.0
# 100101011101: 0.0
# 100101011110: 0.0
# 100101011111: 0.0
# 100101100000: 0.0
# 100101100001: 0.0
# 100101100010: 0.0
# 100101100011: 0.0
# 100101100100: 0.0
# 100101100101: 0.0
# 100101100110: 0.0001725658665252582
# 100101100111: 0.0
# 100101101000: 0.0
# 100101101001: -0.00012868313114077455
# 100101101010: 0.0
# 100101101011: 0.0
# 100101101100: 0.0
# 100101101101: 0.0
# 100101101110: 0.0
# 100101101111: 0.0
# 100101110000: 0.0
# 100101110001: 0.0
# 100101110010: 0.0
# 100101110011: 0.0
# 100101110100: 0.0
# 100101110101: 0.0
# 100101110110: 0.0
# 100101110111: 0.0
# 100101111000: 0.0
# 100101111001: 0.0
# 100101111010: 0.0
# 100101111011: 0.0
# 100101111100: 0.0
# 100101111101: 0.0
# 100101111110: 0.0
# 100101111111: 0.0
# 100110000000: 0.0
# 100110000001: 0.0
# 100110000010: 0.0
# 100110000011: 0.0
# 100110000100: 0.0
# 100110000101: 0.0
# 100110000110: 0.0
# 100110000111: 0.0
# 100110001000: 0.0
# 100110001001: 0.0
# 100110001010: 0.0
# 100110001011: 0.0
# 100110001100: 0.0
# 100110001101: 0.0
# 100110001110: 0.0
# 100110001111: 0.0
# 100110010000: 0.0
# 100110010001: 0.0
# 100110010010: 0.0
# 100110010011: 0.0
# 100110010100: 0.0
# 100110010101: 0.0
# 100110010110: -0.00012868313114027235
# 100110010111: 0.0
# 100110011000: 0.0
# ...
# 110011011010: 0.0
# 110011011011: 0.0
# 110011011100: 0.0
# 110011011101: 0.0
# 110011011110: 0.0
# 110011011111: 0.0
# 110011100000: 0.0
# 110011100001: 1.8658620679940993e-05
# 110011100010: -5.897989692111444e-05
# 110011100011: 0.0
# 110011100100: -5.8979896921201175e-05
# 110011100101: 0.0
# 110011100110: 0.0
# 110011100111: 0.0
# 110011101000: 1.86586206799514e-05
# 110011101001: 0.0
# 110011101010: 0.0
# 110011101011: 0.0
# 110011101100: 0.0
# 110011101101: 0.0
# 110011101110: 0.0
# 110011101111: 0.0
# 110011110000: 0.0
# 110011110001: 0.0
# 110011110010: 0.0
# 110011110011: 0.0
# 110011110100: 0.0
# 110011110101: 0.0
# 110011110110: 0.0
# 110011110111: 0.0
# 110011111000: 0.0
# 110011111001: 0.0
# 110011111010: 0.0
# 110011111011: 0.0
# 110011111100: 0.0
# 110011111101: 0.0
# 110011111110: 0.0
# 110011111111: 0.0
# 110100000000: 0.0
# 110100000001: 0.0
# 110100000010: 0.0
# 110100000011: 0.0
# 110100000100: 0.0
# 110100000101: 0.0
# 110100000110: 0.0
# 110100000111: -0.045067463245369095
# 110100001000: 0.0
# 110100001001: 0.0
# 110100001010: 0.0
# 110100001011: 0.04511134598075186
# 110100001100: 0.0
# 110100001101: 0.0451113459807519
# 110100001110: -0.04506746324536909
# 110100001111: 0.0
# 110100010000: 0.0
# 110100010001: 0.0
# 110100010010: 0.0
# 110100010011: 0.0
# 110100010100: 0.0
# 110100010101: 0.0
# 110100010110: 0.045258687732574535
# 110100010111: 0.0
# 110100011000: 0.0
# 110100011001: -0.045299009008816886
# 110100011010: 0.0
# 110100011011: 0.0
# 110100011100: 0.0
# 110100011101: 0.0
# 110100011110: 0.0
# 110100011111: 0.0
# 110100100000: 0.0
# 110100100001: 0.0
# 110100100010: 0.0
# 110100100011: 0.0
# 110100100100: 0.0
# 110100100101: 0.0
# 110100100110: -0.00019122448720610558
# 110100100111: 0.0
# 110100101000: 0.0
# 110100101001: 0.00018766302806343463
# 110100101010: 0.0
# 110100101011: 0.0
# 110100101100: 0.0
# 110100101101: 0.0
# 110100101110: 0.0
# 110100101111: 0.0
# 110100110000: 0.0
# 110100110001: 0.0
# 110100110010: 0.0
# 110100110011: 0.0
# 110100110100: 0.0
# 110100110101: 0.0
# 110100110110: 0.0
# 110100110111: 0.0
# 110100111000: 0.0
# 110100111001: 0.0
# 110100111010: 0.0
# 110100111011: 0.0
# 110100111100: 0.0
# 110100111101: 0.0
# 110100111110: 0.0
# 110100111111: 0.0
# 110101000000: 0.0
# 110101000001: 0.0
# 110101000010: 0.0
# 110101000011: 0.0
# 110101000100: 0.0
# 110101000101: 0.0
# 110101000110: -0.0001912244872060041
# 110101000111: 0.0
# 110101001000: 0.0
# 110101001001: 0.00018766302806343463
# 110101001010: 0.0
# 110101001011: 0.0
# 110101001100: 0.0
# 110101001101: 0.0
# 110101001110: 0.0
# 110101001111: 0.0
# 110101010000: 0.0
# 110101010001: 0.0
# 110101010010: 0.0
# 110101010011: 0.0
# 110101010100: 0.0
# 110101010101: 0.0
# 110101010110: 0.0
# 110101010111: 0.0
# 110101011000: 0.0
# 110101011001: 0.0
# 110101011010: 0.0
# 110101011011: 0.0
# 110101011100: 0.0
# 110101011101: 0.0
# 110101011110: 0.0
# 110101011111: 0.0
# 110101100000: 0.0
# 110101100001: -5.897989691708641e-05
# 110101100010: 1.8658620676093376e-05
# 110101100011: 0.0
# 110101100100: 1.865862067614195e-05
# 110101100101: 0.0
# 110101100110: 0.0
# 110101100111: 0.0
# 110101101000: -5.897989691695457e-05
# 110101101001: 0.0
# 110101101010: 0.0
# 110101101011: 0.0
# 110101101100: 0.0
# 110101101101: 0.0
# 110101101110: 0.0
# 110101101111: 0.0
# 110101110000: 4.032127624109712e-05
# 110101110001: 0.0
# 110101110010: 0.0
# 110101110011: 0.0
# 110101110100: 0.0
# 110101110101: 0.0
# 110101110110: 0.0
# 110101110111: 0.0
# 110101111000: 0.0
# 110101111001: 0.0
# 110101111010: 0.0
# 110101111011: 0.0
# 110101111100: 0.0
# 110101111101: 0.0
# 110101111110: 0.0
# 110101111111: 0.0
# 110110000000: 0.0
# 110110000001: 0.0
# 110110000010: 0.0
# 110110000011: 0.0
# 110110000100: 0.0
# 110110000101: 0.0
# 110110000110: 0.045258687732574555
# 110110000111: 0.0
# 110110001000: 0.0
# 110110001001: -0.04529900900881679
# 110110001010: 0.0
# 110110001011: 0.0
# 110110001100: 0.0
# 110110001101: 0.0
# 110110001110: 0.0
# 110110001111: 0.0
# 110110010000: 0.0
# 110110010001: 0.04512644314228827
# 110110010010: -0.045130004601429616
# 110110010011: 0.0
# 110110010100: -0.04513000460142964
# 110110010101: 0.0
# 110110010110: 0.0
# 110110010111: 0.0
# 110110011000: 0.04512644314228828
# 110110011001: 0.0
# 110110011010: 0.0
# 110110011011: 0.0
# 110110011100: 0.0
# 110110011101: 0.0
# 110110011110: 0.0
# 110110011111: 0.0
# 110110100000: 0.0
# 110110100001: 0.0
# 110110100010: 0.0
# 110110100011: 0.0
# 110110100100: 0.0
# 110110100101: 0.0
# 110110100110: 0.0
# 110110100111: 0.0
# 110110101000: 0.0
# 110110101001: 0.0
# 110110101010: 0.0
# 110110101011: 0.0
# 110110101100: 0.0
# 110110101101: 0.0
# 110110101110: 0.0
# 110110101111: 0.0
# 110110110000: 3.5614591442200555e-06
# 110110110001: 0.0
# 110110110010: 0.0
# 110110110011: 0.0
# 110110110100: 0.0
# 110110110101: 0.0
# 110110110110: 0.0
# 110110110111: 0.0
# 110110111000: 0.0
# 110110111001: 0.0
# 110110111010: 0.0
# 110110111011: 0.0
# 110110111100: 0.0
# 110110111101: 0.0
# 110110111110: 0.0
# 110110111111: 0.0
# 110111000000: 0.0
# 110111000001: 0.0
# 110111000010: 0.0
# 110111000011: 0.0
# 110111000100: 0.0
# 110111000101: 0.0
# 110111000110: 0.0
# 110111000111: 0.0
# 110111001000: 0.0
# 110111001001: 0.0
# 110111001010: 0.0
# 110111001011: 0.0
# 110111001100: 0.0
# 110111001101: 0.0
# 110111001110: 0.0
# 110111001111: 0.0
# 110111010000: 3.5614591441888305e-06
# 110111010001: 0.0
# 110111010010: 0.0
# 110111010011: 0.0
# 110111010100: 0.0
# 110111010101: 0.0
# 110111010110: 0.0
# 110111010111: 0.0
# 110111011000: 0.0
# 110111011001: 0.0
# 110111011010: 0.0
# 110111011011: 0.0
# 110111011100: 0.0
# 110111011101: 0.0
# 110111011110: 0.0
# 110111011111: 0.0
# 110111100000: 4.032127624117865e-05
# 110111100001: 0.0
# 110111100010: 0.0
# 110111100011: 0.0
# 110111100100: 0.0
# 110111100101: 0.0
# 110111100110: 0.0
# 110111100111: 0.0
# 110111101000: 0.0
# 110111101001: 0.0
# 110111101010: 0.0
# 110111101011: 0.0
# 110111101100: 0.0
# 110111101101: 0.0
# 110111101110: 0.0
# 110111101111: 0.0
# 110111110000: 0.0
# 110111110001: 0.0
# 110111110010: 0.0
# 110111110011: 0.0
# 110111110100: 0.0
# 110111110101: 0.0
# 110111110110: 0.0
# 110111110111: 0.0
# 110111111000: 0.0
# 110111111001: 0.0
# 110111111010: 0.0
# 110111111011: 0.0
# 110111111100: 0.0
# 110111111101: 0.0
# 110111111110: 0.0
# 110111111111: 0.0
# 111000000000: 0.0
# 111000000001: 0.0
# 111000000010: 0.0
# 111000000011: 0.0
# 111000000100: 0.0
# 111000000101: 0.0
# 111000000110: 0.0
# 111000000111: -0.04506746324536913
# 111000001000: 0.0
# 111000001001: 0.0
# 111000001010: 0.0
# 111000001011: 0.04511134598075177
# 111000001100: 0.0
# 111000001101: 0.04511134598075187
# 111000001110: -0.04506746324536914
# 111000001111: 0.0
# 111000010000: 0.0
# 111000010001: 0.0
# 111000010010: 0.0
# 111000010011: 0.0
# 111000010100: 0.0
# 111000010101: 0.0
# 111000010110: 0.045258687732574514
# 111000010111: 0.0
# 111000011000: 0.0
# 111000011001: -0.045299009008816955
# 111000011010: 0.0
# 111000011011: 0.0
# 111000011100: 0.0
# 111000011101: 0.0
# 111000011110: 0.0
# 111000011111: 0.0
# 111000100000: 0.0
# 111000100001: 0.0
# 111000100010: 0.0
# 111000100011: 0.0
# 111000100100: 0.0
# 111000100101: 0.0
# 111000100110: -0.00019122448720604486
# 111000100111: 0.0
# 111000101000: 0.0
# 111000101001: 0.00018766302806358034
# 111000101010: 0.0
# 111000101011: 0.0
# 111000101100: 0.0
# 111000101101: 0.0
# 111000101110: 0.0
# 111000101111: 0.0
# 111000110000: 0.0
# 111000110001: 0.0
# 111000110010: 0.0
# 111000110011: 0.0
# 111000110100: 0.0
# 111000110101: 0.0
# 111000110110: 0.0
# 111000110111: 0.0
# 111000111000: 0.0
# 111000111001: 0.0
# 111000111010: 0.0
# 111000111011: 0.0
# 111000111100: 0.0
# 111000111101: 0.0
# 111000111110: 0.0
# 111000111111: 0.0
# 111001000000: 0.0
# 111001000001: 0.0
# 111001000010: 0.0
# 111001000011: 0.0
# 111001000100: 0.0
# 111001000101: 0.0
# 111001000110: -0.00019122448720589828
# 111001000111: 0.0
# 111001001000: 0.0
# 111001001001: 0.00018766302806352136
# 111001001010: 0.0
# 111001001011: 0.0
# 111001001100: 0.0
# 111001001101: 0.0
# 111001001110: 0.0
# 111001001111: 0.0
# 111001010000: 0.0
# 111001010001: 0.0
# 111001010010: 0.0
# 111001010011: 0.0
# 111001010100: 0.0
# 111001010101: 0.0
# 111001010110: 0.0
# 111001010111: 0.0
# 111001011000: 0.0
# 111001011001: 0.0
# 111001011010: 0.0
# 111001011011: 0.0
# 111001011100: 0.0
# 111001011101: 0.0
# 111001011110: 0.0
# 111001011111: 0.0
# 111001100000: 0.0
# 111001100001: -5.897989691703784e-05
# 111001100010: 1.8658620676169704e-05
# 111001100011: 0.0
# 111001100100: 1.86586206762495e-05
# 111001100101: 0.0
# 111001100110: 0.0
# 111001100111: 0.0
# 111001101000: -5.8979896917006613e-05
# 111001101001: 0.0
# 111001101010: 0.0
# 111001101011: 0.0
# 111001101100: 0.0
# 111001101101: 0.0
# 111001101110: 0.0
# 111001101111: 0.0
# 111001110000: 4.032127624106242e-05
# 111001110001: 0.0
# 111001110010: 0.0
# 111001110011: 0.0
# 111001110100: 0.0
# 111001110101: 0.0
# 111001110110: 0.0
# 111001110111: 0.0
# 111001111000: 0.0
# 111001111001: 0.0
# 111001111010: 0.0
# 111001111011: 0.0
# 111001111100: 0.0
# 111001111101: 0.0
# 111001111110: 0.0
# 111001111111: 0.0
# 111010000000: 0.0
# 111010000001: 0.0
# 111010000010: 0.0
# 111010000011: 0.0
# 111010000100: 0.0
# 111010000101: 0.0
# 111010000110: 0.045258687732574486
# 111010000111: 0.0
# 111010001000: 0.0
# 111010001001: -0.04529900900881688
# 111010001010: 0.0
# 111010001011: 0.0
# 111010001100: 0.0
# 111010001101: 0.0
# 111010001110: 0.0
# 111010001111: 0.0
# 111010010000: 0.0
# 111010010001: 0.045126443142288204
# 111010010010: -0.0451300046014297
# 111010010011: 0.0
# 111010010100: -0.04513000460142971
# 111010010101: 0.0
# 111010010110: 0.0
# 111010010111: 0.0
# 111010011000: 0.04512644314228821
# 111010011001: 0.0
# 111010011010: 0.0
# 111010011011: 0.0
# 111010011100: 0.0
# 111010011101: 0.0
# 111010011110: 0.0
# 111010011111: 0.0
# 111010100000: 0.0
# 111010100001: 0.0
# 111010100010: 0.0
# 111010100011: 0.0
# 111010100100: 0.0
# 111010100101: 0.0
# 111010100110: 0.0
# 111010100111: 0.0
# 111010101000: 0.0
# 111010101001: 0.0
# 111010101010: 0.0
# 111010101011: 0.0
# 111010101100: 0.0
# 111010101101: 0.0
# 111010101110: 0.0
# 111010101111: 0.0
# 111010110000: 3.5614591443172e-06
# 111010110001: 0.0
# 111010110010: 0.0
# 111010110011: 0.0
# 111010110100: 0.0
# 111010110101: 0.0
# 111010110110: 0.0
# 111010110111: 0.0
# 111010111000: 0.0
# 111010111001: 0.0
# 111010111010: 0.0
# 111010111011: 0.0
# 111010111100: 0.0
# 111010111101: 0.0
# 111010111110: 0.0
# 111010111111: 0.0
# 111011000000: 0.0
# 111011000001: 0.0
# 111011000010: 0.0
# 111011000011: 0.0
# 111011000100: 0.0
# 111011000101: 0.0
# 111011000110: 0.0
# 111011000111: 0.0
# 111011001000: 0.0
# 111011001001: 0.0
# 111011001010: 0.0
# 111011001011: 0.0
# 111011001100: 0.0
# 111011001101: 0.0
# 111011001110: 0.0
# 111011001111: 0.0
# 111011010000: 3.561459144341486e-06
# 111011010001: 0.0
# 111011010010: 0.0
# 111011010011: 0.0
# 111011010100: 0.0
# 111011010101: 0.0
# 111011010110: 0.0
# 111011010111: 0.0
# 111011011000: 0.0
# 111011011001: 0.0
# 111011011010: 0.0
# 111011011011: 0.0
# 111011011100: 0.0
# 111011011101: 0.0
# 111011011110: 0.0
# 111011011111: 0.0
# 111011100000: 4.032127624113875e-05
# 111011100001: 0.0
# 111011100010: 0.0
# 111011100011: 0.0
# 111011100100: 0.0
# 111011100101: 0.0
# 111011100110: 0.0
# 111011100111: 0.0
# 111011101000: 0.0
# 111011101001: 0.0
# 111011101010: 0.0
# 111011101011: 0.0
# 111011101100: 0.0
# 111011101101: 0.0
# 111011101110: 0.0
# 111011101111: 0.0
# 111011110000: 0.0
# 111011110001: 0.0
# 111011110010: 0.0
# 111011110011: 0.0
# 111011110100: 0.0
# 111011110101: 0.0
# 111011110110: 0.0
# 111011110111: 0.0
# 111011111000: 0.0
# 111011111001: 0.0
# 111011111010: 0.0
# 111011111011: 0.0
# 111011111100: 0.0
# 111011111101: 0.0
# 111011111110: 0.0
# 111011111111: 0.0
# 111100000000: 0.0
# 111100000001: 0.0
# 111100000010: 0.0
# 111100000011: -4.388273538560514e-05
# 111100000100: 0.0
# 111100000101: -4.388273538563506e-05
# 111100000110: 0.0
# 111100000111: 0.0
# 111100001000: 0.0
# 111100001001: 0.0
# 111100001010: -4.3882735385606005e-05
# 111100001011: 0.0
# 111100001100: -4.388273538564677e-05
# 111100001101: 0.0
# 111100001110: 0.0
# 111100001111: 0.0
# 111100010000: 0.0
# 111100010001: 0.00017256586652805413
# 111100010010: -0.0001286831311418709
# 111100010011: 0.0
# 111100010100: -0.000128683131141929
# 111100010101: 0.0
# 111100010110: 0.0
# 111100010111: 0.0
# 111100011000: 0.00017256586652817643
# 111100011001: 0.0
# 111100011010: 0.0
# 111100011011: 0.0
# 111100011100: 0.0
# 111100011101: 0.0
# 111100011110: 0.0
# 111100011111: 0.0
# 111100100000: 0.0
# 111100100001: -0.00012868313114379817
# 111100100010: 0.00017256586652728825
# 111100100011: 0.0
# 111100100100: 0.00017256586652738236
# 111100100101: 0.0
# 111100100110: 0.0
# 111100100111: 0.0
# 111100101000: -0.0001286831311438025
# 111100101001: 0.0
# 111100101010: 0.0
# 111100101011: 0.0
# 111100101100: 0.0
# 111100101101: 0.0
# 111100101110: 0.0
# 111100101111: 0.0
# 111100110000: -4.388273538346449e-05
# 111100110001: 0.0
# 111100110010: 0.0
# 111100110011: 0.0
# 111100110100: 0.0
# 111100110101: 0.0
# 111100110110: 0.0
# 111100110111: 0.0
# 111100111000: 0.0
# 111100111001: 0.0
# 111100111010: 0.0
# 111100111011: 0.0
# 111100111100: 0.0
# 111100111101: 0.0
# 111100111110: 0.0
# 111100111111: 0.0
# 111101000000: 0.0
# 111101000001: -0.00012868313114381118
# 111101000010: 0.00017256586652730646
# 111101000011: 0.0
# 111101000100: 0.00017256586652742876
# 111101000101: 0.0
# 111101000110: 0.0
# 111101000111: 0.0
# 111101001000: -0.00012868313114384154
# 111101001001: 0.0
# 111101001010: 0.0
# 111101001011: 0.0
# 111101001100: 0.0
# 111101001101: 0.0
# 111101001110: 0.0
# 111101001111: 0.0
# 111101010000: -4.3882735383431095e-05
# 111101010001: 0.0
# 111101010010: 0.0
# 111101010011: 0.0
# 111101010100: 0.0
# 111101010101: 0.0
# 111101010110: 0.0
# 111101010111: 0.0
# 111101011000: 0.0
# 111101011001: 0.0
# 111101011010: 0.0
# 111101011011: 0.0
# 111101011100: 0.0
# 111101011101: 0.0
# 111101011110: 0.0
# 111101011111: 0.0
# 111101100000: 0.0
# 111101100001: 0.0
# 111101100010: 0.0
# 111101100011: 0.0
# 111101100100: 0.0
# 111101100101: 0.0
# 111101100110: 0.0
# 111101100111: 0.0
# 111101101000: 0.0
# 111101101001: 0.0
# 111101101010: 0.0
# 111101101011: 0.0
# 111101101100: 0.0
# 111101101101: 0.0
# 111101101110: 0.0
# 111101101111: 0.0
# 111101110000: 0.0
# 111101110001: 0.0
# 111101110010: 0.0
# 111101110011: 0.0
# 111101110100: 0.0
# 111101110101: 0.0
# 111101110110: 0.0
# 111101110111: 0.0
# 111101111000: 0.0
# 111101111001: 0.0
# 111101111010: 0.0
# 111101111011: 0.0
# 111101111100: 0.0
# 111101111101: 0.0
# 111101111110: 0.0
# 111101111111: 0.0
# 111110000000: 0.0
# 111110000001: 0.00017256586652811354
# 111110000010: -0.00012868313114196197
# 111110000011: 0.0
# 111110000100: -0.00012868313114198972
# 111110000101: 0.0
# 111110000110: 0.0
# 111110000111: 0.0
# 111110001000: 0.00017256586652817122
# 111110001001: 0.0
# 111110001010: 0.0
# 111110001011: 0.0
# 111110001100: 0.0
# 111110001101: 0.0
# 111110001110: 0.0
# 111110001111: 0.0
# 111110010000: 0.0
# 111110010001: 0.0
# 111110010010: 0.0
# 111110010011: 0.0
# 111110010100: 0.0
# 111110010101: 0.0
# 111110010110: 0.0
# 111110010111: 0.0
# 111110011000: 0.0
# 111110011001: 0.0
# 111110011010: 0.0
# 111110011011: 0.0
# 111110011100: 0.0
# 111110011101: 0.0
# 111110011110: 0.0
# 111110011111: 0.0
# 111110100000: -4.388273538338903e-05
# 111110100001: 0.0
# 111110100010: 0.0
# 111110100011: 0.0
# 111110100100: 0.0
# 111110100101: 0.0
# 111110100110: 0.0
# 111110100111: 0.0
# 111110101000: 0.0
# 111110101001: 0.0
# 111110101010: 0.0
# 111110101011: 0.0
# 111110101100: 0.0
# 111110101101: 0.0
# 111110101110: 0.0
# 111110101111: 0.0
# 111110110000: 0.0
# 111110110001: 0.0
# 111110110010: 0.0
# 111110110011: 0.0
# 111110110100: 0.0
# 111110110101: 0.0
# 111110110110: 0.0
# 111110110111: 0.0
# 111110111000: 0.0
# 111110111001: 0.0
# 111110111010: 0.0
# 111110111011: 0.0
# 111110111100: 0.0
# 111110111101: 0.0
# 111110111110: 0.0
# 111110111111: 0.0
# 111111000000: -4.3882735383400304e-05
# 111111000001: 0.0
# 111111000010: 0.0
# 111111000011: 0.0
# 111111000100: 0.0
# 111111000101: 0.0
# 111111000110: 0.0
# 111111000111: 0.0
# 111111001000: 0.0
# 111111001001: 0.0
# 111111001010: 0.0
# 111111001011: 0.0
# 111111001100: 0.0
# 111111001101: 0.0
# 111111001110: 0.0
# 111111001111: 0.0
# 111111010000: 0.0
# 111111010001: 0.0
# 111111010010: 0.0
# 111111010011: 0.0
# 111111010100: 0.0
# 111111010101: 0.0
# 111111010110: 0.0
# 111111010111: 0.0
# 111111011000: 0.0
# 111111011001: 0.0
# 111111011010: 0.0
# 111111011011: 0.0
# 111111011100: 0.0
# 111111011101: 0.0
# 111111011110: 0.0
# 111111011111: 0.0
# 111111100000: 0.0
# 111111100001: 0.0
# 111111100010: 0.0
# 111111100011: 0.0
# 111111100100: 0.0
# 111111100101: 0.0
# 111111100110: 0.0
# 111111100111: 0.0
# 111111101000: 0.0
# 111111101001: 0.0
# 111111101010: 0.0
# 111111101011: 0.0
# 111111101100: 0.0
# 111111101101: 0.0
# 111111101110: 0.0
# 111111101111: 0.0
# 111111110000: 0.0
# 111111110001: 0.0
# 111111110010: 0.0
# 111111110011: 0.0
# 111111110100: 0.0
# 111111110101: 0.0
# 111111110110: 0.0
# 111111110111: 0.0
# 111111111000: 0.0
# 111111111001: 0.0
# 111111111010: 0.0
# 111111111011: 0.0
# 111111111100: 0.0
# 111111111101: 0.0
# 111111111110: 0.0
# 111111111111: 0.0
# Total Non-Zero Components in min_scar: 360
# ==================================================

# %%
# check if other states have 360 non-zero components - it's only the 5 scars!

# Count distinct non_zero_count values
distinct_counts = set()

# Counter to track occurrences of each non_zero_count
non_zero_count_occurrences = Counter()

# Iterate over all eigenvectors
for i in range(eigenvectors.shape[1]):
    eigenvector = eigenvectors[:, i]
    non_zero_count = 0  # Counter for non-zero components
    
    # Count non-zero components
    for component in eigenvector:
        if np.abs(component) >= 1e-12:
            non_zero_count += 1
    
    # Update the counter
    non_zero_count_occurrences[non_zero_count] += 1
    print(f"Total Non-Zero Components in Eigenvector {i}: {non_zero_count}")

# Print the number of distinct non_zero_count values
print(f"Number of distinct non_zero_count values: {len(non_zero_count_occurrences)}")
print(f"Distinct non_zero_count values: {sorted(non_zero_count_occurrences.keys())}")

# Print how many times each distinct non_zero_count appears
print("Occurrences of each non_zero_count:")
for count, occurrences in sorted(non_zero_count_occurrences.items()):
    print(f"Non-Zero Count: {count}, Occurrences: {occurrences}")
# Out:
# Total Non-Zero Components in Eigenvector 0: 2280
# Total Non-Zero Components in Eigenvector 1: 2115
# Total Non-Zero Components in Eigenvector 2: 2048
# Total Non-Zero Components in Eigenvector 3: 2048
# Total Non-Zero Components in Eigenvector 4: 2048
# Total Non-Zero Components in Eigenvector 5: 2048
# Total Non-Zero Components in Eigenvector 6: 2048
# Total Non-Zero Components in Eigenvector 7: 2048
# Total Non-Zero Components in Eigenvector 8: 2048
# Total Non-Zero Components in Eigenvector 9: 2048
# Total Non-Zero Components in Eigenvector 10: 1984
# Total Non-Zero Components in Eigenvector 11: 1984
# Total Non-Zero Components in Eigenvector 12: 1984
# Total Non-Zero Components in Eigenvector 13: 1984
# Total Non-Zero Components in Eigenvector 14: 1984
# Total Non-Zero Components in Eigenvector 15: 1984
# Total Non-Zero Components in Eigenvector 16: 2048
# Total Non-Zero Components in Eigenvector 17: 2048
# Total Non-Zero Components in Eigenvector 18: 2048
# Total Non-Zero Components in Eigenvector 19: 2048
# Total Non-Zero Components in Eigenvector 20: 2048
# Total Non-Zero Components in Eigenvector 21: 1982
# Total Non-Zero Components in Eigenvector 22: 1982
# Total Non-Zero Components in Eigenvector 23: 1982
# Total Non-Zero Components in Eigenvector 24: 1982
# Total Non-Zero Components in Eigenvector 25: 1982
# Total Non-Zero Components in Eigenvector 26: 2048
# Total Non-Zero Components in Eigenvector 27: 2048
# Total Non-Zero Components in Eigenvector 28: 2048
# Total Non-Zero Components in Eigenvector 29: 2048
# Total Non-Zero Components in Eigenvector 30: 2048
# Total Non-Zero Components in Eigenvector 31: 2048
# Total Non-Zero Components in Eigenvector 32: 2048
# Total Non-Zero Components in Eigenvector 33: 2048
# Total Non-Zero Components in Eigenvector 34: 2048
# Total Non-Zero Components in Eigenvector 35: 2048
# Total Non-Zero Components in Eigenvector 36: 2048
# Total Non-Zero Components in Eigenvector 37: 2048
# Total Non-Zero Components in Eigenvector 38: 2048
# Total Non-Zero Components in Eigenvector 39: 1984
# Total Non-Zero Components in Eigenvector 40: 1984
# Total Non-Zero Components in Eigenvector 41: 1984
# Total Non-Zero Components in Eigenvector 42: 1984
# Total Non-Zero Components in Eigenvector 43: 1984
# Total Non-Zero Components in Eigenvector 44: 1984
# Total Non-Zero Components in Eigenvector 45: 1982
# Total Non-Zero Components in Eigenvector 46: 1982
# Total Non-Zero Components in Eigenvector 47: 1982
# Total Non-Zero Components in Eigenvector 48: 1982
# Total Non-Zero Components in Eigenvector 49: 1982
# Total Non-Zero Components in Eigenvector 50: 1984
# Total Non-Zero Components in Eigenvector 51: 1984
# Total Non-Zero Components in Eigenvector 52: 1984
# Total Non-Zero Components in Eigenvector 53: 1984
# Total Non-Zero Components in Eigenvector 54: 1984
# Total Non-Zero Components in Eigenvector 55: 1984
# Total Non-Zero Components in Eigenvector 56: 1984
# Total Non-Zero Components in Eigenvector 57: 1984
# Total Non-Zero Components in Eigenvector 58: 1984
# Total Non-Zero Components in Eigenvector 59: 1984
# Total Non-Zero Components in Eigenvector 60: 1984
# Total Non-Zero Components in Eigenvector 61: 1984
# Total Non-Zero Components in Eigenvector 62: 1984
# Total Non-Zero Components in Eigenvector 63: 1984
# Total Non-Zero Components in Eigenvector 64: 1984
# Total Non-Zero Components in Eigenvector 65: 1664
# Total Non-Zero Components in Eigenvector 66: 1664
# Total Non-Zero Components in Eigenvector 67: 1664
# Total Non-Zero Components in Eigenvector 68: 1664
# Total Non-Zero Components in Eigenvector 69: 1664
# Total Non-Zero Components in Eigenvector 70: 1664
# Total Non-Zero Components in Eigenvector 71: 1664
# Total Non-Zero Components in Eigenvector 72: 1664
# Total Non-Zero Components in Eigenvector 73: 1664
# Total Non-Zero Components in Eigenvector 74: 1664
# Total Non-Zero Components in Eigenvector 75: 1664
# Total Non-Zero Components in Eigenvector 76: 1664
# Total Non-Zero Components in Eigenvector 77: 1664
# Total Non-Zero Components in Eigenvector 78: 1664
# Total Non-Zero Components in Eigenvector 79: 1664
# Total Non-Zero Components in Eigenvector 80: 1920
# Total Non-Zero Components in Eigenvector 81: 1920
# Total Non-Zero Components in Eigenvector 82: 1920
# Total Non-Zero Components in Eigenvector 83: 1920
# Total Non-Zero Components in Eigenvector 84: 1920
# Total Non-Zero Components in Eigenvector 85: 1920
# Total Non-Zero Components in Eigenvector 86: 1920
# Total Non-Zero Components in Eigenvector 87: 1920
# Total Non-Zero Components in Eigenvector 88: 1920
# Total Non-Zero Components in Eigenvector 89: 1920
# Total Non-Zero Components in Eigenvector 90: 1920
# Total Non-Zero Components in Eigenvector 91: 1920
# Total Non-Zero Components in Eigenvector 92: 1920
# Total Non-Zero Components in Eigenvector 93: 1920
# Total Non-Zero Components in Eigenvector 94: 1920
# Total Non-Zero Components in Eigenvector 95: 1920
# Total Non-Zero Components in Eigenvector 96: 1920
# Total Non-Zero Components in Eigenvector 97: 1920
# Total Non-Zero Components in Eigenvector 98: 1920
# Total Non-Zero Components in Eigenvector 99: 1920
# Total Non-Zero Components in Eigenvector 100: 1920
# Total Non-Zero Components in Eigenvector 101: 1920
# Total Non-Zero Components in Eigenvector 102: 1920
# Total Non-Zero Components in Eigenvector 103: 1920
# Total Non-Zero Components in Eigenvector 104: 2024
# Total Non-Zero Components in Eigenvector 105: 2024
# Total Non-Zero Components in Eigenvector 106: 2024
# Total Non-Zero Components in Eigenvector 107: 2024
# Total Non-Zero Components in Eigenvector 108: 2024
# Total Non-Zero Components in Eigenvector 109: 2024
# Total Non-Zero Components in Eigenvector 110: 2024
# Total Non-Zero Components in Eigenvector 111: 2024
# Total Non-Zero Components in Eigenvector 112: 2024
# Total Non-Zero Components in Eigenvector 113: 2024
# Total Non-Zero Components in Eigenvector 114: 2024
# Total Non-Zero Components in Eigenvector 115: 2024
# Total Non-Zero Components in Eigenvector 116: 2024
# Total Non-Zero Components in Eigenvector 117: 2024
# Total Non-Zero Components in Eigenvector 118: 2024
# Total Non-Zero Components in Eigenvector 119: 2024
# Total Non-Zero Components in Eigenvector 120: 2024
# Total Non-Zero Components in Eigenvector 121: 2024
# Total Non-Zero Components in Eigenvector 122: 2024
# Total Non-Zero Components in Eigenvector 123: 2024
# Total Non-Zero Components in Eigenvector 124: 2024
# Total Non-Zero Components in Eigenvector 125: 2024
# Total Non-Zero Components in Eigenvector 126: 2024
# Total Non-Zero Components in Eigenvector 127: 2024
# Total Non-Zero Components in Eigenvector 128: 1970
# Total Non-Zero Components in Eigenvector 129: 1970
# Total Non-Zero Components in Eigenvector 130: 1970
# Total Non-Zero Components in Eigenvector 131: 1970
# Total Non-Zero Components in Eigenvector 132: 1970
# Total Non-Zero Components in Eigenvector 133: 1970
# Total Non-Zero Components in Eigenvector 134: 1970
# Total Non-Zero Components in Eigenvector 135: 1970
# Total Non-Zero Components in Eigenvector 136: 1970
# Total Non-Zero Components in Eigenvector 137: 1640
# Total Non-Zero Components in Eigenvector 138: 1640
# Total Non-Zero Components in Eigenvector 139: 1640
# Total Non-Zero Components in Eigenvector 140: 1640
# Total Non-Zero Components in Eigenvector 141: 1640
# Total Non-Zero Components in Eigenvector 142: 1640
# Total Non-Zero Components in Eigenvector 143: 1640
# Total Non-Zero Components in Eigenvector 144: 1640
# Total Non-Zero Components in Eigenvector 145: 1640
# Total Non-Zero Components in Eigenvector 146: 2048
# Total Non-Zero Components in Eigenvector 147: 1982
# Total Non-Zero Components in Eigenvector 148: 1982
# Total Non-Zero Components in Eigenvector 149: 1982
# Total Non-Zero Components in Eigenvector 150: 1982
# Total Non-Zero Components in Eigenvector 151: 1982
# Total Non-Zero Components in Eigenvector 152: 2048
# Total Non-Zero Components in Eigenvector 153: 2048
# Total Non-Zero Components in Eigenvector 154: 2048
# Total Non-Zero Components in Eigenvector 155: 2048
# Total Non-Zero Components in Eigenvector 156: 2048
# Total Non-Zero Components in Eigenvector 157: 2048
# Total Non-Zero Components in Eigenvector 158: 2048
# Total Non-Zero Components in Eigenvector 159: 2048
# Total Non-Zero Components in Eigenvector 160: 2048
# Total Non-Zero Components in Eigenvector 161: 2048
# Total Non-Zero Components in Eigenvector 162: 2048
# Total Non-Zero Components in Eigenvector 163: 2048
# Total Non-Zero Components in Eigenvector 164: 2048
# Total Non-Zero Components in Eigenvector 165: 2048
# Total Non-Zero Components in Eigenvector 166: 2048
# Total Non-Zero Components in Eigenvector 167: 2048
# Total Non-Zero Components in Eigenvector 168: 2048
# Total Non-Zero Components in Eigenvector 169: 2048
# Total Non-Zero Components in Eigenvector 170: 1984
# Total Non-Zero Components in Eigenvector 171: 1984
# Total Non-Zero Components in Eigenvector 172: 1984
# Total Non-Zero Components in Eigenvector 173: 1984
# Total Non-Zero Components in Eigenvector 174: 1984
# Total Non-Zero Components in Eigenvector 175: 1984
# Total Non-Zero Components in Eigenvector 176: 1984
# Total Non-Zero Components in Eigenvector 177: 1984
# Total Non-Zero Components in Eigenvector 178: 1984
# Total Non-Zero Components in Eigenvector 179: 1984
# Total Non-Zero Components in Eigenvector 180: 1984
# Total Non-Zero Components in Eigenvector 181: 1984
# Total Non-Zero Components in Eigenvector 182: 1984
# Total Non-Zero Components in Eigenvector 183: 1984
# Total Non-Zero Components in Eigenvector 184: 1984
# Total Non-Zero Components in Eigenvector 185: 1920
# Total Non-Zero Components in Eigenvector 186: 1920
# Total Non-Zero Components in Eigenvector 187: 1920
# Total Non-Zero Components in Eigenvector 188: 1920
# Total Non-Zero Components in Eigenvector 189: 1920
# Total Non-Zero Components in Eigenvector 190: 1920
# Total Non-Zero Components in Eigenvector 191: 1920
# Total Non-Zero Components in Eigenvector 192: 1920
# Total Non-Zero Components in Eigenvector 193: 1920
# Total Non-Zero Components in Eigenvector 194: 1920
# Total Non-Zero Components in Eigenvector 195: 1920
# Total Non-Zero Components in Eigenvector 196: 1920
# Total Non-Zero Components in Eigenvector 197: 1920
# Total Non-Zero Components in Eigenvector 198: 1920
# Total Non-Zero Components in Eigenvector 199: 1920
# Total Non-Zero Components in Eigenvector 200: 1920
# Total Non-Zero Components in Eigenvector 201: 1920
# Total Non-Zero Components in Eigenvector 202: 1920
# Total Non-Zero Components in Eigenvector 203: 1920
# Total Non-Zero Components in Eigenvector 204: 1920
# Total Non-Zero Components in Eigenvector 205: 1920
# Total Non-Zero Components in Eigenvector 206: 1920
# Total Non-Zero Components in Eigenvector 207: 1920
# Total Non-Zero Components in Eigenvector 208: 1920
# Total Non-Zero Components in Eigenvector 209: 1982
# Total Non-Zero Components in Eigenvector 210: 1982
# Total Non-Zero Components in Eigenvector 211: 1982
# Total Non-Zero Components in Eigenvector 212: 1982
# Total Non-Zero Components in Eigenvector 213: 1982
# Total Non-Zero Components in Eigenvector 214: 1664
# Total Non-Zero Components in Eigenvector 215: 1664
# Total Non-Zero Components in Eigenvector 216: 1664
# Total Non-Zero Components in Eigenvector 217: 1664
# Total Non-Zero Components in Eigenvector 218: 1664
# Total Non-Zero Components in Eigenvector 219: 1664
# Total Non-Zero Components in Eigenvector 220: 1664
# Total Non-Zero Components in Eigenvector 221: 1664
# Total Non-Zero Components in Eigenvector 222: 1664
# Total Non-Zero Components in Eigenvector 223: 1664
# Total Non-Zero Components in Eigenvector 224: 1664
# Total Non-Zero Components in Eigenvector 225: 1664
# Total Non-Zero Components in Eigenvector 226: 1664
# Total Non-Zero Components in Eigenvector 227: 1664
# Total Non-Zero Components in Eigenvector 228: 1664
# Total Non-Zero Components in Eigenvector 229: 1664
# Total Non-Zero Components in Eigenvector 230: 1664
# Total Non-Zero Components in Eigenvector 231: 1664
# Total Non-Zero Components in Eigenvector 232: 1664
# Total Non-Zero Components in Eigenvector 233: 1664
# Total Non-Zero Components in Eigenvector 234: 2048
# Total Non-Zero Components in Eigenvector 235: 1970
# Total Non-Zero Components in Eigenvector 236: 1970
# Total Non-Zero Components in Eigenvector 237: 1970
# Total Non-Zero Components in Eigenvector 238: 1970
# Total Non-Zero Components in Eigenvector 239: 1970
# Total Non-Zero Components in Eigenvector 240: 1970
# Total Non-Zero Components in Eigenvector 241: 1970
# Total Non-Zero Components in Eigenvector 242: 1970
# Total Non-Zero Components in Eigenvector 243: 1970
# Total Non-Zero Components in Eigenvector 244: 1664
# Total Non-Zero Components in Eigenvector 245: 1664
# Total Non-Zero Components in Eigenvector 246: 1664
# Total Non-Zero Components in Eigenvector 247: 1664
# Total Non-Zero Components in Eigenvector 248: 1664
# Total Non-Zero Components in Eigenvector 249: 1664
# Total Non-Zero Components in Eigenvector 250: 1664
# Total Non-Zero Components in Eigenvector 251: 1664
# Total Non-Zero Components in Eigenvector 252: 1664
# Total Non-Zero Components in Eigenvector 253: 1664
# Total Non-Zero Components in Eigenvector 254: 1664
# Total Non-Zero Components in Eigenvector 255: 1664
# Total Non-Zero Components in Eigenvector 256: 1664
# Total Non-Zero Components in Eigenvector 257: 1664
# Total Non-Zero Components in Eigenvector 258: 1664
# Total Non-Zero Components in Eigenvector 259: 1664
# Total Non-Zero Components in Eigenvector 260: 1664
# Total Non-Zero Components in Eigenvector 261: 1664
# Total Non-Zero Components in Eigenvector 262: 1664
# Total Non-Zero Components in Eigenvector 263: 1664
# Total Non-Zero Components in Eigenvector 264: 1664
# Total Non-Zero Components in Eigenvector 265: 1664
# Total Non-Zero Components in Eigenvector 266: 1664
# Total Non-Zero Components in Eigenvector 267: 1664
# Total Non-Zero Components in Eigenvector 268: 1664
# Total Non-Zero Components in Eigenvector 269: 1664
# Total Non-Zero Components in Eigenvector 270: 1664
# Total Non-Zero Components in Eigenvector 271: 1664
# Total Non-Zero Components in Eigenvector 272: 1664
# Total Non-Zero Components in Eigenvector 273: 1664
# Total Non-Zero Components in Eigenvector 274: 1664
# Total Non-Zero Components in Eigenvector 275: 1664
# Total Non-Zero Components in Eigenvector 276: 1664
# Total Non-Zero Components in Eigenvector 277: 1664
# Total Non-Zero Components in Eigenvector 278: 1664
# Total Non-Zero Components in Eigenvector 279: 1664
# Total Non-Zero Components in Eigenvector 280: 1664
# Total Non-Zero Components in Eigenvector 281: 1664
# Total Non-Zero Components in Eigenvector 282: 1664
# Total Non-Zero Components in Eigenvector 283: 1664
# Total Non-Zero Components in Eigenvector 284: 1664
# Total Non-Zero Components in Eigenvector 285: 1664
# Total Non-Zero Components in Eigenvector 286: 1664
# Total Non-Zero Components in Eigenvector 287: 1664
# Total Non-Zero Components in Eigenvector 288: 1664
# Total Non-Zero Components in Eigenvector 289: 1664
# Total Non-Zero Components in Eigenvector 290: 1664
# Total Non-Zero Components in Eigenvector 291: 1664
# Total Non-Zero Components in Eigenvector 292: 1664
# Total Non-Zero Components in Eigenvector 293: 1664
# Total Non-Zero Components in Eigenvector 294: 1664
# Total Non-Zero Components in Eigenvector 295: 1664
# Total Non-Zero Components in Eigenvector 296: 1664
# Total Non-Zero Components in Eigenvector 297: 1664
# Total Non-Zero Components in Eigenvector 298: 1664
# Total Non-Zero Components in Eigenvector 299: 1664
# Total Non-Zero Components in Eigenvector 300: 1664
# Total Non-Zero Components in Eigenvector 301: 1664
# Total Non-Zero Components in Eigenvector 302: 1664
# Total Non-Zero Components in Eigenvector 303: 1664
# Total Non-Zero Components in Eigenvector 304: 2024
# Total Non-Zero Components in Eigenvector 305: 2024
# Total Non-Zero Components in Eigenvector 306: 2024
# Total Non-Zero Components in Eigenvector 307: 2024
# Total Non-Zero Components in Eigenvector 308: 2024
# Total Non-Zero Components in Eigenvector 309: 2024
# Total Non-Zero Components in Eigenvector 310: 2024
# Total Non-Zero Components in Eigenvector 311: 2024
# Total Non-Zero Components in Eigenvector 312: 2024
# Total Non-Zero Components in Eigenvector 313: 2024
# Total Non-Zero Components in Eigenvector 314: 2024
# Total Non-Zero Components in Eigenvector 315: 2024
# Total Non-Zero Components in Eigenvector 316: 2024
# Total Non-Zero Components in Eigenvector 317: 2024
# Total Non-Zero Components in Eigenvector 318: 2024
# Total Non-Zero Components in Eigenvector 319: 2024
# Total Non-Zero Components in Eigenvector 320: 2024
# Total Non-Zero Components in Eigenvector 321: 2024
# Total Non-Zero Components in Eigenvector 322: 2024
# Total Non-Zero Components in Eigenvector 323: 2024
# Total Non-Zero Components in Eigenvector 324: 2024
# Total Non-Zero Components in Eigenvector 325: 2024
# Total Non-Zero Components in Eigenvector 326: 2024
# Total Non-Zero Components in Eigenvector 327: 2024
# Total Non-Zero Components in Eigenvector 328: 1984
# Total Non-Zero Components in Eigenvector 329: 1984
# Total Non-Zero Components in Eigenvector 330: 1984
# Total Non-Zero Components in Eigenvector 331: 1984
# Total Non-Zero Components in Eigenvector 332: 1984
# Total Non-Zero Components in Eigenvector 333: 1984
# Total Non-Zero Components in Eigenvector 334: 1024
# Total Non-Zero Components in Eigenvector 335: 1024
# Total Non-Zero Components in Eigenvector 336: 1024
# Total Non-Zero Components in Eigenvector 337: 1024
# Total Non-Zero Components in Eigenvector 338: 1024
# Total Non-Zero Components in Eigenvector 339: 1024
# Total Non-Zero Components in Eigenvector 340: 1024
# Total Non-Zero Components in Eigenvector 341: 1024
# Total Non-Zero Components in Eigenvector 342: 1024
# Total Non-Zero Components in Eigenvector 343: 1024
# Total Non-Zero Components in Eigenvector 344: 1024
# Total Non-Zero Components in Eigenvector 345: 1024
# Total Non-Zero Components in Eigenvector 346: 1024
# Total Non-Zero Components in Eigenvector 347: 1024
# Total Non-Zero Components in Eigenvector 348: 1024
# Total Non-Zero Components in Eigenvector 349: 1024
# Total Non-Zero Components in Eigenvector 350: 1024
# Total Non-Zero Components in Eigenvector 351: 1024
# Total Non-Zero Components in Eigenvector 352: 1024
# Total Non-Zero Components in Eigenvector 353: 1024
# Total Non-Zero Components in Eigenvector 354: 2048
# Total Non-Zero Components in Eigenvector 355: 1520
# Total Non-Zero Components in Eigenvector 356: 1520
# Total Non-Zero Components in Eigenvector 357: 1520
# Total Non-Zero Components in Eigenvector 358: 1520
# Total Non-Zero Components in Eigenvector 359: 1520
# Total Non-Zero Components in Eigenvector 360: 1520
# Total Non-Zero Components in Eigenvector 361: 1520
# Total Non-Zero Components in Eigenvector 362: 1520
# Total Non-Zero Components in Eigenvector 363: 1520
# Total Non-Zero Components in Eigenvector 364: 1520
# Total Non-Zero Components in Eigenvector 365: 1520
# Total Non-Zero Components in Eigenvector 366: 1520
# Total Non-Zero Components in Eigenvector 367: 1520
# Total Non-Zero Components in Eigenvector 368: 1520
# Total Non-Zero Components in Eigenvector 369: 1520
# Total Non-Zero Components in Eigenvector 370: 1520
# Total Non-Zero Components in Eigenvector 371: 1520
# Total Non-Zero Components in Eigenvector 372: 1520
# Total Non-Zero Components in Eigenvector 373: 1520
# Total Non-Zero Components in Eigenvector 374: 1520
# Total Non-Zero Components in Eigenvector 375: 1520
# Total Non-Zero Components in Eigenvector 376: 1520
# Total Non-Zero Components in Eigenvector 377: 1520
# Total Non-Zero Components in Eigenvector 378: 1520
# Total Non-Zero Components in Eigenvector 379: 1520
# Total Non-Zero Components in Eigenvector 380: 1520
# Total Non-Zero Components in Eigenvector 381: 1520
# Total Non-Zero Components in Eigenvector 382: 1520
# Total Non-Zero Components in Eigenvector 383: 1520
# Total Non-Zero Components in Eigenvector 384: 1520
# Total Non-Zero Components in Eigenvector 385: 1640
# Total Non-Zero Components in Eigenvector 386: 1640
# Total Non-Zero Components in Eigenvector 387: 1640
# Total Non-Zero Components in Eigenvector 388: 1640
# Total Non-Zero Components in Eigenvector 389: 1640
# Total Non-Zero Components in Eigenvector 390: 1640
# Total Non-Zero Components in Eigenvector 391: 1640
# Total Non-Zero Components in Eigenvector 392: 1640
# Total Non-Zero Components in Eigenvector 393: 1640
# Total Non-Zero Components in Eigenvector 394: 1800
# Total Non-Zero Components in Eigenvector 395: 1800
# Total Non-Zero Components in Eigenvector 396: 1800
# Total Non-Zero Components in Eigenvector 397: 1800
# Total Non-Zero Components in Eigenvector 398: 1800
# Total Non-Zero Components in Eigenvector 399: 1800
# Total Non-Zero Components in Eigenvector 400: 1800
# Total Non-Zero Components in Eigenvector 401: 1800
# Total Non-Zero Components in Eigenvector 402: 1800
# Total Non-Zero Components in Eigenvector 403: 1800
# Total Non-Zero Components in Eigenvector 404: 1800
# Total Non-Zero Components in Eigenvector 405: 1800
# Total Non-Zero Components in Eigenvector 406: 1800
# Total Non-Zero Components in Eigenvector 407: 1800
# Total Non-Zero Components in Eigenvector 408: 1800
# Total Non-Zero Components in Eigenvector 409: 1800
# Total Non-Zero Components in Eigenvector 410: 1800
# Total Non-Zero Components in Eigenvector 411: 1800
# Total Non-Zero Components in Eigenvector 412: 1800
# Total Non-Zero Components in Eigenvector 413: 1800
# Total Non-Zero Components in Eigenvector 414: 1800
# Total Non-Zero Components in Eigenvector 415: 1800
# Total Non-Zero Components in Eigenvector 416: 1800
# Total Non-Zero Components in Eigenvector 417: 1800
# Total Non-Zero Components in Eigenvector 418: 1800
# Total Non-Zero Components in Eigenvector 419: 1800
# Total Non-Zero Components in Eigenvector 420: 1800
# Total Non-Zero Components in Eigenvector 421: 1800
# Total Non-Zero Components in Eigenvector 422: 1800
# Total Non-Zero Components in Eigenvector 423: 1800
# Total Non-Zero Components in Eigenvector 424: 1800
# Total Non-Zero Components in Eigenvector 425: 1800
# Total Non-Zero Components in Eigenvector 426: 1800
# Total Non-Zero Components in Eigenvector 427: 1800
# Total Non-Zero Components in Eigenvector 428: 1800
# Total Non-Zero Components in Eigenvector 429: 1800
# Total Non-Zero Components in Eigenvector 430: 1800
# Total Non-Zero Components in Eigenvector 431: 1800
# Total Non-Zero Components in Eigenvector 432: 1800
# Total Non-Zero Components in Eigenvector 433: 1800
# Total Non-Zero Components in Eigenvector 434: 1800
# Total Non-Zero Components in Eigenvector 435: 1800
# Total Non-Zero Components in Eigenvector 436: 1800
# Total Non-Zero Components in Eigenvector 437: 1800
# Total Non-Zero Components in Eigenvector 438: 1800
# Total Non-Zero Components in Eigenvector 439: 1800
# Total Non-Zero Components in Eigenvector 440: 1800
# Total Non-Zero Components in Eigenvector 441: 1800
# Total Non-Zero Components in Eigenvector 442: 1800
# Total Non-Zero Components in Eigenvector 443: 1800
# Total Non-Zero Components in Eigenvector 444: 1800
# Total Non-Zero Components in Eigenvector 445: 1800
# Total Non-Zero Components in Eigenvector 446: 1800
# Total Non-Zero Components in Eigenvector 447: 1800
# Total Non-Zero Components in Eigenvector 448: 1800
# Total Non-Zero Components in Eigenvector 449: 1800
# Total Non-Zero Components in Eigenvector 450: 1800
# Total Non-Zero Components in Eigenvector 451: 1800
# Total Non-Zero Components in Eigenvector 452: 1800
# Total Non-Zero Components in Eigenvector 453: 1800
# Total Non-Zero Components in Eigenvector 454: 1800
# Total Non-Zero Components in Eigenvector 455: 1800
# Total Non-Zero Components in Eigenvector 456: 1800
# Total Non-Zero Components in Eigenvector 457: 1800
# Total Non-Zero Components in Eigenvector 458: 1800
# Total Non-Zero Components in Eigenvector 459: 1800
# Total Non-Zero Components in Eigenvector 460: 1800
# Total Non-Zero Components in Eigenvector 461: 1800
# Total Non-Zero Components in Eigenvector 462: 1800
# Total Non-Zero Components in Eigenvector 463: 1800
# Total Non-Zero Components in Eigenvector 464: 1800
# Total Non-Zero Components in Eigenvector 465: 1800
# Total Non-Zero Components in Eigenvector 466: 1800
# Total Non-Zero Components in Eigenvector 467: 1800
# Total Non-Zero Components in Eigenvector 468: 1800
# Total Non-Zero Components in Eigenvector 469: 1520
# Total Non-Zero Components in Eigenvector 470: 1520
# Total Non-Zero Components in Eigenvector 471: 1520
# Total Non-Zero Components in Eigenvector 472: 1520
# Total Non-Zero Components in Eigenvector 473: 1520
# Total Non-Zero Components in Eigenvector 474: 2048
# Total Non-Zero Components in Eigenvector 475: 2048
# Total Non-Zero Components in Eigenvector 476: 2048
# Total Non-Zero Components in Eigenvector 477: 2048
# Total Non-Zero Components in Eigenvector 478: 2048
# Total Non-Zero Components in Eigenvector 479: 2048
# Total Non-Zero Components in Eigenvector 480: 1982
# Total Non-Zero Components in Eigenvector 481: 1982
# Total Non-Zero Components in Eigenvector 482: 1982
# Total Non-Zero Components in Eigenvector 483: 1982
# Total Non-Zero Components in Eigenvector 484: 1982
# Total Non-Zero Components in Eigenvector 485: 860
# Total Non-Zero Components in Eigenvector 486: 860
# Total Non-Zero Components in Eigenvector 487: 860
# Total Non-Zero Components in Eigenvector 488: 860
# Total Non-Zero Components in Eigenvector 489: 860
# Total Non-Zero Components in Eigenvector 490: 2048
# Total Non-Zero Components in Eigenvector 491: 2048
# Total Non-Zero Components in Eigenvector 492: 2048
# Total Non-Zero Components in Eigenvector 493: 2048
# Total Non-Zero Components in Eigenvector 494: 2048
# Total Non-Zero Components in Eigenvector 495: 2024
# Total Non-Zero Components in Eigenvector 496: 2024
# Total Non-Zero Components in Eigenvector 497: 2024
# Total Non-Zero Components in Eigenvector 498: 2024
# Total Non-Zero Components in Eigenvector 499: 2024
# Total Non-Zero Components in Eigenvector 500: 2024
# Total Non-Zero Components in Eigenvector 501: 2024
# Total Non-Zero Components in Eigenvector 502: 2024
# Total Non-Zero Components in Eigenvector 503: 2024
# Total Non-Zero Components in Eigenvector 504: 2024
# Total Non-Zero Components in Eigenvector 505: 2024
# Total Non-Zero Components in Eigenvector 506: 2024
# Total Non-Zero Components in Eigenvector 507: 2024
# Total Non-Zero Components in Eigenvector 508: 2024
# Total Non-Zero Components in Eigenvector 509: 2024
# Total Non-Zero Components in Eigenvector 510: 2024
# Total Non-Zero Components in Eigenvector 511: 2024
# Total Non-Zero Components in Eigenvector 512: 2024
# Total Non-Zero Components in Eigenvector 513: 2024
# Total Non-Zero Components in Eigenvector 514: 2024
# Total Non-Zero Components in Eigenvector 515: 2024
# Total Non-Zero Components in Eigenvector 516: 2024
# Total Non-Zero Components in Eigenvector 517: 2024
# Total Non-Zero Components in Eigenvector 518: 2024
# Total Non-Zero Components in Eigenvector 519: 1320
# Total Non-Zero Components in Eigenvector 520: 1320
# Total Non-Zero Components in Eigenvector 521: 1320
# Total Non-Zero Components in Eigenvector 522: 1320
# Total Non-Zero Components in Eigenvector 523: 1320
# Total Non-Zero Components in Eigenvector 524: 1320
# Total Non-Zero Components in Eigenvector 525: 1320
# Total Non-Zero Components in Eigenvector 526: 1320
# Total Non-Zero Components in Eigenvector 527: 1320
# Total Non-Zero Components in Eigenvector 528: 1320
# Total Non-Zero Components in Eigenvector 529: 1970
# Total Non-Zero Components in Eigenvector 530: 1970
# Total Non-Zero Components in Eigenvector 531: 1970
# Total Non-Zero Components in Eigenvector 532: 1970
# Total Non-Zero Components in Eigenvector 533: 1970
# Total Non-Zero Components in Eigenvector 534: 1970
# Total Non-Zero Components in Eigenvector 535: 1970
# Total Non-Zero Components in Eigenvector 536: 1970
# Total Non-Zero Components in Eigenvector 537: 1970
# Total Non-Zero Components in Eigenvector 538: 1920
# Total Non-Zero Components in Eigenvector 539: 1920
# Total Non-Zero Components in Eigenvector 540: 1920
# Total Non-Zero Components in Eigenvector 541: 1920
# Total Non-Zero Components in Eigenvector 542: 1920
# Total Non-Zero Components in Eigenvector 543: 1920
# Total Non-Zero Components in Eigenvector 544: 1920
# Total Non-Zero Components in Eigenvector 545: 1920
# Total Non-Zero Components in Eigenvector 546: 1920
# Total Non-Zero Components in Eigenvector 547: 1920
# Total Non-Zero Components in Eigenvector 548: 1920
# Total Non-Zero Components in Eigenvector 549: 1920
# Total Non-Zero Components in Eigenvector 550: 1920
# Total Non-Zero Components in Eigenvector 551: 1920
# Total Non-Zero Components in Eigenvector 552: 1920
# Total Non-Zero Components in Eigenvector 553: 1920
# Total Non-Zero Components in Eigenvector 554: 1920
# Total Non-Zero Components in Eigenvector 555: 1920
# Total Non-Zero Components in Eigenvector 556: 1920
# Total Non-Zero Components in Eigenvector 557: 1920
# Total Non-Zero Components in Eigenvector 558: 1920
# Total Non-Zero Components in Eigenvector 559: 1920
# Total Non-Zero Components in Eigenvector 560: 1920
# Total Non-Zero Components in Eigenvector 561: 1920
# Total Non-Zero Components in Eigenvector 562: 2048
# Total Non-Zero Components in Eigenvector 563: 2048
# Total Non-Zero Components in Eigenvector 564: 2048
# Total Non-Zero Components in Eigenvector 565: 2048
# Total Non-Zero Components in Eigenvector 566: 2048
# Total Non-Zero Components in Eigenvector 567: 1640
# Total Non-Zero Components in Eigenvector 568: 1640
# Total Non-Zero Components in Eigenvector 569: 1640
# Total Non-Zero Components in Eigenvector 570: 1640
# Total Non-Zero Components in Eigenvector 571: 1640
# Total Non-Zero Components in Eigenvector 572: 1640
# Total Non-Zero Components in Eigenvector 573: 1640
# Total Non-Zero Components in Eigenvector 574: 1640
# Total Non-Zero Components in Eigenvector 575: 1640
# Total Non-Zero Components in Eigenvector 576: 2048
# Total Non-Zero Components in Eigenvector 577: 1984
# Total Non-Zero Components in Eigenvector 578: 1984
# Total Non-Zero Components in Eigenvector 579: 1984
# Total Non-Zero Components in Eigenvector 580: 1984
# Total Non-Zero Components in Eigenvector 581: 1984
# Total Non-Zero Components in Eigenvector 582: 1984
# Total Non-Zero Components in Eigenvector 583: 1982
# Total Non-Zero Components in Eigenvector 584: 1982
# Total Non-Zero Components in Eigenvector 585: 1982
# Total Non-Zero Components in Eigenvector 586: 1982
# Total Non-Zero Components in Eigenvector 587: 1982
# Total Non-Zero Components in Eigenvector 588: 1320
# Total Non-Zero Components in Eigenvector 589: 1320
# Total Non-Zero Components in Eigenvector 590: 1320
# Total Non-Zero Components in Eigenvector 591: 1320
# Total Non-Zero Components in Eigenvector 592: 1320
# Total Non-Zero Components in Eigenvector 593: 1320
# Total Non-Zero Components in Eigenvector 594: 1320
# Total Non-Zero Components in Eigenvector 595: 1320
# Total Non-Zero Components in Eigenvector 596: 1320
# Total Non-Zero Components in Eigenvector 597: 1320
# Total Non-Zero Components in Eigenvector 598: 1664
# Total Non-Zero Components in Eigenvector 599: 1664
# Total Non-Zero Components in Eigenvector 600: 1664
# Total Non-Zero Components in Eigenvector 601: 1664
# Total Non-Zero Components in Eigenvector 602: 1664
# Total Non-Zero Components in Eigenvector 603: 1664
# Total Non-Zero Components in Eigenvector 604: 1664
# Total Non-Zero Components in Eigenvector 605: 1664
# Total Non-Zero Components in Eigenvector 606: 1664
# Total Non-Zero Components in Eigenvector 607: 1664
# Total Non-Zero Components in Eigenvector 608: 1664
# Total Non-Zero Components in Eigenvector 609: 1664
# Total Non-Zero Components in Eigenvector 610: 1664
# Total Non-Zero Components in Eigenvector 611: 1664
# Total Non-Zero Components in Eigenvector 612: 1664
# Total Non-Zero Components in Eigenvector 613: 1664
# Total Non-Zero Components in Eigenvector 614: 1664
# Total Non-Zero Components in Eigenvector 615: 1664
# Total Non-Zero Components in Eigenvector 616: 1664
# Total Non-Zero Components in Eigenvector 617: 1664
# Total Non-Zero Components in Eigenvector 618: 1024
# Total Non-Zero Components in Eigenvector 619: 1024
# Total Non-Zero Components in Eigenvector 620: 1024
# Total Non-Zero Components in Eigenvector 621: 1024
# Total Non-Zero Components in Eigenvector 622: 1024
# Total Non-Zero Components in Eigenvector 623: 1024
# Total Non-Zero Components in Eigenvector 624: 1024
# Total Non-Zero Components in Eigenvector 625: 1024
# Total Non-Zero Components in Eigenvector 626: 1024
# Total Non-Zero Components in Eigenvector 627: 1024
# Total Non-Zero Components in Eigenvector 628: 1024
# Total Non-Zero Components in Eigenvector 629: 1024
# Total Non-Zero Components in Eigenvector 630: 1024
# Total Non-Zero Components in Eigenvector 631: 1024
# Total Non-Zero Components in Eigenvector 632: 1024
# Total Non-Zero Components in Eigenvector 633: 1984
# Total Non-Zero Components in Eigenvector 634: 1984
# Total Non-Zero Components in Eigenvector 635: 1984
# Total Non-Zero Components in Eigenvector 636: 1984
# Total Non-Zero Components in Eigenvector 637: 1984
# Total Non-Zero Components in Eigenvector 638: 1984
# Total Non-Zero Components in Eigenvector 639: 1984
# Total Non-Zero Components in Eigenvector 640: 1984
# Total Non-Zero Components in Eigenvector 641: 1984
# Total Non-Zero Components in Eigenvector 642: 1984
# Total Non-Zero Components in Eigenvector 643: 1984
# Total Non-Zero Components in Eigenvector 644: 1984
# Total Non-Zero Components in Eigenvector 645: 1984
# Total Non-Zero Components in Eigenvector 646: 1984
# Total Non-Zero Components in Eigenvector 647: 1984
# Total Non-Zero Components in Eigenvector 648: 1664
# Total Non-Zero Components in Eigenvector 649: 1664
# Total Non-Zero Components in Eigenvector 650: 1664
# Total Non-Zero Components in Eigenvector 651: 1664
# Total Non-Zero Components in Eigenvector 652: 1664
# Total Non-Zero Components in Eigenvector 653: 1664
# Total Non-Zero Components in Eigenvector 654: 1664
# Total Non-Zero Components in Eigenvector 655: 1664
# Total Non-Zero Components in Eigenvector 656: 1664
# Total Non-Zero Components in Eigenvector 657: 1664
# Total Non-Zero Components in Eigenvector 658: 1664
# Total Non-Zero Components in Eigenvector 659: 1664
# Total Non-Zero Components in Eigenvector 660: 1664
# Total Non-Zero Components in Eigenvector 661: 1664
# Total Non-Zero Components in Eigenvector 662: 1664
# Total Non-Zero Components in Eigenvector 663: 1664
# Total Non-Zero Components in Eigenvector 664: 1664
# Total Non-Zero Components in Eigenvector 665: 1664
# Total Non-Zero Components in Eigenvector 666: 1664
# Total Non-Zero Components in Eigenvector 667: 1664
# Total Non-Zero Components in Eigenvector 668: 1664
# Total Non-Zero Components in Eigenvector 669: 1664
# Total Non-Zero Components in Eigenvector 670: 1664
# Total Non-Zero Components in Eigenvector 671: 1664
# Total Non-Zero Components in Eigenvector 672: 1664
# Total Non-Zero Components in Eigenvector 673: 1664
# Total Non-Zero Components in Eigenvector 674: 1664
# Total Non-Zero Components in Eigenvector 675: 1664
# Total Non-Zero Components in Eigenvector 676: 1664
# Total Non-Zero Components in Eigenvector 677: 1664
# Total Non-Zero Components in Eigenvector 678: 1664
# Total Non-Zero Components in Eigenvector 679: 1664
# Total Non-Zero Components in Eigenvector 680: 1664
# Total Non-Zero Components in Eigenvector 681: 1664
# Total Non-Zero Components in Eigenvector 682: 1664
# Total Non-Zero Components in Eigenvector 683: 1664
# Total Non-Zero Components in Eigenvector 684: 1664
# Total Non-Zero Components in Eigenvector 685: 1664
# Total Non-Zero Components in Eigenvector 686: 1664
# Total Non-Zero Components in Eigenvector 687: 1664
# Total Non-Zero Components in Eigenvector 688: 1664
# Total Non-Zero Components in Eigenvector 689: 1664
# Total Non-Zero Components in Eigenvector 690: 1664
# Total Non-Zero Components in Eigenvector 691: 1664
# Total Non-Zero Components in Eigenvector 692: 1664
# Total Non-Zero Components in Eigenvector 693: 2048
# Total Non-Zero Components in Eigenvector 694: 2048
# Total Non-Zero Components in Eigenvector 695: 2048
# Total Non-Zero Components in Eigenvector 696: 2048
# Total Non-Zero Components in Eigenvector 697: 2048
# Total Non-Zero Components in Eigenvector 698: 2048
# Total Non-Zero Components in Eigenvector 699: 960
# Total Non-Zero Components in Eigenvector 700: 960
# Total Non-Zero Components in Eigenvector 701: 960
# Total Non-Zero Components in Eigenvector 702: 960
# Total Non-Zero Components in Eigenvector 703: 960
# Total Non-Zero Components in Eigenvector 704: 960
# Total Non-Zero Components in Eigenvector 705: 960
# Total Non-Zero Components in Eigenvector 706: 960
# Total Non-Zero Components in Eigenvector 707: 960
# Total Non-Zero Components in Eigenvector 708: 960
# Total Non-Zero Components in Eigenvector 709: 960
# Total Non-Zero Components in Eigenvector 710: 960
# Total Non-Zero Components in Eigenvector 711: 960
# Total Non-Zero Components in Eigenvector 712: 960
# Total Non-Zero Components in Eigenvector 713: 960
# Total Non-Zero Components in Eigenvector 714: 960
# Total Non-Zero Components in Eigenvector 715: 960
# Total Non-Zero Components in Eigenvector 716: 960
# Total Non-Zero Components in Eigenvector 717: 960
# Total Non-Zero Components in Eigenvector 718: 960
# Total Non-Zero Components in Eigenvector 719: 960
# Total Non-Zero Components in Eigenvector 720: 960
# Total Non-Zero Components in Eigenvector 721: 960
# Total Non-Zero Components in Eigenvector 722: 960
# Total Non-Zero Components in Eigenvector 723: 960
# Total Non-Zero Components in Eigenvector 724: 960
# Total Non-Zero Components in Eigenvector 725: 960
# Total Non-Zero Components in Eigenvector 726: 960
# Total Non-Zero Components in Eigenvector 727: 960
# Total Non-Zero Components in Eigenvector 728: 960
# Total Non-Zero Components in Eigenvector 729: 960
# Total Non-Zero Components in Eigenvector 730: 960
# Total Non-Zero Components in Eigenvector 731: 960
# Total Non-Zero Components in Eigenvector 732: 960
# Total Non-Zero Components in Eigenvector 733: 960
# Total Non-Zero Components in Eigenvector 734: 960
# Total Non-Zero Components in Eigenvector 735: 960
# Total Non-Zero Components in Eigenvector 736: 960
# Total Non-Zero Components in Eigenvector 737: 960
# Total Non-Zero Components in Eigenvector 738: 960
# Total Non-Zero Components in Eigenvector 739: 1920
# Total Non-Zero Components in Eigenvector 740: 1920
# Total Non-Zero Components in Eigenvector 741: 1920
# Total Non-Zero Components in Eigenvector 742: 1920
# Total Non-Zero Components in Eigenvector 743: 1920
# Total Non-Zero Components in Eigenvector 744: 1920
# Total Non-Zero Components in Eigenvector 745: 1920
# Total Non-Zero Components in Eigenvector 746: 1920
# Total Non-Zero Components in Eigenvector 747: 1920
# Total Non-Zero Components in Eigenvector 748: 1920
# Total Non-Zero Components in Eigenvector 749: 1920
# Total Non-Zero Components in Eigenvector 750: 1920
# Total Non-Zero Components in Eigenvector 751: 1920
# Total Non-Zero Components in Eigenvector 752: 1920
# Total Non-Zero Components in Eigenvector 753: 1920
# Total Non-Zero Components in Eigenvector 754: 1920
# Total Non-Zero Components in Eigenvector 755: 1920
# Total Non-Zero Components in Eigenvector 756: 1920
# Total Non-Zero Components in Eigenvector 757: 1920
# Total Non-Zero Components in Eigenvector 758: 1920
# Total Non-Zero Components in Eigenvector 759: 1920
# Total Non-Zero Components in Eigenvector 760: 1920
# Total Non-Zero Components in Eigenvector 761: 1920
# Total Non-Zero Components in Eigenvector 762: 1920
# Total Non-Zero Components in Eigenvector 763: 2048
# Total Non-Zero Components in Eigenvector 764: 1520
# Total Non-Zero Components in Eigenvector 765: 1520
# Total Non-Zero Components in Eigenvector 766: 1520
# Total Non-Zero Components in Eigenvector 767: 1520
# Total Non-Zero Components in Eigenvector 768: 1520
# Total Non-Zero Components in Eigenvector 769: 1520
# Total Non-Zero Components in Eigenvector 770: 1520
# Total Non-Zero Components in Eigenvector 771: 1520
# Total Non-Zero Components in Eigenvector 772: 1520
# Total Non-Zero Components in Eigenvector 773: 1520
# Total Non-Zero Components in Eigenvector 774: 1520
# Total Non-Zero Components in Eigenvector 775: 1520
# Total Non-Zero Components in Eigenvector 776: 1520
# Total Non-Zero Components in Eigenvector 777: 1520
# Total Non-Zero Components in Eigenvector 778: 1520
# Total Non-Zero Components in Eigenvector 779: 1520
# Total Non-Zero Components in Eigenvector 780: 1520
# Total Non-Zero Components in Eigenvector 781: 1520
# Total Non-Zero Components in Eigenvector 782: 1520
# Total Non-Zero Components in Eigenvector 783: 1520
# Total Non-Zero Components in Eigenvector 784: 1520
# Total Non-Zero Components in Eigenvector 785: 1520
# Total Non-Zero Components in Eigenvector 786: 1520
# Total Non-Zero Components in Eigenvector 787: 1520
# Total Non-Zero Components in Eigenvector 788: 1520
# Total Non-Zero Components in Eigenvector 789: 1520
# Total Non-Zero Components in Eigenvector 790: 1520
# Total Non-Zero Components in Eigenvector 791: 1520
# Total Non-Zero Components in Eigenvector 792: 1520
# Total Non-Zero Components in Eigenvector 793: 1520
# Total Non-Zero Components in Eigenvector 794: 2024
# Total Non-Zero Components in Eigenvector 795: 2024
# Total Non-Zero Components in Eigenvector 796: 2024
# Total Non-Zero Components in Eigenvector 797: 2024
# Total Non-Zero Components in Eigenvector 798: 2024
# Total Non-Zero Components in Eigenvector 799: 2024
# Total Non-Zero Components in Eigenvector 800: 2024
# Total Non-Zero Components in Eigenvector 801: 2024
# Total Non-Zero Components in Eigenvector 802: 2024
# Total Non-Zero Components in Eigenvector 803: 2024
# Total Non-Zero Components in Eigenvector 804: 2024
# Total Non-Zero Components in Eigenvector 805: 2024
# Total Non-Zero Components in Eigenvector 806: 2024
# Total Non-Zero Components in Eigenvector 807: 2024
# Total Non-Zero Components in Eigenvector 808: 2024
# Total Non-Zero Components in Eigenvector 809: 2024
# Total Non-Zero Components in Eigenvector 810: 2024
# Total Non-Zero Components in Eigenvector 811: 2024
# Total Non-Zero Components in Eigenvector 812: 2024
# Total Non-Zero Components in Eigenvector 813: 2024
# Total Non-Zero Components in Eigenvector 814: 2024
# Total Non-Zero Components in Eigenvector 815: 2024
# Total Non-Zero Components in Eigenvector 816: 2024
# Total Non-Zero Components in Eigenvector 817: 2024
# Total Non-Zero Components in Eigenvector 818: 2048
# Total Non-Zero Components in Eigenvector 819: 2048
# Total Non-Zero Components in Eigenvector 820: 2048
# Total Non-Zero Components in Eigenvector 821: 2048
# Total Non-Zero Components in Eigenvector 822: 2048
# Total Non-Zero Components in Eigenvector 823: 1800
# Total Non-Zero Components in Eigenvector 824: 1800
# Total Non-Zero Components in Eigenvector 825: 1800
# Total Non-Zero Components in Eigenvector 826: 1800
# Total Non-Zero Components in Eigenvector 827: 1800
# Total Non-Zero Components in Eigenvector 828: 1800
# Total Non-Zero Components in Eigenvector 829: 1800
# Total Non-Zero Components in Eigenvector 830: 1800
# Total Non-Zero Components in Eigenvector 831: 1800
# Total Non-Zero Components in Eigenvector 832: 1800
# Total Non-Zero Components in Eigenvector 833: 1800
# Total Non-Zero Components in Eigenvector 834: 1800
# Total Non-Zero Components in Eigenvector 835: 1800
# Total Non-Zero Components in Eigenvector 836: 1800
# Total Non-Zero Components in Eigenvector 837: 1800
# Total Non-Zero Components in Eigenvector 838: 1800
# Total Non-Zero Components in Eigenvector 839: 1800
# Total Non-Zero Components in Eigenvector 840: 1800
# Total Non-Zero Components in Eigenvector 841: 1800
# Total Non-Zero Components in Eigenvector 842: 1800
# Total Non-Zero Components in Eigenvector 843: 1800
# Total Non-Zero Components in Eigenvector 844: 1800
# Total Non-Zero Components in Eigenvector 845: 1800
# Total Non-Zero Components in Eigenvector 846: 1800
# Total Non-Zero Components in Eigenvector 847: 1800
# Total Non-Zero Components in Eigenvector 848: 1800
# Total Non-Zero Components in Eigenvector 849: 1800
# Total Non-Zero Components in Eigenvector 850: 1800
# Total Non-Zero Components in Eigenvector 851: 1800
# Total Non-Zero Components in Eigenvector 852: 1800
# Total Non-Zero Components in Eigenvector 853: 1800
# Total Non-Zero Components in Eigenvector 854: 1800
# Total Non-Zero Components in Eigenvector 855: 1800
# Total Non-Zero Components in Eigenvector 856: 1800
# Total Non-Zero Components in Eigenvector 857: 1800
# Total Non-Zero Components in Eigenvector 858: 1800
# Total Non-Zero Components in Eigenvector 859: 1800
# Total Non-Zero Components in Eigenvector 860: 1800
# Total Non-Zero Components in Eigenvector 861: 1800
# Total Non-Zero Components in Eigenvector 862: 1800
# Total Non-Zero Components in Eigenvector 863: 1800
# Total Non-Zero Components in Eigenvector 864: 1800
# Total Non-Zero Components in Eigenvector 865: 1800
# Total Non-Zero Components in Eigenvector 866: 1800
# Total Non-Zero Components in Eigenvector 867: 1800
# Total Non-Zero Components in Eigenvector 868: 1984
# Total Non-Zero Components in Eigenvector 869: 1984
# Total Non-Zero Components in Eigenvector 870: 1984
# Total Non-Zero Components in Eigenvector 871: 1984
# Total Non-Zero Components in Eigenvector 872: 1984
# Total Non-Zero Components in Eigenvector 873: 1984
# Total Non-Zero Components in Eigenvector 874: 1984
# Total Non-Zero Components in Eigenvector 875: 1984
# Total Non-Zero Components in Eigenvector 876: 1984
# Total Non-Zero Components in Eigenvector 877: 1984
# Total Non-Zero Components in Eigenvector 878: 1984
# Total Non-Zero Components in Eigenvector 879: 1984
# Total Non-Zero Components in Eigenvector 880: 1984
# Total Non-Zero Components in Eigenvector 881: 1984
# Total Non-Zero Components in Eigenvector 882: 1984
# Total Non-Zero Components in Eigenvector 883: 1320
# Total Non-Zero Components in Eigenvector 884: 1320
# Total Non-Zero Components in Eigenvector 885: 1320
# Total Non-Zero Components in Eigenvector 886: 1320
# Total Non-Zero Components in Eigenvector 887: 1320
# Total Non-Zero Components in Eigenvector 888: 1320
# Total Non-Zero Components in Eigenvector 889: 1320
# Total Non-Zero Components in Eigenvector 890: 1320
# Total Non-Zero Components in Eigenvector 891: 1320
# Total Non-Zero Components in Eigenvector 892: 1320
# Total Non-Zero Components in Eigenvector 893: 1320
# Total Non-Zero Components in Eigenvector 894: 1320
# Total Non-Zero Components in Eigenvector 895: 1320
# Total Non-Zero Components in Eigenvector 896: 1320
# Total Non-Zero Components in Eigenvector 897: 1320
# Total Non-Zero Components in Eigenvector 898: 1320
# Total Non-Zero Components in Eigenvector 899: 1320
# Total Non-Zero Components in Eigenvector 900: 1320
# Total Non-Zero Components in Eigenvector 901: 1320
# Total Non-Zero Components in Eigenvector 902: 1320
# Total Non-Zero Components in Eigenvector 903: 1320
# Total Non-Zero Components in Eigenvector 904: 1320
# Total Non-Zero Components in Eigenvector 905: 1320
# Total Non-Zero Components in Eigenvector 906: 1320
# Total Non-Zero Components in Eigenvector 907: 1320
# Total Non-Zero Components in Eigenvector 908: 1320
# Total Non-Zero Components in Eigenvector 909: 1320
# Total Non-Zero Components in Eigenvector 910: 1320
# Total Non-Zero Components in Eigenvector 911: 1320
# Total Non-Zero Components in Eigenvector 912: 1320
# Total Non-Zero Components in Eigenvector 913: 1982
# Total Non-Zero Components in Eigenvector 914: 1982
# Total Non-Zero Components in Eigenvector 915: 1982
# Total Non-Zero Components in Eigenvector 916: 1982
# Total Non-Zero Components in Eigenvector 917: 1982
# Total Non-Zero Components in Eigenvector 918: 1970
# Total Non-Zero Components in Eigenvector 919: 1970
# Total Non-Zero Components in Eigenvector 920: 1970
# Total Non-Zero Components in Eigenvector 921: 1970
# Total Non-Zero Components in Eigenvector 922: 1970
# Total Non-Zero Components in Eigenvector 923: 1970
# Total Non-Zero Components in Eigenvector 924: 1970
# Total Non-Zero Components in Eigenvector 925: 1970
# Total Non-Zero Components in Eigenvector 926: 1970
# Total Non-Zero Components in Eigenvector 927: 1640
# Total Non-Zero Components in Eigenvector 928: 1640
# Total Non-Zero Components in Eigenvector 929: 1640
# Total Non-Zero Components in Eigenvector 930: 1640
# Total Non-Zero Components in Eigenvector 931: 1640
# Total Non-Zero Components in Eigenvector 932: 1640
# Total Non-Zero Components in Eigenvector 933: 1640
# Total Non-Zero Components in Eigenvector 934: 1640
# Total Non-Zero Components in Eigenvector 935: 1640
# Total Non-Zero Components in Eigenvector 936: 1320
# Total Non-Zero Components in Eigenvector 937: 1320
# Total Non-Zero Components in Eigenvector 938: 1320
# Total Non-Zero Components in Eigenvector 939: 1320
# Total Non-Zero Components in Eigenvector 940: 1320
# Total Non-Zero Components in Eigenvector 941: 1320
# Total Non-Zero Components in Eigenvector 942: 1320
# Total Non-Zero Components in Eigenvector 943: 1320
# ...
# Total Non-Zero Components in Eigenvector 3811: 1800
# Total Non-Zero Components in Eigenvector 3812: 1800
# Total Non-Zero Components in Eigenvector 3813: 1800
# Total Non-Zero Components in Eigenvector 3814: 1800
# Total Non-Zero Components in Eigenvector 3815: 1800
# Total Non-Zero Components in Eigenvector 3816: 1800
# Total Non-Zero Components in Eigenvector 3817: 1800
# Total Non-Zero Components in Eigenvector 3818: 1800
# Total Non-Zero Components in Eigenvector 3819: 1800
# Total Non-Zero Components in Eigenvector 3820: 1800
# Total Non-Zero Components in Eigenvector 3821: 1800
# Total Non-Zero Components in Eigenvector 3822: 1800
# Total Non-Zero Components in Eigenvector 3823: 1800
# Total Non-Zero Components in Eigenvector 3824: 1800
# Total Non-Zero Components in Eigenvector 3825: 1800
# Total Non-Zero Components in Eigenvector 3826: 1800
# Total Non-Zero Components in Eigenvector 3827: 1800
# Total Non-Zero Components in Eigenvector 3828: 1800
# Total Non-Zero Components in Eigenvector 3829: 1800
# Total Non-Zero Components in Eigenvector 3830: 1640
# Total Non-Zero Components in Eigenvector 3831: 1640
# Total Non-Zero Components in Eigenvector 3832: 1640
# Total Non-Zero Components in Eigenvector 3833: 1640
# Total Non-Zero Components in Eigenvector 3834: 1640
# Total Non-Zero Components in Eigenvector 3835: 1640
# Total Non-Zero Components in Eigenvector 3836: 1640
# Total Non-Zero Components in Eigenvector 3837: 1640
# Total Non-Zero Components in Eigenvector 3838: 1640
# Total Non-Zero Components in Eigenvector 3839: 840
# Total Non-Zero Components in Eigenvector 3840: 840
# Total Non-Zero Components in Eigenvector 3841: 840
# Total Non-Zero Components in Eigenvector 3842: 840
# Total Non-Zero Components in Eigenvector 3843: 840
# Total Non-Zero Components in Eigenvector 3844: 840
# Total Non-Zero Components in Eigenvector 3845: 840
# Total Non-Zero Components in Eigenvector 3846: 840
# Total Non-Zero Components in Eigenvector 3847: 840
# Total Non-Zero Components in Eigenvector 3848: 840
# Total Non-Zero Components in Eigenvector 3849: 840
# Total Non-Zero Components in Eigenvector 3850: 840
# Total Non-Zero Components in Eigenvector 3851: 840
# Total Non-Zero Components in Eigenvector 3852: 840
# Total Non-Zero Components in Eigenvector 3853: 840
# Total Non-Zero Components in Eigenvector 3854: 840
# Total Non-Zero Components in Eigenvector 3855: 1664
# Total Non-Zero Components in Eigenvector 3856: 1664
# Total Non-Zero Components in Eigenvector 3857: 1664
# Total Non-Zero Components in Eigenvector 3858: 1664
# Total Non-Zero Components in Eigenvector 3859: 1664
# Total Non-Zero Components in Eigenvector 3860: 1664
# Total Non-Zero Components in Eigenvector 3861: 1664
# Total Non-Zero Components in Eigenvector 3862: 1664
# Total Non-Zero Components in Eigenvector 3863: 1664
# Total Non-Zero Components in Eigenvector 3864: 1664
# Total Non-Zero Components in Eigenvector 3865: 1664
# Total Non-Zero Components in Eigenvector 3866: 1664
# Total Non-Zero Components in Eigenvector 3867: 1664
# Total Non-Zero Components in Eigenvector 3868: 1664
# Total Non-Zero Components in Eigenvector 3869: 1664
# Total Non-Zero Components in Eigenvector 3870: 1664
# Total Non-Zero Components in Eigenvector 3871: 1664
# Total Non-Zero Components in Eigenvector 3872: 1664
# Total Non-Zero Components in Eigenvector 3873: 1664
# Total Non-Zero Components in Eigenvector 3874: 1664
# Total Non-Zero Components in Eigenvector 3875: 1970
# Total Non-Zero Components in Eigenvector 3876: 1970
# Total Non-Zero Components in Eigenvector 3877: 1970
# Total Non-Zero Components in Eigenvector 3878: 1970
# Total Non-Zero Components in Eigenvector 3879: 1970
# Total Non-Zero Components in Eigenvector 3880: 1970
# Total Non-Zero Components in Eigenvector 3881: 1970
# Total Non-Zero Components in Eigenvector 3882: 1970
# Total Non-Zero Components in Eigenvector 3883: 1970
# Total Non-Zero Components in Eigenvector 3884: 1984
# Total Non-Zero Components in Eigenvector 3885: 1984
# Total Non-Zero Components in Eigenvector 3886: 1984
# Total Non-Zero Components in Eigenvector 3887: 1984
# Total Non-Zero Components in Eigenvector 3888: 1984
# Total Non-Zero Components in Eigenvector 3889: 1984
# Total Non-Zero Components in Eigenvector 3890: 2048
# Total Non-Zero Components in Eigenvector 3891: 2048
# Total Non-Zero Components in Eigenvector 3892: 2048
# Total Non-Zero Components in Eigenvector 3893: 2048
# Total Non-Zero Components in Eigenvector 3894: 2048
# Total Non-Zero Components in Eigenvector 3895: 2048
# Total Non-Zero Components in Eigenvector 3896: 1664
# Total Non-Zero Components in Eigenvector 3897: 1664
# Total Non-Zero Components in Eigenvector 3898: 1664
# Total Non-Zero Components in Eigenvector 3899: 1664
# Total Non-Zero Components in Eigenvector 3900: 1664
# Total Non-Zero Components in Eigenvector 3901: 1664
# Total Non-Zero Components in Eigenvector 3902: 1664
# Total Non-Zero Components in Eigenvector 3903: 1664
# Total Non-Zero Components in Eigenvector 3904: 1664
# Total Non-Zero Components in Eigenvector 3905: 1664
# Total Non-Zero Components in Eigenvector 3906: 1664
# Total Non-Zero Components in Eigenvector 3907: 1664
# Total Non-Zero Components in Eigenvector 3908: 1664
# Total Non-Zero Components in Eigenvector 3909: 1664
# Total Non-Zero Components in Eigenvector 3910: 1664
# Total Non-Zero Components in Eigenvector 3911: 1664
# Total Non-Zero Components in Eigenvector 3912: 1664
# Total Non-Zero Components in Eigenvector 3913: 1664
# Total Non-Zero Components in Eigenvector 3914: 1664
# Total Non-Zero Components in Eigenvector 3915: 1664
# Total Non-Zero Components in Eigenvector 3916: 1664
# Total Non-Zero Components in Eigenvector 3917: 1664
# Total Non-Zero Components in Eigenvector 3918: 1664
# Total Non-Zero Components in Eigenvector 3919: 1664
# Total Non-Zero Components in Eigenvector 3920: 1664
# Total Non-Zero Components in Eigenvector 3921: 1664
# Total Non-Zero Components in Eigenvector 3922: 1664
# Total Non-Zero Components in Eigenvector 3923: 1664
# Total Non-Zero Components in Eigenvector 3924: 1664
# Total Non-Zero Components in Eigenvector 3925: 1664
# Total Non-Zero Components in Eigenvector 3926: 1664
# Total Non-Zero Components in Eigenvector 3927: 1664
# Total Non-Zero Components in Eigenvector 3928: 1664
# Total Non-Zero Components in Eigenvector 3929: 1664
# Total Non-Zero Components in Eigenvector 3930: 1664
# Total Non-Zero Components in Eigenvector 3931: 1664
# Total Non-Zero Components in Eigenvector 3932: 1664
# Total Non-Zero Components in Eigenvector 3933: 1664
# Total Non-Zero Components in Eigenvector 3934: 1664
# Total Non-Zero Components in Eigenvector 3935: 1664
# Total Non-Zero Components in Eigenvector 3936: 1664
# Total Non-Zero Components in Eigenvector 3937: 1664
# Total Non-Zero Components in Eigenvector 3938: 1664
# Total Non-Zero Components in Eigenvector 3939: 1664
# Total Non-Zero Components in Eigenvector 3940: 1664
# Total Non-Zero Components in Eigenvector 3941: 2024
# Total Non-Zero Components in Eigenvector 3942: 2024
# Total Non-Zero Components in Eigenvector 3943: 2024
# Total Non-Zero Components in Eigenvector 3944: 2024
# Total Non-Zero Components in Eigenvector 3945: 2024
# Total Non-Zero Components in Eigenvector 3946: 2024
# Total Non-Zero Components in Eigenvector 3947: 2024
# Total Non-Zero Components in Eigenvector 3948: 2024
# Total Non-Zero Components in Eigenvector 3949: 2024
# Total Non-Zero Components in Eigenvector 3950: 2024
# Total Non-Zero Components in Eigenvector 3951: 2024
# Total Non-Zero Components in Eigenvector 3952: 2024
# Total Non-Zero Components in Eigenvector 3953: 2024
# Total Non-Zero Components in Eigenvector 3954: 2024
# Total Non-Zero Components in Eigenvector 3955: 2024
# Total Non-Zero Components in Eigenvector 3956: 2024
# Total Non-Zero Components in Eigenvector 3957: 2024
# Total Non-Zero Components in Eigenvector 3958: 2024
# Total Non-Zero Components in Eigenvector 3959: 2024
# Total Non-Zero Components in Eigenvector 3960: 2024
# Total Non-Zero Components in Eigenvector 3961: 2024
# Total Non-Zero Components in Eigenvector 3962: 2024
# Total Non-Zero Components in Eigenvector 3963: 2024
# Total Non-Zero Components in Eigenvector 3964: 2024
# Total Non-Zero Components in Eigenvector 3965: 1982
# Total Non-Zero Components in Eigenvector 3966: 1982
# Total Non-Zero Components in Eigenvector 3967: 1982
# Total Non-Zero Components in Eigenvector 3968: 1982
# Total Non-Zero Components in Eigenvector 3969: 1982
# Total Non-Zero Components in Eigenvector 3970: 1320
# Total Non-Zero Components in Eigenvector 3971: 1320
# Total Non-Zero Components in Eigenvector 3972: 1320
# Total Non-Zero Components in Eigenvector 3973: 1320
# Total Non-Zero Components in Eigenvector 3974: 1320
# Total Non-Zero Components in Eigenvector 3975: 1320
# Total Non-Zero Components in Eigenvector 3976: 1320
# Total Non-Zero Components in Eigenvector 3977: 1320
# Total Non-Zero Components in Eigenvector 3978: 1320
# Total Non-Zero Components in Eigenvector 3979: 1320
# Total Non-Zero Components in Eigenvector 3980: 1520
# Total Non-Zero Components in Eigenvector 3981: 1520
# Total Non-Zero Components in Eigenvector 3982: 1520
# Total Non-Zero Components in Eigenvector 3983: 1520
# Total Non-Zero Components in Eigenvector 3984: 1520
# Total Non-Zero Components in Eigenvector 3985: 1520
# Total Non-Zero Components in Eigenvector 3986: 1520
# Total Non-Zero Components in Eigenvector 3987: 1520
# Total Non-Zero Components in Eigenvector 3988: 1520
# Total Non-Zero Components in Eigenvector 3989: 1520
# Total Non-Zero Components in Eigenvector 3990: 1520
# Total Non-Zero Components in Eigenvector 3991: 1520
# Total Non-Zero Components in Eigenvector 3992: 1520
# Total Non-Zero Components in Eigenvector 3993: 1520
# Total Non-Zero Components in Eigenvector 3994: 1520
# Total Non-Zero Components in Eigenvector 3995: 1520
# Total Non-Zero Components in Eigenvector 3996: 1520
# Total Non-Zero Components in Eigenvector 3997: 1520
# Total Non-Zero Components in Eigenvector 3998: 1520
# Total Non-Zero Components in Eigenvector 3999: 1520
# Total Non-Zero Components in Eigenvector 4000: 1520
# Total Non-Zero Components in Eigenvector 4001: 1520
# Total Non-Zero Components in Eigenvector 4002: 1520
# Total Non-Zero Components in Eigenvector 4003: 1520
# Total Non-Zero Components in Eigenvector 4004: 1520
# Total Non-Zero Components in Eigenvector 4005: 1520
# Total Non-Zero Components in Eigenvector 4006: 1520
# Total Non-Zero Components in Eigenvector 4007: 1520
# Total Non-Zero Components in Eigenvector 4008: 1520
# Total Non-Zero Components in Eigenvector 4009: 1520
# Total Non-Zero Components in Eigenvector 4010: 2048
# Total Non-Zero Components in Eigenvector 4011: 2048
# Total Non-Zero Components in Eigenvector 4012: 2048
# Total Non-Zero Components in Eigenvector 4013: 2048
# Total Non-Zero Components in Eigenvector 4014: 2048
# Total Non-Zero Components in Eigenvector 4015: 1640
# Total Non-Zero Components in Eigenvector 4016: 1640
# Total Non-Zero Components in Eigenvector 4017: 1640
# Total Non-Zero Components in Eigenvector 4018: 1640
# Total Non-Zero Components in Eigenvector 4019: 1640
# Total Non-Zero Components in Eigenvector 4020: 1640
# Total Non-Zero Components in Eigenvector 4021: 1640
# Total Non-Zero Components in Eigenvector 4022: 1640
# Total Non-Zero Components in Eigenvector 4023: 1640
# Total Non-Zero Components in Eigenvector 4024: 1520
# Total Non-Zero Components in Eigenvector 4025: 1520
# Total Non-Zero Components in Eigenvector 4026: 1520
# Total Non-Zero Components in Eigenvector 4027: 1520
# Total Non-Zero Components in Eigenvector 4028: 1520
# Total Non-Zero Components in Eigenvector 4029: 1984
# Total Non-Zero Components in Eigenvector 4030: 1984
# Total Non-Zero Components in Eigenvector 4031: 1984
# Total Non-Zero Components in Eigenvector 4032: 1984
# Total Non-Zero Components in Eigenvector 4033: 1984
# Total Non-Zero Components in Eigenvector 4034: 1984
# Total Non-Zero Components in Eigenvector 4035: 1984
# Total Non-Zero Components in Eigenvector 4036: 1984
# Total Non-Zero Components in Eigenvector 4037: 1984
# Total Non-Zero Components in Eigenvector 4038: 1984
# Total Non-Zero Components in Eigenvector 4039: 1984
# Total Non-Zero Components in Eigenvector 4040: 1984
# Total Non-Zero Components in Eigenvector 4041: 1984
# Total Non-Zero Components in Eigenvector 4042: 1984
# Total Non-Zero Components in Eigenvector 4043: 1984
# Total Non-Zero Components in Eigenvector 4044: 2048
# Total Non-Zero Components in Eigenvector 4045: 2048
# Total Non-Zero Components in Eigenvector 4046: 1920
# Total Non-Zero Components in Eigenvector 4047: 1920
# Total Non-Zero Components in Eigenvector 4048: 1920
# Total Non-Zero Components in Eigenvector 4049: 1920
# Total Non-Zero Components in Eigenvector 4050: 1920
# Total Non-Zero Components in Eigenvector 4051: 1920
# Total Non-Zero Components in Eigenvector 4052: 1920
# Total Non-Zero Components in Eigenvector 4053: 1920
# Total Non-Zero Components in Eigenvector 4054: 1920
# Total Non-Zero Components in Eigenvector 4055: 1920
# Total Non-Zero Components in Eigenvector 4056: 1920
# Total Non-Zero Components in Eigenvector 4057: 1920
# Total Non-Zero Components in Eigenvector 4058: 1920
# Total Non-Zero Components in Eigenvector 4059: 1920
# Total Non-Zero Components in Eigenvector 4060: 1920
# Total Non-Zero Components in Eigenvector 4061: 1920
# Total Non-Zero Components in Eigenvector 4062: 1920
# Total Non-Zero Components in Eigenvector 4063: 1920
# Total Non-Zero Components in Eigenvector 4064: 1920
# Total Non-Zero Components in Eigenvector 4065: 1920
# Total Non-Zero Components in Eigenvector 4066: 1920
# Total Non-Zero Components in Eigenvector 4067: 1920
# Total Non-Zero Components in Eigenvector 4068: 1920
# Total Non-Zero Components in Eigenvector 4069: 1920
# Total Non-Zero Components in Eigenvector 4070: 1982
# Total Non-Zero Components in Eigenvector 4071: 1982
# Total Non-Zero Components in Eigenvector 4072: 1982
# Total Non-Zero Components in Eigenvector 4073: 1982
# Total Non-Zero Components in Eigenvector 4074: 1982
# Total Non-Zero Components in Eigenvector 4075: 1970
# Total Non-Zero Components in Eigenvector 4076: 1970
# Total Non-Zero Components in Eigenvector 4077: 1970
# Total Non-Zero Components in Eigenvector 4078: 1970
# Total Non-Zero Components in Eigenvector 4079: 1970
# Total Non-Zero Components in Eigenvector 4080: 1970
# Total Non-Zero Components in Eigenvector 4081: 1970
# Total Non-Zero Components in Eigenvector 4082: 1970
# Total Non-Zero Components in Eigenvector 4083: 1970
# Total Non-Zero Components in Eigenvector 4084: 2048
# Total Non-Zero Components in Eigenvector 4085: 2048
# Total Non-Zero Components in Eigenvector 4086: 2048
# Total Non-Zero Components in Eigenvector 4087: 2048
# Total Non-Zero Components in Eigenvector 4088: 2048
# Total Non-Zero Components in Eigenvector 4089: 2048
# Total Non-Zero Components in Eigenvector 4090: 2048
# Total Non-Zero Components in Eigenvector 4091: 2048
# Total Non-Zero Components in Eigenvector 4092: 2048
# Total Non-Zero Components in Eigenvector 4093: 2048
# Total Non-Zero Components in Eigenvector 4094: 2048
# Total Non-Zero Components in Eigenvector 4095: 2048
# Number of distinct non_zero_count values: 24
# Distinct non_zero_count values: [192, 360, 384, 480, 840, 860, 960, 1024, 1200, 1320, 1344, 1384, 1520, 1640, 1664, 1800, 1920, 1970, 1982, 1984, 2024, 2048, 2115, 2280]
# Occurrences of each non_zero_count:
# Non-Zero Count: 192, Occurrences: 12
# Non-Zero Count: 360, Occurrences: 5
# Non-Zero Count: 384, Occurrences: 30
# Non-Zero Count: 480, Occurrences: 90
# Non-Zero Count: 840, Occurrences: 159
# Non-Zero Count: 860, Occurrences: 20
# Non-Zero Count: 960, Occurrences: 280
# Non-Zero Count: 1024, Occurrences: 140
# Non-Zero Count: 1200, Occurrences: 64
# Non-Zero Count: 1320, Occurrences: 364
# Non-Zero Count: 1344, Occurrences: 262
# Non-Zero Count: 1384, Occurrences: 67
# Non-Zero Count: 1520, Occurrences: 270
# Non-Zero Count: 1640, Occurrences: 108
# Non-Zero Count: 1664, Occurrences: 570
# Non-Zero Count: 1800, Occurrences: 480
# Non-Zero Count: 1920, Occurrences: 288
# Non-Zero Count: 1970, Occurrences: 135
# Non-Zero Count: 1982, Occurrences: 85
# Non-Zero Count: 1984, Occurrences: 189
# Non-Zero Count: 2024, Occurrences: 288
# Non-Zero Count: 2048, Occurrences: 188
# Non-Zero Count: 2115, Occurrences: 1
# Non-Zero Count: 2280, Occurrences: 1
